# %%
# import packages
import pandas as pd
import numpy as np
import pickle
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras
from sklearn.pipeline import Pipeline
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
# load test data
input_path = 'H:\RediMinds\VCQI'
#train = pd.read_csv(input_path+"\VCQI_clean_train.csv")
test = pd.read_csv(input_path+"\VCQI_clean_test_30_day_complications.csv")

# %%
test.drop(labels=['PATIENTNUMBER'], inplace=True, axis=1)

# %%
#x_train = train.drop(labels='INTRA_OP_COMPLICATIONS', axis = 'columns').copy()
#y_train = train['INTRA_OP_COMPLICATIONS'].copy()
x_test = test.drop(labels='POSTOP_COMPLICATIONS', axis = 'columns').copy()
y_test = test['POSTOP_COMPLICATIONS'].copy()

# %%
# check % of pos labels in test set
#print('% pos labels train {:.2f}'.format(y_train.sum()/len(y_train)))
print('% pos labels test {:.2f}'.format(y_test.sum()/len(y_test)))
# Out:
# % pos labels test 0.21

# %%
# Generate prediction for the Random Forest Model
with open (input_path+'\cat_col_30_day_complications', 'rb') as fp:
    cat_col = pickle.load(fp)

model_path = 'output/models/'
from joblib import load
encoder = load(model_path+'OHE.joblib')

# %%
# Create dummy variables
one_hot_encoded_array = encoder.transform(x_test[cat_col]).toarray()
column_name = encoder.get_feature_names(cat_col)
x_test_OHE =  pd.DataFrame(one_hot_encoded_array, columns= column_name)
x_test_NN = x_test.merge(x_test_OHE, how = 'left', left_index = True, right_index =True) # create dummy variables
x_test_NN = x_test_NN.drop(labels = cat_col, axis = 'columns') # drop original variables

# %% [markdown]
# ### Load Models

# %%
model_path = 'output/models/'

# %%
# import Decision Tree Classifier
from joblib import load
DTC = load(model_path+'DTC.joblib')

# %%
# import Random Forest Classifer
from joblib import load
RFR = load(model_path+'RFR.joblib')

# %%
# import Random Forest Classifer
from joblib import load
Logit = load(model_path+'Logit.joblib')

# %%
# load Neural Network Model
from joblib import load
# Load the pipeline first:
pipeline = load(model_path+'nn_pipeline.pkl')

# Then, load the Keras model:
pipeline_model = keras.models.load_model(model_path+'nn_model.h5')

nn_model = Pipeline(steps=[('preprocessor', pipeline),
                ('classifier',pipeline_model)
               ])

# %% [markdown]
# ### Generate Predictions for the Test set

# %%
# Generate prediction for the Decsiion Tree Model
results_DTC = pd.DataFrame(DTC.predict(x_test), columns=['pred_label'])
results_DTC['pred_prob'] =  pd.DataFrame(DTC.predict_proba(x_test))[1]
results_DTC['true_label'] = np.array(y_test)

# %%
# Generate prediction for the Random Forest Model
results_RFR = pd.DataFrame(RFR.predict(x_test), columns=['pred_label'])
results_RFR['pred_prob'] =  pd.DataFrame(RFR.predict_proba(x_test))[1]
results_RFR['true_label'] = np.array(y_test)

# %%
# Generate prediction for the Logitic Regressions Model
results_Logit = pd.DataFrame(Logit.predict(x_test), columns=['pred_label'])
results_Logit['pred_prob'] =  pd.DataFrame(Logit.predict_proba(x_test))[1]
results_Logit['true_label'] = np.array(y_test)

# %%
# Generate prediction for Neural Network Model

# Generate prediction for the Neural Network Model
results_NN = pd.DataFrame(nn_model.predict(x_test_NN), columns=['pred_prob'])
results_NN['pred_label'] =  results_NN['pred_prob'].apply(lambda x: 1 if x>=0.5 else 0)
results_NN['true_label'] = np.array(y_test)

# %% [markdown]
# ### Performance of the models for the testset

# %%
# Define function to calculate Precision-Recall Curve
def calc_aucpr_data(result):
    y_ACTUAL = result['true_label']
    scores_prob = result['pred_prob']
    yhat = result['pred_label']
    precision, recall, thresholds = metrics.precision_recall_curve(y_ACTUAL, scores_prob, pos_label=1)
    prc_auc = metrics.auc(recall,precision)
    return prc_auc


print("AUC-ROC DTC: {:.3f}".format(metrics.roc_auc_score(results_DTC['true_label'], results_DTC['pred_prob'])))
print("AUC-ROC LOGIT: {:.3f}".format(metrics.roc_auc_score(results_Logit['true_label'], results_Logit['pred_prob'])))
print("AUC-ROC RFR: {:.3f}".format(metrics.roc_auc_score(results_RFR['true_label'], results_RFR['pred_prob'])))
print("AUC-ROC NN: {:.3f} \n".format(metrics.roc_auc_score(results_NN['true_label'], results_NN['pred_prob'])))


print("PR-AUC DTC: {:.3f}".format(calc_aucpr_data(results_DTC)))
print("PR-AUC LOGIT: {:.3f}".format(calc_aucpr_data(results_Logit)))
print("PR-AUC RFR: {:.3f}".format(calc_aucpr_data(results_RFR)))
print("PR-AUC NN: {:.3f}\n".format(calc_aucpr_data(results_NN)))

print("DTC Sentivity/Recall: {:.3f}".format(metrics.recall_score(results_DTC['true_label'], results_DTC['pred_label'])))
print("LOGIT Sentivity/Recall: {:.3f}".format(metrics.recall_score(results_Logit['true_label'], results_Logit['pred_label'])))
print("RFR Sentivity/Recall: {:.3f}".format(metrics.recall_score(results_RFR['true_label'], results_RFR['pred_label'])))
print("NN Sentivity/Recall: {:.3f}\n".format(metrics.recall_score(results_NN['true_label'], results_NN['pred_label'])))

print("DTC Specificity/True Negative Rate: {:.3f}".format(metrics.recall_score(results_DTC['true_label'], results_DTC['pred_label'], pos_label = 0)))
print("LOGIT Specificity/True Negative Rate: {:.3f}".format(metrics.recall_score(results_Logit['true_label'], results_Logit['pred_label'], pos_label = 0)))
print("RFR Specificity/True Negative Rate: {:.3f}".format(metrics.recall_score(results_RFR['true_label'], results_RFR['pred_label'], pos_label = 0)))
print("NN Specificity/True Negative Rate: {:.3f}\n".format(metrics.recall_score(results_NN['true_label'], results_NN['pred_label'], pos_label = 0)))

print("DTC PPV/Precision: {:.3f}".format(metrics.precision_score(results_DTC['true_label'], results_DTC['pred_label'])))
print("LOGIT PPV/Precision: {:.3f}".format(metrics.precision_score(results_Logit['true_label'], results_Logit['pred_label'])))
print("RFR PPV/Precision: {:.3f}".format(metrics.precision_score(results_RFR['true_label'], results_RFR['pred_label'])))
print("NN PPV/Precision: {:.3f}\n".format(metrics.precision_score(results_NN['true_label'], results_NN['pred_label'])))

print("DTC NPV: {:.3f}".format(metrics.precision_score(results_DTC['true_label'], results_DTC['pred_label'], pos_label = 0)))
print("LOGIT NPV: {:.3f}".format(metrics.precision_score(results_Logit['true_label'], results_Logit['pred_label'], pos_label = 0)))
print("RFR NPV: {:.3f}".format(metrics.precision_score(results_RFR['true_label'], results_RFR['pred_label'], pos_label = 0)))
print("NN NPV: {:.3f}\n".format(metrics.precision_score(results_NN['true_label'], results_NN['pred_label'], pos_label = 0)))

print("DTC NPV: {:.3f}".format(metrics.precision_score(results_DTC['true_label'], results_DTC['pred_label'], pos_label = 0)))
print("LOGIT NPV: {:.3f}".format(metrics.precision_score(results_Logit['true_label'], results_Logit['pred_label'], pos_label = 0)))
print("RFR NPV: {:.3f}".format(metrics.precision_score(results_RFR['true_label'], results_RFR['pred_label'], pos_label = 0)))
print("NN NPV: {:.3f}\n".format(metrics.precision_score(results_NN['true_label'], results_NN['pred_label'], pos_label = 0)))

print("DTC F-1 Score: {:.3f}".format(metrics.f1_score(results_DTC['true_label'], results_DTC['pred_label'])))
print("LOGIT F-1 Score: {:.3f}".format(metrics.f1_score(results_Logit['true_label'], results_Logit['pred_label'])))
print("RFR F-1 Score: {:.3f}".format(metrics.f1_score(results_RFR['true_label'], results_RFR['pred_label'])))
print("NN F-1 Score: {:.3f}\n".format(metrics.f1_score(results_NN['true_label'], results_NN['pred_label'])))
# Out:
# AUC-ROC DTC: 0.759
# AUC-ROC LOGIT: 0.837
# AUC-ROC RFR: 0.875
# AUC-ROC NN: 0.837
#
# PR-AUC DTC: 0.494
# PR-AUC LOGIT: 0.584
# PR-AUC RFR: 0.706
# PR-AUC NN: 0.649
#
# DTC Sentivity/Recall: 0.640
# LOGIT Sentivity/Recall: 0.730
# RFR Sentivity/Recall: 0.427
# NN Sentivity/Recall: 0.281
#
# DTC Specificity/True Negative Rate: 0.727
# LOGIT Specificity/True Negative Rate: 0.793
# RFR Specificity/True Negative Rate: 0.967
# NN Specificity/True Negative Rate: 0.985
#
# DTC PPV/Precision: 0.385
# LOGIT PPV/Precision: 0.485
# RFR PPV/Precision: 0.776
# NN PPV/Precision: 0.833
#
# DTC NPV: 0.883
# LOGIT NPV: 0.917
# RFR NPV: 0.863
# NN NPV: 0.837
#
# DTC NPV: 0.883
# LOGIT NPV: 0.917
# RFR NPV: 0.863
# NN NPV: 0.837
#
# DTC F-1 Score: 0.481
# LOGIT F-1 Score: 0.583
# RFR F-1 Score: 0.551
# NN F-1 Score: 0.420

# %%
# %matplotlib inline

# Plotting AUROC Curve - Calculatae Metrics
from sklearn import metrics
def calc_aucroc_data(result):
    y_ACTUAL= result['true_label']
    scores_prob = result['pred_prob']
    fpr, tpr, thresholds = metrics.roc_curve(y_ACTUAL, scores_prob, pos_label=1)
    roc_auc = metrics.auc(fpr, tpr)
    return fpr, tpr, thresholds, roc_auc

def calc_aucpr_data(result):
    y_ACTUAL = result['true_label']
    scores_prob = result['pred_prob']
    yhat = result['pred_label']
    precision, recall, thresholds = metrics.precision_recall_curve(y_ACTUAL, scores_prob, pos_label=1)
    prc_auc = metrics.auc(recall,precision)
    f1 = metrics.f1_score(y_ACTUAL, yhat)
    ap = metrics.average_precision_score(y_ACTUAL, yhat)
    mortality_ratio = round(sum(result['true_label'])/(len(result['true_label'])),2)
    return recall, precision, f1, prc_auc, mortality_ratio

### Calculate metrics for models trained on original data
#fpr_DTC, tpr_DTC, thresholds_DTC, roc_auc_DTC = calc_aucroc_data(results_DTC)
fpr_Logit, tpr_Logit, thresholds_Logit, roc_auc_Logit = calc_aucroc_data(results_Logit)
fpr_RFR, tpr_RFR, thresholds_RFR, roc_auc_RFR = calc_aucroc_data(results_RFR)
fpr_NN, tpr_NN, thresholds_NN, roc_auc_NN = calc_aucroc_data(results_NN)

#recall_DTC, precision_DTC, f1_DTC, prc_auc_DTC, mortality_ratio = calc_aucpr_data(results_DTC)
recall_Logit, precision_Logit, f1_Logit, prc_auc_Logit, mortality_ratio = calc_aucpr_data(results_Logit)
recall_RFR, precision_RFR, f1_RFR, prc_auc_RFR, mortality_ratio = calc_aucpr_data(results_RFR)
recall_NN, precision_NN, f1_NN, prc_auc_NN, mortality_ratio = calc_aucpr_data(results_NN)


# Plotting performance of models developed using original data
import matplotlib.pyplot as plt
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(16,6))
fig.suptitle('Postoperative Events', fontsize=25, y=1.02)

# Plotting AUROC Curve - Plot Curve
ax1.set_title('Receiver Operating Characteristic',fontdict={"size":20})
ax1.set_xlim([0, 1])
ax1.set_ylim([0, 1])
ax1.set_ylabel('True Positive Rate or Sensitivity', fontdict={"size":15})
ax1.set_xlabel('False Positive Rate or 1-Specificity',fontdict={"size":15})

#ax1.plot(fpr_DTC, tpr_DTC, label = 'AUC-ROC DTC = %0.2f' % roc_auc_DTC)
ax1.plot(fpr_Logit, tpr_Logit, label = 'AUC-ROC LR_POE = %0.2f' % roc_auc_Logit)
ax1.plot(fpr_RFR, tpr_RFR, label = 'AUC-ROC RFC_POE = %0.2f' % roc_auc_RFR)
ax1.plot(fpr_NN, tpr_NN, label = 'AUC-ROC NN_POE = %0.2f' % roc_auc_NN)


ax1.plot([0, 1], [0, 1],linestyle='--',color='red', label = 'No Skill Line')
ax1.legend(loc='upper center', bbox_to_anchor=(0.5, -0.125), fontsize = 12)  

# Plotting Precision-Recall Curve - PLot Curve
ax2.set_title('Precision Recall Curve',fontdict={"size":20})
ax2.set_xlim([0, 1])
ax2.set_ylim([0, 1])
ax2.set_ylabel('Precision',fontdict={"size":15})
ax2.set_xlabel('Recall',fontdict={"size":15})

#ax2.plot(recall_DTC, precision_DTC, label = 'PR-AUC DTC=%.2f' % (prc_auc_DTC))
ax2.plot(recall_Logit, precision_Logit, label = 'PR-AUC LR_POE=%.2f' % (prc_auc_Logit))
ax2.plot(recall_RFR, precision_RFR, label = 'PR-AUC RFC_POE=%.2f' % (prc_auc_RFR))
ax2.plot(recall_NN, precision_NN, label = 'PR-AUC NN_POE=%.2f' % (prc_auc_NN))

positive_class_ratio = mortality_ratio
ax2.plot([0, 1], [positive_class_ratio, positive_class_ratio],linestyle='--',color='red', label = 'No Skill Line')
ax2.legend(loc='upper center', bbox_to_anchor=(0.5, -0.125),fontsize = 12)
fig.show()
# Out:
# C:\Users\anubhav\Anaconda3\envs\Tensorflow\lib\site-packages\ipykernel_launcher.py:71: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
# Plotting Calibration curve
from sklearn.calibration import calibration_curve

def calib_curve(result):
    x, y = calibration_curve(result['true_label'],result['pred_prob'],n_bins = 10, strategy='uniform')
    return x, y

x_DTC, y_DTC = calib_curve(results_DTC)
x_Logit, y_Logit = calib_curve(results_Logit)
x_RFR, y_RFR = calib_curve(results_RFR)
x_NN, y_NN = calib_curve(results_NN)




import matplotlib.pyplot as plt
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(16,6))
fig.suptitle('Comparision of Calibration Plots (Reliability Curves)', fontsize=20)

#ax1.plot(x_DTC, y_DTC, marker = 'o', color = 'tab:blue', label = 'DTC')
ax1.plot(x_Logit, y_Logit, marker = 'o', color = 'tab:orange', label = 'LOGIT')
ax1.plot(x_RFR, y_RFR, marker = 'o', color = 'tab:red', label = 'RFR')
ax1.plot(x_NN, y_NN, marker = 'o', color = 'tab:green', label = 'NN')

ax1.plot([0, 1], [0, 1],linestyle='--',color='black', label = 'Perfectly Calibrated')
ax1.legend(loc='upper center', bbox_to_anchor=(0.5, -0.125),fontsize = 12)
ax1.set_ylabel('Fraction of Positives',fontdict={"size":15})
ax1.set_xlabel('Mean Predicted value',fontdict={"size":15})



ax2.plot([0, 1], [0, 1],linestyle='--',color='black', label = 'Perfectly Calibrated')
ax2.legend(loc='upper center', bbox_to_anchor=(0.5, -0.125),fontsize = 12)
ax2.set_ylabel('Fraction of Positives',fontdict={"size":15})
ax2.set_xlabel('Mean Predicted value',fontdict={"size":15})

fig.show()
# Out:
# C:\Users\anubhav\Anaconda3\envs\Tensorflow\lib\site-packages\ipykernel_launcher.py:37: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ### Create bootstrapped confidence intervals for each model

# %%
def bootstrapped_AUC(result):
    """
    This function can be used to create bootstrapped estimate of AUCROC and PRAUC
    The input for this funtion is a dataframe with following variables.
    
    Variables in dataframe
    ----------------------
    true_label : True label of testset
    
    pred_prob : The predicted probability
    
    pred_label : The predicted label
    """
    from sklearn.utils import resample
    #from tqdm import tqdm

    n_iter = 10000
    roc_auc = list()
    prc_auc = list()


    for i in range(n_iter):
        result_sample = resample(result, n_samples = len(result),random_state=i)
        #Calculating AUROC for each sample
        y_ACTUAL= result_sample['true_label']
        scores_prob = result_sample['pred_prob']
        fpr, tpr, thresholds = metrics.roc_curve(y_ACTUAL, scores_prob, pos_label=1)
        roc_auc.append(metrics.auc(fpr, tpr))

        #calculate AUPRC for each sample
        y_ACTUAL = result_sample['true_label']
        scores_prob = result_sample['pred_prob']
        yhat = result_sample['pred_label']
        precision, recall, thresholds = metrics.precision_recall_curve(y_ACTUAL, scores_prob, pos_label=1)
        prc_auc.append(metrics.auc(recall,precision))
    
    return roc_auc, prc_auc

# %%
# %%time
# Create bootstrapped estimates of AUCROC and PR
roc_auc_LR, pr_auc_LR  = bootstrapped_AUC(results_Logit)
roc_auc_RFR, pr_auc_RFR  = bootstrapped_AUC(results_RFR)
roc_auc_NN, pr_auc_NN  = bootstrapped_AUC(results_NN)
# Out:
# Wall time: 1min 12s

# %%
dict_AUCROC = {'roc_auc_LR': roc_auc_LR,
               'roc_auc_RFR': roc_auc_RFR,
               'roc_auc_NN': roc_auc_NN,

              }

dict_PRAUC = {'pr_auc_LR': pr_auc_LR,
               'pr_auc_RFR': pr_auc_RFR,
               'pr_auc_NN': pr_auc_NN,
 
              }
df_AUCROC = pd.DataFrame(dict_AUCROC)
df_PRAUC = pd.DataFrame(dict_PRAUC)

# %%
df_AUCROC.head()
# Out:
#    roc_auc_LR  roc_auc_RFR  roc_auc_NN
# 0    0.866117     0.886184    0.855157
# 1    0.854038     0.884531    0.856587
# 2    0.846979     0.883983    0.844984
# 3    0.869961     0.885641    0.874627
# 4    0.853918     0.895368    0.859237

# %%
df_PRAUC.head()
# Out:
#    pr_auc_LR  pr_auc_RFR  pr_auc_NN
# 0   0.700387    0.752123   0.678714
# 1   0.650781    0.755719   0.702943
# 2   0.549002    0.702846   0.612219
# 3   0.615756    0.707034   0.716623
# 4   0.659808    0.738291   0.666809

# %%
# Print Confidence intervals for AUCROC
x = df_AUCROC.describe(percentiles=[0.025,0.975])
for i in df_AUCROC.columns:
    print(i+' 95%CI: {:.3f} (95% CI {:.3f},{:.3f})'.format(x[i]['mean'], x[i]['2.5%'], x[i]['97.5%']))
# Out:
# roc_auc_LR 95%CI: 0.837 (95% CI 0.786,0.882)
# roc_auc_RFR 95%CI: 0.875 (95% CI 0.834,0.913)
# roc_auc_NN 95%CI: 0.837 (95% CI 0.786,0.883)

# %%
# Print Confidence intervals for PRAUC
x = df_PRAUC.describe(percentiles=[0.025,0.975])
for i in df_PRAUC.columns:
    print(i+' 95%CI: {:.3f} (95% CI {:.3f},{:.3f})'.format(x[i]['mean'], x[i]['2.5%'], x[i]['97.5%']))
# Out:
# pr_auc_LR 95%CI: 0.591 (95% CI 0.477,0.701)
# pr_auc_RFR 95%CI: 0.706 (95% CI 0.610,0.790)
# pr_auc_NN 95%CI: 0.649 (95% CI 0.549,0.739)

# %% [markdown]
# ### Bootsrap Hypothesis Testing

# %%
from sklearn.utils import resample
def calculate_roc_auc(result):
    #Calculating AUROC for each sample
    y_ACTUAL= result['true_label']
    scores_prob = result['pred_prob']
    fpr, tpr, thresholds = metrics.roc_curve(y_ACTUAL, scores_prob, pos_label=1)
    roc_auc = metrics.auc(fpr, tpr)

    #calculate AUPRC for each sample
    y_ACTUAL = result['true_label']
    scores_prob = result['pred_prob']
    yhat = result['pred_label']
    precision, recall, thresholds = metrics.precision_recall_curve(y_ACTUAL, scores_prob, pos_label=1)
    prc_auc = metrics.auc(recall,precision)
    return roc_auc, prc_auc

# %%
def permutaion_diff(x, y):
    """
    This function creates a combined dataset under null hypothesis that there is no 
    difference between AUROC and PRAUC, of x and y.
    10000 samples are taken from combined dataset of length x, y respectively and the
    difference in AUCROC and PRROC is caulcated. 
    
    """
    # Combining the results of both algorithms under assumption that there is no difference between the results
    combined = pd.concat([x, y], sort = True)

    # Draw 10000 samples from combined dataset for each of length x and y where x, y are results of agorithms being tested
    # Calculate difference between the permuted sets


    dif_bootstrap_auc = []
    dif_bootstrap_prauc = []

    for i in range(10000):
        np.random.seed(i)
        perms_auroc_x, perms_prauc_x = calculate_roc_auc(resample(combined, n_samples = len(x)))
        perms_auroc_y, perms_prauc_y = calculate_roc_auc(resample(combined, n_samples = len(y)))
        dif_bootstrap_auc.append(perms_auroc_x-perms_auroc_y)
        dif_bootstrap_prauc.append(perms_prauc_x - perms_prauc_y)
    return dif_bootstrap_auc, dif_bootstrap_prauc

# %%
def permutaion_pvalue(x,y, bootstrap_diff,metric):
    """
    This function will take the x,y and calculate observed difference in metric.
    Check likelihood of getting the observed diff againt bootstrapped diff and provide p_value.
    If bootstrap_diff contains diff of AUC-ROC values then select metric as 'AUCROC'.
    If bootstrap_diff contains diff of PR-AUC values then select metric as 'PRAUC'.
    """
    
    if metric == 'AUCROC':
        metric = 0
    else: 
        metric = 1
    
    # Check the likelihood of getting observed differewnce in AUCROC and PRAUC
    obs_difs = (calculate_roc_auc(x)[metric] - calculate_roc_auc(y)[metric])
    #print('observed difference : {}'.format(obs_difs))
    p_value = sum(bootstrap_diff >= obs_difs)/10000
    #print('p-value: {}'.format(p_value))
    return obs_difs, p_value

# %%
def permutation_test(x,y):
    """
    This esxecutes permutaion test to check if diff in AUCROC and PRAUC of two classifiers is significant
    """
    dif_bootstrap_auc, dif_bootstrap_prauc = permutaion_diff(x,y)
    obs_difs_AUCROC, p_value_AUCROC = permutaion_pvalue(x,y,dif_bootstrap_auc, metric = 'AUCROC')
    obs_difs_PRAUC, p_value_PRAUC = permutaion_pvalue(x,y,dif_bootstrap_prauc, metric = 'PRAUC')
    return [obs_difs_AUCROC, obs_difs_PRAUC, p_value_AUCROC, p_value_PRAUC]

# %%
perm_stats = {'RFR_LR' : permutation_test(x = results_RFR, y = results_Logit),
              'RFR_NN' : permutation_test(x = results_RFR, y = results_NN),
              'LR_RFR' : permutation_test(x = results_Logit, y = results_RFR),
              'NN_RFR' : permutation_test(x = results_NN, y = results_RFR),
              'NN_LR'  : permutation_test(x = results_NN, y = results_Logit),
              'LR_NN'  : permutation_test(x = results_Logit, y = results_NN)
}

# %%
df_perm_stats = pd.DataFrame(perm_stats, index=['obs_difs_AUCROC',
                                               'obs_difs_PRAUC',
                                               'p_value_AUCROC',
                                               'p_value_PRAUC'])

# %%
df_perm_stats
# Out:
#                    RFR_LR    RFR_NN    LR_RFR    NN_RFR     NN_LR     LR_NN
# obs_difs_AUCROC  0.038735  0.038634 -0.038735 -0.038634  0.000101 -0.000101
# obs_difs_PRAUC   0.121272  0.057099 -0.121272 -0.057099  0.064173 -0.064173
# p_value_AUCROC   0.109300  0.157800  0.891300  0.846200  0.498400  0.510400
# p_value_PRAUC    0.067800  0.206000  0.931500  0.799500  0.214300  0.786300

# %%
import matplotlib.pyplot as plt
from sklearn.inspection import permutation_importance
result = permutation_importance(RFR, x_test, y_test, n_repeats=100,
                                random_state=42, n_jobs=-1)
sorted_idx = result.importances_mean.argsort()

# %%
fig, ax = plt.subplots(figsize=(10,30))
ax.boxplot(result.importances[sorted_idx].T,
           vert=False, labels=x_test.columns[sorted_idx])
ax.set_title("Permutation Importances (test set)")
ax.axvline(x = 0,linestyle='--',color='black')
fig.tight_layout()
plt.show()

# %%
f_imp = pd.DataFrame(result.importances[sorted_idx].T, columns=x_test.columns[sorted_idx])
f_imp
# Out:
#          BMI  EARLYUNCLAMPING  DAVINCIMODEL  LOCATIONTOPOLARLINE  \
# 0  -0.010865        -0.004434      0.000737            -0.003894
# 1  -0.015628        -0.009267     -0.002373            -0.003265
# 2  -0.004506        -0.005974      0.000280            -0.014263
# 3  -0.017172        -0.002937     -0.008551            -0.004249
# 4  -0.016659        -0.004462     -0.005453            -0.003605
# ..       ...              ...           ...                  ...
# 95 -0.001082        -0.005493     -0.000598            -0.005715
# 96 -0.005248        -0.005897     -0.007760            -0.002863
# 97 -0.015982        -0.003654     -0.002509            -0.009355
# 98 -0.009403        -0.005063     -0.006141             0.004786
# 99 -0.017228        -0.003212     -0.007153            -0.005784
#
#     R.E.N.A.L.NEPHRORISKSTRATIFICATION        CT  TUMORlOCATION   PREOPHB  \
# 0                        -3.649309e-03 -0.011145      -0.001996  0.000151
# 1                         2.211503e-03 -0.005044      -0.002366  0.000281
# 2                        -7.330590e-03 -0.002443      -0.002634  0.000331
# 3                        -2.603659e-03 -0.003583      -0.001010  0.004749
# 4                        -6.770003e-03 -0.002692      -0.003057 -0.015175
# ..                                 ...       ...            ...       ...
# 95                       -5.178192e-03 -0.005879      -0.001584  0.002539
# 96                       -4.393214e-03  0.000005      -0.002301  0.001096
# 97                       -2.401263e-03 -0.002440      -0.001391 -0.014788
# 98                       -4.252961e-03 -0.003504      -0.000535 -0.003382
# 99                       -8.891900e-07 -0.003888      -0.000819 -0.005384
#
#      PREOPHT  RIMLOCATION  ...  NEARNESSOFTUMOUR  INNERRENORRHAPHY  \
# 0  -0.004782    -0.007903  ...          0.006946          0.008006
# 1  -0.003735    -0.004507  ...          0.000534          0.008260
# 2  -0.004651    -0.001234  ...          0.005987          0.008196
# 3  -0.003482     0.001042  ...          0.006346          0.006433
# 4  -0.002547    -0.004861  ...          0.006444          0.018301
# ..       ...          ...  ...               ...               ...
# 95 -0.007087    -0.003929  ...          0.012000          0.019003
# 96 -0.003482    -0.004245  ...          0.004120          0.008310
# 97 -0.007127    -0.001276  ...          0.011611          0.019246
# 98 -0.001508    -0.003322  ...          0.002866          0.015229
# 99 -0.003290     0.000124  ...          0.009327          0.002239
#
#     BLOODLOSSml  DUALCONSOLE        CN  ISCHEMIATIMEmin      RACE  \
# 0      0.010752     0.004095 -0.012555         0.011665  0.000806
# 1      0.006896    -0.001991  0.006446         0.011204  0.004011
# 2      0.015104     0.026397  0.011085         0.004894  0.019237
# 3      0.005625     0.016477  0.026554         0.017973  0.012591
# 4      0.010612     0.012673  0.024246         0.019534  0.007644
# ..          ...          ...       ...              ...       ...
# 95     0.012544     0.002408  0.012745         0.020788  0.012758
# 96     0.015878     0.012599  0.011726         0.019607  0.015180
# 97     0.001492     0.011264 -0.002686         0.008637  0.011147
# 98     0.004362     0.008306  0.015829         0.007968  0.012362
# 99     0.010678     0.016690  0.020396         0.015134  0.011528
#
#     center_volume  HAEMOSTATICAGENTS  CENTERCODE
# 0        0.000420           0.017093    0.036590
# 1        0.010424           0.009988    0.029631
# 2        0.035248           0.024991    0.042690
# 3        0.028525           0.039740    0.038373
# 4        0.016519           0.016131    0.039717
# ..            ...                ...         ...
# 95       0.022199           0.009121    0.044865
# 96       0.013966           0.047946    0.051816
# 97       0.012998           0.037520    0.035990
# 98       0.024292           0.049488    0.035996
# 99       0.026890           0.038302    0.038019
#
# [100 rows x 59 columns]

# %%
f_imp_dict = {}
for i in f_imp:
    f_imp_dict.update({i:[i,"{:.3f} [95% CI {:.3f}, {:.3f}]".format(f_imp[i].median(), f_imp[i].quantile(0.05), f_imp[i].quantile(0.95)), f_imp[i].median()]
    })

# %%
f_imp_metrics = pd.DataFrame.from_dict(f_imp_dict, orient='index', 
                       columns=['Features','Permutation Importance (95% CI)', 'Median']).reset_index(drop = True)

# %%
f_imp_metrics.sort_values(['Median'], ascending = False)
# Out:
#                               Features Permutation Importance (95% CI)  \
# 58                          CENTERCODE     0.037 [95% CI 0.018, 0.054]
# 57                   HAEMOSTATICAGENTS     0.029 [95% CI 0.009, 0.048]
# 56                       center_volume     0.016 [95% CI 0.004, 0.029]
# 54                     ISCHEMIATIMEmin     0.012 [95% CI 0.007, 0.020]
# 55                                RACE     0.012 [95% CI 0.003, 0.025]
# 53                                  CN    0.012 [95% CI -0.005, 0.028]
# 52                         DUALCONSOLE    0.011 [95% CI -0.003, 0.026]
# 51                         BLOODLOSSml     0.009 [95% CI 0.001, 0.016]
# 50                    INNERRENORRHAPHY    0.008 [95% CI -0.002, 0.020]
# 49                    NEARNESSOFTUMOUR     0.008 [95% CI 0.001, 0.012]
# 48                            SYMPTOMS    0.007 [95% CI -0.001, 0.014]
# 46                      SOLITARYKIDNEY    0.005 [95% CI -0.003, 0.013]
# 47                           PADUARISK     0.005 [95% CI 0.000, 0.012]
# 45                           EDUCATION    0.004 [95% CI -0.005, 0.011]
# 43                        FLUORESCENCE    0.004 [95% CI -0.001, 0.009]
# 44                              ACCESS    0.004 [95% CI -0.005, 0.014]
# 41                                FACE    0.003 [95% CI -0.001, 0.007]
# 39                        ROBOTICSARMS    0.003 [95% CI -0.006, 0.008]
# 40                 ANTERIORORPOSTERIOR    0.003 [95% CI -0.002, 0.008]
# 42           SELECTIVEARTERIALCLAMPING    0.003 [95% CI -0.000, 0.009]
# 38                    ASSISTENTTROCARS    0.003 [95% CI -0.003, 0.006]
# 36                       MARITALSTATUS    0.002 [95% CI -0.003, 0.005]
# 37                        AGEATSURGERY    0.001 [95% CI -0.006, 0.009]
# 34                       EXOPHYTICRATE    0.001 [95% CI -0.002, 0.005]
# 30                           CLAMPVEIN    0.001 [95% CI -0.008, 0.008]
# 31                 INTRAOPTRANSUFUSION    0.001 [95% CI -0.000, 0.002]
# 35                    OUTERRENORRHAPHY    0.001 [95% CI -0.005, 0.011]
# 32                       SIDEOFSURGERY    0.001 [95% CI -0.002, 0.004]
# 33                    OPERATIVETIMEmin    0.001 [95% CI -0.006, 0.009]
# 29                      CLINICALSIZEmm    0.001 [95% CI -0.010, 0.011]
# 28                          PREOPCREAT   -0.000 [95% CI -0.007, 0.007]
# 27                         NOOFLESIONS   -0.000 [95% CI -0.000, 0.001]
# 26                       CHARLSONSCORE   -0.000 [95% CI -0.004, 0.004]
# 24                INTRAOPCOMPLICATIONS   -0.000 [95% CI -0.001, 0.000]
# 25                            PREOPWBC   -0.000 [95% CI -0.005, 0.005]
# 22             PARTIALNEPHROINDICATION   -0.001 [95% CI -0.004, 0.001]
# 19                   CLINICALSIZEGROUP   -0.001 [95% CI -0.005, 0.002]
# 23              LYMPHNODEDISSECTIONLND   -0.001 [95% CI -0.002, 0.000]
# 20                         CLAMPARTERY   -0.001 [95% CI -0.003, 0.001]
# 21                         SIDEOFTUMOR   -0.001 [95% CI -0.004, 0.003]
# 15                       POLARLOCATION   -0.001 [95% CI -0.010, 0.005]
# 18                           UCSREPAIR   -0.001 [95% CI -0.007, 0.005]
# 16                              GENDER   -0.001 [95% CI -0.008, 0.005]
# 17                            ISCHEMIA   -0.002 [95% CI -0.005, 0.000]
# 14                          RENALSINUS   -0.002 [95% CI -0.005, 0.001]
# 13           RADIUSmaximaldiameterincm   -0.002 [95% CI -0.005, 0.000]
# 9                          RIMLOCATION   -0.002 [95% CI -0.007, 0.003]
# 10                            ASASCORE   -0.002 [95% CI -0.007, 0.003]
# 12                 BILATERALITYOFTUMOR   -0.002 [95% CI -0.005, 0.003]
# 8                              PREOPHT   -0.003 [95% CI -0.007, 0.002]
# 11                       MULTIFOCALITY   -0.003 [95% CI -0.006, 0.005]
# 5                                   CT   -0.003 [95% CI -0.007, 0.001]
# 3                  LOCATIONTOPOLARLINE   -0.003 [95% CI -0.011, 0.003]
# 6                        TUMORlOCATION   -0.003 [95% CI -0.007, 0.001]
# 7                              PREOPHB   -0.003 [95% CI -0.012, 0.008]
# 4   R.E.N.A.L.NEPHRORISKSTRATIFICATION   -0.003 [95% CI -0.008, 0.002]
# 2                         DAVINCIMODEL   -0.004 [95% CI -0.009, 0.003]
# 1                      EARLYUNCLAMPING  -0.006 [95% CI -0.009, -0.002]
# 0                                  BMI  -0.009 [95% CI -0.017, -0.002]
#
#       Median
# 58  0.036791
# 57  0.029202
# 56  0.015808
# 54  0.012389
# 55  0.012273
# 53  0.012094
# 52  0.010982
# 51  0.008687
# 50  0.008101
# 49  0.007633
# 48  0.006505
# 46  0.005364
# 47  0.004990
# 45  0.003625
# 43  0.003599
# 44  0.003556
# 41  0.003206
# 39  0.002886
# 40  0.002708
# 42  0.002637
# 38  0.002572
# 36  0.001717
# 37  0.001334
# 34  0.001310
# 30  0.001187
# 31  0.001077
# 35  0.000976
# 32  0.000974
# 33  0.000919
# 29  0.000569
# 28 -0.000091
# 27 -0.000104
# 26 -0.000207
# 24 -0.000257
# 25 -0.000284
# 22 -0.000524
# 19 -0.000719
# 23 -0.000778
# 20 -0.000967
# 21 -0.001145
# 15 -0.001330
# 18 -0.001443
# 16 -0.001460
# 17 -0.001509
# 14 -0.001803
# 13 -0.002067
# 9  -0.002212
# 10 -0.002216
# 12 -0.002333
# 8  -0.002771
# 11 -0.002850
# 5  -0.002882
# 3  -0.002889
# 6  -0.003109
# 7  -0.003237
# 4  -0.003428
# 2  -0.003679
# 1  -0.005539
# 0  -0.009085

# %%
pd.crosstab(x_test['RACE'],y_test)
# Out:
# POSTOP_COMPLICATIONS    0   1
# RACE
# 0                       8   0
# 1                      45  25
# 2                      22  23
# 3                      67  25
# 4                     191  16

# %%
pd.crosstab(x_test['RACE'],results_RFR['pred_label'])
# Out:
# pred_label    0   1
# RACE
# 0             8   0
# 1            51  19
# 2            22  23
# 3            91   1
# 4           201   6

# %%
pd.crosstab(x_test['RACE'],x_test['HAEMOSTATICAGENTS'])
# Out:
# HAEMOSTATICAGENTS  0   1    2
# RACE
# 0                  0   4    4
# 1                  0  30   40
# 2                  1   7   37
# 3                  0   8   84
# 4                  0  83  124

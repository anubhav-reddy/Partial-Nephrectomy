# %%
# Import Packages
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)  
#pd.set_option('display.expand_frame_repr', False)
#pd.set_option('max_colwidth', -1)

# %%
output_path = 'output/models/'

import os
if not os.path.exists(output_path):
    os.makedirs(output_path)

# %%
# Import prospective dataset
df= pd.read_excel('H:/RediMinds/DRMahen/Preethi PN_Data validation_2014-2018.xlsx', sheet_name='PN_Data validation_2014-2018')

# %%
#clean Clavien grade
df['INTRAOPCOMPLICATIONS'] = df['INTRAOPCOMPLICATIONS'].map(lambda x: str(x).split(',')[0])

# %%
# Dropping patinets with Intraoperative complication smarked as "others"
df = df[df['INTRAOPCOMPLICATIONS']!='335'].copy()

# %%
df_ori = df.copy()

# %%
#check number of patients and columns in Retrospective dataset
print('Number of patients in Combined dataset {}'. format(df.shape[0]))
print('Number of variables in Combined dataset {}'. format(df.shape[1]))
# Out:
# Number of patients in Combined dataset 3385
# Number of variables in Combined dataset 161

# %%
# reset index for combined dataset
df.reset_index(inplace=True, drop=True)

# %%
df['MU']
# Out:
# ['PATIENTNUMBER',
#  'PROCNAME',
#  'CENTERCODE',
#  'SURGEONCODE',
#  'RECPROGRESS',
#  'CREATEDDATE',
#  'GENDER',
#  'DATEOFBIRTH',
#  'AGEATSURGERY',
#  'MARITALSTATUS',
#  'RACE',
#  'EDUCATION',
#  'WEIGHT',
#  'HEIGHT',
#  'BMI',
#  'CLINICALSIZEmm',
#  'ECOG',
#  'CHARLSONSCORE',
#  'CHARLSONAGEADJUSTSCORE',
#  'SYMPTOMS',
#  'SOLITARYKIDNEY',
#  'TYPEOFSOLITARYKIDNEY',
#  'BILATERALITYOFTUMOR',
#  'SIDEOFTUMOR',
#  'SIDEOFSURGERY',
#  'PREOPMULTIFOCALITY',
#  'FACE',
#  'TUMORlOCATION',
#  'PREOPHB',
#  'PREOPHT',
#  'PREOPWBC',
#  'PREOPCREAT',
#  'PREOPGFR',
#  'PREOPEGFR',
#  'PREOPERPF',
#  'PADUASCORE',
#  'PADUARISK',
#  'POLARLOCATION',
#  'RIMLOCATION',
#  'RENALSINUS',
#  'UCSINVASION',
#  'EXOPHYTICRATE',
#  'CLINICALSIZEGROUP',
#  'CT',
#  'CN',
#  'CM',
#  'R.E.N.A.L.NEPHROSCORE',
#  'R.E.N.A.L.NEPHRORISKSTRATIFICATION',
#  'RADIUSmaximaldiameterincm',
#  'EXOPHYTICENDOPHYTICPROPERTIES',
#  'NEARNESSOFTUMOUR',
#  'ANTERIORORPOSTERIOR',
#  'LOCATIONTOPOLARLINE',
#  'TumorConsistencyonImaging',
#  'BosniakClassification',
#  'DATEOFSURGERY',
#  'ASASCORE',
#  'PARTIALNEPHROINDICATION',
#  'MULTIFOCALITY',
#  'NOOFLESIONS',
#  'ImagingFeaturesofotherexcisedtumor',
#  'Consistencyoftheotherexcisedtumors',
#  'ACCESS',
#  'DAVINCIMODEL',
#  'ROBOTICSARMS',
#  'ASSISTENTTROCARS',
#  'DUALCONSOLE',
#  'PRIMARYSURGEON',
#  'OPERATIVETIMEmin',
#  'ISCHEMIA',
#  'CLAMPARTERY',
#  'SELECTIVEARTERIALCLAMPING',
#  'CLAMPVEIN',
#  'EARLYUNCLAMPING',
#  'FLUORESCENCE',
#  'INNERRENORRHAPHY',
#  'OUTERRENORRHAPHY',
#  'ISCHEMIATIMEmin',
#  'UCSREPAIR',
#  'HAEMOSTATICAGENTS',
#  'HAEMOSTATICDetails',
#  'LYMPHNODEDISSECTIONLND',
#  'BLOODLOSSml',
#  'INTRAOPTRANSUFUSION',
#  'SURGICALCONSIDERATIONS',
#  'INTRAOPCOMPLICATION',
#  'INTRAOPCOMPLICATIONS',
#  'NeedtoConverttoRadicalNephrectomy',
#  'TREATMENTOFCOMPLICATION',
#  'POSTOPCOMPLICATION',
#  'SURGICALCOMPLICATIONS',
#  'NONSURGICALCOMPLICATIONS',
#  'POSTOPTREATMENTOFCOMPLICATION',
#  'CLAVIENGRADE',
#  'POSTOPHB_Day1',
#  'POSTOPHT_Day1',
#  'POSTOPCreat_Day1',
#  'POSTOPEGFR_Day1',
#  'POSTOPWBC_Day1',
#  'POSTOPHB_Day2',
#  'POSTOPHT_Day2',
#  'POSTOPCreat_Day2',
#  'POSTOPEGFR_Day2',
#  'POSTOPWBC_Day2',
#  'POSTOPHB_Day3',
#  'POSTOPHT_Day3',
#  'POSTOPCreat_Day3',
#  'POSTOPEGFR_Day3',
#  'POSTOPWBC_Day3',
#  'LENGTHOFSTAYdays',
#  'PATHOLOGICALTUMORSIZE',
#  'MINTHICKNESSMARGIN',
#  'MAXTHICKNESSMARGIN',
#  'MULITIFOCALITY',
#  'PATHOLOGY',
#  'HYSTOTYPEMALIGNANAT',
#  'HYSTOTYPEMALIGNANATYES',
#  'HYSTOTYPEBENIGN',
#  'HYSTOTYPEBENIGNYES',
#  'FUHRMANGRADING',
#  'SARCOMATOIDDIFF',
#  'SARCOMATOIDDIFF_A',
#  'NECROSIS',
#  'MICROVENOUSINVASION',
#  'UCSINVASION_A',
#  'PERIRENALFATINVASION',
#  'HilarFatInvasion',
#  'SINUSFATINVASION',
#  'MICSCORE',
#  'ADRENALINVASION',
#  'GEROTAINVASION',
#  'RenalVeinInvasion',
#  'VENOUSTHROMBUS',
#  'SURGICALMARGIN',
#  'UNIFOCALMULTIFOCAL',
#  'NO_OF_NODE_TAKEN',
#  'NO_OF_NODE_POSITIVE',
#  'SITEOFPOSITIVENODE',
#  'TREATMENTPSM',
#  'PT',
#  'PN',
#  'OTHERTUMORS',
#  'DATEOFRECURRENCE',
#  'LASTFOLLOWUPDURATION',
#  'TIMETORECURRENCE',
#  'LASTFOLLOWUPSTATUS',
#  'LASTFOLLOWUPRECURRENCE',
#  'LASTTREATMENTOFRECURRENCE',
#  'TYPEOFCOMPLICATIONSs',
#  'SELECTEDSURGICALCOMPLICATIONSs',
#  'SELECTEDNONSURGICALCOMPLICATIONSs',
#  'TREATMENTOFCOMPLICATIONSs',
#  'RECURRENCEs',
#  'FOLLOWUPDATEs',
#  'STATUSs',
#  'TREATMENTs',
#  'CREATININEs',
#  'EGFRs',
#  'SRFs',
#  'ERPFs',
#  'Year']

# %%
df.head(5)
# Out:
#   PATIENTNUMBER             PROCNAME CENTERCODE SURGEONCODE  \
# 0   10PAT000065  Partial Nephrectomy   U5WT3NOY    QIG8PUOL
# 1   13PAT000522  Partial Nephrectomy   08ZMCILJ    G4X4XVDW
# 2   22PAT000131  Partial Nephrectomy   WGC7XYXZ    DCCYSH8C
# 3   11PAT000166  Partial Nephrectomy   0VZRZWAI    WLU4FAKU
# 4   13PAT000509  Partial Nephrectomy   08ZMCILJ    G4X4XVDW
#
#            RECPROGRESS            CREATEDDATE  GENDER  DATEOFBIRTH  \
# 0  Pathology completed  2018-11-18 13:00:00.0    Male       1964.0
# 1  Pathology completed  2018-04-22 18:30:00.0    Male       1957.0
# 2  Pathology completed  2018-03-28 18:30:00.0    Male       1960.0
# 3           Follow-up1  2018-08-15 18:30:00.0    Male       1962.0
# 4  Pathology completed  2018-04-12 18:30:00.0  Female       1948.0
#
#    AGEATSURGERY MARITALSTATUS             RACE     EDUCATION  WEIGHT  HEIGHT  \
# 0          54.0       Married  White/Caucasian  Not Provided     NaN     NaN
# 1          61.0       Married  Mongoloid/Asian      Graduate    70.0   167.0
# 2          58.0       Married  Mongoloid/Asian  Not Provided    71.0   175.0
# 3          56.0       Married  Mongoloid/Asian  Not Provided    74.0   178.0
# 4          70.0       Married  Mongoloid/Asian      Graduate    85.0   160.0
#
#      BMI  CLINICALSIZEmm                                               ECOG  \
# 0    NaN             NaN  Fully active, able to carry on all pre-disease...
# 1  25.10            33.0  Fully active, able to carry on all pre-disease...
# 2  23.18            44.0  Fully active, able to carry on all pre-disease...
# 3  23.36             NaN  Fully active, able to carry on all pre-disease...
# 4  33.20             2.1  Ambulatory and capable of all selfcare but una...
#
#    CHARLSONSCORE  CHARLSONAGEADJUSTSCORE SYMPTOMS SOLITARYKIDNEY  \
# 0            0.0                     2.0   Absent             No
# 1            0.0                     3.0   Absent            Yes
# 2            0.0                     2.0   Absent             No
# 3            0.0                     2.0   Absent             No
# 4            5.0                     9.0   Absent             No
#
#   TYPEOFSOLITARYKIDNEY BILATERALITYOFTUMOR SIDEOFTUMOR SIDEOFSURGERY  \
# 0                  NaN                  No        Left          Left
# 1                 Left                  No        Left          Left
# 2                  NaN                  No        Left          Left
# 3                  NaN                  No        Left          Left
# 4                  NaN                  No        Left          Left
#
#   PREOPMULTIFOCALITY      FACE TUMORlOCATION  PREOPHB  PREOPHT  PREOPWBC  \
# 0                 No       NaN     Lower Pol     15.4     48.0    6300.0
# 1                 No  Anterior     Lower Pol     12.3     39.4    5400.0
# 2                 No  Anterior      Mid Pole     14.0     41.0    5100.0
# 3                 No  Anterior     Lower Pol     10.2     36.4    5200.0
# 4                 No  Anterior     Upper Pol      9.4     28.4    6020.0
#
#    PREOPCREAT PREOPGFR  PREOPEGFR PREOPERPF  PADUASCORE  \
# 0        8.10      NaN       0.49       NaN         NaN
# 1        1.25      NaN      58.72       NaN         9.0
# 2        0.90      999      86.67       999        11.0
# 3        0.70      NaN     116.66       NaN         6.0
# 4        1.70       52      29.71       NaN         6.0
#
#                PADUARISK                                      POLARLOCATION  \
# 0                    NaN                                                NaN
# 1  2(Intermidiate  Risk)  Tumours entirely located above the upper or be...
# 2          3(High  Risk)  Tumours crossing the sinus line >50% or fallin...
# 3           1(Low  Risk)  Tumours entirely located above the upper or be...
# 4           1(Low  Risk)  Tumours entirely located above the upper or be...
#
#                                 RIMLOCATION  \
# 0                                       NaN
# 1              At the medial rim (2 points)
# 2              At the medial rim (2 points)
# 3  Tumours located at the lateral (1 point)
# 4  Tumours located at the lateral (1 point)
#
#                                           RENALSINUS  \
# 0                                                NaN
# 1  Tumours without renal sinus involvement (1 point)
# 2            With renal sinus involvement (2 points)
# 3  Tumours without renal sinus involvement (1 point)
# 4  Tumours without renal sinus involvement (1 point)
#
#                                          UCSINVASION  \
# 0                                                NaN
# 1  With involving, dislocation or infiltration of...
# 2  With involving, dislocation or infiltration of...
# 3             Absent relationship with UCS (1 point)
# 4             Absent relationship with UCS (1 point)
#
#                EXOPHYTICRATE CLINICALSIZEGROUP   CT   CN   CM  \
# 0                        NaN               NaN  NaN  NaN  NaN
# 1  < 50%exophytic (2 points)             =<4cm  T1a   N0   M0
# 2  = 50% exophytic (1 point)         4.1cm-7cm  T1b   N0   M0
# 3  = 50% exophytic (1 point)             =<4cm  T1a   N0   M0
# 4  = 50% exophytic (1 point)             =<4cm  T1a   N0   M0
#
#   R.E.N.A.L.NEPHROSCORE R.E.N.A.L.NEPHRORISKSTRATIFICATION  \
# 0                   NaN                                NaN
# 1                    8x               2(Intermidiate Risk)
# 2                  10ah                       3(High Risk)
# 3                    4a                        1(Low Risk)
# 4                    5a                        1(Low Risk)
#
#   RADIUSmaximaldiameterincm EXOPHYTICENDOPHYTICPROPERTIES NEARNESSOFTUMOUR  \
# 0                       NaN                           NaN              NaN
# 1                       =<4                          <50%              =<4
# 2                  4 but <7                          <50%              =<4
# 3                       =<4                           50%              =>7
# 4                       =<4                           50%        >4 but <7
#
#   ANTERIORORPOSTERIOR  LOCATIONTOPOLARLINE TumorConsistencyonImaging  \
# 0                 NaN                  NaN                       NaN
# 1          Neither(x)                  2.0    Some cystic components
# 2        Anterior (a)                  3.0            Entirely solid
# 3        Anterior (a)                  1.0            Entirely solid
# 4        Anterior (a)                  1.0            Entirely solid
#
#   BosniakClassification          DATEOFSURGERY    ASASCORE  \
# 0                   NaN  2018-11-21 00:00:00.0  Category 2
# 1  Bosniak Grade 4 cyst  2018-04-23 00:00:00.0  Category 3
# 2  Entirely solid tumor  2018-03-29 00:00:00.0  Category 1
# 3  Entirely solid tumor  2018-08-16 00:00:00.0  Category 1
# 4  Entirely solid tumor  2018-04-13 00:00:00.0  Category 2
#
#   PARTIALNEPHROINDICATION MULTIFOCALITY  NOOFLESIONS  \
# 0                Relative            No          1.0
# 1                Elective            No          1.0
# 2                Elective            No          1.0
# 3                Elective            No          1.0
# 4                Elective            No          1.0
#
#   ImagingFeaturesofotherexcisedtumor Consistencyoftheotherexcisedtumors  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN               Entirely solid tumor
# 4                                NaN               Entirely solid tumor
#
#             ACCESS DAVINCIMODEL ROBOTICSARMS ASSISTENTTROCARS DUALCONSOLE  \
# 0  Transperitoneal           Xi       4-arms       Only 12 mm          No
# 1  Transperitoneal           Xi       4-arms       Only 12 mm          No
# 2  Transperitoneal           Xi       3-arms     5 mm + 12 mm          No
# 3  Transperitoneal           Xi       4-arms       Only 12 mm          No
# 4  Transperitoneal           Xi       4-arms       Only 12 mm          No
#
#   PRIMARYSURGEON OPERATIVETIMEmin       ISCHEMIA CLAMPARTERY  \
# 0          Staff            02:30           Warm     Bulldog
# 1          Staff            03:00           Warm     Bulldog
# 2          Staff            02:50           Warm     Bulldog
# 3          Staff            02:40           Warm     Bulldog
# 4          Staff            01:42  Not Performed          No
#
#   SELECTIVEARTERIALCLAMPING CLAMPVEIN EARLYUNCLAMPING FLUORESCENCE  \
# 0                        No        No              No         Used
# 1                       Yes        No              No         Used
# 2                        No        No              No     Not Used
# 3                        No        No              No     Not Used
# 4                       Yes        No              No         Used
#
#   INNERRENORRHAPHY OUTERRENORRHAPHY  ISCHEMIATIMEmin      UCSREPAIR  \
# 0              Yes              Yes             31.0      Performed
# 1              Yes              Yes             25.0      Performed
# 2              Yes              Yes             21.0  Not Performed
# 3               No               No             20.0  Not Performed
# 4              Yes              Yes              0.0      Performed
#
#   HAEMOSTATICAGENTS HAEMOSTATICDetails LYMPHNODEDISSECTIONLND  BLOODLOSSml  \
# 0               Yes           Surgiflo          Not Performed         50.0
# 1               Yes           surgicel              Performed        100.0
# 2                No                NaN          Not Performed        300.0
# 3                No                NaN          Not Performed         75.0
# 4               Yes           surgicel          Not Performed         40.0
#
#   INTRAOPTRANSUFUSION                    SURGICALCONSIDERATIONS  \
# 0                  No                                       NaN
# 1                  No  single kidney - tertiary artery clamping
# 2                  No                                       NaN
# 3                  No                                       NaN
# 4                  No                           supra selective
#
#   INTRAOPCOMPLICATION INTRAOPCOMPLICATIONS NeedtoConverttoRadicalNephrectomy  \
# 0                  No                  nan                                No
# 1                  No                  nan                                No
# 2                  No                  nan                                No
# 3                  No                  nan                                No
# 4                  No                  nan                                No
#
#   TREATMENTOFCOMPLICATION POSTOPCOMPLICATION SURGICALCOMPLICATIONS  \
# 0                     NaN      Complications                   NaN
# 1                     NaN   No Complications                   320
# 2                     NaN      Complications                   319
# 3                     NaN      Complications                   314
# 4                     NaN   No Complications                   314
#
#   NONSURGICALCOMPLICATIONS                     POSTOPTREATMENTOFCOMPLICATION  \
# 0                  321,323  IV antibiotics, discharged with oral antibiotics
# 1                      321                                               NaN
# 2                      321                            Conservative treatment
# 3                      321                                               NaN
# 4                      321                                               NaN
#
#                                         CLAVIENGRADE       POSTOPHB_Day1  \
# 0  Grade 2: Complications needing only use of int...  13.699999999999999
# 1  Grade 1: Any deviation from the normal postope...                  12
# 2               Grade 0: Absence of any complication                 999
# 3  Grade 1: Any deviation from the normal postope...                10.9
# 4               Grade 0: Absence of any complication                  12
#
#   POSTOPHT_Day1 POSTOPCreat_Day1 POSTOPEGFR_Day1 POSTOPWBC_Day1 POSTOPHB_Day2  \
# 0            45             1.14              63          12900           999
# 1            32              1.3              49           8000          12.2
# 2           999              999             999            999          11.8
# 3          39.9              0.9             110           9800          14.1
# 4            35              1.3              37           7200           999
#
#   POSTOPHT_Day2 POSTOPCreat_Day2 POSTOPEGFR_Day2 POSTOPWBC_Day2 POSTOPHB_Day3  \
# 0           999              999             999            NaN            13
# 1          39.7              1.2              78           9050           999
# 2            36              1.1              80           4588          11.6
# 3          42.3             1.13              75          14560           999
# 4           999              999             999            NaN           999
#
#   POSTOPHT_Day3 POSTOPCreat_Day3 POSTOPEGFR_Day3 POSTOPWBC_Day3  \
# 0            35              0,9              61           4300
# 1           999              999             999            999
# 2           999             0.81              70           9540
# 3          37.1             1.04            55.1           5470
# 4           999              999             999            999
#
#    LENGTHOFSTAYdays  PATHOLOGICALTUMORSIZE  MINTHICKNESSMARGIN  \
# 0               5.0                    8.0                 NaN
# 1               2.0                    3.5                 1.0
# 2               6.0                    NaN                 NaN
# 3               5.0                    3.0               999.0
# 4               4.0                   25.0                 5.0
#
#    MAXTHICKNESSMARGIN MULITIFOCALITY PATHOLOGY HYSTOTYPEMALIGNANAT  \
# 0                 NaN         Absent    Benign                  No
# 1                 3.0         Absent    Malign                 Yes
# 2                 NaN            NaN       NaN                 NaN
# 3               999.0         Absent    Malign                 Yes
# 4                 NaN         Absent    Malign                 Yes
#
#             HYSTOTYPEMALIGNANATYES HYSTOTYPEBENIGN HYSTOTYPEBENIGNYES  \
# 0                              NaN             Yes     Angiomyolipoma
# 1  Clear cell renal cell carcinoma              No                NaN
# 2                              NaN             NaN                NaN
# 3  Clear cell renal cell carcinoma              No                NaN
# 4  Clear cell renal cell carcinoma             NaN                NaN
#
#    FUHRMANGRADING SARCOMATOIDDIFF  SARCOMATOIDDIFF_A NECROSIS  \
# 0             NaN          Absent                NaN   Absent
# 1             1.0          Absent                0.0   Absent
# 2             NaN             NaN                NaN      NaN
# 3             3.0          Absent                NaN   Absent
# 4             2.0          Absent                NaN   Absent
#
#   MICROVENOUSINVASION UCSINVASION_A PERIRENALFATINVASION HilarFatInvasion  \
# 0              Absent        Absent               Absent           Absent
# 1              Absent        Absent               Absent           Absent
# 2                 NaN           NaN                  NaN              NaN
# 3              Absent        Absent               Absent           Absent
# 4              Absent        Absent               Absent           Absent
#
#   SINUSFATINVASION  MICSCORE ADRENALINVASION GEROTAINVASION RenalVeinInvasion  \
# 0           Absent       0.0          Absent         Absent            Absent
# 1           Absent       0.0          Absent         Absent            Absent
# 2              NaN       NaN             NaN            NaN               NaN
# 3           Absent       0.0          Absent         Absent            Absent
# 4           Absent       0.0          Absent         Absent            Absent
#
#   VENOUSTHROMBUS SURGICALMARGIN UNIFOCALMULTIFOCAL  NO_OF_NODE_TAKEN  \
# 0         Absent       Negative                NaN               NaN
# 1         Absent       Negative                NaN               0.0
# 2            NaN            NaN                NaN               NaN
# 3         Absent       Negative                NaN               0.0
# 4         Absent       Negative                NaN               NaN
#
#   NO_OF_NODE_POSITIVE SITEOFPOSITIVENODE    TREATMENTPSM      PT   PN  \
# 0                 NaN                NaN  Wait and Watch  Benign  NaN
# 1                   0     Not Applicable             NaN     T1a   Nx
# 2                 NaN                NaN             NaN     NaN  NaN
# 3                 NaN                NaN  Wait and Watch     T1a   Nx
# 4                 NaN                NaN             NaN     T1a   Nx
#
#   OTHERTUMORS DATEOFRECURRENCE  LASTFOLLOWUPDURATION TIMETORECURRENCE  \
# 0         NaN              NaN                   NaN              NaN
# 1         NaN              NaN                   NaN              NaN
# 2         NaN              NaN                   NaN              NaN
# 3         NaN              NaN                   NaN              NaN
# 4         NaN              NaN                   NaN              NaN
#
#   LASTFOLLOWUPSTATUS LASTFOLLOWUPRECURRENCE LASTTREATMENTOFRECURRENCE  \
# 0                NaN                    NaN                       NaN
# 1                NaN                    NaN                       NaN
# 2                NaN                    NaN                       NaN
# 3                NaN                    NaN                       NaN
# 4                NaN                    NaN                       NaN
#
#   TYPEOFCOMPLICATIONSs SELECTEDSURGICALCOMPLICATIONSs  \
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2                  NaN                            NaN
# 3                  NaN                            NaN
# 4                  NaN                            NaN
#
#   SELECTEDNONSURGICALCOMPLICATIONSs TREATMENTOFCOMPLICATIONSs RECURRENCEs  \
# 0                               NaN                       NaN         NaN
# 1                               NaN                       NaN         NaN
# 2                               NaN                       NaN         NaN
# 3                               NaN                       NaN         NaN
# 4                               NaN                       NaN         NaN
#
#   FOLLOWUPDATEs STATUSs TREATMENTs CREATININEs EGFRs SRFs ERPFs    Year
# 0           NaN     NaN        NaN         NaN   NaN  NaN   NaN  2018.0
# 1           NaN     NaN        NaN         NaN   NaN  NaN   NaN  2018.0
# 2           NaN     NaN        NaN         NaN   NaN  NaN   NaN  2018.0
# 3           NaN     NaN        NaN         NaN   NaN  NaN   NaN  2018.0
# 4           NaN     NaN        NaN         NaN   NaN  NaN   NaN  2018.0

# %%
df.info(verbose = True, null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3385 entries, 0 to 3384
# Data columns (total 161 columns):
# PATIENTNUMBER                         3385 non-null object
# PROCNAME                              3385 non-null object
# CENTERCODE                            3385 non-null object
# SURGEONCODE                           939 non-null object
# RECPROGRESS                           3385 non-null object
# CREATEDDATE                           3385 non-null object
# GENDER                                3374 non-null object
# DATEOFBIRTH                           2019 non-null float64
# AGEATSURGERY                          3366 non-null float64
# MARITALSTATUS                         2150 non-null object
# RACE                                  2089 non-null object
# EDUCATION                             1917 non-null object
# WEIGHT                                2353 non-null float64
# HEIGHT                                2351 non-null float64
# BMI                                   2999 non-null float64
# CLINICALSIZEmm                        3188 non-null float64
# ECOG                                  1813 non-null object
# CHARLSONSCORE                         2806 non-null float64
# CHARLSONAGEADJUSTSCORE                2767 non-null float64
# SYMPTOMS                              2559 non-null object
# SOLITARYKIDNEY                        2860 non-null object
# TYPEOFSOLITARYKIDNEY                  116 non-null object
# BILATERALITYOFTUMOR                   2063 non-null object
# SIDEOFTUMOR                           2310 non-null object
# SIDEOFSURGERY                         3371 non-null object
# PREOPMULTIFOCALITY                    967 non-null object
# FACE                                  2514 non-null object
# TUMORlOCATION                         2869 non-null object
# PREOPHB                               2542 non-null float64
# PREOPHT                               2416 non-null float64
# PREOPWBC                              2111 non-null float64
# PREOPCREAT                            3321 non-null float64
# PREOPGFR                              244 non-null object
# PREOPEGFR                             2647 non-null float64
# PREOPERPF                             184 non-null object
# PADUASCORE                            2142 non-null float64
# PADUARISK                             2085 non-null object
# POLARLOCATION                         2630 non-null object
# RIMLOCATION                           2011 non-null object
# RENALSINUS                            2107 non-null object
# UCSINVASION                           2119 non-null object
# EXOPHYTICRATE                         2456 non-null object
# CLINICALSIZEGROUP                     2777 non-null object
# CT                                    2959 non-null object
# CN                                    2646 non-null object
# CM                                    2020 non-null object
# R.E.N.A.L.NEPHROSCORE                 2709 non-null object
# R.E.N.A.L.NEPHRORISKSTRATIFICATION    2560 non-null object
# RADIUSmaximaldiameterincm             2992 non-null object
# EXOPHYTICENDOPHYTICPROPERTIES         2418 non-null object
# NEARNESSOFTUMOUR                      2298 non-null object
# ANTERIORORPOSTERIOR                   2670 non-null object
# LOCATIONTOPOLARLINE                   2004 non-null float64
# TumorConsistencyonImaging             592 non-null object
# BosniakClassification                 587 non-null object
# DATEOFSURGERY                         3384 non-null object
# ASASCORE                              2923 non-null object
# PARTIALNEPHROINDICATION               2465 non-null object
# MULTIFOCALITY                         2050 non-null object
# NOOFLESIONS                           2778 non-null float64
# ImagingFeaturesofotherexcisedtumor    75 non-null object
# Consistencyoftheotherexcisedtumors    371 non-null object
# ACCESS                                2503 non-null object
# DAVINCIMODEL                          2210 non-null object
# ROBOTICSARMS                          2922 non-null object
# ASSISTENTTROCARS                      2705 non-null object
# DUALCONSOLE                           2466 non-null object
# PRIMARYSURGEON                        2041 non-null object
# OPERATIVETIMEmin                      3072 non-null object
# ISCHEMIA                              2800 non-null object
# CLAMPARTERY                           2795 non-null object
# SELECTIVEARTERIALCLAMPING             2048 non-null object
# CLAMPVEIN                             2583 non-null object
# EARLYUNCLAMPING                       2570 non-null object
# FLUORESCENCE                          2467 non-null object
# INNERRENORRHAPHY                      2050 non-null object
# OUTERRENORRHAPHY                      2049 non-null object
# ISCHEMIATIMEmin                       3120 non-null float64
# UCSREPAIR                             2430 non-null object
# HAEMOSTATICAGENTS                     2456 non-null object
# HAEMOSTATICDetails                    1746 non-null object
# LYMPHNODEDISSECTIONLND                2466 non-null object
# BLOODLOSSml                           3262 non-null float64
# INTRAOPTRANSUFUSION                   2701 non-null object
# SURGICALCONSIDERATIONS                207 non-null object
# INTRAOPCOMPLICATION                   2955 non-null object
# INTRAOPCOMPLICATIONS                  3385 non-null object
# NeedtoConverttoRadicalNephrectomy     916 non-null object
# TREATMENTOFCOMPLICATION               573 non-null object
# POSTOPCOMPLICATION                    2831 non-null object
# SURGICALCOMPLICATIONS                 112 non-null object
# NONSURGICALCOMPLICATIONS              73 non-null object
# POSTOPTREATMENTOFCOMPLICATION         538 non-null object
# CLAVIENGRADE                          2401 non-null object
# POSTOPHB_Day1                         1391 non-null object
# POSTOPHT_Day1                         1484 non-null object
# POSTOPCreat_Day1                      2398 non-null object
# POSTOPEGFR_Day1                       2067 non-null object
# POSTOPWBC_Day1                        1081 non-null object
# POSTOPHB_Day2                         844 non-null object
# POSTOPHT_Day2                         910 non-null object
# POSTOPCreat_Day2                      1065 non-null object
# POSTOPEGFR_Day2                       921 non-null object
# POSTOPWBC_Day2                        777 non-null object
# POSTOPHB_Day3                         779 non-null object
# POSTOPHT_Day3                         824 non-null object
# POSTOPCreat_Day3                      994 non-null object
# POSTOPEGFR_Day3                       793 non-null object
# POSTOPWBC_Day3                        772 non-null object
# LENGTHOFSTAYdays                      3176 non-null float64
# PATHOLOGICALTUMORSIZE                 2931 non-null float64
# MINTHICKNESSMARGIN                    1524 non-null float64
# MAXTHICKNESSMARGIN                    649 non-null float64
# MULITIFOCALITY                        2562 non-null object
# PATHOLOGY                             3240 non-null object
# HYSTOTYPEMALIGNANAT                   3324 non-null object
# HYSTOTYPEMALIGNANATYES                2609 non-null object
# HYSTOTYPEBENIGN                       3294 non-null object
# HYSTOTYPEBENIGNYES                    641 non-null object
# FUHRMANGRADING                        2760 non-null float64
# SARCOMATOIDDIFF                       2279 non-null object
# SARCOMATOIDDIFF_A                     1398 non-null float64
# NECROSIS                              2417 non-null object
# MICROVENOUSINVASION                   2482 non-null object
# UCSINVASION_A                         2376 non-null object
# PERIRENALFATINVASION                  2787 non-null object
# HilarFatInvasion                      1056 non-null object
# SINUSFATINVASION                      2377 non-null object
# MICSCORE                              2438 non-null float64
# ADRENALINVASION                       2237 non-null object
# GEROTAINVASION                        2300 non-null object
# RenalVeinInvasion                     917 non-null object
# VENOUSTHROMBUS                        2352 non-null object
# SURGICALMARGIN                        3133 non-null object
# UNIFOCALMULTIFOCAL                    79 non-null object
# NO_OF_NODE_TAKEN                      2025 non-null float64
# NO_OF_NODE_POSITIVE                   1219 non-null object
# SITEOFPOSITIVENODE                    808 non-null object
# TREATMENTPSM                          309 non-null object
# PT                                    2907 non-null object
# PN                                    2418 non-null object
# OTHERTUMORS                           15 non-null object
# DATEOFRECURRENCE                      24 non-null object
# LASTFOLLOWUPDURATION                  1902 non-null float64
# TIMETORECURRENCE                      199 non-null object
# LASTFOLLOWUPSTATUS                    1525 non-null object
# LASTFOLLOWUPRECURRENCE                1451 non-null object
# LASTTREATMENTOFRECURRENCE             462 non-null object
# TYPEOFCOMPLICATIONSs                  2807 non-null object
# SELECTEDSURGICALCOMPLICATIONSs        2807 non-null object
# SELECTEDNONSURGICALCOMPLICATIONSs     2807 non-null object
# TREATMENTOFCOMPLICATIONSs             2807 non-null object
# RECURRENCEs                           2807 non-null object
# FOLLOWUPDATEs                         2807 non-null object
# STATUSs                               2807 non-null object
# TREATMENTs                            2807 non-null object
# CREATININEs                           2807 non-null object
# EGFRs                                 2807 non-null object
# SRFs                                  2807 non-null object
# ERPFs                                 2807 non-null object
# Year                                  3382 non-null float64
# dtypes: float64(28), object(133)
# memory usage: 4.2+ MB

# %%
# Prepare target variable for INTRA OP complications
df['INTRA_OP_COMPLICATIONS'] = 0

# selecting indicator == 'Yes' and code vailability or Intra-op Bloos transfusion>1 unit as Intra-op complication
df.loc[((df['INTRAOPCOMPLICATIONS']!='nan') & (df['INTRAOPCOMPLICATION'] == 'Yes'))|(df['INTRAOPTRANSUFUSION']=='>1 Unit') ,['INTRA_OP_COMPLICATIONS']] = 1
num_complications = df['INTRA_OP_COMPLICATIONS'].sum()

# %%
# Total Number patients with complications
print('Total number of patients {}'.format(len(df)))
print('Total number of patients with complications {}'.format(num_complications))
print('Total % of patients with complications {:.3f}'.format(num_complications/len(df)))
# Out:
# Total number of patients 3385
# Total number of patients with complications 126
# Total % of patients with complications 0.037

# %% [markdown]
# ### Define numeric columns and replace encoded missing values with NaN

# %%
# List of columns tobre converted to numeric
numeric_col_list = ['AGEATSURGERY',
'WEIGHT',
'HEIGHT',
'BMI',
'CLINICALSIZEmm',
'PREOPHB',
'PREOPHT',
'PREOPWBC',
'PREOPCREAT',
'PREOPGFR',
'PREOPEGFR',
'PREOPERPF',
'NOOFLESIONS',
'BLOODLOSSml',
'POSTOPHB_Day1',
'POSTOPHT_Day1',
'POSTOPCreat_Day1',
'POSTOPEGFR_Day1',
'POSTOPWBC_Day1',
'POSTOPHB_Day2',
'POSTOPHT_Day2',
'POSTOPCreat_Day2',
'POSTOPEGFR_Day2',
'POSTOPWBC_Day2',
'POSTOPHB_Day3',
'POSTOPHT_Day3',
'POSTOPCreat_Day3',
'POSTOPEGFR_Day3',
'POSTOPWBC_Day3',
'LENGTHOFSTAYdays',
'PATHOLOGICALTUMORSIZE',
'MINTHICKNESSMARGIN',
'MAXTHICKNESSMARGIN',
'SARCOMATOIDDIFF_A',
'NO_OF_NODE_TAKEN',
'LASTFOLLOWUPDURATION',
'CHARLSONSCORE',
'CHARLSONAGEADJUSTSCORE',
'PADUASCORE',
]

# %%
# Convert columns in numeric_col_list to numeric and invalid values are set NaN 
for col in numeric_col_list:
    df[col]= pd.to_numeric(df[col], errors='coerce')

# %%
# Summary of numeric columns
df.describe(include = [np.number]).round(2)
# Out:
#        DATEOFBIRTH  AGEATSURGERY   WEIGHT   HEIGHT      BMI  CLINICALSIZEmm  \
# count      2019.00       3366.00  2353.00  2351.00  2999.00         3188.00
# mean       1956.31         57.72    89.96   163.93    28.67           34.45
# std          13.24         12.71    56.04    39.77     5.92           37.90
# min        1921.00         16.00     7.71     1.70    15.10            0.00
# 25%        1947.00         49.00    69.00   160.00    24.58           22.00
# 50%        1956.00         59.00    79.60   169.00    27.54           30.00
# 75%        1965.00         67.00    93.00   176.00    31.70           42.00
# max        1998.00         89.00   999.00   999.00    55.60          999.00
#
#        CHARLSONSCORE  CHARLSONAGEADJUSTSCORE  PREOPHB  PREOPHT  PREOPWBC  \
# count        2806.00                 2767.00  2542.00  2416.00   2111.00
# mean            1.52                    3.52    20.38    46.64   7217.03
# std             2.00                    2.28    80.33   102.27   3351.87
# min             0.00                    0.00     3.80     0.24      0.00
# 25%             0.00                    2.00    12.90    36.00   5600.00
# 50%             1.00                    3.00    13.90    40.80   7000.00
# 75%             2.00                    5.00    14.90    44.00   8500.00
# max            19.00                   18.00   999.00   999.00  56000.00
#
#        PREOPCREAT  PREOPGFR  PREOPEGFR  PREOPERPF  PADUASCORE  \
# count     3321.00    152.00    2647.00     177.00     2142.00
# mean         4.41    586.08      80.38     730.84        8.40
# std         57.44    466.89      30.42     396.76        1.74
# min          0.00     18.00       0.02      43.50        2.00
# 25%          0.78     66.50      65.27     210.00        7.00
# 50%          0.91    999.00      79.33     999.00        8.00
# 75%          1.10    999.00      94.00     999.00       10.00
# max        999.00    999.00     999.00     999.00       14.00
#
#        LOCATIONTOPOLARLINE  NOOFLESIONS  ISCHEMIATIMEmin  BLOODLOSSml  \
# count              2004.00      2778.00          3120.00      3262.00
# mean                  1.89         1.06            19.87       184.16
# std                   0.82         0.29            36.67       222.27
# min                   1.00         0.00             0.00         0.00
# 25%                   1.00         1.00            14.00        50.00
# 50%                   2.00         1.00            18.00       100.00
# 75%                   3.00         1.00            23.00       200.00
# max                   3.00         6.00           999.00      3500.00
#
#        POSTOPHB_Day1  POSTOPHT_Day1  POSTOPCreat_Day1  POSTOPEGFR_Day1  \
# count        1297.00        1447.00           2357.00          1828.00
# mean           49.77          59.49             19.53            97.97
# std           179.21         167.00            133.63           170.22
# min             1.00           0.27              0.00             4.00
# 25%            11.00          30.40              0.96            52.64
# 50%            12.10          35.00              1.00            65.00
# 75%            13.30          38.30              1.30            81.00
# max           999.00         999.00            999.00           999.00
#
#        POSTOPWBC_Day1  POSTOPHB_Day2  POSTOPHT_Day2  POSTOPCreat_Day2  \
# count          943.00         570.00         611.00            794.00
# mean          1980.31         164.80         163.25            108.24
# std           4249.18         350.43         338.85            308.68
# min              3.60           0.00           0.00              0.00
# 25%              9.16          10.90          27.20              0.91
# 50%             11.60          12.20          34.20              1.17
# 75%             18.75          14.48          40.55              1.57
# max          19610.00         999.00         999.00            999.00
#
#        POSTOPEGFR_Day2  POSTOPWBC_Day2  POSTOPHB_Day3  POSTOPHT_Day3  \
# count           581.00          492.00         439.00         449.00
# mean            213.41         2805.69         230.31         270.17
# std             344.00         4982.11         409.95         421.08
# min               0.00            2.10           0.00           0.00
# 25%              49.72            9.50          10.70          29.00
# 50%              67.67           12.00          12.20          35.20
# 75%              94.97         4990.00          14.15         332.00
# max             999.00        27780.00         999.00         999.00
#
#        POSTOPCreat_Day3  POSTOPEGFR_Day3  POSTOPWBC_Day3  LENGTHOFSTAYdays  \
# count            653.00           410.00          429.00           3176.00
# mean             144.80           291.49         2760.82              3.82
# std              350.55           400.93         4142.01             25.11
# min                0.00             0.00            2.60              0.00
# 25%                0.90            55.66            9.10              2.00
# 50%                1.12            74.32          999.00              3.00
# 75%                1.54           130.98         4300.00              4.00
# max              999.00           999.00        16060.00            999.00
#
#        PATHOLOGICALTUMORSIZE  MINTHICKNESSMARGIN  MAXTHICKNESSMARGIN  \
# count                2931.00             1524.00              649.00
# mean                   10.88               73.43              194.07
# std                    23.71              253.37              386.00
# min                     0.00                0.00                0.00
# 25%                     2.40                1.00                2.00
# 50%                     3.60                2.00                5.00
# 75%                     8.25                5.00               25.00
# max                   999.00              999.00              999.00
#
#        FUHRMANGRADING  SARCOMATOIDDIFF_A  MICSCORE  NO_OF_NODE_TAKEN  \
# count         2760.00            1398.00   2438.00           2025.00
# mean           133.98              15.11      0.28              1.09
# std            337.75             143.21      0.45             31.39
# min              1.00            -999.00      0.00              0.00
# 25%              2.00               0.00      0.00              0.00
# 50%              2.00               0.00      0.00              0.00
# 75%              3.00               0.00      1.00              0.00
# max            999.00             999.00      1.00            999.00
#
#        LASTFOLLOWUPDURATION     Year  INTRA_OP_COMPLICATIONS
# count               1902.00  3382.00                 3385.00
# mean                  16.94  2013.33                    0.04
# std                   19.61     2.98                    0.19
# min                    0.00  2006.00                    0.00
# 25%                    3.00  2011.00                    0.00
# 50%                   10.00  2013.00                    0.00
# 75%                   24.00  2016.00                    0.00
# max                  101.00  2018.00                    1.00

# %%
#replace missing values such as 999 in the dataframe with NaN
df = df.replace([99,999,9999,99999,999999,-99,-999,-9999,-99999,-999999],np.nan)

# %%
# replacing negative numbers in the dataframe with nan as given variables cannot contain negative numbers
for col in list(df.select_dtypes('float64')):
    df[col] = df[col].apply(lambda x: np.nan if x<0 else x)

# %%
# Summary of numeric columns - to check missing values such as 99, 999, 999 have been replaced
df.describe(include = [np.number]).round(2)
# Out:
#        DATEOFBIRTH  AGEATSURGERY   WEIGHT   HEIGHT      BMI  CLINICALSIZEmm  \
# count      2019.00       3366.00  2343.00  2348.00  2999.00         3184.00
# mean       1956.31         57.72    88.00   162.86    28.67           33.24
# std          13.24         12.71    37.22    26.29     5.92           16.36
# min        1921.00         16.00     7.71     1.70    15.10            0.00
# 25%        1947.00         49.00    69.00   160.00    24.58           22.00
# 50%        1956.00         59.00    79.40   169.00    27.54           30.00
# 75%        1965.00         67.00    93.00   176.00    31.70           42.00
# max        1998.00         89.00   377.00   208.30    55.60          135.00
#
#        CHARLSONSCORE  CHARLSONAGEADJUSTSCORE  PREOPHB  PREOPHT  PREOPWBC  \
# count        2806.00                 2767.00  2525.00  2389.00   2088.00
# mean            1.52                    3.52    13.79    35.88   7285.53
# std             2.00                    2.28     1.75    14.41   3305.76
# min             0.00                    0.00     3.80     0.24      0.00
# 25%             0.00                    2.00    12.80    36.00   5600.00
# 50%             1.00                    3.00    13.90    40.70   7000.00
# 75%             2.00                    5.00    14.90    44.00   8510.00
# max            19.00                   18.00    39.60    88.00  56000.00
#
#        PREOPCREAT  PREOPGFR  PREOPEGFR  PREOPERPF  PADUASCORE  \
# count     3310.00     67.00    2631.00      56.00     2142.00
# mean         1.11     62.23      79.93     151.44        8.40
# std          3.27     23.65      24.65      61.02        1.74
# min          0.00     18.00       0.02      43.50        2.00
# 25%          0.78     42.00      65.00     110.00        7.00
# 50%          0.91     58.00      79.07     132.00        8.00
# 75%          1.10     83.00      93.60     182.50       10.00
# max         96.00    124.00     253.97     340.00       14.00
#
#        LOCATIONTOPOLARLINE  NOOFLESIONS  ISCHEMIATIMEmin  BLOODLOSSml  \
# count              2004.00      2778.00          3116.00      3259.00
# mean                  1.89         1.06            18.61       183.41
# std                   0.82         0.29            10.66       220.99
# min                   1.00         0.00             0.00         0.00
# 25%                   1.00         1.00            14.00        50.00
# 50%                   2.00         1.00            18.00       100.00
# 75%                   3.00         1.00            23.00       200.00
# max                   3.00         6.00           320.00      3500.00
#
#        POSTOPHB_Day1  POSTOPHT_Day1  POSTOPCreat_Day1  POSTOPEGFR_Day1  \
# count        1253.00        1403.00           2314.00          1761.00
# mean           16.44          30.03              1.33            66.25
# std            21.65          13.90              4.60            21.75
# min             1.00           0.27              0.00             4.00
# 25%            11.00          30.15              0.95            52.00
# 50%            12.00          34.90              1.00            64.00
# 75%            13.20          38.00              1.29            79.00
# max           162.00          96.80            143.00           198.30
#
#        POSTOPWBC_Day1  POSTOPHB_Day2  POSTOPHT_Day2  POSTOPCreat_Day2  \
# count          896.00         485.00         525.00            709.00
# mean          2031.78          18.60          26.34              1.45
# std           4353.21          27.08          15.71              6.51
# min              3.60           0.00           0.00              0.00
# 25%              9.10          10.70           1.46              0.90
# 50%             11.30          11.90          32.70              1.10
# 75%             15.80          13.10          36.90              1.40
# max          19610.00         152.00          51.00            174.00
#
#        POSTOPEGFR_Day2  POSTOPWBC_Day2  POSTOPHB_Day3  POSTOPHT_Day3  \
# count           484.00          466.00         342.00         337.00
# mean             63.41         2906.49          12.30          27.95
# std              24.83         5100.64          10.87          22.37
# min               0.00            2.10           0.00           0.00
# 25%              47.22            9.30          10.40          25.70
# 50%              62.80           11.60          11.70          32.80
# 75%              79.00         5635.00          12.70          37.00
# max             157.70        27780.00         131.00         332.00
#
#        POSTOPCreat_Day3  POSTOPEGFR_Day3  POSTOPWBC_Day3  LENGTHOFSTAYdays  \
# count            559.00           308.00          333.00           3174.00
# mean               1.15            65.96         3268.74              3.19
# std                0.56            36.50         4578.29              2.47
# min                0.00             0.00            2.60              0.00
# 25%                0.86            49.92            8.50              2.00
# 50%                1.07            65.00           11.80              3.00
# 75%                1.27            79.25         6940.00              4.00
# max                5.80           543.00        16060.00             51.00
#
#        PATHOLOGICALTUMORSIZE  MINTHICKNESSMARGIN  MAXTHICKNESSMARGIN  \
# count                2930.00             1416.00              527.00
# mean                   10.54                4.10               11.14
# std                    15.12               10.43               46.67
# min                     0.00                0.00                0.00
# 25%                     2.40                1.00                1.90
# 50%                     3.60                2.00                3.00
# 75%                     8.20                4.00                8.00
# max                   115.00              240.00              979.00
#
#        FUHRMANGRADING  SARCOMATOIDDIFF_A  MICSCORE  NO_OF_NODE_TAKEN  \
# count         2395.00            1366.00   2438.00           2023.00
# mean             2.15               0.12      0.28              0.11
# std              0.67               2.29      0.45              0.64
# min              1.00               0.00      0.00              0.00
# 25%              2.00               0.00      0.00              0.00
# 50%              2.00               0.00      0.00              0.00
# 75%              3.00               0.00      1.00              0.00
# max              4.00              70.00      1.00             12.00
#
#        LASTFOLLOWUPDURATION     Year  INTRA_OP_COMPLICATIONS
# count               1902.00  3382.00                 3385.00
# mean                  16.94  2013.33                    0.04
# std                   19.61     2.98                    0.19
# min                    0.00  2006.00                    0.00
# 25%                    3.00  2011.00                    0.00
# 50%                   10.00  2013.00                    0.00
# 75%                   24.00  2016.00                    0.00
# max                  101.00  2018.00                    1.00

# %%
# Correcting the units for erroroneously entered data
def clean_WBC(x):
    if len(str(x))<6:
        x = x*1000
    return x
        

# if the value of PRE-OP WBC value contains is less the 4 digits then multiply it by 1000
df['PREOPWBC'] = df['PREOPWBC'].apply(lambda x: clean_WBC(x))

# if the value of POST-OP WBC_Day 1 value contains is less the 4 digits then multiply it by 1000
df['POSTOPWBC_Day1'] = df['POSTOPWBC_Day1'].apply(lambda x: clean_WBC(x))

# if the value of POST-OP WBC_Day 2 value contains is less the 4 digits then multiply it by 1000
df['POSTOPWBC_Day2'] = df['POSTOPWBC_Day2'].apply(lambda x: clean_WBC(x))

# if the value of POST-OP WBC_Day 2 value contains is less the 4 digits then multiply it by 1000
df['POSTOPWBC_Day3'] = df['POSTOPWBC_Day3'].apply(lambda x: clean_WBC(x))

# %%
# Correcting the units for erroroneously entered data for PREOPHB
df['PREOPHB'] = df['PREOPHB'].apply(lambda x: x*100 if x<10 else x)

# Correcting the units for erroroneously entered data for PREOPHB
df['PREOPHT'] = df['PREOPHT'].apply(lambda x: x*100 if x<10 else x)

# %% [markdown]
# ### Define Categorical columns

# %%
cat_col = ['PROCNAME',
'CENTERCODE',
'SURGEONCODE',
'RECPROGRESS',
'GENDER',
'MARITALSTATUS',
'RACE',
'EDUCATION',
'ECOG',
'SYMPTOMS',
'SOLITARYKIDNEY',
'TYPEOFSOLITARYKIDNEY',
'BILATERALITYOFTUMOR',
'SIDEOFTUMOR',
'SIDEOFSURGERY',
'PREOPMULTIFOCALITY',
'FACE',
'TUMORlOCATION',

'PADUARISK',
'POLARLOCATION',
'RIMLOCATION',
'RENALSINUS',
'UCSINVASION',
'EXOPHYTICRATE',
'CLINICALSIZEGROUP',
'CT',
'CN',
'CM',
'R.E.N.A.L.NEPHROSCORE',
'R.E.N.A.L.NEPHRORISKSTRATIFICATION',
'RADIUSmaximaldiameterincm',
'EXOPHYTICENDOPHYTICPROPERTIES',
'NEARNESSOFTUMOUR',
'ANTERIORORPOSTERIOR',
'LOCATIONTOPOLARLINE',
'TumorConsistencyonImaging',
'BosniakClassification',
'ASASCORE',
'PARTIALNEPHROINDICATION',
'MULTIFOCALITY',
'ImagingFeaturesofotherexcisedtumor',
'Consistencyoftheotherexcisedtumors',
'ACCESS',
'DAVINCIMODEL',
'ROBOTICSARMS',
'ASSISTENTTROCARS',
'DUALCONSOLE',
'PRIMARYSURGEON',
'ISCHEMIA',
'CLAMPARTERY',
'SELECTIVEARTERIALCLAMPING',
'CLAMPVEIN',
'EARLYUNCLAMPING',
'FLUORESCENCE',
'INNERRENORRHAPHY',
'OUTERRENORRHAPHY',
'UCSREPAIR',
'HAEMOSTATICAGENTS',
'HAEMOSTATICDetails',
'LYMPHNODEDISSECTIONLND',
'INTRAOPTRANSUFUSION',
'SURGICALCONSIDERATIONS',
'INTRAOPCOMPLICATION',
'INTRAOPCOMPLICATIONS',
'NeedtoConverttoRadicalNephrectomy',
'TREATMENTOFCOMPLICATION',
'POSTOPCOMPLICATION',
'SURGICALCOMPLICATIONS',
'NONSURGICALCOMPLICATIONS',
'POSTOPTREATMENTOFCOMPLICATION',
'CLAVIENGRADE',
'MULITIFOCALITY',
'PATHOLOGY',
'HYSTOTYPEMALIGNANAT',
'HYSTOTYPEMALIGNANATYES',
'HYSTOTYPEBENIGN',
'HYSTOTYPEBENIGNYES',
'FUHRMANGRADING',
'SARCOMATOIDDIFF',
'NECROSIS',
'MICROVENOUSINVASION',
'UCSINVASION_A',
'PERIRENALFATINVASION',
'HilarFatInvasion',
'SINUSFATINVASION',
'MICSCORE',
'ADRENALINVASION',
'GEROTAINVASION',
'RenalVeinInvasion',
'VENOUSTHROMBUS',
'SURGICALMARGIN',
'UNIFOCALMULTIFOCAL',
'NO_OF_NODE_POSITIVE',
'SITEOFPOSITIVENODE',
'TREATMENTPSM',
'PT',
'PN',
'OTHERTUMORS',
'LASTFOLLOWUPSTATUS',
'LASTFOLLOWUPRECURRENCE',
'LASTTREATMENTOFRECURRENCE'
]

# %% [markdown]
# ### Select Variables for analysis

# %%
# list of variables included for Intra-Op complications 
intra_op_col = [
'PATIENTNUMBER',
#'PROCNAME',
'CENTERCODE',
#'SURGEONCODE',
#'RECPROGRESS',
#'CREATEDDATE',
'GENDER',
#'DATEOFBIRTH',
'AGEATSURGERY',
'MARITALSTATUS',
'RACE',
'EDUCATION',
#'WEIGHT',
#'HEIGHT',
'BMI',
'CLINICALSIZEmm',
'ECOG',
'CHARLSONSCORE',
#'CHARLSONAGEADJUSTSCORE',
'SYMPTOMS',
'SOLITARYKIDNEY',
'TYPEOFSOLITARYKIDNEY',
'BILATERALITYOFTUMOR',
'SIDEOFTUMOR',
'SIDEOFSURGERY',
'PREOPMULTIFOCALITY',
'FACE',
'TUMORlOCATION',
'PREOPHB',
'PREOPHT',
'PREOPWBC',
'PREOPCREAT',
'PREOPGFR',
'PREOPEGFR',
'PREOPERPF',
#'PADUASCORE',
'PADUARISK',
'POLARLOCATION',
'RIMLOCATION',
'RENALSINUS',
#'UCSINVASION',
'EXOPHYTICRATE',
'CLINICALSIZEGROUP',
'CT',
'CN',
'CM',
#'R.E.N.A.L.NEPHROSCORE',
'R.E.N.A.L.NEPHRORISKSTRATIFICATION',
'RADIUSmaximaldiameterincm',
'EXOPHYTICENDOPHYTICPROPERTIES',
'NEARNESSOFTUMOUR',
'ANTERIORORPOSTERIOR',
'LOCATIONTOPOLARLINE',
'TumorConsistencyonImaging',
'BosniakClassification',
#'DATEOFSURGERY',
'ASASCORE',
'PARTIALNEPHROINDICATION',
'MULTIFOCALITY',
'NOOFLESIONS',
#'ImagingFeaturesofotherexcisedtumor', #too many categories
#'Consistencyoftheotherexcisedtumors',
#'ACCESS',
#'DAVINCIMODEL',
#'ROBOTICSARMS',
#'ASSISTENTTROCARS',
#'DUALCONSOLE',
#'PRIMARYSURGEON',
#'OPERATIVETIMEmin',
#'ISCHEMIA',
#'CLAMPARTERY',
#'SELECTIVEARTERIALCLAMPING',
#'CLAMPVEIN',
#'EARLYUNCLAMPING',
#'FLUORESCENCE',
#'INNERRENORRHAPHY',
#'OUTERRENORRHAPHY',
#'ISCHEMIATIMEmin',
#'UCSREPAIR',
#'HAEMOSTATICAGENTS',
#'HAEMOSTATICDetails',
#'LYMPHNODEDISSECTIONLND',
#'BLOODLOSSml',
#'INTRAOPTRANSUFUSION',
#'SURGICALCONSIDERATIONS',
#'INTRAOPCOMPLICATION',
#'INTRAOPCOMPLICATIONS',
'INTRA_OP_COMPLICATIONS'    
]

# %%
len(intra_op_col)
# Out:
# 50

# %% [markdown]
# ### Data Cleaning

# %%
# Selecting dataframe relevant columsn for analysis
df = df[intra_op_col].copy()

# %%
#Keep columns having less than 50% missing data
print("Total number of columns before removing columns with more than 50% missing data: {}".format(len(list(df))))

df = df[df.columns[df.isnull().mean() <= 0.50]].copy()

print("Total number of columns left after removing columns with more than 50% missing data: {}".format(len(list(df))))
# Out:
# Total number of columns before removing columns with more than 50% missing data: 50
# Total number of columns left after removing columns with more than 50% missing data: 43

# %%
target = 'INTRA_OP_COMPLICATIONS'

# %%
df.describe()
# Out:
#        AGEATSURGERY          BMI  CLINICALSIZEmm  CHARLSONSCORE      PREOPHB  \
# count   3366.000000  2999.000000     3184.000000    2806.000000  2525.000000
# mean      57.721331    28.673555       33.236778       1.518175    30.087311
# std       12.714053     5.915251       16.362454       1.997732   118.876716
# min       16.000000    15.100000        0.000000       0.000000    10.000000
# 25%       49.000000    24.580000       22.000000       0.000000    12.900000
# 50%       59.000000    27.540000       30.000000       1.000000    14.000000
# 75%       67.000000    31.700000       42.000000       2.000000    15.000000
# max       89.000000    55.600000      135.000000      19.000000   990.000000
#
#            PREOPHT       PREOPWBC   PREOPCREAT    PREOPEGFR  \
# count  2389.000000    2088.000000  3310.000000  2631.000000
# mean     41.291754    7592.260987     1.109467    79.925134
# std       6.112658    4968.375460     3.270266    24.654798
# min      10.400000       0.000000     0.000000     0.020000
# 25%      38.300000    5770.000000     0.780000    65.005000
# 50%      41.600000    7100.000000     0.910000    79.067989
# 75%      44.500000    8600.000000     1.100000    93.605000
# max     180.000000  186000.000000    96.000000   253.971416
#
#        LOCATIONTOPOLARLINE  NOOFLESIONS  INTRA_OP_COMPLICATIONS
# count          2004.000000  2778.000000             3385.000000
# mean              1.893713     1.055796                0.037223
# std               0.817422     0.292969                0.189336
# min               1.000000     0.000000                0.000000
# 25%               1.000000     1.000000                0.000000
# 50%               2.000000     1.000000                0.000000
# 75%               3.000000     1.000000                0.000000
# max               3.000000     6.000000                1.000000

# %%
numeric_stats = df.describe()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)
f, axes = plt.subplots(2, 4, figsize=(20, 8))
sns.despine(left=True)
sns.boxplot(data = df, y = 'AGEATSURGERY', x = target,ax=axes[0, 0])
sns.boxplot(data = df, y = 'BMI', x = target, ax=axes[0, 1])
sns.boxplot(data = df, y = 'CLINICALSIZEmm', x = target, ax=axes[0, 2])
sns.boxplot(data = df, y = 'PREOPHB', x = target, ax=axes[0, 3])
sns.boxplot(data = df, y = 'PREOPHT', x = target, ax=axes[1, 0])
sns.boxplot(data = df, y = 'PREOPWBC', x = target, ax=axes[1, 1])
sns.boxplot(data = df, y = 'PREOPCREAT', x = target, ax=axes[1, 2])
sns.boxplot(data = df, y = 'PREOPEGFR', x = target, ax=axes[1, 3])

# %%
# Check the number of outliers
outlier_dict = {}
clean_cols = ['BMI','CLINICALSIZEmm','PREOPHB','PREOPHT','PREOPWBC','PREOPCREAT','PREOPEGFR']
for i in clean_cols:
    q1 = numeric_stats.loc['25%'][i]
    q3 = numeric_stats.loc['75%'][i]
    IQR = q3-q1
    LL = q1-(1.5*IQR)
    UL = q3+(1.5*IQR)
    outlier_dict.update({i:{'LL':LL,'UL':UL}})
    print('{:<14s} {:>4d} {:>4d}'.format(i,len(df.loc[(df[i]>=UL)]),len(df.loc[(df[i]<=LL)])), 'UL-LL {:>4.2f}-{:>4.2f}'.format(UL,LL))
print(outlier_dict)
# Out:
# BMI              97    0 UL-LL 42.38-13.90
# CLINICALSIZEmm   78    0 UL-LL 72.00--8.00
# PREOPHB          55    0 UL-LL 18.15-9.75
# PREOPHT           8   30 UL-LL 53.80-29.00
# PREOPWBC         85   38 UL-LL 12845.00-1525.00
# PREOPCREAT      161    2 UL-LL 1.58-0.30
# PREOPEGFR        49   27 UL-LL 136.51-22.10
# {'BMI': {'LL': 13.899999999999997, 'UL': 42.38}, 'CLINICALSIZEmm': {'LL': -8.0, 'UL': 72.0}, 'PREOPHB': {'LL': 9.75, 'UL': 18.15}, 'PREOPHT': {'LL': 28.999999999999993, 'UL': 53.800000000000004}, 'PREOPWBC': {'LL': 1525.0, 'UL': 12845.0}, 'PREOPCREAT': {'LL': 0.29999999999999993, 'UL': 1.58}, 'PREOPEGFR': {'LL': 22.104999999999983, 'UL': 136.50500000000002}}

# %%
#Export the outlier dict
import json
with open(output_path + "outlier_dict.json", "w") as write_file:
    json.dump(outlier_dict, write_file)

# %%
#replacing inaccurate readings with missing values
clean_cols = ['BMI','CLINICALSIZEmm','PREOPHB','PREOPHT','PREOPWBC','PREOPCREAT','PREOPEGFR']
for i in clean_cols:
    q1 = numeric_stats.loc['25%'][i]
    q3 = numeric_stats.loc['75%'][i]
    IQR = q3-q1
    LL = q1-(1.5*IQR)
    UL = q3+(1.5*IQR)
    df.drop(df.loc[(df[i]<=LL)|(df[i]>=UL),[i]].index, inplace=True)

# %%
df.describe()
# Out:
#        AGEATSURGERY          BMI  CLINICALSIZEmm  CHARLSONSCORE      PREOPHB  \
# count   2829.000000  2505.000000     2713.000000    2357.000000  2136.000000
# mean      57.559915    28.086950       31.750571       1.473059    13.915103
# std       12.584384     5.041671       13.858003       1.967859     1.444019
# min       16.000000    15.100000        0.000000       0.000000    10.000000
# 25%       49.000000    24.450000       22.000000       0.000000    12.900000
# 50%       59.000000    27.260000       30.000000       1.000000    14.000000
# 75%       67.000000    31.200000       40.000000       2.000000    15.000000
# max       89.000000    42.300000       71.000000      19.000000    17.800000
#
#            PREOPHT      PREOPWBC   PREOPCREAT    PREOPEGFR  \
# count  2005.000000   1707.000000  2792.000000  2169.000000
# mean     41.561546   7210.774423     0.927768    81.125886
# std       4.253200   1954.015857     0.209810    18.854179
# min      29.000000   1840.000000     0.360000    34.000000
# 25%      38.800000   5700.000000     0.780000    67.420000
# 50%      41.900000   7000.000000     0.900000    80.000000
# 75%      44.700000   8400.000000     1.060000    93.232044
# max      53.700000  12840.000000     1.570000   136.493592
#
#        LOCATIONTOPOLARLINE  NOOFLESIONS  INTRA_OP_COMPLICATIONS
# count          1645.000000  2327.000000             2846.000000
# mean              1.896049     1.045982                0.036543
# std               0.819183     0.245405                0.187669
# min               1.000000     0.000000                0.000000
# 25%               1.000000     1.000000                0.000000
# 50%               2.000000     1.000000                0.000000
# 75%               3.000000     1.000000                0.000000
# max               3.000000     4.000000                1.000000

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)
f, axes = plt.subplots(2, 4, figsize=(20, 8))
sns.despine(left=True)
sns.boxplot(data = df, y = 'AGEATSURGERY', x = target,ax=axes[0, 0])
sns.boxplot(data = df, y = 'BMI', x = target, ax=axes[0, 1])
sns.boxplot(data = df, y = 'CLINICALSIZEmm', x = target, ax=axes[0, 2])
sns.boxplot(data = df, y = 'PREOPHB', x = target, ax=axes[0, 3])
sns.boxplot(data = df, y = 'PREOPHT', x = target, ax=axes[1, 0])
sns.boxplot(data = df, y = 'PREOPWBC', x = target, ax=axes[1, 1])
sns.boxplot(data = df, y = 'PREOPCREAT', x = target, ax=axes[1, 2])
sns.boxplot(data = df, y = 'PREOPEGFR', x = target, ax=axes[1, 3])

# %%
# The percentage of missing data
df.isnull().mean()
# Out:
# PATIENTNUMBER                         0.000000
# CENTERCODE                            0.000000
# GENDER                                0.003865
# AGEATSURGERY                          0.005973
# MARITALSTATUS                         0.368587
# RACE                                  0.397400
# EDUCATION                             0.442727
# BMI                                   0.119817
# CLINICALSIZEmm                        0.046732
# ECOG                                  0.464863
# CHARLSONSCORE                         0.171820
# SYMPTOMS                              0.233661
# SOLITARYKIDNEY                        0.141954
# BILATERALITYOFTUMOR                   0.394238
# SIDEOFTUMOR                           0.333099
# SIDEOFSURGERY                         0.003514
# FACE                                  0.248770
# TUMORlOCATION                         0.140900
# PREOPHB                               0.249473
# PREOPHT                               0.295502
# PREOPWBC                              0.400211
# PREOPCREAT                            0.018974
# PREOPEGFR                             0.237878
# PADUARISK                             0.375966
# POLARLOCATION                         0.210471
# RIMLOCATION                           0.405481
# RENALSINUS                            0.369993
# EXOPHYTICRATE                         0.269150
# CLINICALSIZEGROUP                     0.165144
# CT                                    0.122277
# CN                                    0.213633
# CM                                    0.408995
# R.E.N.A.L.NEPHRORISKSTRATIFICATION    0.242446
# RADIUSmaximaldiameterincm             0.119817
# EXOPHYTICENDOPHYTICPROPERTIES         0.292691
# NEARNESSOFTUMOUR                      0.339775
# ANTERIORORPOSTERIOR                   0.222066
# LOCATIONTOPOLARLINE                   0.421996
# ASASCORE                              0.135980
# PARTIALNEPHROINDICATION               0.278285
# MULTIFOCALITY                         0.397400
# NOOFLESIONS                           0.182361
# INTRA_OP_COMPLICATIONS                0.000000
# dtype: float64

# %%
# Calculate number missing values per row
df.reset_index(inplace=True, drop=True)
missing = {}

for i in range(len(df)):
    miss_cnt = 0
    for col in df.columns:
        if pd.isna(df[col][i]) == True:
            miss_cnt = miss_cnt+1
    df.loc[i,'Missing'] = miss_cnt

# %%
# calculate number of records with over 25% missing data
print("Total Records {}".format(len(df)))
print("Records with >=25% missing data {}".format(sum(df['Missing']<= round((len(df.columns)-2)*.30))))
print("Records to be dropped {}".format(len(df) - sum(df['Missing']<= round((len(df.columns)-2)*.30))))
# Out:
# Total Records 2846
# Records with >=25% missing data 1690
# Records to be dropped 1156

# %%
# Check thenumber of missing values for eahc variables if records with a certain missing threshold were removed
df[df['Missing']<= round((len(df.columns)-2)*.30) ].isnull().mean()
# Out:
# PATIENTNUMBER                         0.000000
# CENTERCODE                            0.000000
# GENDER                                0.000000
# AGEATSURGERY                          0.001183
# MARITALSTATUS                         0.086982
# RACE                                  0.098225
# EDUCATION                             0.123669
# BMI                                   0.068639
# CLINICALSIZEmm                        0.029586
# ECOG                                  0.297041
# CHARLSONSCORE                         0.048521
# SYMPTOMS                              0.019527
# SOLITARYKIDNEY                        0.001183
# BILATERALITYOFTUMOR                   0.084024
# SIDEOFTUMOR                           0.081065
# SIDEOFSURGERY                         0.000592
# FACE                                  0.108876
# TUMORlOCATION                         0.015385
# PREOPHB                               0.021893
# PREOPHT                               0.023077
# PREOPWBC                              0.107692
# PREOPCREAT                            0.008876
# PREOPEGFR                             0.186982
# PADUARISK                             0.139053
# POLARLOCATION                         0.067456
# RIMLOCATION                           0.124260
# RENALSINUS                            0.124260
# EXOPHYTICRATE                         0.101775
# CLINICALSIZEGROUP                     0.043195
# CT                                    0.060947
# CN                                    0.061538
# CM                                    0.239053
# R.E.N.A.L.NEPHRORISKSTRATIFICATION    0.118935
# RADIUSmaximaldiameterincm             0.004142
# EXOPHYTICENDOPHYTICPROPERTIES         0.232544
# NEARNESSOFTUMOUR                      0.121302
# ANTERIORORPOSTERIOR                   0.100000
# LOCATIONTOPOLARLINE                   0.102959
# ASASCORE                              0.055030
# PARTIALNEPHROINDICATION               0.011243
# MULTIFOCALITY                         0.089349
# NOOFLESIONS                           0.021302
# INTRA_OP_COMPLICATIONS                0.000000
# Missing                               0.000000
# dtype: float64

# %%
#removing patients with more than 75% missing data
df = df[df['Missing']<= round((len(df.columns)-2)*.30) ].copy()

# %%
#Keep columns having less than 10% missing data
df = df[df.columns[df.isnull().mean() <= 0.15]].copy()

print("Total number of columns left after removing columns with missing data: {}".format(len(list(df))))
# Out:
# Total number of columns left after removing columns with missing data: 40

# %%
# Print the list of patients with clean data
patient_list = df['PATIENTNUMBER'].tolist()
with open(output_path + 'patient_list.txt', 'w') as f:
    for item in patient_list:
        f.write("%s\n" % item)

# %%
# The percentage of missing data
df.isnull().mean()
# Out:
# PATIENTNUMBER                         0.000000
# CENTERCODE                            0.000000
# GENDER                                0.000000
# AGEATSURGERY                          0.001183
# MARITALSTATUS                         0.086982
# RACE                                  0.098225
# EDUCATION                             0.123669
# BMI                                   0.068639
# CLINICALSIZEmm                        0.029586
# CHARLSONSCORE                         0.048521
# SYMPTOMS                              0.019527
# SOLITARYKIDNEY                        0.001183
# BILATERALITYOFTUMOR                   0.084024
# SIDEOFTUMOR                           0.081065
# SIDEOFSURGERY                         0.000592
# FACE                                  0.108876
# TUMORlOCATION                         0.015385
# PREOPHB                               0.021893
# PREOPHT                               0.023077
# PREOPWBC                              0.107692
# PREOPCREAT                            0.008876
# PADUARISK                             0.139053
# POLARLOCATION                         0.067456
# RIMLOCATION                           0.124260
# RENALSINUS                            0.124260
# EXOPHYTICRATE                         0.101775
# CLINICALSIZEGROUP                     0.043195
# CT                                    0.060947
# CN                                    0.061538
# R.E.N.A.L.NEPHRORISKSTRATIFICATION    0.118935
# RADIUSmaximaldiameterincm             0.004142
# NEARNESSOFTUMOUR                      0.121302
# ANTERIORORPOSTERIOR                   0.100000
# LOCATIONTOPOLARLINE                   0.102959
# ASASCORE                              0.055030
# PARTIALNEPHROINDICATION               0.011243
# MULTIFOCALITY                         0.089349
# NOOFLESIONS                           0.021302
# INTRA_OP_COMPLICATIONS                0.000000
# Missing                               0.000000
# dtype: float64

# %%
# Replcaing missing values in categorical column with NA
for k in cat_col:
    if k in df.columns:
        df[k].fillna('NA',inplace = True)

# %%
# Create dictionary mean value for numeric columns
numeric_col_mean_dict = {}
for k in numeric_col_list:
    if k in df.columns:
        numeric_col_mean_dict.update({k:round(df[k].mean())})
print(numeric_col_mean_dict)
# Out:
# {'AGEATSURGERY': 57.0, 'BMI': 28.0, 'CLINICALSIZEmm': 32.0, 'PREOPHB': 14.0, 'PREOPHT': 42.0, 'PREOPWBC': 7128.0, 'PREOPCREAT': 1.0, 'NOOFLESIONS': 1.0, 'CHARLSONSCORE': 1.0}

# %%
# export the numeric_col_mean_dict
import json
with open(output_path+ "numeric_col_mean_dict.json", "w") as write_file:
    json.dump(numeric_col_mean_dict, write_file)

# %%
# Replacing missing values in numerical columns with their respective mean 
for k in numeric_col_list:
    if k in df.columns:
        df[k].fillna(round(df[k].mean()), inplace = True)

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1690 entries, 0 to 2845
# Data columns (total 40 columns):
# PATIENTNUMBER                         1690 non-null object
# CENTERCODE                            1690 non-null object
# GENDER                                1690 non-null object
# AGEATSURGERY                          1690 non-null float64
# MARITALSTATUS                         1690 non-null object
# RACE                                  1690 non-null object
# EDUCATION                             1690 non-null object
# BMI                                   1690 non-null float64
# CLINICALSIZEmm                        1690 non-null float64
# CHARLSONSCORE                         1690 non-null float64
# SYMPTOMS                              1690 non-null object
# SOLITARYKIDNEY                        1690 non-null object
# BILATERALITYOFTUMOR                   1690 non-null object
# SIDEOFTUMOR                           1690 non-null object
# SIDEOFSURGERY                         1690 non-null object
# FACE                                  1690 non-null object
# TUMORlOCATION                         1690 non-null object
# PREOPHB                               1690 non-null float64
# PREOPHT                               1690 non-null float64
# PREOPWBC                              1690 non-null float64
# PREOPCREAT                            1690 non-null float64
# PADUARISK                             1690 non-null object
# POLARLOCATION                         1690 non-null object
# RIMLOCATION                           1690 non-null object
# RENALSINUS                            1690 non-null object
# EXOPHYTICRATE                         1690 non-null object
# CLINICALSIZEGROUP                     1690 non-null object
# CT                                    1690 non-null object
# CN                                    1690 non-null object
# R.E.N.A.L.NEPHRORISKSTRATIFICATION    1690 non-null object
# RADIUSmaximaldiameterincm             1690 non-null object
# NEARNESSOFTUMOUR                      1690 non-null object
# ANTERIORORPOSTERIOR                   1690 non-null object
# LOCATIONTOPOLARLINE                   1690 non-null object
# ASASCORE                              1690 non-null object
# PARTIALNEPHROINDICATION               1690 non-null object
# MULTIFOCALITY                         1690 non-null object
# NOOFLESIONS                           1690 non-null float64
# INTRA_OP_COMPLICATIONS                1690 non-null int64
# Missing                               1690 non-null float64
# dtypes: float64(10), int64(1), object(29)
# memory usage: 541.3+ KB

# %%
# check unique value in each column of type object
unique_count_list = {}

for k in cat_col:
    if k in df.columns:
        unique_count_list.update({k:len(df[k].unique())})

unique_count_list
# Out:
# {'CENTERCODE': 18,
#  'GENDER': 2,
#  'MARITALSTATUS': 5,
#  'RACE': 5,
#  'EDUCATION': 5,
#  'SYMPTOMS': 4,
#  'SOLITARYKIDNEY': 4,
#  'BILATERALITYOFTUMOR': 3,
#  'SIDEOFTUMOR': 4,
#  'SIDEOFSURGERY': 4,
#  'FACE': 3,
#  'TUMORlOCATION': 6,
#  'PADUARISK': 5,
#  'POLARLOCATION': 3,
#  'RIMLOCATION': 3,
#  'RENALSINUS': 3,
#  'EXOPHYTICRATE': 4,
#  'CLINICALSIZEGROUP': 4,
#  'CT': 6,
#  'CN': 4,
#  'R.E.N.A.L.NEPHRORISKSTRATIFICATION': 5,
#  'RADIUSmaximaldiameterincm': 4,
#  'NEARNESSOFTUMOUR': 4,
#  'ANTERIORORPOSTERIOR': 4,
#  'LOCATIONTOPOLARLINE': 4,
#  'ASASCORE': 5,
#  'PARTIALNEPHROINDICATION': 4,
#  'MULTIFOCALITY': 3}

# %%
# convert object columns with less than 10 unique values into type category
for col in unique_count_list:
        df[col] = df[col].astype('category').copy()

# %%
# list of features with high number of categories
for col in unique_count_list:
    if unique_count_list[col]>10:
        print(col,unique_count_list[col])
# Out:
# CENTERCODE 18

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df.reset_index(drop=True, inplace=True)
print("Number records for predicting intra-op complications: {}".format(len(df)))
# Out:
# Number records for predicting intra-op complications: 1690

# %%
for i in df.select_dtypes('category').columns:
    df[i] = df[i].apply(str)

# %%
# fit label encoder to each column of type category
cat_col =df.select_dtypes('category')
df_codes = df.copy()
from sklearn.preprocessing import LabelEncoder
le_dict = {col: LabelEncoder() for col in cat_col }
for col in cat_col:
    le_dict[col].fit_transform(df_codes[col])

# %%
# create a dictionary cantaining mapping of categorical values to numerical values
label_mapping = dict()
label_mapping = {col: dict(zip(le_dict[col].classes_,le_dict[col].transform(le_dict[col].classes_))) for col in cat_col}
label_mapping
# Out:
# {'CENTERCODE': {'08ZMCILJ': 0,
#   '0VZRZWAI': 1,
#   '39HIP3LQ': 2,
#   '3QWOG020': 3,
#   '4M49I4D5': 4,
#   '4UPDM0XB': 5,
#   '57T3OUKU': 6,
#   '63DCGHNW': 7,
#   '94ISQMHX': 8,
#   'FWL0MH42': 9,
#   'GCIEYK6L': 10,
#   'GQHLD5Q4': 11,
#   'QRJWT5QR': 12,
#   'RETM03Y8': 13,
#   'U5WT3NOY': 14,
#   'VNO3BPES': 15,
#   'VRVRQ639': 16,
#   'WGC7XYXZ': 17},
#  'GENDER': {'Female': 0, 'Male': 1},
#  'MARITALSTATUS': {'Divorced': 0,
#   'Married': 1,
#   'NA': 2,
#   'Single': 3,
#   'Widowed': 4},
#  'RACE': {'Black': 0,
#   'Mongoloid/Asian': 1,
#   'NA': 2,
#   'Others': 3,
#   'White/Caucasian': 4},
#  'EDUCATION': {'Graduate': 0,
#   'NA': 1,
#   'Not Provided': 2,
#   'Post Graduate': 3,
#   'Upto High School': 4},
#  'SYMPTOMS': {'Absent': 0,
#   'Local Symptoms': 1,
#   'NA': 2,
#   'Systemic Symptoms': 3},
#  'SOLITARYKIDNEY': {'NA': 0, 'No': 1, 'Yes': 2, 'no': 3},
#  'BILATERALITYOFTUMOR': {'NA': 0, 'No': 1, 'Yes': 2},
#  'SIDEOFTUMOR': {'Bilateral': 0, 'Left': 1, 'NA': 2, 'Right': 3},
#  'SIDEOFSURGERY': {'Bilateral': 0, 'Left': 1, 'NA': 2, 'Right': 3},
#  'FACE': {'Anterior': 0, 'NA': 1, 'Posterior': 2},
#  'TUMORlOCATION': {'Lower Pol': 0,
#   'Lower Pole': 1,
#   'Mid Pole': 2,
#   'NA': 3,
#   'Upper Pol': 4,
#   'Upper Pole': 5},
#  'PADUARISK': {'0': 0,
#   '1(Low  Risk)': 1,
#   '2(Intermidiate  Risk)': 2,
#   '3(High  Risk)': 3,
#   'NA': 4},
#  'POLARLOCATION': {'NA': 0,
#   'Tumours crossing the sinus line >50% or falling entirely between the sinus lines (2 points)': 1,
#   'Tumours entirely located above the upper or below the lower sinus line, or crossing the sinus line < 50% (1 point)': 2},
#  'RIMLOCATION': {'At the medial rim (2 points)': 0,
#   'NA': 1,
#   'Tumours located at the lateral (1 point)': 2},
#  'RENALSINUS': {'NA': 0,
#   'Tumours without renal sinus involvement (1 point)': 1,
#   'With renal sinus involvement (2 points)': 2},
#  'EXOPHYTICRATE': {'< 50%exophytic (2 points)': 0,
#   '= 50% exophytic (1 point)': 1,
#   'Endophytic (3 points)': 2,
#   'NA': 3},
#  'CLINICALSIZEGROUP': {'4.1cm-7cm': 0, '=<4cm': 1, '=>7cm': 2, 'NA': 3},
#  'CT': {'NA': 0, 'T1a': 1, 'T1b': 2, 'T2a': 3, 'T2b': 4, 'T3a': 5},
#  'CN': {'N+': 0, 'N0': 1, 'NA': 2, 'Nx': 3},
#  'R.E.N.A.L.NEPHRORISKSTRATIFICATION': {'0': 0,
#   '1(Low Risk)': 1,
#   '2(Intermidiate Risk)': 2,
#   '3(High Risk)': 3,
#   'NA': 4},
#  'RADIUSmaximaldiameterincm': {'4 but <7': 0, '=<4': 1, '=>7': 2, 'NA': 3},
#  'NEARNESSOFTUMOUR': {'=<4': 0, '=>7': 1, '>4 but <7': 2, 'NA': 3},
#  'ANTERIORORPOSTERIOR': {'Anterior (a)': 0,
#   'NA': 1,
#   'Neither(x)': 2,
#   'Posterior (p)': 3},
#  'LOCATIONTOPOLARLINE': {'1.0': 0, '2.0': 1, '3.0': 2, 'NA': 3},
#  'ASASCORE': {'Category 1': 0,
#   'Category 2': 1,
#   'Category 3': 2,
#   'Category 4': 3,
#   'NA': 4},
#  'PARTIALNEPHROINDICATION': {'Absolute': 0,
#   'Elective': 1,
#   'NA': 2,
#   'Relative': 3},
#  'MULTIFOCALITY': {'NA': 0, 'No': 1, 'Yes': 2}}

# %%
# export the numeric_col_mean_dict
from joblib import dump
dump(le_dict, output_path + 'Label_enc_dict.joblib')
# Out:
# ['output/models/Label_enc_dict.joblib']

# %%
# mapping categorical column values to integer labels
for col in cat_col:
    df_codes[col] = le_dict[col].transform(df_codes[col]).copy()

# %%
df_codes.head()
# Out:
#   PATIENTNUMBER  CENTERCODE  GENDER  AGEATSURGERY  MARITALSTATUS  RACE  \
# 0   13PAT000522           0       1          61.0              1     1
# 1   22PAT000131          17       1          58.0              1     1
# 2   11PAT000166           1       1          56.0              1     1
# 3   15PAT000097          15       0          65.0              1     4
# 4   15PAT000095          15       0          23.0              3     4
#
#    EDUCATION    BMI  CLINICALSIZEmm  CHARLSONSCORE  SYMPTOMS  SOLITARYKIDNEY  \
# 0          0  25.10            33.0            0.0         0               2
# 1          2  23.18            44.0            0.0         0               1
# 2          2  23.36            32.0            0.0         0               1
# 3          2  26.67            32.0            0.0         0               1
# 4          2  19.65            23.0            0.0         0               1
#
#    BILATERALITYOFTUMOR  SIDEOFTUMOR  SIDEOFSURGERY  FACE  TUMORlOCATION  \
# 0                    1            1              1     0              0
# 1                    1            1              1     0              2
# 2                    1            1              1     0              0
# 3                    1            1              1     1              4
# 4                    1            3              3     2              3
#
#    PREOPHB  PREOPHT  PREOPWBC  PREOPCREAT  PADUARISK  POLARLOCATION  \
# 0     12.3     39.4    5400.0        1.25          2              2
# 1     14.0     41.0    5100.0        0.90          3              1
# 2     10.2     36.4    5200.0        0.70          1              2
# 3     11.8     36.0    5300.0        1.12          1              2
# 4     13.3     39.2   12100.0        0.70          3              1
#
#    RIMLOCATION  RENALSINUS  EXOPHYTICRATE  CLINICALSIZEGROUP  CT  CN  \
# 0            0           1              0                  1   1   1
# 1            0           2              1                  0   2   1
# 2            2           1              1                  1   1   1
# 3            2           1              0                  1   1   1
# 4            0           2              2                  1   1   1
#
#    R.E.N.A.L.NEPHRORISKSTRATIFICATION  RADIUSmaximaldiameterincm  \
# 0                                   2                          1
# 1                                   3                          0
# 2                                   1                          1
# 3                                   1                          1
# 4                                   3                          1
#
#    NEARNESSOFTUMOUR  ANTERIORORPOSTERIOR  LOCATIONTOPOLARLINE  ASASCORE  \
# 0                 0                    2                    1         2
# 1                 0                    0                    2         0
# 2                 1                    0                    0         0
# 3                 2                    2                    0         1
# 4                 0                    3                    2         0
#
#    PARTIALNEPHROINDICATION  MULTIFOCALITY  NOOFLESIONS  \
# 0                        1              1          1.0
# 1                        1              1          1.0
# 2                        1              1          1.0
# 3                        1              1          1.0
# 4                        1              1          1.0
#
#    INTRA_OP_COMPLICATIONS  Missing
# 0                       0      0.0
# 1                       0      1.0
# 2                       0      2.0
# 3                       0      3.0
# 4                       0      2.0

# %% [markdown]
# ### Create Stats fot dataset

# %%
# print median , IQR for numeric columns 
for i in df.columns:#['AGEATSURGERY','BMI','CLINICALSIZEmm','PREOPHB','PREOPHT','PREOPWBC','PREOPCREAT','PREOPEGFR','NOOFLESIONS']:
    if i in numeric_col_list:
        print(i, "{0:.1f} [{1:.1f}-{2:.1f}]".format(np.median(df[i]),np.percentile(df[i],25),np.percentile(df[i],75)))
# Out:
# AGEATSURGERY 58.0 [48.0-66.0]
# BMI 27.3 [24.3-30.1]
# CLINICALSIZEmm 30.0 [22.0-41.0]
# CHARLSONSCORE 1.0 [0.0-2.0]
# PREOPHB 14.0 [13.1-15.0]
# PREOPHT 42.0 [39.2-44.8]
# PREOPWBC 7128.0 [5872.5-8100.0]
# PREOPCREAT 0.9 [0.8-1.1]
# NOOFLESIONS 1.0 [1.0-1.0]

# %%
#Print number of records for each category in categorical columns
for i in df_codes.columns:
    if i in cat_col:
        print(pd.DataFrame(df_codes[i].apply(lambda x: le_dict[i].inverse_transform([x])[0]).value_counts()))
# Out:
#           CENTERCODE
# GCIEYK6L         440
# 63DCGHNW         211
# 4UPDM0XB         176
# 4M49I4D5         174
# VNO3BPES         115
# 08ZMCILJ         109
# 0VZRZWAI          74
# FWL0MH42          73
# QRJWT5QR          57
# U5WT3NOY          54
# WGC7XYXZ          43
# GQHLD5Q4          35
# RETM03Y8          30
# 57T3OUKU          29
# 3QWOG020          25
# VRVRQ639          24
# 39HIP3LQ          15
# 94ISQMHX           6
#         GENDER
# Male      1109
# Female     581
#           MARITALSTATUS
# Married            1287
# Single              157
# NA                  147
# Divorced             51
# Widowed              48
#                  RACE
# White/Caucasian   864
# Others            349
# Mongoloid/Asian   265
# NA                166
# Black              46
#                   EDUCATION
# Not Provided            703
# Graduate                398
# Upto High School        220
# NA                      209
# Post Graduate           160
#                    SYMPTOMS
# Absent                 1329
# Local Symptoms          298
# NA                       33
# Systemic Symptoms        30
#      SOLITARYKIDNEY
# No             1155
# no              489
# Yes              44
# NA                2
#      BILATERALITYOFTUMOR
# No                  1472
# NA                   142
# Yes                   76
#            SIDEOFTUMOR
# Right              767
# Left               726
# NA                 137
# Bilateral           60
#            SIDEOFSURGERY
# Right                871
# Left                 817
# NA                     1
# Bilateral              1
#            FACE
# Anterior    798
# Posterior   708
# NA          184
#             TUMORlOCATION
# Mid Pole              636
# Upper Pole            457
# Lower Pole            434
# Upper Pol              71
# Lower Pol              66
# NA                     26
#                        PADUARISK
# 1(Low  Risk)                 523
# 2(Intermidiate  Risk)        509
# 3(High  Risk)                422
# NA                           235
# 0                              1
#                                                     POLARLOCATION
# Tumours entirely located above the upper or bel...            901
# Tumours crossing the sinus line >50% or falling...            675
# NA                                                            114
#                                           RIMLOCATION
# Tumours located at the lateral (1 point)          955
# At the medial rim (2 points)                      525
# NA                                                210
#                                                    RENALSINUS
# Tumours without renal sinus involvement (1 point)         983
# With renal sinus involvement (2 points)                   497
# NA                                                        210
#                            EXOPHYTICRATE
# = 50% exophytic (1 point)            678
# < 50%exophytic (2 points)            621
# Endophytic (3 points)                219
# NA                                   172
#            CLINICALSIZEGROUP
# =<4cm                   1129
# 4.1cm-7cm                476
# NA                        73
# =>7cm                     12
#        CT
# T1a  1134
# T1b   422
# NA    103
# T2a    24
# T3a     5
# T2b     2
#      CN
# N0  981
# Nx  600
# NA  104
# N+    5
#                       R.E.N.A.L.NEPHRORISKSTRATIFICATION
# 2(Intermidiate Risk)                                 778
# 1(Low Risk)                                          551
# NA                                                   201
# 3(High Risk)                                         157
# 0                                                      3
#           RADIUSmaximaldiameterincm
# =<4                            1182
# 4 but <7                        487
# =>7                              14
# NA                                7
#            NEARNESSOFTUMOUR
# =<4                     672
# =>7                     440
# >4 but <7               373
# NA                      205
#                ANTERIORORPOSTERIOR
# Anterior (a)                   668
# Posterior (p)                  640
# Neither(x)                     213
# NA                             169
#      LOCATIONTOPOLARLINE
# 1.0                  584
# 2.0                  477
# 3.0                  455
# NA                   174
#             ASASCORE
# Category 2       800
# Category 1       502
# Category 3       290
# NA                93
# Category 4         5
#           PARTIALNEPHROINDICATION
# Elective                     1351
# Relative                      258
# Absolute                       62
# NA                             19
#      MULTIFOCALITY
# No            1457
# NA             151
# Yes             82

# %%
traget_stats = pd.merge(df_codes[['PATIENTNUMBER','INTRA_OP_COMPLICATIONS']],
                        df_ori[['PATIENTNUMBER','INTRAOPCOMPLICATIONS','INTRAOPCOMPLICATION','INTRAOPTRANSUFUSION']], 
                        left_on='PATIENTNUMBER', 
                        right_on='PATIENTNUMBER').copy()

# %%
traget_stats.loc[traget_stats['INTRA_OP_COMPLICATIONS']==1]['INTRAOPCOMPLICATIONS'].value_counts()
# Out:
# 179    70
# 180    14
# 181     5
# 182     3
# 310     2
# nan     1
# Name: INTRAOPCOMPLICATIONS, dtype: int64

# %%
traget_stats.loc[traget_stats['INTRA_OP_COMPLICATIONS']==1]['INTRAOPTRANSUFUSION'].value_counts()
# Out:
# No         86
# 1 Unit      4
# >1 Unit     3
# Name: INTRAOPTRANSUFUSION, dtype: int64

# %% [markdown]
# ### Create Train and Test dataset

# %%
df_codes.corr()['INTRA_OP_COMPLICATIONS']
# Out:
# CENTERCODE                            0.089367
# GENDER                               -0.045110
# AGEATSURGERY                          0.024710
# MARITALSTATUS                        -0.039085
# RACE                                  0.123084
# EDUCATION                             0.039851
# BMI                                   0.046839
# CLINICALSIZEmm                       -0.006560
# CHARLSONSCORE                        -0.025499
# SYMPTOMS                             -0.024250
# SOLITARYKIDNEY                       -0.083211
# BILATERALITYOFTUMOR                   0.206581
# SIDEOFTUMOR                          -0.110623
# SIDEOFSURGERY                         0.010472
# FACE                                  0.019241
# TUMORlOCATION                         0.006732
# PREOPHB                               0.011179
# PREOPHT                              -0.011083
# PREOPWBC                             -0.008450
# PREOPCREAT                           -0.018785
# PADUARISK                             0.018298
# POLARLOCATION                        -0.038318
# RIMLOCATION                          -0.029016
# RENALSINUS                            0.077661
# EXOPHYTICRATE                         0.022332
# CLINICALSIZEGROUP                    -0.031972
# CT                                    0.024907
# CN                                    0.187436
# R.E.N.A.L.NEPHRORISKSTRATIFICATION    0.007812
# RADIUSmaximaldiameterincm            -0.011545
# NEARNESSOFTUMOUR                     -0.047142
# ANTERIORORPOSTERIOR                   0.024188
# LOCATIONTOPOLARLINE                   0.037552
# ASASCORE                              0.032990
# PARTIALNEPHROINDICATION               0.122797
# MULTIFOCALITY                         0.235826
# NOOFLESIONS                           0.101645
# INTRA_OP_COMPLICATIONS                1.000000
# Missing                              -0.071586
# Name: INTRA_OP_COMPLICATIONS, dtype: float64

# %%
print('Number of patients {}'.format(len(df_codes)))
print('% of patients with complications {:.2f}%'.format(sum(df_codes['INTRA_OP_COMPLICATIONS'])/len(df_codes)*100))
# Out:
# Number of patients 1690
# % of patients with complications 5.62%

# %%
# Split data in test and train
from sklearn.model_selection import train_test_split
train, test = train_test_split(df_codes, test_size=0.30, random_state=42, stratify = df_codes['INTRA_OP_COMPLICATIONS'])

# %%
# Percentage of complications in trainset
train['INTRA_OP_COMPLICATIONS'].sum()/len(train)
# Out:
# 0.0566356720202874

# %%
# Percentage of complications in testset
test['INTRA_OP_COMPLICATIONS'].sum()/len(test)
# Out:
# 0.055226824457593686

# %%
output_path = 'H:\RediMinds\VCQI'
df_codes.drop(labels=['Missing','PATIENTNUMBER'], axis='columns', inplace=True)
df_codes.to_csv(output_path+"\VCQI_clean.csv",index=False)

# %%
patient_list_train = train['PATIENTNUMBER'].tolist()
patient_list_test = test['PATIENTNUMBER'].tolist()
from joblib import dump
dump(patient_list_train, 'output/models/patient_list_train.joblib')
dump(patient_list_test, 'output/models/patient_list_test.joblib')
# Out:
# ['output/models/patient_list_test.joblib']

# %%
# Save train and test dataset
train.drop(labels=['Missing','PATIENTNUMBER'], axis='columns', inplace=True)
test.drop(labels=['Missing','PATIENTNUMBER'], axis='columns', inplace=True)
train.to_csv(output_path+"\VCQI_clean_train.csv",index=False)
test.to_csv(output_path+"\VCQI_clean_test.csv",index=False)
# Out:
# C:\Users\anubhav\Anaconda3\envs\Tensorflow\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
import pickle

cat_col = df.select_dtypes('category')

with open(output_path+'\cat_col', 'wb') as fp:
    pickle.dump(cat_col.columns.to_list(), fp)

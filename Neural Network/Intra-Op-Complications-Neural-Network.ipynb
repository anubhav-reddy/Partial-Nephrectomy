# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)  
#pd.set_option('display.expand_frame_repr', False)
#pd.set_option('max_colwidth', -1)

from sklearn import tree

# %%
df_prospective = pd.read_excel('H:\RediMinds\DRMahen/VCQI_PN_2014-Jun2018.xlsx', sheet_name='Prospective')

# %%
df_retro = pd.read_excel('H:\RediMinds\DRMahen/VCQI_PN_2014-Jun2018.xlsx', sheet_name='Retro')

# %%
#checking shape of dataframe
df_prospective.shape
# Out:
# (921, 161)

# %%
#checking shape of dataframe 
df_retro.shape
# Out:
# (2391, 161)

# %%
df_prospective['data_record'] = 'prospective'

# %%
df_retro['data_record'] = 'retro'

# %%
df = df_prospective.append(df_retro)

# %%
df.shape
# Out:
# (3312, 162)

# %%
df.head(10)
# Out:
#   PATIENT NUMBER            PROC NAME CENTER CODE SURGEON CODE REC PROGRESS  \
# 0    21PAT000148  Partial Nephrectomy    GQHLD5Q4     CWQW6ZDS   Follow-up1
# 1    18PAT000042  Partial Nephrectomy    GCIEYK6L     O3PZE5DE   Follow-up1
# 2     7PAT000058  Partial Nephrectomy    4M49I4D5     8M960UR8   Follow-up1
# 3     3PAT000044  Partial Nephrectomy    FWL0MH42     FUSA7KDH   Follow-up1
# 4     5PAT000015  Partial Nephrectomy    QRJWT5QR     67SDDBN2   Follow-up1
# 5     6PAT000025  Partial Nephrectomy    4UPDM0XB     HC9VH08V   Follow-up1
# 6    18PAT000010  Partial Nephrectomy    GCIEYK6L     O3PZE5DE   Follow-up1
# 7    18PAT000023  Partial Nephrectomy    GCIEYK6L     O3PZE5DE   Follow-up1
# 8    19PAT000007  Partial Nephrectomy    RETM03Y8     NIVPXZRL   Follow-up1
# 9    21PAT000166  Partial Nephrectomy    GQHLD5Q4     CWQW6ZDS   Follow-up1
#
#             CREATED DATE  GENDER  DATE OF BIRTH  AGE AT SURGERY  \
# 0  2017-09-24 18:30:00.0  Female         1967.0            50.0
# 1  2016-03-08 08:00:00.0  Female         1947.0            69.0
# 2  2016-01-01 23:00:00.0  Female         1933.0            83.0
# 3  2015-02-24 00:00:00.0    Male            NaN            66.0
# 4  2015-06-23 00:00:00.0    Male            NaN            61.0
# 5  2015-08-12 00:00:00.0    Male         1972.0            43.0
# 6  2015-11-03 08:00:00.0    Male         1952.0            63.0
# 7  2015-12-08 08:00:00.0  Female         1980.0            35.0
# 8  2016-03-07 00:00:00.0    Male         1963.0            53.0
# 9  2017-11-13 18:30:00.0    Male         1975.0            42.0
#
#   MARITAL STATUS             RACE         EDUCATION  WEIGHT  HEIGHT    BMI  \
# 0        Married           Others          Graduate   57.00   168.0  20.20
# 1       Divorced  White/Caucasian      Not Provided   68.60   161.3  26.37
# 2        Widowed  White/Caucasian      Not Provided   83.65   164.0  31.10
# 3         Single  White/Caucasian          Graduate  235.00    71.0  32.78
# 4        Married           Others          Graduate   82.90   171.0  28.35
# 5       Divorced  White/Caucasian  Upto High School   80.00   182.0  24.15
# 6        Widowed  White/Caucasian      Not Provided  101.20   167.6  36.03
# 7        Married            Black      Not Provided   77.10   154.9  32.13
# 8        Married  White/Caucasian     Post Graduate   96.00   170.0  33.22
# 9        Married           Others          Graduate   84.00   181.0  25.64
#
#    CLINICAL SIZE (mm)                                               ECOG  \
# 0                 7.0  Fully active, able to carry on all pre-disease...
# 1                74.0  Fully active, able to carry on all pre-disease...
# 2                80.0  Restricted in physically strenuous activity bu...
# 3                73.0  Fully active, able to carry on all pre-disease...
# 4                 8.0  Fully active, able to carry on all pre-disease...
# 5                55.0  Fully active, able to carry on all pre-disease...
# 6                74.0  Fully active, able to carry on all pre-disease...
# 7                50.0  Fully active, able to carry on all pre-disease...
# 8                56.0  Fully active, able to carry on all pre-disease...
# 9                64.0  Fully active, able to carry on all pre-disease...
#
#    CHARLSON SCORE  CHARLSON AGE-ADJUST SCORE        SYMPTOMS SOLITARY KIDNEY  \
# 0             0.0                        2.0          Absent              No
# 1             1.0                        4.0          Absent              No
# 2             3.0                        8.0          Absent              No
# 3             2.0                        5.0          Absent              No
# 4             0.0                        NaN          Absent              No
# 5             0.0                        NaN  Local Symptoms              No
# 6             2.0                        5.0          Absent              No
# 7             1.0                        1.0          Absent              No
# 8             0.0                        NaN          Absent              No
# 9             0.0                        1.0          Absent              No
#
#   TYPE OF SOLITARY KIDNEY BILATERALITY OF TUMOR SIDE OF TUMOR SIDE OF SURGERY  \
# 0                     NaN                    No          Left            Left
# 1                     NaN                    No         Right           Right
# 2                     NaN                    No          Left            Left
# 3                     NaN                    No         Right           Right
# 4                     NaN                    No         Right           Right
# 5                     NaN                    No          Left            Left
# 6                     NaN                    No          Left            Left
# 7                     NaN                    No          Left            Left
# 8                     NaN                    No         Right           Right
# 9                     NaN                    No         Right           Right
#
#   PRE-OP MULTIFOCALITY       FACE TUMOR lOCATION PRE-OP HB PRE-OP HT  \
# 0                   No  Posterior     Lower Pole      13.2        50
# 1                   No  Posterior       Mid Pole      14.7      44.2
# 2                   No   Anterior     Lower Pole      12.5      38.9
# 3                   No  Posterior     Upper Pole      17.0      50.8
# 4                   No  Posterior       Mid Pole      12.1      37.1
# 5                   No  Posterior       Mid Pole        15     0.455
# 6                   No  Posterior       Mid Pole      15.4      47.6
# 7                   No   Anterior     Upper Pole      10.4        32
# 8                   No   Anterior     Upper Pole      15.4      46.2
# 9                   No  Posterior     Upper Pole        12        34
#
#   PRE-OP WBC  PRE-OP CREAT PRE-OP GFR  PRE-OP EGFR  \
# 0       7800          0.63       67.7   100.030000
# 1        6.4          0.80        NaN    71.119672
# 2       5590          0.97         55    54.844682
# 3        8.0          0.93        NaN    81.290783
# 4       7.71          1.10       62.2    68.053260
# 5        8.5          0.92        NaN    89.790998
# 6        7.9          1.30        999    55.754675
# 7        4.8          0.66        NaN   123.318380
# 8        5.1          0.95        NaN    82.931020
# 9       5600          1.20         44    66.400000
#
#   PRE-OP Split Renal Function PRE-OP ERPF  PADUA SCORE             PADUA RISK  \
# 0                          50       168.5         12.0          3(High  Risk)
# 1                         NaN         NaN         10.0          3(High  Risk)
# 2                         999         999          9.0  2(Intermidiate  Risk)
# 3                         NaN         NaN          8.0  2(Intermidiate  Risk)
# 4                         56%         NaN         12.0          3(High  Risk)
# 5                         NaN         NaN          9.0  2(Intermidiate  Risk)
# 6                         999         999         12.0          3(High  Risk)
# 7                         999         NaN          8.0  2(Intermidiate  Risk)
# 8                         NaN         NaN          9.0  2(Intermidiate  Risk)
# 9                          49         999         10.0          3(High  Risk)
#
#                                       POLAR LOCATION  \
# 0  Tumours entirely located above the upper or be...
# 1  Tumours crossing the sinus line >50% or fallin...
# 2  Tumours entirely located above the upper or be...
# 3  Tumours entirely located above the upper or be...
# 4  Tumours crossing the sinus line >50% or fallin...
# 5  Tumours entirely located above the upper or be...
# 6  Tumours crossing the sinus line >50% or fallin...
# 7  Tumours crossing the sinus line >50% or fallin...
# 8  Tumours entirely located above the upper or be...
# 9  Tumours crossing the sinus line >50% or fallin...
#
#                                RIM LOCATION  \
# 0              At the medial rim (2 points)
# 1              At the medial rim (2 points)
# 2  Tumours located at the lateral (1 point)
# 3  Tumours located at the lateral (1 point)
# 4  Tumours located at the lateral (1 point)
# 5              At the medial rim (2 points)
# 6  Tumours located at the lateral (1 point)
# 7  Tumours located at the lateral (1 point)
# 8              At the medial rim (2 points)
# 9  Tumours located at the lateral (1 point)
#
#                                          RENAL SINUS  \
# 0            With renal sinus involvement (2 points)
# 1  Tumours without renal sinus involvement (1 point)
# 2  Tumours without renal sinus involvement (1 point)
# 3  Tumours without renal sinus involvement (1 point)
# 4            With renal sinus involvement (2 points)
# 5            With renal sinus involvement (2 points)
# 6            With renal sinus involvement (2 points)
# 7  Tumours without renal sinus involvement (1 point)
# 8            With renal sinus involvement (2 points)
# 9            With renal sinus involvement (2 points)
#
#                                         UCS INVASION  \
# 0  With involving, dislocation or infiltration of...
# 1             Absent relationship with UCS (1 point)
# 2  With involving, dislocation or infiltration of...
# 3             Absent relationship with UCS (1 point)
# 4  With involving, dislocation or infiltration of...
# 5             Absent relationship with UCS (1 point)
# 6  With involving, dislocation or infiltration of...
# 7             Absent relationship with UCS (1 point)
# 8             Absent relationship with UCS (1 point)
# 9  With involving, dislocation or infiltration of...
#
#               EXOPHYTIC RATE CLINICAL SIZE GROUP   CT  CN              CM  \
# 0  < 50%exophytic (2 points)               =>7cm  T2a  Nx  Not Applicable
# 1  = 50% exophytic (1 point)               =>7cm  T2a  Nx              M0
# 2  = 50% exophytic (1 point)               =>7cm  T2a  N0              M0
# 3  = 50% exophytic (1 point)               =>7cm  T1b  N0              M0
# 4  < 50%exophytic (2 points)               =>7cm  T2a  N0              M0
# 5  = 50% exophytic (1 point)           4.1cm-7cm  T1a  Nx  Not Applicable
# 6  < 50%exophytic (2 points)               =>7cm  T2a  Nx              M0
# 7  = 50% exophytic (1 point)           4.1cm-7cm  T1b  Nx              M0
# 8  = 50% exophytic (1 point)           4.1cm-7cm  T1b  N0              M0
# 9  = 50% exophytic (1 point)           4.1cm-7cm  T1b  N0              M0
#
#   R.E.N.A.L. NEPHRO SCORE R.E.N.A.L. NEPHRO RISK STRATIFICATION  \
# 0                     11x                          3(High Risk)
# 1                     8ph                  2(Intermidiate Risk)
# 2                      8a                  2(Intermidiate Risk)
# 3                      8p                  2(Intermidiate Risk)
# 4                     11x                          3(High Risk)
# 5                      8p                  2(Intermidiate Risk)
# 6                    11ph                          3(High Risk)
# 7                      7a                  2(Intermidiate Risk)
# 8                     8ah                  2(Intermidiate Risk)
# 9                      8x                  2(Intermidiate Risk)
#
#   RADIUS (maximal diameter in cm) EXOPHYTIC/ENDOPHYTIC PROPERTIES  \
# 0                             =>7                            <50%
# 1                             =>7                             50%
# 2                             =>7                             50%
# 3                             =>7                             50%
# 4                             =>7                            <50%
# 5                        4 but <7                             50%
# 6                             =>7                            <50%
# 7                        4 but <7                             50%
# 8                        4 but <7                             50%
# 9                        4 but <7                             50%
#
#   NEARNESS OF TUMOUR ANTERIOR OR POSTERIOR  LOCATION TO POLAR LINE  \
# 0                =<4            Neither(x)                     3.0
# 1                =>7         Posterior (p)                     3.0
# 2                =<4          Anterior (a)                     1.0
# 3                =<4         Posterior (p)                     1.0
# 4                =<4            Neither(x)                     3.0
# 5                =<4         Posterior (p)                     2.0
# 6                =<4         Posterior (p)                     3.0
# 7                =>7          Anterior (a)                     3.0
# 8                =<4          Anterior (a)                     2.0
# 9                =<4            Neither(x)                     2.0
#
#   Tumor Consistency on Imaging Bosniak Classification        DATE OF SURGERY  \
# 0               Entirely solid   Entirely solid tumor  2017-09-24 00:00:00.0
# 1                          NaN                    NaN  2016-03-09 00:00:00.0
# 2                          NaN                    NaN  2016-01-04 00:00:00.0
# 3                          NaN                    NaN  2015-02-25 00:00:00.0
# 4                          NaN                    NaN  2015-06-24 00:00:00.0
# 5                          NaN                    NaN  2015-08-28 00:00:00.0
# 6                          NaN                    NaN  2015-11-04 00:00:00.0
# 7                          NaN                    NaN  2015-12-09 00:00:00.0
# 8       Some cystic components   Bosniak Grade 4 cyst  2016-03-08 00:00:00.0
# 9               Entirely solid   Entirely solid tumor  2017-11-15 00:00:00.0
#
#     ASA SCORE PARTIAL NEPHRO INDICATION MULTIFOCALITY  NO OF LESIONS  \
# 0  Category 1                  Elective            No            1.0
# 1  Category 3                  Relative            No            1.0
# 2  Category 2                  Elective            No            1.0
# 3  Category 2                  Elective            No            1.0
# 4  Category 2                  Elective            No            1.0
# 5  Category 1                  Elective            No            1.0
# 6  Category 3                  Relative            No            1.0
# 7  Category 3                  Elective            No            1.0
# 8  Category 2                  Elective            No            1.0
# 9  Category 1                  Elective            No            1.0
#
#   Imaging Features of other excised tumor  \
# 0                                      NP
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                 cONTRAST ENHANCING MASS
#
#   Consistency of the other excised tumor/s           ACCESS DA VINCI MODEL  \
# 0                     Entirely solid tumor  Transperitoneal             Xi
# 1                                      NaN  Retroperitoneal             Si
# 2                                      NaN  Transperitoneal             Xi
# 3                                      NaN  Transperitoneal             Si
# 4                                      NaN  Transperitoneal             Si
# 5                                      NaN  Transperitoneal             Si
# 6                                      NaN  Retroperitoneal             Si
# 7                                      NaN  Transperitoneal             Si
# 8                                      NaN  Transperitoneal             Si
# 9                     Entirely solid tumor  Transperitoneal             Xi
#
#   ROBOTICS ARMS ASSISTENT TROCARS DUAL CONSOLE PRIMARY SURGEON  \
# 0        4-arms      5 mm + 12 mm           No           Staff
# 1        4-arms        Only 12 mm          Yes           Staff
# 2        4-arms        Only 12 mm           No           Staff
# 3        4-arms        Only 12 mm          Yes           Staff
# 4        4-arms        Only 12 mm           No           Staff
# 5        3-arms      5 mm + 12 mm          Yes           Staff
# 6        3-arms        Only 12 mm          Yes           Staff
# 7        4-arms        Only 12 mm          Yes           Staff
# 8        4-arms        Only 12 mm           No           Staff
# 9        4-arms      5 mm + 12 mm           No           Staff
#
#   OPERATIVE TIME(min) ISCHEMIA    CLAMP ARTERY SELECTIVE ARTERIAL CLAMPING  \
# 0                3:40     Warm  Satinsky Clamp                          No
# 1               02:07     Warm         Bulldog                         Yes
# 2               04:00     Warm         Bulldog                          No
# 3                8:48     Warm              No                          No
# 4               02:30     Warm         Bulldog                          No
# 5               02:15     Warm         Bulldog                          No
# 6                4:48     Warm         Bulldog                          No
# 7                2:36     Warm         Bulldog                          No
# 8               02:55     Warm         Bulldog                          No
# 9               03:00     Warm         Bulldog                          No
#
#        CLAMP VEIN EARLY UNCLAMPING FLUORESCENCE INNER RENORRHAPHY  \
# 0  Satinsky Clamp               No     Not Used               Yes
# 1              No              Yes         Used               Yes
# 2              No              Yes     Not Used               Yes
# 3              No               No     Not Used               Yes
# 4         Bulldog               No     Not Used               Yes
# 5              No               No     Not Used               Yes
# 6         Bulldog               No         Used               Yes
# 7         Bulldog               No         Used               Yes
# 8         Bulldog              Yes     Not Used               Yes
# 9         Bulldog               No     Not Used               Yes
#
#   OUTER RENORRHAPHY ISCHEMIA TIME (min)     UCS REPAIR HAEMOSTATIC AGENTS  \
# 0               Yes                  24      Performed                Yes
# 1               Yes                  15      Performed                 No
# 2               Yes               15.16      Performed                Yes
# 3               Yes                  30  Not Performed                 No
# 4               Yes                  20      Performed                Yes
# 5               Yes                  14  Not Performed                Yes
# 6               Yes                  23      Performed                Yes
# 7               Yes                  18  Not Performed                 No
# 8               Yes                  25      Performed                Yes
# 9               Yes                  23      Performed                Yes
#
#          HAEMOSTATIC Details LYMPH NODE DISSECTION(LND) BLOOD LOSS (ml)  \
# 0          Surgicel+surgiflo              Not Performed             600
# 1                        NaN              Not Performed             300
# 2         perclot & surgicel              Not Performed             700
# 3                        NaN                  Performed            2000
# 4  surgiflo + nuknit bolster              Not Performed             300
# 5                     Evicel              Not Performed             800
# 6                   Surgicel                  Performed             650
# 7                        NaN                  Performed             150
# 8            fibrin Vivostat              Not Performed             200
# 9                    FLOSEAL              Not Performed             150
#
#   INTRA-OP TRANSUFUSION SURGICAL CONSIDERATIONS INTRA-OP COMPLICATION  \
# 0                1 Unit                     NaN                   Yes
# 1                    No                     NaN                    No
# 2                    No                     NaN                    No
# 3                    No                     NaN                    No
# 4                    No                     NaN                    No
# 5                    No                     NaN                    No
# 6                    No                     NaN                    No
# 7                    No                     NaN                    No
# 8                    No                       0                    No
# 9                    No                     NaN                    No
#
#   INTRA-OP COMPLICATIONS Need to Convert to Radical Nephrectomy  \
# 0                180,310                                     No
# 1                    NaN                                     No
# 2                    NaN                                     No
# 3                    NaN                                    Yes
# 4                    NaN                                     No
# 5                    NaN                                     No
# 6                    NaN                                     No
# 7                    NaN                                     No
# 8                    NaN                                     No
# 9                    NaN                                     No
#
#   TREATMENT OF COMPLICATION POST-OP COMPLICATION SURGICAL COMPLICATIONS  \
# 0                       NaN     No Complications                    NaN
# 1                       NaN     No Complications                    NaN
# 2                       NaN        Complications                    320
# 3                       NaN     No Complications                    NaN
# 4                       NaN     No Complications                    NaN
# 5                       NaN     No Complications                    NaN
# 6                       NaN        Complications                316,319
# 7                       NaN     No Complications                    NaN
# 8                       NaN     No Complications                    NaN
# 9                       NaN     No Complications                    NaN
#
#   NON SURGICAL COMPLICATIONS  \
# 0                        NaN
# 1                        NaN
# 2                        322
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
#
#                    POST-OP TREATMENT OF COMPLICATION  \
# 0                                                NaN
# 1                                                NaN
# 2    blood  transfusion 1U\r\nArrhythmia: medication
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  Diagnostic Laparoscopy performed: Intra-abdomi...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                        CLAVIEN GRADE POST-OP HB_Day 1  \
# 0               Grade 0: Absence of any complication              9.5
# 1               Grade 0: Absence of any complication              999
# 2  Grade 2: Complications needing only use of int...              8.6
# 3               Grade 0: Absence of any complication             13.7
# 4               Grade 0: Absence of any complication             10.7
# 5               Grade 0: Absence of any complication              116
# 6  Grade 3: Complications needing surgical, endos...             10.8
# 7               Grade 0: Absence of any complication              999
# 8               Grade 0: Absence of any complication             13.5
# 9               Grade 0: Absence of any complication             12.6
#
#   POST-OP HT_Day 1 POST-OP Creat_Day 1 POST-OP EGFR_Day 1 POST-OP WBC_Day 1  \
# 0             28.8                 0.8               75.7             14600
# 1             32.5                0.79              76.91               999
# 2             27.9                1.06                 50              4370
# 3             41.5                1.30                999              14.5
# 4             33.1                 1.4                 52              13.4
# 5            0.354                1.17                 69                10
# 6             32.6                2.51              26.21              17.6
# 7             29.6                1.01              83.52               999
# 8             38.7                   1               86.2              11.3
# 9             38.9                1.46                 81             16600
#
#    POST-OP HB_Day 2  POST-OP HT_Day 2 POST-OP Creat_Day 2 POST-OP EGFR_Day 2  \
# 0             999.0             999.0                 999                999
# 1             999.0             999.0                 999                999
# 2               8.3              26.4                0.89                 61
# 3              12.2              37.0                1.51                999
# 4              10.7              34.4                 1.6                 44
# 5             999.0             999.0                 999                999
# 6              10.3              31.3                2.58              25.35
# 7             999.0              28.2                0.99              85.56
# 8              13.5              39.5                 1.1               76.8
# 9             999.0             999.0                 999                999
#
#   POST-OP WBC_Day 2  POST-OP HB_Day 3  POST-OP HT_Day 3  POST-OP Creat_Day 3  \
# 0               999             999.0             999.0               999.00
# 1               999             999.0             999.0               999.00
# 2              4550               8.9              28.8                 0.91
# 3              15.2              11.1              33.1                 1.25
# 4             14.16              11.1              29.4                 1.30
# 5               999             999.0             999.0               999.00
# 6              14.9               8.2              24.4                 2.12
# 7               999             999.0             999.0               999.00
# 8              14.5              12.9              39.2                 1.06
# 9               999              12.0              35.0                 1.30
#
#   POST-OP EGFR_Day 3 POST-OP WBC_Day 3  LENGTH OF STAY (days)  \
# 0                999               999                    5.0
# 1                999               999                    1.0
# 2                 59              5820                   11.0
# 3                999              10.4                    6.0
# 4                 56              10.2                    3.0
# 5                999               999                    2.0
# 6              32.15                10                    4.0
# 7                999               999                    2.0
# 8               80.3              16.3                    3.0
# 9                 92               999                    3.0
#
#    PATHOLOGICAL TUMOR SIZE  MIN THICKNESS MARGIN  MAX THICKNESS MARGIN  \
# 0                      8.5                   0.4                   0.4
# 1                      8.5                   9.0                 999.0
# 2                      7.5                 999.0                 999.0
# 3                      7.0                 999.0                 999.0
# 4                      7.0                   8.0                   0.0
# 5                     68.0                   1.0                   1.0
# 6                      6.5                   3.0                 999.0
# 7                      6.5                   1.0                   7.0
# 8                      6.5                   8.0                  23.0
# 9                      6.0                   2.0                   2.0
#
#   MULITIFOCALITY PATHOLOGY HYSTOTYPE MALIGNANAT  \
# 0         Absent    Benign                   No
# 1         Absent    Benign                   No
# 2         Absent    Malign                  Yes
# 3         Absent    Malign                  Yes
# 4         Absent    Malign                  Yes
# 5         Absent    Malign                  Yes
# 6         Absent    Benign                   No
# 7         Absent    Malign                  Yes
# 8         Absent    Malign                  Yes
# 9         Absent    Malign                  Yes
#
#            HYSTOTYPE MALIGNANAT YES HYSTOTYPE BENIGN HYSTOTYPE BENIGN YES  \
# 0                               NaN              Yes       Angiomyolipoma
# 1                               NaN              Yes       Angiomyolipoma
# 2   Clear cell renal cell carcinoma               No                  NaN
# 3  Chromophobe renal cell carcinoma               No                  NaN
# 4   Clear cell renal cell carcinoma               No                  NaN
# 5   Clear cell renal cell carcinoma               No                  NaN
# 6                               NaN              Yes           Oncocytoma
# 7    Papillary renal cell carcinoma               No                  NaN
# 8   Clear cell renal cell carcinoma               No                  NaN
# 9   Clear cell renal cell carcinoma               No                  NaN
#
#   FUHRMAN GRADING SARCOMATOID DIFF  %SARCOMATOID DIFF NECROSIS  \
# 0             999           Absent                0.0   Absent
# 1             999           Absent                0.0   Absent
# 2               2           Absent                0.0   Absent
# 3             999           Absent                0.0   Absent
# 4               2           Absent                0.0   Absent
# 5               1           Absent                0.0   Absent
# 6             999          Present                0.0   Absent
# 7               2           Absent                0.0   Absent
# 8               3           Absent                0.0   Absent
# 9               1           Absent                NaN   Absent
#
#   MICRO VENOUS INVASION UCS INVASION.1 PERIRENAL FAT INVASION  \
# 0                Absent         Absent                 Absent
# 1                Absent         Absent                 Absent
# 2                Absent         Absent                 Absent
# 3                Absent         Absent                Present
# 4                Absent         Absent                 Absent
# 5                Absent         Absent                 Absent
# 6                Absent         Absent                 Absent
# 7                Absent         Absent                 Absent
# 8                Absent         Absent                 Absent
# 9                Absent        Present                 Absent
#
#   Hilar Fat Invasion SINUS FAT INVASION  MIC SCORE ADRENAL INVASION  \
# 0             Absent             Absent        0.0           Absent
# 1             Absent             Absent        0.0           Absent
# 2             Absent             Absent        NaN           Absent
# 3             Absent             Absent        0.0           Absent
# 4             Absent             Absent        NaN           Absent
# 5             Absent             Absent        0.0           Absent
# 6             Absent             Absent        0.0           Absent
# 7             Absent             Absent        0.0           Absent
# 8             Absent             Absent        0.0           Absent
# 9             Absent             Absent        0.0           Absent
#
#   GEROTA INVASION Renal Vein Invasion VENOUS THROMBUS SURGICAL MARGIN  \
# 0          Absent              Absent          Absent        Negative
# 1          Absent              Absent          Absent        Negative
# 2          Absent              Absent          Absent        Negative
# 3          Absent             Present          Absent        Negative
# 4          Absent              Absent          Absent        Negative
# 5          Absent              Absent          Absent        Negative
# 6          Absent              Absent          Absent        Negative
# 7          Absent              Absent          Absent        Negative
# 8          Absent              Absent          Absent        Negative
# 9          Absent              Absent          Absent        Negative
#
#   UNIFOCAL/MULTIFOCAL NO_OF_NODE_TAKEN NO_OF_NODE_POSITIVE  \
# 0                 NaN                0                   0
# 1                 NaN                0                   0
# 2                 NaN                0                   0
# 3                 NaN                1                   0
# 4                 NaN                1                   0
# 5                 NaN                0                   0
# 6                 NaN                4                   0
# 7                 NaN                1                   0
# 8                 NaN                0                   0
# 9                 NaN              NaN                 NaN
#
#   SITE OF POSITIVE NODE    TREATMENT PSM      PT  PN OTHER TUMORS  \
# 0         Not Applicable             NaN  Benign  Nx          NaN
# 1         Not Applicable             NaN  Benign  Nx          NaN
# 2         Not Applicable             NaN     T2a  Nx          NaN
# 3         Not Applicable             NaN     T3a  N0          NaN
# 4         Not Applicable             NaN     T1b  N0          NaN
# 5         Not Applicable             NaN     T1a  Nx          NaN
# 6                   Ilar             NaN  Benign  N0          NaN
# 7         Not Applicable             NaN     T1b  N0          NaN
# 8         Not Applicable  Wait and Watch     T1b  Nx          NaN
# 9                    NaN             NaN     T1b  Nx          NaN
#
#   DATE OF RECURRENCE  LAST FOLLOW UP DURATION TIME TO RECURRENCE  \
# 0                NaN                      0.5                NaN
# 1                NaN                      2.8                NaN
# 2                NaN                     -0.2                NaN
# 3                NaN                      7.5                NaN
# 4                NaN                      1.7                NaN
# 5                NaN                      2.5                NaN
# 6                NaN                      0.0                NaN
# 7                NaN                      0.4                NaN
# 8                NaN                      3.1                NaN
# 9                NaN                      3.1                NaN
#
#     LAST FOLLOW UP STATUS LAST FOLLOW UP RECURRENCE  \
# 0  Alive and disease free                      None
# 1  Alive and disease free                      None
# 2  Alive and disease free                      None
# 3  Alive and disease free                      None
# 4  Alive and disease free                      None
# 5  Alive and disease free                      None
# 6  Alive and disease free                      None
# 7  Alive and disease free                      None
# 8  Alive and disease free                      None
# 9  Alive and disease free                      None
#
#   LAST TREATMENT OF RECURRENCE   TYPE OF COMPLICATIONS(s)  \
# 0                         None  (FUP1 : No Complications)
# 1                         None  (FUP1 : No Complications)
# 2                         None  (FUP1 : No Complications)
# 3                         None  (FUP1 : No Complications)
# 4                         None  (FUP1 : No Complications)
# 5                         None  (FUP1 : No Complications)
# 6                         None     (FUP1 : Complications)
# 7                         None  (FUP1 : No Complications)
# 8                         None  (FUP1 : No Complications)
# 9                         None  (FUP1 : No Complications)
#
#   SELECTED SURGICAL COMPLICATIONS(s) SELECTED NON SURGICAL COMPLICATIONS(s)  \
# 0                      (FUP1 : NULL)                          (FUP1 : NULL)
# 1                      (FUP1 : NULL)                          (FUP1 : NULL)
# 2                      (FUP1 : NULL)                          (FUP1 : NULL)
# 3                      (FUP1 : NULL)                          (FUP1 : NULL)
# 4                      (FUP1 : NULL)                          (FUP1 : NULL)
# 5                      (FUP1 : NULL)                          (FUP1 : NULL)
# 6                   (FUP1 : 316,319)                           (FUP1 : 324)
# 7                      (FUP1 : NULL)                          (FUP1 : NULL)
# 8                      (FUP1 : NULL)                          (FUP1 : NULL)
# 9                      (FUP1 : NULL)                          (FUP1 : NULL)
#
#                        TREATMENT OF COMPLICATIONS(s)  RECURRENCE(s)  \
# 0                                          (FUP1 : )  (FUP1 : None)
# 1                                          (FUP1 : )  (FUP1 : None)
# 2                                          (FUP1 : )  (FUP1 : None)
# 3  (FUP1 : The extensive nature of the surgery ha...  (FUP1 : None)
# 4                                       (FUP1 : Nil)  (FUP1 : None)
# 5                                          (FUP1 : )  (FUP1 : None)
# 6  (FUP1 : Intra-abdominal bleed; clot removed an...  (FUP1 : None)
# 7                                        (FUP1 : NA)  (FUP1 : None)
# 8                                          (FUP1 : )  (FUP1 : None)
# 9                                          (FUP1 : )  (FUP1 : None)
#
#      FOLLOW UP DATE(s)                        STATUS(s)   TREATMENT(s)  \
# 0  (FUP1 : 2017-10-10)  (FUP1 : Alive and disease free)  (FUP1 : None)
# 1  (FUP1 : 2016-05-31)  (FUP1 : Alive and disease free)  (FUP1 : None)
# 2  (FUP1 : 2015-12-29)  (FUP1 : Alive and disease free)  (FUP1 : None)
# 3  (FUP1 : 2015-10-08)  (FUP1 : Alive and disease free)  (FUP1 : None)
# 4  (FUP1 : 2015-08-13)  (FUP1 : Alive and disease free)  (FUP1 : None)
# 5  (FUP1 : 2015-11-11)  (FUP1 : Alive and disease free)  (FUP1 : None)
# 6  (FUP1 : 2015-11-05)  (FUP1 : Alive and disease free)  (FUP1 : None)
# 7  (FUP1 : 2015-12-22)  (FUP1 : Alive and disease free)  (FUP1 : None)
# 8  (FUP1 : 2016-06-09)  (FUP1 : Alive and disease free)  (FUP1 : None)
# 9  (FUP1 : 2018-02-16)  (FUP1 : Alive and disease free)  (FUP1 : None)
#
#    CREATININE(s)         EGFR(s)              SRF(s)      ERPF(s)  data_record
# 0     (FUP1 : 1)     (FUP1 : NP)         (FUP1 : NP)  (FUP1 : NP)  prospective
# 1   (FUP1 : .67)  (FUP1 : 84.27)         (FUP1 : NP)  (FUP1 : NP)  prospective
# 2  (FUP1 : 0.85)     (FUP1 : 60)         (FUP1 : NA)  (FUP1 : NA)  prospective
# 3  (FUP1 : 1.26)     (FUP1 : 58)           (FUP1 : )    (FUP1 : )  prospective
# 4   (FUP1 : 1.2)   (FUP1 : 61.6)  (FUP1 : 30.5(45%))   (FUP1 : -)  prospective
# 5  (FUP1 : 1.17)     (FUP1 : 69)         (FUP1 : NP)  (FUP1 : NP)  prospective
# 6  (FUP1 : 2.51)  (FUP1 : 26.21)         (FUP1 : NP)  (FUP1 : NP)  prospective
# 7  (FUP1 : 1.16)     (FUP1 : 71)         (FUP1 : NP)  (FUP1 : NP)  prospective
# 8  (FUP1 : 0,94)   (FUP1 : 89,7)           (FUP1 : )    (FUP1 : )  prospective
# 9  (FUP1 : 0.92)     (FUP1 : 96)         (FUP1 : 43)  (FUP1 : NA)  prospective

# %%
df.describe()
# Out:
#        DATE OF BIRTH  AGE AT SURGERY       WEIGHT      HEIGHT          BMI  \
# count     1919.00000     3294.000000  2327.000000  2289.00000  2958.000000
# mean      1955.81136       57.843655    90.291609   161.08460    28.906286
# std         13.14144       12.702301    40.666559    29.14078     8.013751
# min       1921.00000        0.000000     7.711150    51.00000     2.320000
# 25%       1946.00000       49.000000    69.000000   160.00000    24.610000
# 50%       1955.00000       59.000000    80.000000   169.00000    27.700000
# 75%       1965.00000       67.000000    94.750000   176.00000    31.910000
# max       2015.00000       89.000000   377.000000   208.30000   304.000000
#
#        CLINICAL SIZE (mm)  CHARLSON SCORE  CHARLSON AGE-ADJUST SCORE  \
# count         3122.000000     2737.000000                2702.000000
# mean            43.947341        1.522835                   3.541451
# std            333.125372        1.916268                   2.199328
# min              0.000000        0.000000                   0.000000
# 25%             21.000000        0.000000                   2.000000
# 50%             30.000000        1.000000                   3.000000
# 75%             42.000000        2.000000                   5.000000
# max          18200.000000       19.000000                  14.000000
#
#        PRE-OP CREAT  PRE-OP EGFR  PADUA SCORE  LOCATION TO POLAR LINE  \
# count   3264.000000  2569.000000  2123.000000             1944.000000
# mean       6.943323    80.452488     8.404145                1.899177
# std       76.017258    24.170568     1.748467                0.822433
# min        0.000000     0.266354     2.000000                1.000000
# 25%        0.780000    65.720000     7.000000                1.000000
# 50%        0.910000    79.572342     8.000000                2.000000
# 75%        1.100000    94.000000    10.000000                3.000000
# max      999.000000   253.971416    14.000000                3.000000
#
#        NO OF LESIONS  POST-OP HB_Day 2  POST-OP HT_Day 2  POST-OP HB_Day 3  \
# count    2678.000000       1114.000000       1154.000000        986.000000
# mean        1.053771        335.618887        349.216124        468.772809
# std         0.266591        458.270906        456.519416        490.323768
# min         0.000000          1.330000          0.204000          0.300000
# 25%         1.000000         11.300000         31.800000         11.500000
# 50%         1.000000         13.000000         37.000000         14.350000
# 75%         1.000000        999.000000        999.000000        999.000000
# max         5.000000        999.000000        999.000000        999.000000
#
#        POST-OP HT_Day 3  POST-OP Creat_Day 3  LENGTH OF STAY (days)  \
# count        996.000000          1199.000000            3067.000000
# mean         509.636336           376.595229               3.161722
# std          484.899641           483.504763               2.479386
# min            0.284000             0.270000               0.000000
# 25%           33.075000             1.000000               2.000000
# 50%           45.500000             1.400000               3.000000
# 75%          999.000000           999.000000               4.000000
# max          999.000000           999.000000              51.000000
#
#        PATHOLOGICAL TUMOR SIZE  MIN THICKNESS MARGIN  MAX THICKNESS MARGIN  \
# count              2781.000000           1664.000000            974.000000
# mean                 11.626124            274.839844            690.035421
# std                  40.328840           2490.582220           3321.287384
# min                   0.000000              0.000000              0.000000
# 25%                   2.400000              1.000000              3.625000
# 50%                   3.500000              3.000000            999.000000
# 75%                   7.300000             11.000000            999.000000
# max                 999.000000          99999.000000          99999.000000
#
#        %SARCOMATOID DIFF    MIC SCORE  LAST FOLLOW UP DURATION
# count        1365.000000  2290.000000              1923.000000
# mean           14.015385     0.297817                16.916485
# std           154.822902     0.457398                19.503374
# min          -999.000000     0.000000                -0.800000
# 25%             0.000000     0.000000                 3.000000
# 50%             0.000000     0.000000                10.000000
# 75%             0.000000     1.000000                24.000000
# max           999.000000     1.000000               101.000000

# %%
df.info(verbose = True, null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3312 entries, 0 to 2390
# Data columns (total 162 columns):
# PATIENT NUMBER                              3312 non-null object
# PROC NAME                                   3312 non-null object
# CENTER CODE                                 3312 non-null object
# SURGEON CODE                                921 non-null object
# REC PROGRESS                                3312 non-null object
# CREATED DATE                                3312 non-null object
# GENDER                                      3302 non-null object
# DATE OF BIRTH                               1919 non-null float64
# AGE AT SURGERY                              3294 non-null float64
# MARITAL STATUS                              2080 non-null object
# RACE                                        2016 non-null object
# EDUCATION                                   1843 non-null object
# WEIGHT                                      2327 non-null float64
# HEIGHT                                      2289 non-null float64
# BMI                                         2958 non-null float64
# CLINICAL SIZE (mm)                          3122 non-null float64
# ECOG                                        1806 non-null object
# CHARLSON SCORE                              2737 non-null float64
# CHARLSON AGE-ADJUST SCORE                   2702 non-null float64
# SYMPTOMS                                    2486 non-null object
# SOLITARY KIDNEY                             2787 non-null object
# TYPE OF SOLITARY KIDNEY                     116 non-null object
# BILATERALITY OF TUMOR                       1994 non-null object
# SIDE OF TUMOR                               2237 non-null object
# SIDE OF SURGERY                             3301 non-null object
# PRE-OP MULTIFOCALITY                        912 non-null object
# FACE                                        2491 non-null object
# TUMOR lOCATION                              2805 non-null object
# PRE-OP HB                                   2506 non-null object
# PRE-OP HT                                   2376 non-null object
# PRE-OP WBC                                  2041 non-null object
# PRE-OP CREAT                                3264 non-null float64
# PRE-OP GFR                                  833 non-null object
# PRE-OP EGFR                                 2569 non-null float64
# PRE-OP Split Renal Function                 463 non-null object
# PRE-OP ERPF                                 414 non-null object
# PADUA SCORE                                 2123 non-null float64
# PADUA RISK                                  2074 non-null object
# POLAR LOCATION                              2574 non-null object
# RIM LOCATION                                1976 non-null object
# RENAL SINUS                                 2061 non-null object
# UCS INVASION                                2069 non-null object
# EXOPHYTIC RATE                              2420 non-null object
# CLINICAL SIZE GROUP                         2716 non-null object
# CT                                          2928 non-null object
# CN                                          2632 non-null object
# CM                                          2582 non-null object
# R.E.N.A.L. NEPHRO SCORE                     2696 non-null object
# R.E.N.A.L. NEPHRO RISK STRATIFICATION       2546 non-null object
# RADIUS (maximal diameter in cm)             2927 non-null object
# EXOPHYTIC/ENDOPHYTIC PROPERTIES             2714 non-null object
# NEARNESS OF TUMOUR                          2281 non-null object
# ANTERIOR OR POSTERIOR                       2645 non-null object
# LOCATION TO POLAR LINE                      1944 non-null float64
# Tumor Consistency on Imaging                538 non-null object
# Bosniak Classification                      530 non-null object
# DATE OF SURGERY                             3312 non-null object
# ASA SCORE                                   2824 non-null object
# PARTIAL NEPHRO INDICATION                   2363 non-null object
# MULTIFOCALITY                               1950 non-null object
# NO OF LESIONS                               2678 non-null float64
# Imaging Features of other excised tumor     122 non-null object
# Consistency of the other excised tumor/s    347 non-null object
# ACCESS                                      2405 non-null object
# DA VINCI MODEL                              2114 non-null object
# ROBOTICS ARMS                               2825 non-null object
# ASSISTENT TROCARS                           2606 non-null object
# DUAL CONSOLE                                2369 non-null object
# PRIMARY SURGEON                             1938 non-null object
# OPERATIVE TIME(min)                         2992 non-null object
# ISCHEMIA                                    2704 non-null object
# CLAMP ARTERY                                2696 non-null object
# SELECTIVE ARTERIAL CLAMPING                 1945 non-null object
# CLAMP VEIN                                  2482 non-null object
# EARLY UNCLAMPING                            2468 non-null object
# FLUORESCENCE                                2365 non-null object
# INNER RENORRHAPHY                           1949 non-null object
# OUTER RENORRHAPHY                           1949 non-null object
# ISCHEMIA TIME (min)                         2953 non-null object
# UCS REPAIR                                  2333 non-null object
# HAEMOSTATIC AGENTS                          2355 non-null object
# HAEMOSTATIC Details                         1647 non-null object
# LYMPH NODE DISSECTION(LND)                  2368 non-null object
# BLOOD LOSS (ml)                             3168 non-null object
# INTRA-OP TRANSUFUSION                       2602 non-null object
# SURGICAL CONSIDERATIONS                     213 non-null object
# INTRA-OP COMPLICATION                       2852 non-null object
# INTRA-OP COMPLICATIONS                      165 non-null object
# Need to Convert to Radical Nephrectomy      867 non-null object
# TREATMENT OF COMPLICATION                   697 non-null object
# POST-OP COMPLICATION                        2722 non-null object
# SURGICAL COMPLICATIONS                      104 non-null object
# NON SURGICAL COMPLICATIONS                  66 non-null object
# POST-OP TREATMENT OF COMPLICATION           515 non-null object
# CLAVIEN GRADE                               2309 non-null object
# POST-OP HB_Day 1                            1858 non-null object
# POST-OP HT_Day 1                            2007 non-null object
# POST-OP Creat_Day 1                         2918 non-null object
# POST-OP EGFR_Day 1                          2448 non-null object
# POST-OP WBC_Day 1                           1508 non-null object
# POST-OP HB_Day 2                            1114 non-null float64
# POST-OP HT_Day 2                            1154 non-null float64
# POST-OP Creat_Day 2                         1340 non-null object
# POST-OP EGFR_Day 2                          1122 non-null object
# POST-OP WBC_Day 2                           1103 non-null object
# POST-OP HB_Day 3                            986 non-null float64
# POST-OP HT_Day 3                            996 non-null float64
# POST-OP Creat_Day 3                         1199 non-null float64
# POST-OP EGFR_Day 3                          953 non-null object
# POST-OP WBC_Day 3                           984 non-null object
# LENGTH OF STAY (days)                       3067 non-null float64
# PATHOLOGICAL TUMOR SIZE                     2781 non-null float64
# MIN THICKNESS MARGIN                        1664 non-null float64
# MAX THICKNESS MARGIN                        974 non-null float64
# MULITIFOCALITY                              2413 non-null object
# PATHOLOGY                                   3084 non-null object
# HYSTOTYPE MALIGNANAT                        3168 non-null object
# HYSTOTYPE MALIGNANAT YES                    2467 non-null object
# HYSTOTYPE BENIGN                            3154 non-null object
# HYSTOTYPE BENIGN YES                        626 non-null object
# FUHRMAN GRADING                             2832 non-null object
# SARCOMATOID DIFF                            2146 non-null object
# %SARCOMATOID DIFF                           1365 non-null float64
# NECROSIS                                    2263 non-null object
# MICRO VENOUS INVASION                       2328 non-null object
# UCS INVASION.1                              2222 non-null object
# PERIRENAL FAT INVASION                      2633 non-null object
# Hilar Fat Invasion                          907 non-null object
# SINUS FAT INVASION                          2225 non-null object
# MIC SCORE                                   2290 non-null float64
# ADRENAL INVASION                            2060 non-null object
# GEROTA INVASION                             2123 non-null object
# Renal Vein Invasion                         754 non-null object
# VENOUS THROMBUS                             2175 non-null object
# SURGICAL MARGIN                             2957 non-null object
# UNIFOCAL/MULTIFOCAL                         72 non-null object
# NO_OF_NODE_TAKEN                            1864 non-null object
# NO_OF_NODE_POSITIVE                         1679 non-null object
# SITE OF POSITIVE NODE                       722 non-null object
# TREATMENT PSM                               276 non-null object
# PT                                          2731 non-null object
# PN                                          2295 non-null object
# OTHER TUMORS                                13 non-null object
# DATE OF RECURRENCE                          24 non-null object
# LAST FOLLOW UP DURATION                     1923 non-null float64
# TIME TO RECURRENCE                          220 non-null object
# LAST FOLLOW UP STATUS                       1546 non-null object
# LAST FOLLOW UP RECURRENCE                   1475 non-null object
# LAST TREATMENT OF RECURRENCE                488 non-null object
# TYPE OF COMPLICATIONS(s)                    2778 non-null object
# SELECTED SURGICAL COMPLICATIONS(s)          2778 non-null object
# SELECTED NON SURGICAL COMPLICATIONS(s)      2778 non-null object
# TREATMENT OF COMPLICATIONS(s)               2778 non-null object
# RECURRENCE(s)                               2778 non-null object
# FOLLOW UP DATE(s)                           2778 non-null object
# STATUS(s)                                   2778 non-null object
# TREATMENT(s)                                2778 non-null object
# CREATININE(s)                               2778 non-null object
# EGFR(s)                                     2778 non-null object
# SRF(s)                                      2778 non-null object
# ERPF(s)                                     2778 non-null object
# data_record                                 3312 non-null object
# dtypes: float64(25), object(137)
# memory usage: 4.1+ MB

# %%
numeric_col_list = [
 'PRE-OP HB',
 'PRE-OP HT',
 'PRE-OP WBC',
 'PRE-OP CREAT',
 'PRE-OP GFR',
 'PRE-OP EGFR',
 'PRE-OP Split Renal Function',
 'PRE-OP ERPF',
 'PADUA SCORE',

 'NO OF LESIONS',
 'POST-OP HB_Day 1',
 'POST-OP HT_Day 1',
 'POST-OP Creat_Day 1',
 'POST-OP EGFR_Day 1',
 'POST-OP WBC_Day 1',
 'POST-OP HB_Day 2',
 'POST-OP HT_Day 2',
 'POST-OP Creat_Day 2',
 'POST-OP EGFR_Day 2',
 'POST-OP WBC_Day 2',
 'POST-OP HB_Day 3',
 'POST-OP HT_Day 3',
 'POST-OP Creat_Day 3',
 'POST-OP EGFR_Day 3',
 'POST-OP WBC_Day 3',
 'LENGTH OF STAY (days)',
 'PATHOLOGICAL TUMOR SIZE',
 'MIN THICKNESS MARGIN',
 'MAX THICKNESS MARGIN',
 'FUHRMAN GRADING',
'BLOOD LOSS (ml)',
'R.E.N.A.L. NEPHRO SCORE',
'OPERATIVE TIME(min)',
'ISCHEMIA TIME (min)',
] 
numeric_col_list
# Out:
# ['PRE-OP HB',
#  'PRE-OP HT',
#  'PRE-OP WBC',
#  'PRE-OP CREAT',
#  'PRE-OP GFR',
#  'PRE-OP EGFR',
#  'PRE-OP Split Renal Function',
#  'PRE-OP ERPF',
#  'PADUA SCORE',
#  'NO OF LESIONS',
#  'POST-OP HB_Day 1',
#  'POST-OP HT_Day 1',
#  'POST-OP Creat_Day 1',
#  'POST-OP EGFR_Day 1',
#  'POST-OP WBC_Day 1',
#  'POST-OP HB_Day 2',
#  'POST-OP HT_Day 2',
#  'POST-OP Creat_Day 2',
#  'POST-OP EGFR_Day 2',
#  'POST-OP WBC_Day 2',
#  'POST-OP HB_Day 3',
#  'POST-OP HT_Day 3',
#  'POST-OP Creat_Day 3',
#  'POST-OP EGFR_Day 3',
#  'POST-OP WBC_Day 3',
#  'LENGTH OF STAY (days)',
#  'PATHOLOGICAL TUMOR SIZE',
#  'MIN THICKNESS MARGIN',
#  'MAX THICKNESS MARGIN',
#  'FUHRMAN GRADING',
#  'BLOOD LOSS (ml)',
#  'R.E.N.A.L. NEPHRO SCORE',
#  'OPERATIVE TIME(min)',
#  'ISCHEMIA TIME (min)']

# %%
for col in numeric_col_list:
    df[col]= pd.to_numeric(df[col], errors='coerce')

# %%
df.describe().round(2)
# Out:
#        DATE OF BIRTH  AGE AT SURGERY   WEIGHT   HEIGHT      BMI  \
# count        1919.00         3294.00  2327.00  2289.00  2958.00
# mean         1955.81           57.84    90.29   161.08    28.91
# std            13.14           12.70    40.67    29.14     8.01
# min          1921.00            0.00     7.71    51.00     2.32
# 25%          1946.00           49.00    69.00   160.00    24.61
# 50%          1955.00           59.00    80.00   169.00    27.70
# 75%          1965.00           67.00    94.75   176.00    31.91
# max          2015.00           89.00   377.00   208.30   304.00
#
#        CLINICAL SIZE (mm)  CHARLSON SCORE  CHARLSON AGE-ADJUST SCORE  \
# count             3122.00         2737.00                    2702.00
# mean                43.95            1.52                       3.54
# std                333.13            1.92                       2.20
# min                  0.00            0.00                       0.00
# 25%                 21.00            0.00                       2.00
# 50%                 30.00            1.00                       3.00
# 75%                 42.00            2.00                       5.00
# max              18200.00           19.00                      14.00
#
#        PRE-OP HB  PRE-OP HT  PRE-OP WBC  PRE-OP CREAT  PRE-OP GFR  \
# count    2503.00    2375.00     2036.00       3264.00      742.00
# mean       27.54      53.16     2893.94          6.94      283.98
# std       115.72     126.12     3848.07         76.02      389.24
# min         0.50       0.25        2.70          0.00        0.60
# 25%        12.80      36.30        6.76          0.78       60.00
# 50%        13.90      41.00       10.40          0.91       82.45
# 75%        14.90      44.00     6400.00          1.10      130.32
# max       999.00     999.00    25510.00        999.00      999.00
#
#        PRE-OP EGFR  PRE-OP Split Renal Function  PRE-OP ERPF  PADUA SCORE  \
# count      2569.00                       431.00       407.00      2123.00
# mean         80.45                       721.53       801.42         8.40
# std          24.17                       430.00       359.65         1.75
# min           0.27                        20.70        38.30         2.00
# 25%          65.72                       100.00       999.00         7.00
# 50%          79.57                       999.00       999.00         8.00
# 75%          94.00                       999.00       999.00        10.00
# max         253.97                       999.00       999.00        14.00
#
#        R.E.N.A.L. NEPHRO SCORE  LOCATION TO POLAR LINE  NO OF LESIONS  \
# count                  1748.00                 1944.00        2678.00
# mean                      6.84                    1.90           1.05
# std                       1.85                    0.82           0.27
# min                       2.00                    1.00           0.00
# 25%                       5.00                    1.00           1.00
# 50%                       7.00                    2.00           1.00
# 75%                       8.00                    3.00           1.00
# max                      12.00                    3.00           5.00
#
#        OPERATIVE TIME(min)  ISCHEMIA TIME (min)  BLOOD LOSS (ml)  \
# count              2145.00              2952.00          3167.00
# mean                190.19                22.84           187.34
# std                 101.79                63.23           277.99
# min                   3.00                 0.00             0.00
# 25%                 140.00                14.00            50.00
# 50%                 177.00                18.00           100.00
# 75%                 218.00                23.00           200.00
# max                 999.00               999.00          9650.00
#
#        POST-OP HB_Day 1  POST-OP HT_Day 1  POST-OP Creat_Day 1  \
# count           1854.00           2003.00              2915.00
# mean              88.98             65.77                28.09
# std              252.48            179.36               161.09
# min                1.00              0.25                 0.00
# 25%               11.10             31.25                 0.95
# 50%               12.30             35.40                 1.00
# 75%               13.80             38.90                 1.32
# max              999.00            999.00               999.00
#
#        POST-OP EGFR_Day 1  POST-OP WBC_Day 1  POST-OP HB_Day 2  \
# count             2369.00            1503.00           1114.00
# mean               182.93            3200.02            335.62
# std                309.10            5536.25            458.27
# min                  1.26               0.00              1.33
# 25%                 54.01               9.90             11.30
# 50%                 69.00              14.10             13.00
# 75%                 88.50            7112.00            999.00
# max                999.00          107000.00            999.00
#
#        POST-OP HT_Day 2  POST-OP Creat_Day 2  POST-OP EGFR_Day 2  \
# count           1154.00              1339.00             1111.00
# mean             349.22               266.15              443.62
# std              456.52               440.39              459.35
# min                0.20                 0.45               11.00
# 25%               31.80                 1.00               58.60
# 50%               37.00                 1.30               86.00
# 75%              999.00               999.00              999.00
# max              999.00               999.00              999.00
#
#        POST-OP WBC_Day 2  POST-OP HB_Day 3  POST-OP HT_Day 3  \
# count            1102.00            986.00            996.00
# mean             3088.59            468.77            509.64
# std              5519.57            490.32            484.90
# min                 2.10              0.30              0.28
# 25%                11.10             11.50             33.08
# 50%               999.00             14.35             45.50
# 75%              5100.00            999.00            999.00
# max            105303.00            999.00            999.00
#
#        POST-OP Creat_Day 3  POST-OP EGFR_Day 3  POST-OP WBC_Day 3  \
# count              1199.00              936.00             982.00
# mean                376.60              564.26            2669.21
# std                 483.50              465.12            3893.59
# min                   0.27               10.00               2.00
# 25%                   1.00               69.00              13.45
# 50%                   1.40              999.00             999.00
# 75%                 999.00              999.00             999.00
# max                 999.00              999.00           25340.00
#
#        LENGTH OF STAY (days)  PATHOLOGICAL TUMOR SIZE  MIN THICKNESS MARGIN  \
# count                3067.00                  2781.00               1664.00
# mean                    3.16                    11.63                274.84
# std                     2.48                    40.33               2490.58
# min                     0.00                     0.00                  0.00
# 25%                     2.00                     2.40                  1.00
# 50%                     3.00                     3.50                  3.00
# 75%                     4.00                     7.30                 11.00
# max                    51.00                   999.00              99999.00
#
#        MAX THICKNESS MARGIN  FUHRMAN GRADING  %SARCOMATOID DIFF  MIC SCORE  \
# count                974.00          2467.00            1365.00    2290.00
# mean                 690.04            76.10              14.02       0.30
# std                 3321.29           261.29             154.82       0.46
# min                    0.00             1.00            -999.00       0.00
# 25%                    3.62             2.00               0.00       0.00
# 50%                  999.00             2.00               0.00       0.00
# 75%                  999.00             3.00               0.00       1.00
# max                99999.00           999.00             999.00       1.00
#
#        LAST FOLLOW UP DURATION
# count                  1923.00
# mean                     16.92
# std                      19.50
# min                      -0.80
# 25%                       3.00
# 50%                      10.00
# 75%                      24.00
# max                     101.00

# %%
#replace default missing values such as 999 in the dataframe with NaN
df = df.replace([99,999,9999,99999,999999],np.nan)

# %%
df.describe().round(2)
# Out:
#        DATE OF BIRTH  AGE AT SURGERY   WEIGHT   HEIGHT      BMI  \
# count        1919.00         3294.00  2323.00  2289.00  2958.00
# mean         1955.81           57.84    90.28   161.08    28.91
# std            13.14           12.70    40.70    29.14     8.01
# min          1921.00            0.00     7.71    51.00     2.32
# 25%          1946.00           49.00    69.00   160.00    24.61
# 50%          1955.00           59.00    80.00   169.00    27.70
# 75%          1965.00           67.00    94.27   176.00    31.91
# max          2015.00           89.00   377.00   208.30   304.00
#
#        CLINICAL SIZE (mm)  CHARLSON SCORE  CHARLSON AGE-ADJUST SCORE  \
# count             3107.00         2737.00                    2702.00
# mean                39.34            1.52                       3.54
# std                327.23            1.92                       2.20
# min                  0.00            0.00                       0.00
# 25%                 21.00            0.00                       2.00
# 50%                 30.00            1.00                       3.00
# 75%                 42.00            2.00                       5.00
# max              18200.00           19.00                      14.00
#
#        PRE-OP HB  PRE-OP HT  PRE-OP WBC  PRE-OP CREAT  PRE-OP GFR  \
# count    2468.00    2334.00     1990.00       3245.00      573.00
# mean       13.76      36.54     2937.75          1.13       73.09
# std         1.80      13.66     3881.38          3.80       25.83
# min         0.50       0.25        2.70          0.00        0.60
# 25%        12.80      36.12        6.70          0.78       60.00
# 50%        13.90      40.80       10.00          0.91       68.00
# 75%        14.90      44.00     6500.00          1.10       89.00
# max        39.60      88.00    25510.00        109.00      213.40
#
#        PRE-OP EGFR  PRE-OP Split Renal Function  PRE-OP ERPF  PADUA SCORE  \
# count      2555.00                       127.00        95.00      2123.00
# mean         80.35                        57.35       152.51         8.40
# std          24.20                        25.01        59.61         1.75
# min           0.27                        20.70        38.30         2.00
# 25%          65.52                        41.00       110.00         7.00
# 50%          79.32                        48.00       140.50         8.00
# 75%          93.71                        58.75       197.22        10.00
# max         253.97                       100.00       340.00        14.00
#
#        R.E.N.A.L. NEPHRO SCORE  LOCATION TO POLAR LINE  NO OF LESIONS  \
# count                  1748.00                 1944.00        2678.00
# mean                      6.84                    1.90           1.05
# std                       1.85                    0.82           0.27
# min                       2.00                    1.00           0.00
# 25%                       5.00                    1.00           1.00
# 50%                       7.00                    2.00           1.00
# 75%                       8.00                    3.00           1.00
# max                      12.00                    3.00           5.00
#
#        OPERATIVE TIME(min)  ISCHEMIA TIME (min)  BLOOD LOSS (ml)  \
# count              2122.00              2940.00          3167.00
# mean                182.27                18.86           187.34
# std                  62.65                10.39           277.99
# min                   3.00                 0.00             0.00
# 25%                 140.00                14.00            50.00
# 50%                 176.00                18.00           100.00
# 75%                 215.00                23.00           200.00
# max                 608.00               320.00          9650.00
#
#        POST-OP HB_Day 1  POST-OP HT_Day 1  POST-OP Creat_Day 1  \
# count           1722.00           1932.00              2836.00
# mean              19.75             31.48                 1.36
# std               28.36             12.40                 4.59
# min                1.00              0.25                 0.00
# 25%               11.00             31.00                 0.94
# 50%               12.10             35.10                 1.00
# 75%               13.30             38.40                 1.30
# max              162.00             88.00               143.00
#
#        POST-OP EGFR_Day 1  POST-OP WBC_Day 1  POST-OP HB_Day 2  \
# count             2069.00            1326.00            755.00
# mean                66.34            3495.18             20.18
# std                 21.67            5831.20             29.01
# min                  1.26               0.00              1.33
# 25%                 51.87               9.50             10.80
# 50%                 64.80              12.58             12.00
# 75%                 79.11            8090.00             13.00
# max                198.38          107000.00            152.00
#
#        POST-OP HT_Day 2  POST-OP Creat_Day 2  POST-OP EGFR_Day 2  \
# count            773.00               984.00              657.00
# mean              28.95                 1.76               65.32
# std               13.61                 7.48               37.22
# min                0.20                 0.45               11.00
# 25%               28.10                 0.90               48.46
# 50%               33.70                 1.10               63.00
# 75%               37.10                 1.40               80.79
# max               50.00               174.00              811.00
#
#        POST-OP WBC_Day 2  POST-OP HB_Day 3  POST-OP HT_Day 3  \
# count             732.00            532.00            503.00
# mean             4146.04             16.29             30.00
# std              6523.04             21.66             18.67
# min                 2.10              0.30              0.28
# 25%                 9.88             10.38             28.50
# 50%                14.00             11.80             33.10
# 75%              8800.00             12.80             37.00
# max            105303.00            131.00            332.00
#
#        POST-OP Creat_Day 3  POST-OP EGFR_Day 3  POST-OP WBC_Day 3  \
# count               748.00              436.00             518.00
# mean                  1.32               67.76            4165.31
# std                   3.98               24.90            4900.99
# min                   0.27               10.00               2.00
# 25%                   0.87               51.53               8.90
# 50%                   1.07               67.00              15.40
# 75%                   1.28               81.53            8623.50
# max                 109.00              174.10           25340.00
#
#        LENGTH OF STAY (days)  PATHOLOGICAL TUMOR SIZE  MIN THICKNESS MARGIN  \
# count                3067.00                   2777.0               1319.00
# mean                    3.16                     10.2                  4.23
# std                     2.48                     14.9                 10.75
# min                     0.00                      0.0                  0.00
# 25%                     2.00                      2.4                  1.00
# 50%                     3.00                      3.5                  2.00
# 75%                     4.00                      7.2                  4.00
# max                    51.00                    115.0                240.00
#
#        MAX THICKNESS MARGIN  FUHRMAN GRADING  %SARCOMATOID DIFF  MIC SCORE  \
# count                468.00          2284.00            1338.00    2290.00
# mean                  11.75             2.16              -5.19       0.30
# std                   49.46             0.67              72.20       0.46
# min                    0.00             1.00            -999.00       0.00
# 25%                    1.20             2.00               0.00       0.00
# 50%                    3.00             2.00               0.00       0.00
# 75%                    8.00             3.00               0.00       1.00
# max                  979.00             4.00              70.00       1.00
#
#        LAST FOLLOW UP DURATION
# count                  1923.00
# mean                     16.92
# std                      19.50
# min                      -0.80
# 25%                       3.00
# 50%                      10.00
# 75%                      24.00
# max                     101.00

# %%
# replacing negative numbers in the dataframe with nan
for col in list(df.select_dtypes('float64')):
    df[col] = df[col].apply(lambda x: np.nan if x<0 else x)

# %%
# if the value of PRE-OP WBC value contains is less the 4 digits then multiply it by 1000
df['PRE-OP WBC'] = df['PRE-OP WBC'].apply(lambda x: x*1000 if len(str(round(x,2))) <6 else x)

# if the value of POST-OP WBC_Day 1 value contains is less the 4 digits then multiply it by 1000
df['POST-OP WBC_Day 1'] = df['POST-OP WBC_Day 1'].apply(lambda x: x*1000 if len(str(round(x,2))) <6 else x)

# if the value of POST-OP WBC_Day 2 value contains is less the 4 digits then multiply it by 1000
df['POST-OP WBC_Day 2'] = df['POST-OP WBC_Day 2'].apply(lambda x: x*1000 if len(str(round(x,2))) <6 else x)

# if the value of POST-OP WBC_Day 2 value contains is less the 4 digits then multiply it by 1000
df['POST-OP WBC_Day 3'] = df['POST-OP WBC_Day 3'].apply(lambda x: x*1000 if len(str(round(x,2))) <6 else x)

# %%
import seaborn as sns
sns.boxplot(x=df['PRE-OP WBC'])

# %%
df.describe().round(2)
# Out:
#        DATE OF BIRTH  AGE AT SURGERY   WEIGHT   HEIGHT      BMI  \
# count        1919.00         3294.00  2323.00  2289.00  2958.00
# mean         1955.81           57.84    90.28   161.08    28.91
# std            13.14           12.70    40.70    29.14     8.01
# min          1921.00            0.00     7.71    51.00     2.32
# 25%          1946.00           49.00    69.00   160.00    24.61
# 50%          1955.00           59.00    80.00   169.00    27.70
# 75%          1965.00           67.00    94.27   176.00    31.91
# max          2015.00           89.00   377.00   208.30   304.00
#
#        CLINICAL SIZE (mm)  CHARLSON SCORE  CHARLSON AGE-ADJUST SCORE  \
# count             3107.00         2737.00                    2702.00
# mean                39.34            1.52                       3.54
# std                327.23            1.92                       2.20
# min                  0.00            0.00                       0.00
# 25%                 21.00            0.00                       2.00
# 50%                 30.00            1.00                       3.00
# 75%                 42.00            2.00                       5.00
# max              18200.00           19.00                      14.00
#
#        PRE-OP HB  PRE-OP HT  PRE-OP WBC  PRE-OP CREAT  PRE-OP GFR  \
# count    2468.00    2334.00     1990.00       3245.00      573.00
# mean       13.76      36.54     7640.82          1.13       73.09
# std         1.80      13.66     2951.85          3.80       25.83
# min         0.50       0.25     1060.00          0.00        0.60
# 25%        12.80      36.12     5800.00          0.78       60.00
# 50%        13.90      40.80     7200.00          0.91       68.00
# 75%        14.90      44.00     8600.00          1.10       89.00
# max        39.60      88.00    56000.00        109.00      213.40
#
#        PRE-OP EGFR  PRE-OP Split Renal Function  PRE-OP ERPF  PADUA SCORE  \
# count      2555.00                       127.00        95.00      2123.00
# mean         80.35                        57.35       152.51         8.40
# std          24.20                        25.01        59.61         1.75
# min           0.27                        20.70        38.30         2.00
# 25%          65.52                        41.00       110.00         7.00
# 50%          79.32                        48.00       140.50         8.00
# 75%          93.71                        58.75       197.22        10.00
# max         253.97                       100.00       340.00        14.00
#
#        R.E.N.A.L. NEPHRO SCORE  LOCATION TO POLAR LINE  NO OF LESIONS  \
# count                  1748.00                 1944.00        2678.00
# mean                      6.84                    1.90           1.05
# std                       1.85                    0.82           0.27
# min                       2.00                    1.00           0.00
# 25%                       5.00                    1.00           1.00
# 50%                       7.00                    2.00           1.00
# 75%                       8.00                    3.00           1.00
# max                      12.00                    3.00           5.00
#
#        OPERATIVE TIME(min)  ISCHEMIA TIME (min)  BLOOD LOSS (ml)  \
# count              2122.00              2940.00          3167.00
# mean                182.27                18.86           187.34
# std                  62.65                10.39           277.99
# min                   3.00                 0.00             0.00
# 25%                 140.00                14.00            50.00
# 50%                 176.00                18.00           100.00
# 75%                 215.00                23.00           200.00
# max                 608.00               320.00          9650.00
#
#        POST-OP HB_Day 1  POST-OP HT_Day 1  POST-OP Creat_Day 1  \
# count           1722.00           1932.00              2836.00
# mean              19.75             31.48                 1.36
# std               28.36             12.40                 4.59
# min                1.00              0.25                 0.00
# 25%               11.00             31.00                 0.94
# 50%               12.10             35.10                 1.00
# 75%               13.30             38.40                 1.30
# max              162.00             88.00               143.00
#
#        POST-OP EGFR_Day 1  POST-OP WBC_Day 1  POST-OP HB_Day 2  \
# count             2069.00            1326.00            755.00
# mean                66.34           10553.41             20.18
# std                 21.67            4281.65             29.01
# min                  1.26               0.00              1.33
# 25%                 51.87            8400.00             10.80
# 50%                 64.80           10100.00             12.00
# 75%                 79.11           12300.00             13.00
# max                198.38          107000.00            152.00
#
#        POST-OP HT_Day 2  POST-OP Creat_Day 2  POST-OP EGFR_Day 2  \
# count            773.00               984.00              657.00
# mean              28.95                 1.76               65.32
# std               13.61                 7.48               37.22
# min                0.20                 0.45               11.00
# 25%               28.10                 0.90               48.46
# 50%               33.70                 1.10               63.00
# 75%               37.10                 1.40               80.79
# max               50.00               174.00              811.00
#
#        POST-OP WBC_Day 2  POST-OP HB_Day 3  POST-OP HT_Day 3  \
# count             732.00            532.00            503.00
# mean            10604.04             16.29             30.00
# std              5372.70             21.66             18.67
# min              1260.00              0.30              0.28
# 25%              8200.00             10.38             28.50
# 50%             10000.00             11.80             33.10
# 75%             12000.00             12.80             37.00
# max            105303.00            131.00            332.00
#
#        POST-OP Creat_Day 3  POST-OP EGFR_Day 3  POST-OP WBC_Day 3  \
# count               748.00              436.00             518.00
# mean                  1.32               67.76            9645.79
# std                   3.98               24.90            6491.65
# min                   0.27               10.00            2000.00
# 25%                   0.87               51.53            7500.00
# 50%                   1.07               67.00            8950.00
# 75%                   1.28               81.53           10800.00
# max                 109.00              174.10          131000.00
#
#        LENGTH OF STAY (days)  PATHOLOGICAL TUMOR SIZE  MIN THICKNESS MARGIN  \
# count                3067.00                   2777.0               1319.00
# mean                    3.16                     10.2                  4.23
# std                     2.48                     14.9                 10.75
# min                     0.00                      0.0                  0.00
# 25%                     2.00                      2.4                  1.00
# 50%                     3.00                      3.5                  2.00
# 75%                     4.00                      7.2                  4.00
# max                    51.00                    115.0                240.00
#
#        MAX THICKNESS MARGIN  FUHRMAN GRADING  %SARCOMATOID DIFF  MIC SCORE  \
# count                468.00          2284.00            1329.00    2290.00
# mean                  11.75             2.16               0.13       0.30
# std                   49.46             0.67               2.33       0.46
# min                    0.00             1.00               0.00       0.00
# 25%                    1.20             2.00               0.00       0.00
# 50%                    3.00             2.00               0.00       0.00
# 75%                    8.00             3.00               0.00       1.00
# max                  979.00             4.00              70.00       1.00
#
#        LAST FOLLOW UP DURATION
# count                  1920.00
# mean                     16.94
# std                      19.51
# min                       0.00
# 25%                       3.00
# 50%                      10.00
# 75%                      24.00
# max                     101.00

# %%
import seaborn as sns
sns.boxplot(x=df['PATHOLOGICAL TUMOR SIZE'])

# %%
import seaborn as sns
sns.distplot(df['PRE-OP CREAT'].dropna())
# Out:
# H:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_error = df[(df['AGE AT SURGERY'] == 0) | 
       ((df['WEIGHT']>=100) & (df['HEIGHT']<=140)) | 
       (df['BMI']>50) | (df['BMI']<15) | 
       (df['CLINICAL SIZE (mm)']>150) |
       (df['NO OF LESIONS']==0) |
       (df['PRE-OP HB']<1) |
       (df['PRE-OP HT']<1) |
       (df['PRE-OP CREAT']>10) |
       (df['PRE-OP GFR']<1) |
       (df['PRE-OP EGFR']<1) |
       (df['OPERATIVE TIME(min)']<10) |
       (df['POST-OP HB_Day 1']<1) |
       (df['POST-OP HT_Day 1']<1) |
       (df['POST-OP Creat_Day 1']>10) |
       (df['POST-OP EGFR_Day 1']<1) |
       (df['POST-OP HB_Day 2']<1) |
       (df['POST-OP HT_Day 2']<1) |
       (df['POST-OP Creat_Day 2']>10) |
       (df['POST-OP EGFR_Day 2']<1) |
       (df['POST-OP HB_Day 3']<1) |
       (df['POST-OP HT_Day 3']<1) |
       (df['POST-OP Creat_Day 3']>10) |
       (df['POST-OP EGFR_Day 3']<1) |
       (df['LENGTH OF STAY (days)']==0) 
      ]

# %%
df2 = pd.concat([df,df_error]).drop_duplicates(keep=False).copy()

# %%
df2.describe()
# Out:
#        DATE OF BIRTH  AGE AT SURGERY       WEIGHT       HEIGHT         BMI  \
# count    1511.000000     2817.000000  1937.000000  1905.000000  2539.00000
# mean     1955.189940       57.816826    79.769882   169.185102    28.47401
# std        13.336265       12.808321    17.630600    10.598855     5.74163
# min      1921.000000       16.000000    37.000000   125.000000    15.10000
# 25%      1945.000000       49.000000    68.000000   162.000000    24.50000
# 50%      1955.000000       59.000000    78.000000   170.000000    27.40000
# 75%      1964.000000       67.000000    90.000000   177.000000    31.48500
# max      1996.000000       89.000000   164.000000   208.300000    50.00000
#
#        CLINICAL SIZE (mm)  CHARLSON SCORE  CHARLSON AGE-ADJUST SCORE  \
# count         2638.000000     2285.000000                2458.000000
# mean            33.092343        1.303720                   3.439788
# std             16.688544        1.393822                   2.161715
# min              0.000000        0.000000                   0.000000
# 25%             21.000000        0.000000                   2.000000
# 50%             30.000000        1.000000                   3.000000
# 75%             42.000000        2.000000                   5.000000
# max            135.000000       12.000000                  14.000000
#
#          PRE-OP HB    PRE-OP HT    PRE-OP WBC  PRE-OP CREAT  PRE-OP GFR  \
# count  2005.000000  1873.000000   1541.000000   2772.000000  501.000000
# mean     13.747995    41.062093   7617.720960      0.967162   73.072255
# std       1.670634     5.097267   2793.367894      0.382571   26.125318
# min       1.300000     1.800000   1060.000000      0.000000    5.000000
# 25%      12.800000    38.000000   5800.000000      0.780000   60.000000
# 50%      13.900000    41.500000   7200.000000      0.900000   67.000000
# 75%      14.900000    44.400000   8600.000000      1.100000   88.780000
# max      24.000000    88.000000  39200.000000      9.740000  213.400000
#
#        PRE-OP EGFR  PRE-OP Split Renal Function  PRE-OP ERPF  PADUA SCORE  \
# count  2091.000000                    124.00000    94.000000   1862.00000
# mean     80.882424                     57.53129   152.941170      8.47261
# std      23.920454                     25.27128    59.776129      1.77512
# min       4.000000                     20.70000    38.300000      5.00000
# 25%      66.000000                     40.75000   110.000000      7.00000
# 50%      80.000000                     48.00000   140.500000      8.00000
# 75%      94.000000                     64.25000   197.837500     10.00000
# max     253.971416                    100.00000   340.000000     14.00000
#
#        R.E.N.A.L. NEPHRO SCORE  LOCATION TO POLAR LINE  NO OF LESIONS  \
# count              1709.000000             1656.000000    2216.000000
# mean                  6.838502                1.920290       1.049639
# std                   1.849018                0.818029       0.258961
# min                   3.000000                1.000000       1.000000
# 25%                   5.000000                1.000000       1.000000
# 50%                   7.000000                2.000000       1.000000
# 75%                   8.000000                3.000000       1.000000
# max                  12.000000                3.000000       5.000000
#
#        OPERATIVE TIME(min)  ISCHEMIA TIME (min)  BLOOD LOSS (ml)  \
# count          1896.000000          2562.000000      2701.000000
# mean            184.366034            18.990047       189.747871
# std              64.450419            10.599615       290.617302
# min              21.000000             0.000000         0.000000
# 25%             140.000000            14.000000        50.000000
# 50%             179.000000            18.000000       100.000000
# 75%             220.000000            23.000000       200.000000
# max             608.000000           320.000000      9650.000000
#
#        POST-OP HB_Day 1  POST-OP HT_Day 1  POST-OP Creat_Day 1  \
# count       1327.000000       1518.000000          2423.000000
# mean          15.227928         35.644269             1.158281
# std           19.336018          4.866770             0.468712
# min            1.000000          3.000000             0.000000
# 25%           11.000000         32.725000             0.930000
# 50%           12.000000         35.800000             1.000000
# 75%           13.100000         38.700000             1.300000
# max          150.000000         88.000000             9.380000
#
#        POST-OP EGFR_Day 1  POST-OP WBC_Day 1  POST-OP HB_Day 2  \
# count         1805.000000         973.000000        538.000000
# mean            66.702173       10267.779034         13.945037
# std             21.961723        3208.170038         15.732860
# min              4.000000           0.000000          4.510000
# 25%             52.000000        8200.000000         10.700000
# 50%             64.867501       10000.000000         11.800000
# 75%             80.000000       12080.000000         12.900000
# max            198.384192       39900.000000        136.000000
#
#        POST-OP HT_Day 2  POST-OP Creat_Day 2  POST-OP EGFR_Day 2  \
# count        552.000000           767.000000          513.000000
# mean          34.672101             1.214110           65.807310
# std            5.038604             0.530269           40.574983
# min           10.900000             0.450000           11.000000
# 25%           31.875000             0.900000           48.710000
# 50%           34.800000             1.100000           63.300000
# 75%           38.000000             1.375000           81.000000
# max           50.000000             5.370000          811.000000
#
#        POST-OP WBC_Day 2  POST-OP HB_Day 3  POST-OP HT_Day 3  \
# count         530.000000        437.000000        409.000000
# mean        10537.771698         12.569291         34.862103
# std          5868.627316         10.710099         15.595987
# min          1260.000000          6.300000          4.200000
# 25%          8100.000000         10.200000         31.000000
# 50%          9937.500000         11.600000         34.300000
# 75%         11877.500000         12.700000         37.700000
# max        105303.000000        126.000000        332.000000
#
#        POST-OP Creat_Day 3  POST-OP EGFR_Day 3  POST-OP WBC_Day 3  \
# count           643.000000          358.000000         424.000000
# mean              1.160824           67.892207        9583.412736
# std               0.548949           25.387877        6730.724903
# min               0.400000           10.000000        3400.000000
# 25%               0.890000           52.585000        7540.500000
# 50%               1.060000           67.000000        9000.000000
# 75%               1.250000           81.000000       10800.000000
# max               5.800000          174.100000      131000.000000
#
#        LENGTH OF STAY (days)  PATHOLOGICAL TUMOR SIZE  MIN THICKNESS MARGIN  \
# count            2601.000000              2337.000000           1043.000000
# mean                3.262207                10.411018              4.590125
# std                 2.489453                15.074896             11.844289
# min                 1.000000                 0.000000              0.000000
# 25%                 2.000000                 2.400000              1.000000
# 50%                 3.000000                 3.500000              2.000000
# 75%                 4.000000                 8.000000              4.000000
# max                51.000000               115.000000            240.000000
#
#        MAX THICKNESS MARGIN  FUHRMAN GRADING  %SARCOMATOID DIFF    MIC SCORE  \
# count            344.000000      1995.000000        1057.000000  2089.000000
# mean              14.625000         2.156391           0.128666     0.320249
# std               57.279668         0.665531           2.526095     0.466684
# min                0.000000         1.000000           0.000000     0.000000
# 25%                2.000000         2.000000           0.000000     0.000000
# 50%                5.000000         2.000000           0.000000     0.000000
# 75%               12.000000         3.000000           0.000000     1.000000
# max              979.000000         4.000000          70.000000     1.000000
#
#        LAST FOLLOW UP DURATION
# count              1667.000000
# mean                 18.456809
# std                  20.314343
# min                   0.000000
# 25%                   3.000000
# 50%                  12.000000
# 75%                  25.300000
# max                 101.000000

# %%
# The percentage of missing data
df2.isnull().mean()
# Out:
# PATIENT NUMBER                            0.000000
# PROC NAME                                 0.000000
# CENTER CODE                               0.000000
# SURGEON CODE                              0.763502
# REC PROGRESS                              0.000000
# CREATED DATE                              0.000000
# GENDER                                    0.003530
# DATE OF BIRTH                             0.466643
# AGE AT SURGERY                            0.005648
# MARITAL STATUS                            0.423932
# RACE                                      0.447229
# EDUCATION                                 0.489234
# WEIGHT                                    0.316273
# HEIGHT                                    0.327568
# BMI                                       0.103777
# CLINICAL SIZE (mm)                        0.068832
# ECOG                                      0.458172
# CHARLSON SCORE                            0.193435
# CHARLSON AGE-ADJUST SCORE                 0.132369
# SYMPTOMS                                  0.288387
# SOLITARY KIDNEY                           0.181786
# TYPE OF SOLITARY KIDNEY                   0.981645
# BILATERALITY OF TUMOR                     0.457819
# SIDE OF TUMOR                             0.376280
# SIDE OF SURGERY                           0.003177
# PRE-OP MULTIFOCALITY                      0.766678
# FACE                                      0.222732
# TUMOR lOCATION                            0.171903
# PRE-OP HB                                 0.292270
# PRE-OP HT                                 0.338863
#                                             ...
# Renal Vein Invasion                       0.805154
# VENOUS THROMBUS                           0.379103
# SURGICAL MARGIN                           0.105542
# UNIFOCAL/MULTIFOCAL                       0.984116
# NO_OF_NODE_TAKEN                          0.490293
# NO_OF_NODE_POSITIVE                       0.550653
# SITE OF POSITIVE NODE                     0.816096
# TREATMENT PSM                             0.910695
# PT                                        0.183551
# PN                                        0.308860
# OTHER TUMORS                              0.997529
# DATE OF RECURRENCE                        0.995411
# LAST FOLLOW UP DURATION                   0.411578
# TIME TO RECURRENCE                        0.926227
# LAST FOLLOW UP STATUS                     0.522061
# LAST FOLLOW UP RECURRENCE                 0.526650
# LAST TREATMENT OF RECURRENCE              0.872573
# TYPE OF COMPLICATIONS(s)                  0.144370
# SELECTED SURGICAL COMPLICATIONS(s)        0.144370
# SELECTED NON SURGICAL COMPLICATIONS(s)    0.144370
# TREATMENT OF COMPLICATIONS(s)             0.144370
# RECURRENCE(s)                             0.144370
# FOLLOW UP DATE(s)                         0.144370
# STATUS(s)                                 0.144370
# TREATMENT(s)                              0.144370
# CREATININE(s)                             0.144370
# EGFR(s)                                   0.144370
# SRF(s)                                    0.144370
# ERPF(s)                                   0.144370
# data_record                               0.000000
# Length: 162, dtype: float64

# %%
#Dropping columns having more that 40% missing data
df2 = df2[df2.columns[df2.isnull().mean() < 0.40]]

# %%
# Total number of columns left after removing columns with missing data
len(list(df2))
# Out:
# 98

# %%
df2.info(verbose = True, null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2833 entries, 0 to 2390
# Data columns (total 98 columns):
# PATIENT NUMBER                            2833 non-null object
# PROC NAME                                 2833 non-null object
# CENTER CODE                               2833 non-null object
# REC PROGRESS                              2833 non-null object
# CREATED DATE                              2833 non-null object
# GENDER                                    2823 non-null object
# AGE AT SURGERY                            2817 non-null float64
# WEIGHT                                    1937 non-null float64
# HEIGHT                                    1905 non-null float64
# BMI                                       2539 non-null float64
# CLINICAL SIZE (mm)                        2638 non-null float64
# CHARLSON SCORE                            2285 non-null float64
# CHARLSON AGE-ADJUST SCORE                 2458 non-null float64
# SYMPTOMS                                  2016 non-null object
# SOLITARY KIDNEY                           2318 non-null object
# SIDE OF TUMOR                             1767 non-null object
# SIDE OF SURGERY                           2824 non-null object
# FACE                                      2202 non-null object
# TUMOR lOCATION                            2346 non-null object
# PRE-OP HB                                 2005 non-null float64
# PRE-OP HT                                 1873 non-null float64
# PRE-OP CREAT                              2772 non-null float64
# PRE-OP EGFR                               2091 non-null float64
# PADUA SCORE                               1862 non-null float64
# PADUA RISK                                1861 non-null object
# POLAR LOCATION                            2219 non-null object
# RIM LOCATION                              1720 non-null object
# RENAL SINUS                               1826 non-null object
# UCS INVASION                              1769 non-null object
# EXOPHYTIC RATE                            2096 non-null object
# CLINICAL SIZE GROUP                       2309 non-null object
# CT                                        2639 non-null object
# CN                                        2316 non-null object
# CM                                        2257 non-null object
# R.E.N.A.L. NEPHRO SCORE                   1709 non-null float64
# R.E.N.A.L. NEPHRO RISK STRATIFICATION     2277 non-null object
# RADIUS (maximal diameter in cm)           2462 non-null object
# EXOPHYTIC/ENDOPHYTIC PROPERTIES           2346 non-null object
# NEARNESS OF TUMOUR                        1986 non-null object
# ANTERIOR OR POSTERIOR                     2354 non-null object
# DATE OF SURGERY                           2833 non-null object
# ASA SCORE                                 2366 non-null object
# PARTIAL NEPHRO INDICATION                 1904 non-null object
# NO OF LESIONS                             2216 non-null float64
# ACCESS                                    1944 non-null object
# ROBOTICS ARMS                             2355 non-null object
# ASSISTENT TROCARS                         2141 non-null object
# DUAL CONSOLE                              1908 non-null object
# OPERATIVE TIME(min)                       1896 non-null float64
# ISCHEMIA                                  2246 non-null object
# CLAMP ARTERY                              2236 non-null object
# CLAMP VEIN                                2022 non-null object
# EARLY UNCLAMPING                          2005 non-null object
# FLUORESCENCE                              1904 non-null object
# ISCHEMIA TIME (min)                       2562 non-null float64
# UCS REPAIR                                1873 non-null object
# HAEMOSTATIC AGENTS                        1894 non-null object
# LYMPH NODE DISSECTION(LND)                1908 non-null object
# BLOOD LOSS (ml)                           2701 non-null float64
# INTRA-OP TRANSUFUSION                     2137 non-null object
# INTRA-OP COMPLICATION                     2387 non-null object
# POST-OP COMPLICATION                      2264 non-null object
# CLAVIEN GRADE                             1968 non-null object
# POST-OP Creat_Day 1                       2423 non-null float64
# POST-OP EGFR_Day 1                        1805 non-null float64
# LENGTH OF STAY (days)                     2601 non-null float64
# PATHOLOGICAL TUMOR SIZE                   2337 non-null float64
# MULITIFOCALITY                            1986 non-null object
# PATHOLOGY                                 2633 non-null object
# HYSTOTYPE MALIGNANAT                      2714 non-null object
# HYSTOTYPE MALIGNANAT YES                  2095 non-null object
# HYSTOTYPE BENIGN                          2700 non-null object
# FUHRMAN GRADING                           1995 non-null float64
# SARCOMATOID DIFF                          1841 non-null object
# NECROSIS                                  1826 non-null object
# MICRO VENOUS INVASION                     1886 non-null object
# UCS INVASION.1                            1783 non-null object
# PERIRENAL FAT INVASION                    2187 non-null object
# SINUS FAT INVASION                        1786 non-null object
# MIC SCORE                                 2089 non-null float64
# GEROTA INVASION                           1707 non-null object
# VENOUS THROMBUS                           1759 non-null object
# SURGICAL MARGIN                           2534 non-null object
# PT                                        2313 non-null object
# PN                                        1958 non-null object
# TYPE OF COMPLICATIONS(s)                  2424 non-null object
# SELECTED SURGICAL COMPLICATIONS(s)        2424 non-null object
# SELECTED NON SURGICAL COMPLICATIONS(s)    2424 non-null object
# TREATMENT OF COMPLICATIONS(s)             2424 non-null object
# RECURRENCE(s)                             2424 non-null object
# FOLLOW UP DATE(s)                         2424 non-null object
# STATUS(s)                                 2424 non-null object
# TREATMENT(s)                              2424 non-null object
# CREATININE(s)                             2424 non-null object
# EGFR(s)                                   2424 non-null object
# SRF(s)                                    2424 non-null object
# ERPF(s)                                   2424 non-null object
# data_record                               2833 non-null object
# dtypes: float64(23), object(75)
# memory usage: 2.1+ MB

# %%
# Replcaing missing values in categorical column with NA
col = list(df2.select_dtypes('object'))
for k in col:
    df2[k] = df2[k].fillna("NA")

# %%
# Replacing missing values in numerical columns with their respective mean 
col_numeric = list(df2.select_dtypes('float64'))
for k in col_numeric:
    df2[k] = df2[k].fillna(df2[k].mean())

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2833 entries, 0 to 2390
# Data columns (total 98 columns):
# PATIENT NUMBER                            2833 non-null object
# PROC NAME                                 2833 non-null object
# CENTER CODE                               2833 non-null object
# REC PROGRESS                              2833 non-null object
# CREATED DATE                              2833 non-null object
# GENDER                                    2833 non-null object
# AGE AT SURGERY                            2833 non-null float64
# WEIGHT                                    2833 non-null float64
# HEIGHT                                    2833 non-null float64
# BMI                                       2833 non-null float64
# CLINICAL SIZE (mm)                        2833 non-null float64
# CHARLSON SCORE                            2833 non-null float64
# CHARLSON AGE-ADJUST SCORE                 2833 non-null float64
# SYMPTOMS                                  2833 non-null object
# SOLITARY KIDNEY                           2833 non-null object
# SIDE OF TUMOR                             2833 non-null object
# SIDE OF SURGERY                           2833 non-null object
# FACE                                      2833 non-null object
# TUMOR lOCATION                            2833 non-null object
# PRE-OP HB                                 2833 non-null float64
# PRE-OP HT                                 2833 non-null float64
# PRE-OP CREAT                              2833 non-null float64
# PRE-OP EGFR                               2833 non-null float64
# PADUA SCORE                               2833 non-null float64
# PADUA RISK                                2833 non-null object
# POLAR LOCATION                            2833 non-null object
# RIM LOCATION                              2833 non-null object
# RENAL SINUS                               2833 non-null object
# UCS INVASION                              2833 non-null object
# EXOPHYTIC RATE                            2833 non-null object
# CLINICAL SIZE GROUP                       2833 non-null object
# CT                                        2833 non-null object
# CN                                        2833 non-null object
# CM                                        2833 non-null object
# R.E.N.A.L. NEPHRO SCORE                   2833 non-null float64
# R.E.N.A.L. NEPHRO RISK STRATIFICATION     2833 non-null object
# RADIUS (maximal diameter in cm)           2833 non-null object
# EXOPHYTIC/ENDOPHYTIC PROPERTIES           2833 non-null object
# NEARNESS OF TUMOUR                        2833 non-null object
# ANTERIOR OR POSTERIOR                     2833 non-null object
# DATE OF SURGERY                           2833 non-null object
# ASA SCORE                                 2833 non-null object
# PARTIAL NEPHRO INDICATION                 2833 non-null object
# NO OF LESIONS                             2833 non-null float64
# ACCESS                                    2833 non-null object
# ROBOTICS ARMS                             2833 non-null object
# ASSISTENT TROCARS                         2833 non-null object
# DUAL CONSOLE                              2833 non-null object
# OPERATIVE TIME(min)                       2833 non-null float64
# ISCHEMIA                                  2833 non-null object
# CLAMP ARTERY                              2833 non-null object
# CLAMP VEIN                                2833 non-null object
# EARLY UNCLAMPING                          2833 non-null object
# FLUORESCENCE                              2833 non-null object
# ISCHEMIA TIME (min)                       2833 non-null float64
# UCS REPAIR                                2833 non-null object
# HAEMOSTATIC AGENTS                        2833 non-null object
# LYMPH NODE DISSECTION(LND)                2833 non-null object
# BLOOD LOSS (ml)                           2833 non-null float64
# INTRA-OP TRANSUFUSION                     2833 non-null object
# INTRA-OP COMPLICATION                     2833 non-null object
# POST-OP COMPLICATION                      2833 non-null object
# CLAVIEN GRADE                             2833 non-null object
# POST-OP Creat_Day 1                       2833 non-null float64
# POST-OP EGFR_Day 1                        2833 non-null float64
# LENGTH OF STAY (days)                     2833 non-null float64
# PATHOLOGICAL TUMOR SIZE                   2833 non-null float64
# MULITIFOCALITY                            2833 non-null object
# PATHOLOGY                                 2833 non-null object
# HYSTOTYPE MALIGNANAT                      2833 non-null object
# HYSTOTYPE MALIGNANAT YES                  2833 non-null object
# HYSTOTYPE BENIGN                          2833 non-null object
# FUHRMAN GRADING                           2833 non-null float64
# SARCOMATOID DIFF                          2833 non-null object
# NECROSIS                                  2833 non-null object
# MICRO VENOUS INVASION                     2833 non-null object
# UCS INVASION.1                            2833 non-null object
# PERIRENAL FAT INVASION                    2833 non-null object
# SINUS FAT INVASION                        2833 non-null object
# MIC SCORE                                 2833 non-null float64
# GEROTA INVASION                           2833 non-null object
# VENOUS THROMBUS                           2833 non-null object
# SURGICAL MARGIN                           2833 non-null object
# PT                                        2833 non-null object
# PN                                        2833 non-null object
# TYPE OF COMPLICATIONS(s)                  2833 non-null object
# SELECTED SURGICAL COMPLICATIONS(s)        2833 non-null object
# SELECTED NON SURGICAL COMPLICATIONS(s)    2833 non-null object
# TREATMENT OF COMPLICATIONS(s)             2833 non-null object
# RECURRENCE(s)                             2833 non-null object
# FOLLOW UP DATE(s)                         2833 non-null object
# STATUS(s)                                 2833 non-null object
# TREATMENT(s)                              2833 non-null object
# CREATININE(s)                             2833 non-null object
# EGFR(s)                                   2833 non-null object
# SRF(s)                                    2833 non-null object
# ERPF(s)                                   2833 non-null object
# data_record                               2833 non-null object
# dtypes: float64(23), object(75)
# memory usage: 2.1+ MB

# %%
df2.head(10)
# Out:
#    PATIENT NUMBER            PROC NAME CENTER CODE REC PROGRESS  \
# 0     21PAT000148  Partial Nephrectomy    GQHLD5Q4   Follow-up1
# 1     18PAT000042  Partial Nephrectomy    GCIEYK6L   Follow-up1
# 2      7PAT000058  Partial Nephrectomy    4M49I4D5   Follow-up1
# 4      5PAT000015  Partial Nephrectomy    QRJWT5QR   Follow-up1
# 6     18PAT000010  Partial Nephrectomy    GCIEYK6L   Follow-up1
# 7     18PAT000023  Partial Nephrectomy    GCIEYK6L   Follow-up1
# 8     19PAT000007  Partial Nephrectomy    RETM03Y8   Follow-up1
# 9     21PAT000166  Partial Nephrectomy    GQHLD5Q4   Follow-up1
# 12    21PAT000136  Partial Nephrectomy    GQHLD5Q4   Follow-up1
# 14    19PAT000033  Partial Nephrectomy    RETM03Y8   Follow-up1
#
#              CREATED DATE  GENDER  AGE AT SURGERY  WEIGHT  HEIGHT    BMI  \
# 0   2017-09-24 18:30:00.0  Female            50.0   57.00   168.0  20.20
# 1   2016-03-08 08:00:00.0  Female            69.0   68.60   161.3  26.37
# 2   2016-01-01 23:00:00.0  Female            83.0   83.65   164.0  31.10
# 4   2015-06-23 00:00:00.0    Male            61.0   82.90   171.0  28.35
# 6   2015-11-03 08:00:00.0    Male            63.0  101.20   167.6  36.03
# 7   2015-12-08 08:00:00.0  Female            35.0   77.10   154.9  32.13
# 8   2016-03-07 00:00:00.0    Male            53.0   96.00   170.0  33.22
# 9   2017-11-13 18:30:00.0    Male            42.0   84.00   181.0  25.64
# 12  2017-09-18 18:30:00.0    Male            65.0   68.90   167.0  24.71
# 14  2018-05-23 00:00:00.0  Female            74.0   77.00   160.0  30.08
#
#     CLINICAL SIZE (mm)  CHARLSON SCORE  CHARLSON AGE-ADJUST SCORE SYMPTOMS  \
# 0                  7.0             0.0                   2.000000   Absent
# 1                 74.0             1.0                   4.000000   Absent
# 2                 80.0             3.0                   8.000000   Absent
# 4                  8.0             0.0                   3.439788   Absent
# 6                 74.0             2.0                   5.000000   Absent
# 7                 50.0             1.0                   1.000000   Absent
# 8                 56.0             0.0                   3.439788   Absent
# 9                 64.0             0.0                   1.000000   Absent
# 12                 5.5             0.0                   3.000000   Absent
# 14                60.0             0.0                   4.000000   Absent
#
#    SOLITARY KIDNEY SIDE OF TUMOR SIDE OF SURGERY       FACE TUMOR lOCATION  \
# 0               No          Left            Left  Posterior     Lower Pole
# 1               No         Right           Right  Posterior       Mid Pole
# 2               No          Left            Left   Anterior     Lower Pole
# 4               No         Right           Right  Posterior       Mid Pole
# 6               No          Left            Left  Posterior       Mid Pole
# 7               No          Left            Left   Anterior     Upper Pole
# 8               No         Right           Right   Anterior     Upper Pole
# 9               No         Right           Right  Posterior     Upper Pole
# 12              No         Right           Right  Posterior       Mid Pole
# 14              No          Left            Left   Anterior     Upper Pole
#
#     PRE-OP HB  PRE-OP HT  PRE-OP CREAT  PRE-OP EGFR  PADUA SCORE  \
# 0        13.2       50.0          0.63   100.030000         12.0
# 1        14.7       44.2          0.80    71.119672         10.0
# 2        12.5       38.9          0.97    54.844682          9.0
# 4        12.1       37.1          1.10    68.053260         12.0
# 6        15.4       47.6          1.30    55.754675         12.0
# 7        10.4       32.0          0.66   123.318380          8.0
# 8        15.4       46.2          0.95    82.931020          9.0
# 9        12.0       34.0          1.20    66.400000         10.0
# 12       12.8       37.9          1.07    69.360000         12.0
# 14       14.0       43.1          0.76    80.882424          8.0
#
#                PADUA RISK                                     POLAR LOCATION  \
# 0           3(High  Risk)  Tumours entirely located above the upper or be...
# 1           3(High  Risk)  Tumours crossing the sinus line >50% or fallin...
# 2   2(Intermidiate  Risk)  Tumours entirely located above the upper or be...
# 4           3(High  Risk)  Tumours crossing the sinus line >50% or fallin...
# 6           3(High  Risk)  Tumours crossing the sinus line >50% or fallin...
# 7   2(Intermidiate  Risk)  Tumours crossing the sinus line >50% or fallin...
# 8   2(Intermidiate  Risk)  Tumours entirely located above the upper or be...
# 9           3(High  Risk)  Tumours crossing the sinus line >50% or fallin...
# 12          3(High  Risk)  Tumours crossing the sinus line >50% or fallin...
# 14  2(Intermidiate  Risk)  Tumours entirely located above the upper or be...
#
#                                 RIM LOCATION  \
# 0               At the medial rim (2 points)
# 1               At the medial rim (2 points)
# 2   Tumours located at the lateral (1 point)
# 4   Tumours located at the lateral (1 point)
# 6   Tumours located at the lateral (1 point)
# 7   Tumours located at the lateral (1 point)
# 8               At the medial rim (2 points)
# 9   Tumours located at the lateral (1 point)
# 12              At the medial rim (2 points)
# 14              At the medial rim (2 points)
#
#                                           RENAL SINUS  \
# 0             With renal sinus involvement (2 points)
# 1   Tumours without renal sinus involvement (1 point)
# 2   Tumours without renal sinus involvement (1 point)
# 4             With renal sinus involvement (2 points)
# 6             With renal sinus involvement (2 points)
# 7   Tumours without renal sinus involvement (1 point)
# 8             With renal sinus involvement (2 points)
# 9             With renal sinus involvement (2 points)
# 12            With renal sinus involvement (2 points)
# 14  Tumours without renal sinus involvement (1 point)
#
#                                          UCS INVASION  \
# 0   With involving, dislocation or infiltration of...
# 1              Absent relationship with UCS (1 point)
# 2   With involving, dislocation or infiltration of...
# 4   With involving, dislocation or infiltration of...
# 6   With involving, dislocation or infiltration of...
# 7              Absent relationship with UCS (1 point)
# 8              Absent relationship with UCS (1 point)
# 9   With involving, dislocation or infiltration of...
# 12  With involving, dislocation or infiltration of...
# 14             Absent relationship with UCS (1 point)
#
#                EXOPHYTIC RATE CLINICAL SIZE GROUP   CT  CN              CM  \
# 0   < 50%exophytic (2 points)               =>7cm  T2a  Nx  Not Applicable
# 1   = 50% exophytic (1 point)               =>7cm  T2a  Nx              M0
# 2   = 50% exophytic (1 point)               =>7cm  T2a  N0              M0
# 4   < 50%exophytic (2 points)               =>7cm  T2a  N0              M0
# 6   < 50%exophytic (2 points)               =>7cm  T2a  Nx              M0
# 7   = 50% exophytic (1 point)           4.1cm-7cm  T1b  Nx              M0
# 8   = 50% exophytic (1 point)           4.1cm-7cm  T1b  N0              M0
# 9   = 50% exophytic (1 point)           4.1cm-7cm  T1b  N0              M0
# 12  < 50%exophytic (2 points)           4.1cm-7cm  T1b  Nx  Not Applicable
# 14  = 50% exophytic (1 point)           4.1cm-7cm  T1b  N0              M0
#
#     R.E.N.A.L. NEPHRO SCORE R.E.N.A.L. NEPHRO RISK STRATIFICATION  \
# 0                  6.838502                          3(High Risk)
# 1                  6.838502                  2(Intermidiate Risk)
# 2                  6.838502                  2(Intermidiate Risk)
# 4                  6.838502                          3(High Risk)
# 6                  6.838502                          3(High Risk)
# 7                  6.838502                  2(Intermidiate Risk)
# 8                  6.838502                  2(Intermidiate Risk)
# 9                  6.838502                  2(Intermidiate Risk)
# 12                 6.838502                          3(High Risk)
# 14                 6.838502                  2(Intermidiate Risk)
#
#    RADIUS (maximal diameter in cm) EXOPHYTIC/ENDOPHYTIC PROPERTIES  \
# 0                              =>7                            <50%
# 1                              =>7                             50%
# 2                              =>7                             50%
# 4                              =>7                            <50%
# 6                              =>7                            <50%
# 7                         4 but <7                             50%
# 8                         4 but <7                             50%
# 9                         4 but <7                             50%
# 12                        4 but <7                            <50%
# 14                        4 but <7                             50%
#
#    NEARNESS OF TUMOUR ANTERIOR OR POSTERIOR        DATE OF SURGERY  \
# 0                 =<4            Neither(x)  2017-09-24 00:00:00.0
# 1                 =>7         Posterior (p)  2016-03-09 00:00:00.0
# 2                 =<4          Anterior (a)  2016-01-04 00:00:00.0
# 4                 =<4            Neither(x)  2015-06-24 00:00:00.0
# 6                 =<4         Posterior (p)  2015-11-04 00:00:00.0
# 7                 =>7          Anterior (a)  2015-12-09 00:00:00.0
# 8                 =<4          Anterior (a)  2016-03-08 00:00:00.0
# 9                 =<4            Neither(x)  2017-11-15 00:00:00.0
# 12                =<4         Posterior (p)  2017-09-19 00:00:00.0
# 14                =<4            Neither(x)  2018-05-24 00:00:00.0
#
#      ASA SCORE PARTIAL NEPHRO INDICATION  NO OF LESIONS           ACCESS  \
# 0   Category 1                  Elective            1.0  Transperitoneal
# 1   Category 3                  Relative            1.0  Retroperitoneal
# 2   Category 2                  Elective            1.0  Transperitoneal
# 4   Category 2                  Elective            1.0  Transperitoneal
# 6   Category 3                  Relative            1.0  Retroperitoneal
# 7   Category 3                  Elective            1.0  Transperitoneal
# 8   Category 2                  Elective            1.0  Transperitoneal
# 9   Category 1                  Elective            1.0  Transperitoneal
# 12  Category 1                  Elective            1.0  Transperitoneal
# 14  Category 2                  Elective            1.0  Transperitoneal
#
#    ROBOTICS ARMS ASSISTENT TROCARS DUAL CONSOLE  OPERATIVE TIME(min) ISCHEMIA  \
# 0         4-arms      5 mm + 12 mm           No           184.366034     Warm
# 1         4-arms        Only 12 mm          Yes           184.366034     Warm
# 2         4-arms        Only 12 mm           No           184.366034     Warm
# 4         4-arms        Only 12 mm           No           184.366034     Warm
# 6         3-arms        Only 12 mm          Yes           184.366034     Warm
# 7         4-arms        Only 12 mm          Yes           184.366034     Warm
# 8         4-arms        Only 12 mm           No           184.366034     Warm
# 9         4-arms      5 mm + 12 mm           No           184.366034     Warm
# 12        4-arms      5 mm + 12 mm           No           184.366034     Warm
# 14        4-arms        Only 12 mm           No           184.366034     Warm
#
#       CLAMP ARTERY      CLAMP VEIN EARLY UNCLAMPING FLUORESCENCE  \
# 0   Satinsky Clamp  Satinsky Clamp               No     Not Used
# 1          Bulldog              No              Yes         Used
# 2          Bulldog              No              Yes     Not Used
# 4          Bulldog         Bulldog               No     Not Used
# 6          Bulldog         Bulldog               No         Used
# 7          Bulldog         Bulldog               No         Used
# 8          Bulldog         Bulldog              Yes     Not Used
# 9          Bulldog         Bulldog               No     Not Used
# 12         Bulldog         Bulldog               No     Not Used
# 14         Bulldog         Bulldog              Yes         Used
#
#     ISCHEMIA TIME (min)     UCS REPAIR HAEMOSTATIC AGENTS  \
# 0                 24.00      Performed                Yes
# 1                 15.00      Performed                 No
# 2                 15.16      Performed                Yes
# 4                 20.00      Performed                Yes
# 6                 23.00      Performed                Yes
# 7                 18.00  Not Performed                 No
# 8                 25.00      Performed                Yes
# 9                 23.00      Performed                Yes
# 12                24.00      Performed                Yes
# 14                17.00      Performed                Yes
#
#    LYMPH NODE DISSECTION(LND)  BLOOD LOSS (ml) INTRA-OP TRANSUFUSION  \
# 0               Not Performed            600.0                1 Unit
# 1               Not Performed            300.0                    No
# 2               Not Performed            700.0                    No
# 4               Not Performed            300.0                    No
# 6                   Performed            650.0                    No
# 7                   Performed            150.0                    No
# 8               Not Performed            200.0                    No
# 9               Not Performed            150.0                    No
# 12              Not Performed            250.0                1 Unit
# 14              Not Performed            100.0                    No
#
#    INTRA-OP COMPLICATION POST-OP COMPLICATION  \
# 0                    Yes     No Complications
# 1                     No     No Complications
# 2                     No        Complications
# 4                     No     No Complications
# 6                     No        Complications
# 7                     No     No Complications
# 8                     No     No Complications
# 9                     No     No Complications
# 12                    No     No Complications
# 14                    No     No Complications
#
#                                         CLAVIEN GRADE  POST-OP Creat_Day 1  \
# 0                Grade 0: Absence of any complication                 0.80
# 1                Grade 0: Absence of any complication                 0.79
# 2   Grade 2: Complications needing only use of int...                 1.06
# 4                Grade 0: Absence of any complication                 1.40
# 6   Grade 3: Complications needing surgical, endos...                 2.51
# 7                Grade 0: Absence of any complication                 1.01
# 8                Grade 0: Absence of any complication                 1.00
# 9                Grade 0: Absence of any complication                 1.46
# 12               Grade 0: Absence of any complication                 1.48
# 14               Grade 0: Absence of any complication                 1.06
#
#     POST-OP EGFR_Day 1  LENGTH OF STAY (days)  PATHOLOGICAL TUMOR SIZE  \
# 0                75.70                    5.0                      8.5
# 1                76.91                    1.0                      8.5
# 2                50.00                   11.0                      7.5
# 4                52.00                    3.0                      7.0
# 6                26.21                    4.0                      6.5
# 7                83.52                    2.0                      6.5
# 8                86.20                    3.0                      6.5
# 9                81.00                    3.0                      6.0
# 12               48.00                    3.0                      6.0
# 14               53.90                    7.0                      6.0
#
#    MULITIFOCALITY PATHOLOGY HYSTOTYPE MALIGNANAT  \
# 0          Absent    Benign                   No
# 1          Absent    Benign                   No
# 2          Absent    Malign                  Yes
# 4          Absent    Malign                  Yes
# 6          Absent    Benign                   No
# 7          Absent    Malign                  Yes
# 8          Absent    Malign                  Yes
# 9          Absent    Malign                  Yes
# 12         Absent    Malign                  Yes
# 14         Absent    Benign                   No
#
#            HYSTOTYPE MALIGNANAT YES HYSTOTYPE BENIGN  FUHRMAN GRADING  \
# 0                                NA              Yes         2.156391
# 1                                NA              Yes         2.156391
# 2   Clear cell renal cell carcinoma               No         2.000000
# 4   Clear cell renal cell carcinoma               No         2.000000
# 6                                NA              Yes         2.156391
# 7    Papillary renal cell carcinoma               No         2.000000
# 8   Clear cell renal cell carcinoma               No         3.000000
# 9   Clear cell renal cell carcinoma               No         1.000000
# 12  Clear cell renal cell carcinoma               No         3.000000
# 14                               NA              Yes         2.156391
#
#    SARCOMATOID DIFF NECROSIS MICRO VENOUS INVASION UCS INVASION.1  \
# 0            Absent   Absent                Absent         Absent
# 1            Absent   Absent                Absent         Absent
# 2            Absent   Absent                Absent         Absent
# 4            Absent   Absent                Absent         Absent
# 6           Present   Absent                Absent         Absent
# 7            Absent   Absent                Absent         Absent
# 8            Absent   Absent                Absent         Absent
# 9            Absent   Absent                Absent        Present
# 12           Absent   Absent                Absent         Absent
# 14           Absent   Absent                Absent         Absent
#
#    PERIRENAL FAT INVASION SINUS FAT INVASION  MIC SCORE GEROTA INVASION  \
# 0                  Absent             Absent   0.000000          Absent
# 1                  Absent             Absent   0.000000          Absent
# 2                  Absent             Absent   0.320249          Absent
# 4                  Absent             Absent   0.320249          Absent
# 6                  Absent             Absent   0.000000          Absent
# 7                  Absent             Absent   0.000000          Absent
# 8                  Absent             Absent   0.000000          Absent
# 9                  Absent             Absent   0.000000          Absent
# 12                 Absent             Absent   0.000000          Absent
# 14                 Absent             Absent   0.000000          Absent
#
#    VENOUS THROMBUS SURGICAL MARGIN      PT  PN   TYPE OF COMPLICATIONS(s)  \
# 0           Absent        Negative  Benign  Nx  (FUP1 : No Complications)
# 1           Absent        Negative  Benign  Nx  (FUP1 : No Complications)
# 2           Absent        Negative     T2a  Nx  (FUP1 : No Complications)
# 4           Absent        Negative     T1b  N0  (FUP1 : No Complications)
# 6           Absent        Negative  Benign  N0     (FUP1 : Complications)
# 7           Absent        Negative     T1b  N0  (FUP1 : No Complications)
# 8           Absent        Negative     T1b  Nx  (FUP1 : No Complications)
# 9           Absent        Negative     T1b  Nx  (FUP1 : No Complications)
# 12          Absent        Negative     T1b  Nx  (FUP1 : No Complications)
# 14          Absent        Negative  Benign  NA  (FUP1 : No Complications)
#
#    SELECTED SURGICAL COMPLICATIONS(s) SELECTED NON SURGICAL COMPLICATIONS(s)  \
# 0                       (FUP1 : NULL)                          (FUP1 : NULL)
# 1                       (FUP1 : NULL)                          (FUP1 : NULL)
# 2                       (FUP1 : NULL)                          (FUP1 : NULL)
# 4                       (FUP1 : NULL)                          (FUP1 : NULL)
# 6                    (FUP1 : 316,319)                           (FUP1 : 324)
# 7                       (FUP1 : NULL)                          (FUP1 : NULL)
# 8                       (FUP1 : NULL)                          (FUP1 : NULL)
# 9                       (FUP1 : NULL)                          (FUP1 : NULL)
# 12                      (FUP1 : NULL)                          (FUP1 : NULL)
# 14                      (FUP1 : NULL)                          (FUP1 : NULL)
#
#                         TREATMENT OF COMPLICATIONS(s)     RECURRENCE(s)  \
# 0                                           (FUP1 : )     (FUP1 : None)
# 1                                           (FUP1 : )     (FUP1 : None)
# 2                                           (FUP1 : )     (FUP1 : None)
# 4                                        (FUP1 : Nil)     (FUP1 : None)
# 6   (FUP1 : Intra-abdominal bleed; clot removed an...     (FUP1 : None)
# 7                                         (FUP1 : NA)     (FUP1 : None)
# 8                                           (FUP1 : )     (FUP1 : None)
# 9                                           (FUP1 : )     (FUP1 : None)
# 12                                          (FUP1 : )     (FUP1 : None)
# 14                                          (FUP1 : )  (FUP1 : Distant)
#
#       FOLLOW UP DATE(s)                        STATUS(s)   TREATMENT(s)  \
# 0   (FUP1 : 2017-10-10)  (FUP1 : Alive and disease free)  (FUP1 : None)
# 1   (FUP1 : 2016-05-31)  (FUP1 : Alive and disease free)  (FUP1 : None)
# 2   (FUP1 : 2015-12-29)  (FUP1 : Alive and disease free)  (FUP1 : None)
# 4   (FUP1 : 2015-08-13)  (FUP1 : Alive and disease free)  (FUP1 : None)
# 6   (FUP1 : 2015-11-05)  (FUP1 : Alive and disease free)  (FUP1 : None)
# 7   (FUP1 : 2015-12-22)  (FUP1 : Alive and disease free)  (FUP1 : None)
# 8   (FUP1 : 2016-06-09)  (FUP1 : Alive and disease free)  (FUP1 : None)
# 9   (FUP1 : 2018-02-16)  (FUP1 : Alive and disease free)  (FUP1 : None)
# 12  (FUP1 : 2017-10-10)  (FUP1 : Alive and disease free)  (FUP1 : None)
# 14  (FUP1 : 2018-07-02)  (FUP1 : Alive and disease free)  (FUP1 : None)
#
#     CREATININE(s)         EGFR(s)              SRF(s)      ERPF(s)  \
# 0      (FUP1 : 1)     (FUP1 : NP)         (FUP1 : NP)  (FUP1 : NP)
# 1    (FUP1 : .67)  (FUP1 : 84.27)         (FUP1 : NP)  (FUP1 : NP)
# 2   (FUP1 : 0.85)     (FUP1 : 60)         (FUP1 : NA)  (FUP1 : NA)
# 4    (FUP1 : 1.2)   (FUP1 : 61.6)  (FUP1 : 30.5(45%))   (FUP1 : -)
# 6   (FUP1 : 2.51)  (FUP1 : 26.21)         (FUP1 : NP)  (FUP1 : NP)
# 7   (FUP1 : 1.16)     (FUP1 : 71)         (FUP1 : NP)  (FUP1 : NP)
# 8   (FUP1 : 0,94)   (FUP1 : 89,7)           (FUP1 : )    (FUP1 : )
# 9   (FUP1 : 0.92)     (FUP1 : 96)         (FUP1 : 43)  (FUP1 : NA)
# 12  (FUP1 : 1.07)     (FUP1 : 67)         (FUP1 : NP)  (FUP1 : NP)
# 14   (FUP1 : 0,7)  (FUP1 : 87,11)           (FUP1 : )    (FUP1 : )
#
#     data_record
# 0   prospective
# 1   prospective
# 2   prospective
# 4   prospective
# 6   prospective
# 7   prospective
# 8   prospective
# 9   prospective
# 12  prospective
# 14  prospective

# %%
col = list(df2.select_dtypes('object'))
unique_count_list = {col:len(df2[col].unique()) for col in col}
unique_count_list
# Out:
# {'PATIENT NUMBER': 2833,
#  'PROC NAME': 1,
#  'CENTER CODE': 20,
#  'REC PROGRESS': 11,
#  'CREATED DATE': 528,
#  'GENDER': 3,
#  'SYMPTOMS': 4,
#  'SOLITARY KIDNEY': 3,
#  'SIDE OF TUMOR': 4,
#  'SIDE OF SURGERY': 4,
#  'FACE': 3,
#  'TUMOR lOCATION': 4,
#  'PADUA RISK': 5,
#  'POLAR LOCATION': 3,
#  'RIM LOCATION': 3,
#  'RENAL SINUS': 5,
#  'UCS INVASION': 3,
#  'EXOPHYTIC RATE': 4,
#  'CLINICAL SIZE GROUP': 4,
#  'CT': 7,
#  'CN': 4,
#  'CM': 4,
#  'R.E.N.A.L. NEPHRO RISK STRATIFICATION': 5,
#  'RADIUS (maximal diameter in cm)': 4,
#  'EXOPHYTIC/ENDOPHYTIC PROPERTIES': 4,
#  'NEARNESS OF TUMOUR': 4,
#  'ANTERIOR OR POSTERIOR': 4,
#  'DATE OF SURGERY': 1632,
#  'ASA SCORE': 5,
#  'PARTIAL NEPHRO INDICATION': 4,
#  'ACCESS': 3,
#  'ROBOTICS ARMS': 4,
#  'ASSISTENT TROCARS': 3,
#  'DUAL CONSOLE': 3,
#  'ISCHEMIA': 4,
#  'CLAMP ARTERY': 5,
#  'CLAMP VEIN': 5,
#  'EARLY UNCLAMPING': 3,
#  'FLUORESCENCE': 3,
#  'UCS REPAIR': 3,
#  'HAEMOSTATIC AGENTS': 3,
#  'LYMPH NODE DISSECTION(LND)': 3,
#  'INTRA-OP TRANSUFUSION': 4,
#  'INTRA-OP COMPLICATION': 3,
#  'POST-OP COMPLICATION': 3,
#  'CLAVIEN GRADE': 7,
#  'MULITIFOCALITY': 3,
#  'PATHOLOGY': 3,
#  'HYSTOTYPE MALIGNANAT': 3,
#  'HYSTOTYPE MALIGNANAT YES': 10,
#  'HYSTOTYPE BENIGN': 3,
#  'SARCOMATOID DIFF': 3,
#  'NECROSIS': 3,
#  'MICRO VENOUS INVASION': 3,
#  'UCS INVASION.1': 3,
#  'PERIRENAL FAT INVASION': 3,
#  'SINUS FAT INVASION': 3,
#  'GEROTA INVASION': 3,
#  'VENOUS THROMBUS': 3,
#  'SURGICAL MARGIN': 3,
#  'PT': 8,
#  'PN': 4,
#  'TYPE OF COMPLICATIONS(s)': 18,
#  'SELECTED SURGICAL COMPLICATIONS(s)': 52,
#  'SELECTED NON SURGICAL COMPLICATIONS(s)': 23,
#  'TREATMENT OF COMPLICATIONS(s)': 150,
#  'RECURRENCE(s)': 37,
#  'FOLLOW UP DATE(s)': 1000,
#  'STATUS(s)': 24,
#  'TREATMENT(s)': 17,
#  'CREATININE(s)': 1021,
#  'EGFR(s)': 770,
#  'SRF(s)': 86,
#  'ERPF(s)': 45,
#  'data_record': 2}

# %%
for col in unique_count_list:
    if unique_count_list[col]<10:
        df2[col] = df2[col].astype('category')

# %%
list(df2.select_dtypes('object'))
# Out:
# ['PATIENT NUMBER',
#  'CENTER CODE',
#  'REC PROGRESS',
#  'CREATED DATE',
#  'DATE OF SURGERY',
#  'HYSTOTYPE MALIGNANAT YES',
#  'TYPE OF COMPLICATIONS(s)',
#  'SELECTED SURGICAL COMPLICATIONS(s)',
#  'SELECTED NON SURGICAL COMPLICATIONS(s)',
#  'TREATMENT OF COMPLICATIONS(s)',
#  'RECURRENCE(s)',
#  'FOLLOW UP DATE(s)',
#  'STATUS(s)',
#  'TREATMENT(s)',
#  'CREATININE(s)',
#  'EGFR(s)',
#  'SRF(s)',
#  'ERPF(s)']

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr = df2.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
#need ot work from here
list(df2)
# Out:
# ['PATIENT NUMBER',
#  'PROC NAME',
#  'CENTER CODE',
#  'REC PROGRESS',
#  'CREATED DATE',
#  'GENDER',
#  'AGE AT SURGERY',
#  'WEIGHT',
#  'HEIGHT',
#  'BMI',
#  'CLINICAL SIZE (mm)',
#  'CHARLSON SCORE',
#  'CHARLSON AGE-ADJUST SCORE',
#  'SYMPTOMS',
#  'SOLITARY KIDNEY',
#  'SIDE OF TUMOR',
#  'SIDE OF SURGERY',
#  'FACE',
#  'TUMOR lOCATION',
#  'PRE-OP HB',
#  'PRE-OP HT',
#  'PRE-OP CREAT',
#  'PRE-OP EGFR',
#  'PADUA SCORE',
#  'PADUA RISK',
#  'POLAR LOCATION',
#  'RIM LOCATION',
#  'RENAL SINUS',
#  'UCS INVASION',
#  'EXOPHYTIC RATE',
#  'CLINICAL SIZE GROUP',
#  'CT',
#  'CN',
#  'CM',
#  'R.E.N.A.L. NEPHRO SCORE',
#  'R.E.N.A.L. NEPHRO RISK STRATIFICATION',
#  'RADIUS (maximal diameter in cm)',
#  'EXOPHYTIC/ENDOPHYTIC PROPERTIES',
#  'NEARNESS OF TUMOUR',
#  'ANTERIOR OR POSTERIOR',
#  'DATE OF SURGERY',
#  'ASA SCORE',
#  'PARTIAL NEPHRO INDICATION',
#  'NO OF LESIONS',
#  'ACCESS',
#  'ROBOTICS ARMS',
#  'ASSISTENT TROCARS',
#  'DUAL CONSOLE',
#  'OPERATIVE TIME(min)',
#  'ISCHEMIA',
#  'CLAMP ARTERY',
#  'CLAMP VEIN',
#  'EARLY UNCLAMPING',
#  'FLUORESCENCE',
#  'ISCHEMIA TIME (min)',
#  'UCS REPAIR',
#  'HAEMOSTATIC AGENTS',
#  'LYMPH NODE DISSECTION(LND)',
#  'BLOOD LOSS (ml)',
#  'INTRA-OP TRANSUFUSION',
#  'INTRA-OP COMPLICATION',
#  'POST-OP COMPLICATION',
#  'CLAVIEN GRADE',
#  'POST-OP Creat_Day 1',
#  'POST-OP EGFR_Day 1',
#  'LENGTH OF STAY (days)',
#  'PATHOLOGICAL TUMOR SIZE',
#  'MULITIFOCALITY',
#  'PATHOLOGY',
#  'HYSTOTYPE MALIGNANAT',
#  'HYSTOTYPE MALIGNANAT YES',
#  'HYSTOTYPE BENIGN',
#  'FUHRMAN GRADING',
#  'SARCOMATOID DIFF',
#  'NECROSIS',
#  'MICRO VENOUS INVASION',
#  'UCS INVASION.1',
#  'PERIRENAL FAT INVASION',
#  'SINUS FAT INVASION',
#  'MIC SCORE',
#  'GEROTA INVASION',
#  'VENOUS THROMBUS',
#  'SURGICAL MARGIN',
#  'PT',
#  'PN',
#  'TYPE OF COMPLICATIONS(s)',
#  'SELECTED SURGICAL COMPLICATIONS(s)',
#  'SELECTED NON SURGICAL COMPLICATIONS(s)',
#  'TREATMENT OF COMPLICATIONS(s)',
#  'RECURRENCE(s)',
#  'FOLLOW UP DATE(s)',
#  'STATUS(s)',
#  'TREATMENT(s)',
#  'CREATININE(s)',
#  'EGFR(s)',
#  'SRF(s)',
#  'ERPF(s)',
#  'data_record']

# %%
df_filter_intra_op = df2[['PROC NAME',
 'GENDER',
 'AGE AT SURGERY',
 'BMI',
 'CLINICAL SIZE (mm)',
 #'CHARLSON SCORE',
 #'CHARLSON AGE-ADJUST SCORE',
 'SYMPTOMS',
 'SOLITARY KIDNEY',
 'SIDE OF SURGERY',
 'FACE',
 'TUMOR lOCATION',
 'PRE-OP HB',
 'PRE-OP HT',
 'PRE-OP CREAT',
 'PRE-OP EGFR',
 'POLAR LOCATION',
 'EXOPHYTIC RATE',
 'CLINICAL SIZE GROUP',
 'CT',
 'CN',
 'CM',
 #'R.E.N.A.L. NEPHRO RISK STRATIFICATION',
 'RADIUS (maximal diameter in cm)',
 'EXOPHYTIC/ENDOPHYTIC PROPERTIES',
 'ANTERIOR OR POSTERIOR',
 'ASA SCORE',
 #'PARTIAL NEPHRO INDICATION',
 'NO OF LESIONS',
 'ACCESS',







'INTRA-OP COMPLICATION']]

# %%
df_filter_intra_op.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2833 entries, 0 to 2390
# Data columns (total 27 columns):
# PROC NAME                          2833 non-null category
# GENDER                             2833 non-null category
# AGE AT SURGERY                     2833 non-null float64
# BMI                                2833 non-null float64
# CLINICAL SIZE (mm)                 2833 non-null float64
# SYMPTOMS                           2833 non-null category
# SOLITARY KIDNEY                    2833 non-null category
# SIDE OF SURGERY                    2833 non-null category
# FACE                               2833 non-null category
# TUMOR lOCATION                     2833 non-null category
# PRE-OP HB                          2833 non-null float64
# PRE-OP HT                          2833 non-null float64
# PRE-OP CREAT                       2833 non-null float64
# PRE-OP EGFR                        2833 non-null float64
# POLAR LOCATION                     2833 non-null category
# EXOPHYTIC RATE                     2833 non-null category
# CLINICAL SIZE GROUP                2833 non-null category
# CT                                 2833 non-null category
# CN                                 2833 non-null category
# CM                                 2833 non-null category
# RADIUS (maximal diameter in cm)    2833 non-null category
# EXOPHYTIC/ENDOPHYTIC PROPERTIES    2833 non-null category
# ANTERIOR OR POSTERIOR              2833 non-null category
# ASA SCORE                          2833 non-null category
# NO OF LESIONS                      2833 non-null float64
# ACCESS                             2833 non-null category
# INTRA-OP COMPLICATION              2833 non-null category
# dtypes: category(19), float64(8)
# memory usage: 254.9 KB

# %%
df_filter2 = df_filter_intra_op[df_filter_intra_op['INTRA-OP COMPLICATION'] != 'NA']

# %%
df_filter2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2387 entries, 0 to 2382
# Data columns (total 27 columns):
# PROC NAME                          2387 non-null category
# GENDER                             2387 non-null category
# AGE AT SURGERY                     2387 non-null float64
# BMI                                2387 non-null float64
# CLINICAL SIZE (mm)                 2387 non-null float64
# SYMPTOMS                           2387 non-null category
# SOLITARY KIDNEY                    2387 non-null category
# SIDE OF SURGERY                    2387 non-null category
# FACE                               2387 non-null category
# TUMOR lOCATION                     2387 non-null category
# PRE-OP HB                          2387 non-null float64
# PRE-OP HT                          2387 non-null float64
# PRE-OP CREAT                       2387 non-null float64
# PRE-OP EGFR                        2387 non-null float64
# POLAR LOCATION                     2387 non-null category
# EXOPHYTIC RATE                     2387 non-null category
# CLINICAL SIZE GROUP                2387 non-null category
# CT                                 2387 non-null category
# CN                                 2387 non-null category
# CM                                 2387 non-null category
# RADIUS (maximal diameter in cm)    2387 non-null category
# EXOPHYTIC/ENDOPHYTIC PROPERTIES    2387 non-null category
# ANTERIOR OR POSTERIOR              2387 non-null category
# ASA SCORE                          2387 non-null category
# NO OF LESIONS                      2387 non-null float64
# ACCESS                             2387 non-null category
# INTRA-OP COMPLICATION              2387 non-null category
# dtypes: category(19), float64(8)
# memory usage: 215.3 KB

# %%
columns=df_filter2.select_dtypes('category')
df_filter2_codes = df_filter2.copy()
from sklearn.preprocessing import LabelEncoder
le_dict = {col: LabelEncoder() for col in columns }
for col in columns:
    le_dict[col].fit_transform(df_filter2_codes[col])

# %%
label_mapping = dict()

# %%
label_mapping = {col: dict(zip(le_dict[col].classes_,le_dict[col].transform(le_dict[col].classes_))) for col in columns}
label_mapping
# Out:
# {'PROC NAME': {'Partial Nephrectomy': 0},
#  'GENDER': {'Female': 0, 'Male': 1, 'NA': 2},
#  'SYMPTOMS': {'Absent': 0,
#   'Local Symptoms': 1,
#   'NA': 2,
#   'Systemic Symptoms': 3},
#  'SOLITARY KIDNEY': {'NA': 0, 'No': 1, 'Yes': 2},
#  'SIDE OF SURGERY': {'Bilateral': 0, 'Left': 1, 'NA': 2, 'Right': 3},
#  'FACE': {'Anterior': 0, 'NA': 1, 'Posterior': 2},
#  'TUMOR lOCATION': {'Lower Pole': 0, 'Mid Pole': 1, 'NA': 2, 'Upper Pole': 3},
#  'POLAR LOCATION': {'NA': 0,
#   'Tumours crossing the sinus line >50% or falling entirely between the sinus lines (2 points)': 1,
#   'Tumours entirely located above the upper or below the lower sinus line, or crossing the sinus line < 50% (1 point)': 2},
#  'EXOPHYTIC RATE': {'< 50%exophytic (2 points)': 0,
#   '= 50% exophytic (1 point)': 1,
#   'Endophytic (3 points)': 2,
#   'NA': 3},
#  'CLINICAL SIZE GROUP': {'4.1cm-7cm': 0, '=<4cm': 1, '=>7cm': 2, 'NA': 3},
#  'CT': {'NA': 0, 'T1a': 1, 'T1b': 2, 'T2a': 3, 'T2b': 4, 'T3a': 5, 'T3b': 6},
#  'CN': {'N+': 0, 'N0': 1, 'NA': 2, 'Nx': 3},
#  'CM': {'M+': 0, 'M0': 1, 'NA': 2, 'Not Applicable': 3},
#  'RADIUS (maximal diameter in cm)': {'4 but <7': 0,
#   '=<4': 1,
#   '=>7': 2,
#   'NA': 3},
#  'EXOPHYTIC/ENDOPHYTIC PROPERTIES': {'50%': 0,
#   '<50%': 1,
#   'Entirely Endophytic': 2,
#   'NA': 3},
#  'ANTERIOR OR POSTERIOR': {'Anterior (a)': 0,
#   'NA': 1,
#   'Neither(x)': 2,
#   'Posterior (p)': 3},
#  'ASA SCORE': {'Category 1': 0,
#   'Category 2': 1,
#   'Category 3': 2,
#   'Category 4': 3,
#   'NA': 4},
#  'ACCESS': {'NA': 0, 'Retroperitoneal': 1, 'Transperitoneal': 2},
#  'INTRA-OP COMPLICATION': {'No': 0, 'Yes': 1}}

# %%
#df_filter2_codes = df_filter2
for col in columns:
    df_filter2_codes[col] = le_dict[col].transform(df_filter2_codes[col])

# %%
for col in columns:
    df_filter2_codes[col] = df_filter2_codes[col].astype('category')

# %%
#X = df_filter.drop(columns=['INTRA-OP COMPLICATION'])
X = df_filter2_codes.drop(columns=['INTRA-OP COMPLICATION'])
Y = df_filter2_codes['INTRA-OP COMPLICATION']
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2387 entries, 0 to 2382
# Data columns (total 26 columns):
# PROC NAME                          2387 non-null category
# GENDER                             2387 non-null category
# AGE AT SURGERY                     2387 non-null float64
# BMI                                2387 non-null float64
# CLINICAL SIZE (mm)                 2387 non-null float64
# SYMPTOMS                           2387 non-null category
# SOLITARY KIDNEY                    2387 non-null category
# SIDE OF SURGERY                    2387 non-null category
# FACE                               2387 non-null category
# TUMOR lOCATION                     2387 non-null category
# PRE-OP HB                          2387 non-null float64
# PRE-OP HT                          2387 non-null float64
# PRE-OP CREAT                       2387 non-null float64
# PRE-OP EGFR                        2387 non-null float64
# POLAR LOCATION                     2387 non-null category
# EXOPHYTIC RATE                     2387 non-null category
# CLINICAL SIZE GROUP                2387 non-null category
# CT                                 2387 non-null category
# CN                                 2387 non-null category
# CM                                 2387 non-null category
# RADIUS (maximal diameter in cm)    2387 non-null category
# EXOPHYTIC/ENDOPHYTIC PROPERTIES    2387 non-null category
# ANTERIOR OR POSTERIOR              2387 non-null category
# ASA SCORE                          2387 non-null category
# NO OF LESIONS                      2387 non-null float64
# ACCESS                             2387 non-null category
# dtypes: category(18), float64(8)
# memory usage: 212.8 KB

# %%
X.head(1)
# Out:
#   PROC NAME GENDER  AGE AT SURGERY   BMI  CLINICAL SIZE (mm) SYMPTOMS  \
# 0         0      0            50.0  20.2                 7.0        0
#
#   SOLITARY KIDNEY SIDE OF SURGERY FACE TUMOR lOCATION  PRE-OP HB  PRE-OP HT  \
# 0               1               1    2              0       13.2       50.0
#
#    PRE-OP CREAT  PRE-OP EGFR POLAR LOCATION EXOPHYTIC RATE  \
# 0          0.63       100.03              2              0
#
#   CLINICAL SIZE GROUP CT CN CM RADIUS (maximal diameter in cm)  \
# 0                   2  3  3  3                               2
#
#   EXOPHYTIC/ENDOPHYTIC PROPERTIES ANTERIOR OR POSTERIOR ASA SCORE  \
# 0                               1                     2         0
#
#    NO OF LESIONS ACCESS
# 0            1.0      2

# %%
Y.head(1)
# Out:
# 0    1
# Name: INTRA-OP COMPLICATION, dtype: category
# Categories (2, int64): [0, 1]

# %%
X_dummies = pd.get_dummies(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_dummies, Y, test_size=0.20, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
stdc = StandardScaler()
X_train_std = stdc.fit_transform(X_train)
X_test_std = stdc.transform(X_test)
# Out:
# H:\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:617: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# H:\Anaconda3\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# H:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.

# %%
X_train_std
# Out:
# array([[-1.06764986, -1.12120865,  4.79918235, ..., -0.69188054,
#         -0.35812092,  0.88174113],
#        [ 0.90918408, -0.30619929,  0.12906698, ...,  1.44533621,
#         -0.35812092, -1.13411972],
#        [-2.17467686, -0.32480681,  1.31216287, ..., -0.69188054,
#         -0.35812092,  0.88174113],
#        ...,
#        [ 0.27659722,  0.14410268, -0.18227405, ..., -0.69188054,
#         -0.35812092,  0.88174113],
#        [ 0.03937715,  2.11649975, -0.18227405, ...,  1.44533621,
#         -0.35812092, -1.13411972],
#        [-0.27691628, -0.58159058, -1.24083353, ..., -0.69188054,
#          2.79235295, -1.13411972]])

# %%
#PCA
import numpy as np
from sklearn.decomposition import PCA
pca = PCA(n_components=20)
pca.fit(X_train_std)
PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
  svd_solver='auto', tol=0.0, whiten=False)
X_train_std_pca = pca.fit_transform(X_train_std)
X_test_std_pca = pca.transform(X_test_std)
print(pca.explained_variance_ratio_)  

print(pca.singular_values_)
# Out:
# [0.12027254 0.07227931 0.05283004 0.0457934  0.03879225 0.0368748
#  0.03456515 0.03346381 0.03233114 0.02976582 0.02807042 0.02667939
#  0.025207   0.02363447 0.0219857  0.02094914 0.02055364 0.01920421
#  0.01805084 0.01657617]
# [131.22507747 101.72802316  86.97092255  80.97202824  74.52570637
#   72.66051156  70.34817438  69.21835845  68.03683982  65.28186052
#   63.39543982  61.80470672  60.07504966  58.17100358  56.10528635
#   54.7667196   54.2472851   52.43627516  50.83727526  48.71646111]

# %%
# Kernel PCA
from sklearn.datasets import load_digits
from sklearn.decomposition import KernelPCA

transformer = KernelPCA(n_components=20, kernel='rbf')
X_train_std_KPCA = transformer.fit_transform(X_train_std)
X_test_std_KPCA = transformer.transform(X_test_std)

# %%
X_train_std_under = pd.DataFrame(X_train_std_KPCA)
X_train_std_under['target'] = list(Y_train)

# %%
df_filter2_codes
target_count = X_train_std_under.target.value_counts()
print('Class 0:', target_count[0])
print('Class 1:', target_count[1])
print('Proportion:', round(target_count[0] / target_count[1], 2), ': 1')

target_count.plot(kind='bar', title='Count (target)');
# Out:
# Class 0: 1765
# Class 1: 144
# Proportion: 12.26 : 1

# %%
# Class count
count_class_0, count_class_1 = X_train_std_under.target.value_counts()

# Divide by class
df_class_0 = X_train_std_under[X_train_std_under.target == 0]
df_class_1 = X_train_std_under[X_train_std_under.target == 1]

# Random undersampling
df_class_0_under = df_class_0.sample(count_class_1)
df_train_under = pd.concat([df_class_0_under, df_class_1], axis=0)

print('Random under-sampling:')
print(df_train_under.target.value_counts())

df_train_under.target.value_counts().plot(kind='bar', title='Count (target)');
# Out:
# Random under-sampling:
# 1    144
# 0    144
# Name: target, dtype: int64

# %%
# Random Over Sampling
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_train_over = pd.concat([df_class_0, df_class_1_over], axis=0)

print('Random over-sampling:')
print(df_train_over.target.value_counts())

df_train_over.target.value_counts().plot(kind='bar', title='Count (target)');
# Out:
# Random over-sampling:
# 1    1765
# 0    1765
# Name: target, dtype: int64

# %%
df_train_under
#Shuffle the training set
df_train_under = df_train_under.sample(frac=1, random_state=123)
Y_train_under = np.array(df_train_under['target'])
df_train_under = np.array(df_train_under.drop(columns='target'))

# %%
df_train_over
#Shuffle the training set
df_train_over = df_train_over.sample(frac=1, random_state=123)
Y_train_over = np.array(df_train_over['target'])
df_train_over = np.array(df_train_over.drop(columns='target'))

# %%
# Tensorflow and tf.keras
import tensorflow as tf
from tensorflow import keras
import numpy as np
np.random.seed(123)
tf.set_random_seed(123)

# %%
# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 1.12.0

# %%
from sklearn import preprocessing
X_train_std
# Out:
# array([[-1.06764986, -1.12120865,  4.79918235, ..., -0.69188054,
#         -0.35812092,  0.88174113],
#        [ 0.90918408, -0.30619929,  0.12906698, ...,  1.44533621,
#         -0.35812092, -1.13411972],
#        [-2.17467686, -0.32480681,  1.31216287, ..., -0.69188054,
#         -0.35812092,  0.88174113],
#        ...,
#        [ 0.27659722,  0.14410268, -0.18227405, ..., -0.69188054,
#         -0.35812092,  0.88174113],
#        [ 0.03937715,  2.11649975, -0.18227405, ...,  1.44533621,
#         -0.35812092, -1.13411972],
#        [-0.27691628, -0.58159058, -1.24083353, ..., -0.69188054,
#          2.79235295, -1.13411972]])

# %%
a = pd.DataFrame(X_train_std_KPCA)
a['target'] = list(Y_train)
a.to_csv("a.csv")

# %%
input_data  = np.array(df_train_over)
#print(input_data.shape)
#print(Y_train_over.shape)

# %%
from tensorflow.keras import backend as K
from sklearn import metrics

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.clip(y_true * y_pred, 0, 1))
    possible_positives = K.sum(K.clip(y_true, 0, 1))
    return true_positives / (possible_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def balanced_accuracy(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return ((true_positives / (possible_positives + K.epsilon()))+(true_negatives / (possible_negatives + K.epsilon())))/2

# %%
from sklearn.utils import class_weight
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(Y_train),
                                                 Y_train)
class_weights
# Out:
# array([0.5407932 , 6.62847222])

# %%
def Keras_NN(units1,units2,
             units3,
             #units4,units5, 
             epochs, dropout_rate):
    from numpy.random import seed
    seed(1)
    from tensorflow import set_random_seed
    set_random_seed(2)
    tf.keras.backend.clear_session()
    model = keras.Sequential(
        [keras.layers.Dense(units1, activation='relu',
                            kernel_initializer='glorot_uniform', bias_initializer='zeros',
                            kernel_regularizer=tf.keras.regularizers.l2(0.01)),
         keras.layers.Dropout(dropout_rate),
         keras.layers.Dense(units2, activation='relu',
                            kernel_initializer='glorot_uniform', bias_initializer='zeros',
                            kernel_regularizer=tf.keras.regularizers.l2(0.01)),
         keras.layers.Dropout(dropout_rate),
         keras.layers.Dense(units3, activation='relu',
                            kernel_initializer='glorot_uniform', bias_initializer='zeros',
                            kernel_regularizer=tf.keras.regularizers.l2(0.01)),
         #keras.layers.Dropout(dropout_rate),
         #keras.layers.Dense(units4, activation='relu',
         #                   kernel_initializer='glorot_uniform', bias_initializer='zeros',
         #                   kernel_regularizer=tf.keras.regularizers.l2(0.01)),
         #keras.layers.Dropout(dropout_rate),
         #keras.layers.Dense(units5, activation='relu',
         #                   kernel_initializer='glorot_uniform', bias_initializer='zeros',
         #                   kernel_regularizer=tf.keras.regularizers.l2(0.01)),
         #keras.layers.Dropout(dropout_rate),        
         keras.layers.Dense(1,activation= tf.nn.sigmoid)])         


    # For a binary classification problem
    model.compile(optimizer=tf.train.AdamOptimizer(learning_rate=0.0001),
                  loss=tf.keras.losses.binary_crossentropy,
                  metrics = [balanced_accuracy, 'accuracy'])
    
    # Keras callback. The patience parameter is the amount of epochs to check for improvement
    early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=2, mode='min', min_delta=0.001)
    model.fit(input_data,np.array(Y_train_over), 
              epochs = epochs,
              #class_weight={0:0.5407932  ,1:6.62847222},
              validation_split = 0.50, callbacks = [early_stop])
    print(model.summary())
    return model

# %%
model_history = Keras_NN(units1 = 512,units2 = 256,units3 = 128, 
                         #units4 = 256,units5=256,
                         epochs = 50, dropout_rate = 0.1)
# Out:
# Train on 1765 samples, validate on 1765 samples
# Epoch 1/50
# 1765/1765 [==============================] - 1s 660us/step - loss: 5.7722 - balanced_accuracy: 0.6469 - acc: 0.6453 - val_loss: 5.3332 - val_balanced_accuracy: 0.6377 - val_acc: 0.6346
# Epoch 2/50
# 1765/1765 [==============================] - 0s 138us/step - loss: 4.9649 - balanced_accuracy: 0.6776 - acc: 0.6754 - val_loss: 4.5922 - val_balanced_accuracy: 0.6552 - val_acc: 0.6516
# Epoch 3/50
# 1765/1765 [==============================] - 0s 139us/step - loss: 4.2792 - balanced_accuracy: 0.6749 - acc: 0.6754 - val_loss: 3.9626 - val_balanced_accuracy: 0.6710 - val_acc: 0.6674
# Epoch 4/50
# 1765/1765 [==============================] - 0s 141us/step - loss: 3.6966 - balanced_accuracy: 0.6883 - acc: 0.6867 - val_loss: 3.4275 - val_balanced_accuracy: 0.6790 - val_acc: 0.6754
# Epoch 5/50
# 1765/1765 [==============================] - 0s 139us/step - loss: 3.2011 - balanced_accuracy: 0.6970 - acc: 0.6952 - val_loss: 2.9717 - val_balanced_accuracy: 0.7159 - val_acc: 0.7150
# Epoch 6/50
# 1765/1765 [==============================] - 0s 128us/step - loss: 2.7790 - balanced_accuracy: 0.6994 - acc: 0.7008 - val_loss: 2.5837 - val_balanced_accuracy: 0.7192 - val_acc: 0.7190
# Epoch 7/50
# 1765/1765 [==============================] - 0s 140us/step - loss: 2.4191 - balanced_accuracy: 0.7294 - acc: 0.7303 - val_loss: 2.2518 - val_balanced_accuracy: 0.7198 - val_acc: 0.7201
# Epoch 8/50
# 1765/1765 [==============================] - 0s 141us/step - loss: 2.1111 - balanced_accuracy: 0.7388 - acc: 0.7365 - val_loss: 1.9677 - val_balanced_accuracy: 0.7173 - val_acc: 0.7184
# Epoch 9/50
# 1765/1765 [==============================] - 0s 134us/step - loss: 1.8474 - balanced_accuracy: 0.7515 - acc: 0.7518 - val_loss: 1.7245 - val_balanced_accuracy: 0.7561 - val_acc: 0.7586
# Epoch 10/50
# 1765/1765 [==============================] - 0s 131us/step - loss: 1.6256 - balanced_accuracy: 0.7667 - acc: 0.7626 - val_loss: 1.5218 - val_balanced_accuracy: 0.7620 - val_acc: 0.7643
# Epoch 11/50
# 1765/1765 [==============================] - 0s 142us/step - loss: 1.4412 - balanced_accuracy: 0.7601 - acc: 0.7603 - val_loss: 1.3554 - val_balanced_accuracy: 0.7645 - val_acc: 0.7671
# Epoch 12/50
# 1765/1765 [==============================] - 0s 131us/step - loss: 1.2897 - balanced_accuracy: 0.7733 - acc: 0.7739 - val_loss: 1.2181 - val_balanced_accuracy: 0.7665 - val_acc: 0.7688
# Epoch 13/50
# 1765/1765 [==============================] - 0s 132us/step - loss: 1.1647 - balanced_accuracy: 0.7672 - acc: 0.7683 - val_loss: 1.1043 - val_balanced_accuracy: 0.7716 - val_acc: 0.7745
# Epoch 14/50
# 1765/1765 [==============================] - 0s 133us/step - loss: 1.0613 - balanced_accuracy: 0.7720 - acc: 0.7711 - val_loss: 1.0109 - val_balanced_accuracy: 0.7728 - val_acc: 0.7756
# Epoch 15/50
# 1765/1765 [==============================] - 0s 133us/step - loss: 0.9753 - balanced_accuracy: 0.7749 - acc: 0.7768 - val_loss: 0.9331 - val_balanced_accuracy: 0.7741 - val_acc: 0.7768
# Epoch 16/50
# 1765/1765 [==============================] - 0s 141us/step - loss: 0.9055 - balanced_accuracy: 0.7789 - acc: 0.7785 - val_loss: 0.8700 - val_balanced_accuracy: 0.7834 - val_acc: 0.7841
# Epoch 17/50
# 1765/1765 [==============================] - 0s 132us/step - loss: 0.8478 - balanced_accuracy: 0.7786 - acc: 0.7762 - val_loss: 0.8168 - val_balanced_accuracy: 0.7755 - val_acc: 0.7785
# Epoch 18/50
# 1765/1765 [==============================] - 0s 142us/step - loss: 0.8007 - balanced_accuracy: 0.7769 - acc: 0.7756 - val_loss: 0.7734 - val_balanced_accuracy: 0.7717 - val_acc: 0.7745
# Epoch 19/50
# 1765/1765 [==============================] - 0s 132us/step - loss: 0.7614 - balanced_accuracy: 0.7781 - acc: 0.7773 - val_loss: 0.7373 - val_balanced_accuracy: 0.7699 - val_acc: 0.7728
# Epoch 20/50
# 1765/1765 [==============================] - 0s 132us/step - loss: 0.7282 - balanced_accuracy: 0.7711 - acc: 0.7683 - val_loss: 0.7082 - val_balanced_accuracy: 0.7770 - val_acc: 0.7790
# Epoch 21/50
# 1765/1765 [==============================] - 0s 141us/step - loss: 0.7006 - balanced_accuracy: 0.7779 - acc: 0.7773 - val_loss: 0.6837 - val_balanced_accuracy: 0.7699 - val_acc: 0.7728
# Epoch 22/50
# 1765/1765 [==============================] - 0s 133us/step - loss: 0.6795 - balanced_accuracy: 0.7724 - acc: 0.7694 - val_loss: 0.6642 - val_balanced_accuracy: 0.7784 - val_acc: 0.7802
# Epoch 23/50
# 1765/1765 [==============================] - 0s 141us/step - loss: 0.6615 - balanced_accuracy: 0.7684 - acc: 0.7683 - val_loss: 0.6490 - val_balanced_accuracy: 0.7775 - val_acc: 0.7796
# Epoch 24/50
# 1765/1765 [==============================] - 0s 132us/step - loss: 0.6458 - balanced_accuracy: 0.7765 - acc: 0.7790 - val_loss: 0.6341 - val_balanced_accuracy: 0.7748 - val_acc: 0.7768
# Epoch 25/50
# 1765/1765 [==============================] - 0s 141us/step - loss: 0.6352 - balanced_accuracy: 0.7703 - acc: 0.7700 - val_loss: 0.6236 - val_balanced_accuracy: 0.7796 - val_acc: 0.7802
# Epoch 26/50
# 1765/1765 [==============================] - 0s 132us/step - loss: 0.6235 - balanced_accuracy: 0.7768 - acc: 0.7779 - val_loss: 0.6139 - val_balanced_accuracy: 0.7764 - val_acc: 0.7785
# Epoch 27/50
# 1765/1765 [==============================] - 0s 143us/step - loss: 0.6153 - balanced_accuracy: 0.7828 - acc: 0.7790 - val_loss: 0.6073 - val_balanced_accuracy: 0.7774 - val_acc: 0.7796
# Epoch 28/50
# 1765/1765 [==============================] - 0s 131us/step - loss: 0.6097 - balanced_accuracy: 0.7719 - acc: 0.7751 - val_loss: 0.6000 - val_balanced_accuracy: 0.7784 - val_acc: 0.7807
# Epoch 29/50
# 1765/1765 [==============================] - 0s 160us/step - loss: 0.6019 - balanced_accuracy: 0.7751 - acc: 0.7773 - val_loss: 0.5942 - val_balanced_accuracy: 0.7727 - val_acc: 0.7751
# Epoch 30/50
# 1765/1765 [==============================] - 0s 141us/step - loss: 0.5973 - balanced_accuracy: 0.7779 - acc: 0.7762 - val_loss: 0.5901 - val_balanced_accuracy: 0.7767 - val_acc: 0.7785
# Epoch 31/50
# 1765/1765 [==============================] - 0s 141us/step - loss: 0.5930 - balanced_accuracy: 0.7757 - acc: 0.7796 - val_loss: 0.5862 - val_balanced_accuracy: 0.7769 - val_acc: 0.7790
# Epoch 32/50
# 1765/1765 [==============================] - 0s 132us/step - loss: 0.5907 - balanced_accuracy: 0.7818 - acc: 0.7796 - val_loss: 0.5832 - val_balanced_accuracy: 0.7775 - val_acc: 0.7796
# Epoch 33/50
# 1765/1765 [==============================] - 0s 142us/step - loss: 0.5877 - balanced_accuracy: 0.7818 - acc: 0.7768 - val_loss: 0.5810 - val_balanced_accuracy: 0.7800 - val_acc: 0.7819
# Epoch 34/50
# 1765/1765 [==============================] - 0s 141us/step - loss: 0.5854 - balanced_accuracy: 0.7800 - acc: 0.7739 - val_loss: 0.5776 - val_balanced_accuracy: 0.7723 - val_acc: 0.7739
# Epoch 35/50
# 1765/1765 [==============================] - 0s 133us/step - loss: 0.5840 - balanced_accuracy: 0.7823 - acc: 0.7796 - val_loss: 0.5766 - val_balanced_accuracy: 0.7809 - val_acc: 0.7830
# Epoch 36/50
# 1765/1765 [==============================] - 0s 142us/step - loss: 0.5797 - balanced_accuracy: 0.7759 - acc: 0.7756 - val_loss: 0.5760 - val_balanced_accuracy: 0.7783 - val_acc: 0.7790
# Epoch 37/50
# 1765/1765 [==============================] - 0s 134us/step - loss: 0.5786 - balanced_accuracy: 0.7833 - acc: 0.7813 - val_loss: 0.5723 - val_balanced_accuracy: 0.7765 - val_acc: 0.7785
# Epoch 38/50
# 1765/1765 [==============================] - 0s 139us/step - loss: 0.5780 - balanced_accuracy: 0.7757 - acc: 0.7790 - val_loss: 0.5732 - val_balanced_accuracy: 0.7787 - val_acc: 0.7796
# Epoch 39/50
# 1765/1765 [==============================] - 0s 142us/step - loss: 0.5771 - balanced_accuracy: 0.7748 - acc: 0.7762 - val_loss: 0.5702 - val_balanced_accuracy: 0.7737 - val_acc: 0.7756
# Epoch 40/50
# 1765/1765 [==============================] - 0s 139us/step - loss: 0.5742 - balanced_accuracy: 0.7766 - acc: 0.7768 - val_loss: 0.5738 - val_balanced_accuracy: 0.7527 - val_acc: 0.7541
# Epoch 41/50
# 1765/1765 [==============================] - 0s 134us/step - loss: 0.5735 - balanced_accuracy: 0.7748 - acc: 0.7745 - val_loss: 0.5675 - val_balanced_accuracy: 0.7804 - val_acc: 0.7819
# Epoch 42/50
# 1765/1765 [==============================] - 0s 141us/step - loss: 0.5720 - balanced_accuracy: 0.7795 - acc: 0.7779 - val_loss: 0.5663 - val_balanced_accuracy: 0.7820 - val_acc: 0.7836
# Epoch 43/50
# 1765/1765 [==============================] - 0s 134us/step - loss: 0.5721 - balanced_accuracy: 0.7779 - acc: 0.7773 - val_loss: 0.5654 - val_balanced_accuracy: 0.7756 - val_acc: 0.7773
# Epoch 44/50
# 1765/1765 [==============================] - 0s 132us/step - loss: 0.5702 - balanced_accuracy: 0.7799 - acc: 0.7802 - val_loss: 0.5651 - val_balanced_accuracy: 0.7763 - val_acc: 0.7785
# Epoch 45/50
# 1765/1765 [==============================] - 0s 131us/step - loss: 0.5702 - balanced_accuracy: 0.7737 - acc: 0.7745 - val_loss: 0.5637 - val_balanced_accuracy: 0.7763 - val_acc: 0.7785
# Epoch 46/50
# 1765/1765 [==============================] - 0s 133us/step - loss: 0.5684 - balanced_accuracy: 0.7788 - acc: 0.7785 - val_loss: 0.5653 - val_balanced_accuracy: 0.7695 - val_acc: 0.7705
# Epoch 47/50
# 1765/1765 [==============================] - 0s 131us/step - loss: 0.5680 - balanced_accuracy: 0.7787 - acc: 0.7790 - val_loss: 0.5635 - val_balanced_accuracy: 0.7752 - val_acc: 0.7773
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                multiple                  10752
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# dense_1 (Dense)              multiple                  131328
# _________________________________________________________________
# dropout_1 (Dropout)          multiple                  0
# _________________________________________________________________
# dense_2 (Dense)              multiple                  32896
# _________________________________________________________________
# dense_3 (Dense)              multiple                  129
# =================================================================
# Total params: 175,105
# Trainable params: 175,105
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
pd.DataFrame(model_history.history.history)[['loss','val_loss']].plot(figsize=(10,8))
pd.DataFrame(model_history.history.history)[['acc','val_acc']].plot(figsize=(10,8))

# %%
a = pd.DataFrame(model_history.predict(input_data), columns=['prediction_prob'])
a['prediction_prob'] = np.round(a['prediction_prob'],2)
a['prediction'] = np.where(a['prediction_prob']>0.50, 1,0)
a['original'] = list(Y_train_over)

# %%
from sklearn import metrics
print(metrics.confusion_matrix(a['original'],a['prediction']))
print(metrics.balanced_accuracy_score(a['original'],a['prediction']))
# Out:
# [[1391  374]
#  [ 398 1367]]
# 0.7813031161473087

# %%
a = pd.DataFrame(model_history.predict(X_test_std_KPCA), columns=['prediction_prob'])
a['prediction_prob'] = np.round(a['prediction_prob'],4)
a['prediction'] = np.where(a['prediction_prob']>0.50, 1,0)
a['original'] = list(Y_test)

# %%
from sklearn import metrics
print(metrics.confusion_matrix(a['original'],a['prediction']))
print(metrics.balanced_accuracy_score(a['original'],a['prediction']))
print(metrics.balanced_accuracy_score(a['original'],model_history.predict_classes(X_test_std_KPCA).flatten()))
# Out:
# [[333 117]
#  [  6  22]]
# 0.7628571428571429
# 0.7628571428571429

# %%
import sklearn

# %%
# Neural Network Using High Level Tensorflow API

# %%
def Keras_NN(dropout_rate = 0.0, units1 = 1,
             units2 = 1,
             units3 = 1,
             units4 = 1,
             #units5 = 1
            ):
    from numpy.random import seed
    seed(123)
    from tensorflow import set_random_seed
    set_random_seed(123)
    tf.keras.backend.clear_session()
    model = keras.Sequential(
            [keras.layers.Dense(units1, activation='relu',
                                kernel_initializer='glorot_uniform', bias_initializer='zeros',
                                kernel_regularizer=tf.keras.regularizers.l2(0.01)),
             keras.layers.Dropout(dropout_rate),
             
             keras.layers.Dense(units2, activation='relu',
                                kernel_initializer='glorot_uniform', bias_initializer='zeros',
                                kernel_regularizer=tf.keras.regularizers.l2(0.01)),
             keras.layers.Dropout(dropout_rate),
             
             keras.layers.Dense(units3, activation='relu',
                                kernel_initializer='glorot_uniform', bias_initializer='zeros',
                                kernel_regularizer=tf.keras.regularizers.l2(0.01)),
             keras.layers.Dropout(dropout_rate),
             
             keras.layers.Dense(units4, activation='relu',
                                kernel_initializer='glorot_uniform', bias_initializer='zeros',
                                kernel_regularizer=tf.keras.regularizers.l2(0.001)),
             keras.layers.Dropout(dropout_rate),
             #
             #keras.layers.Dense(units5, activation='relu',
             #                   kernel_initializer='glorot_uniform', bias_initializer='zeros',
             #                   kernel_regularizer=tf.keras.regularizers.l2(0.001)),
             #keras.layers.Dropout(dropout_rate),

             keras.layers.Dense(1,activation= tf.nn.sigmoid)])
          

    # For a binary classification problem
    model.compile(optimizer=tf.train.AdamOptimizer(learning_rate=0.0001),
                  loss=tf.keras.losses.binary_crossentropy,
                  metrics = [balanced_accuracy])
    

    #print(model.summary())
    return model

# %%
#### from sklearn.model_selection import GridSearchCV
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
model = KerasClassifier(build_fn=Keras_NN, verbose=0)
param_grid = {'epochs':[20], 
              'dropout_rate':[0.0,0.2,0.3,0.4,0.5],
              'units1':[1024],
              'units2':[512],
              'units3':[256],
              'units4':[128]
              #'units5':[128],
              
             }
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring='balanced_accuracy', cv = 5, return_train_score=True)
# Keras callback. The patience parameter is the amount of epochs to check for improvement
early_stop = keras.callbacks.EarlyStopping(monitor='val_balanced_accuracy', patience=2)
grid_result = grid.fit(input_data, np.array(Y_train), class_weight={0:0.5407932 ,1:6.62847222},callbacks = [early_stop])
# Out:
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# WARNING:tensorflow:Early stopping conditioned on metric `val_balanced_accuracy` which is not available. Available metrics are: loss,balanced_accuracy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-186-7575f188d577> in <module>()
#      14 # Keras callback. The patience parameter is the amount of epochs to check for improvement
#      15 early_stop = keras.callbacks.EarlyStopping(monitor='val_balanced_accuracy', patience=2)
# ---> 16 grid_result = grid.fit(input_data, np.array(Y_train), class_weight={0:0.5407932 ,1:6.62847222},callbacks = [early_stop])
#
# H:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     720                 return results_container[0]
#     721
# --> 722             self._run_search(evaluate_candidates)
#     723
#     724         results = results_container[0]
#
# H:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1189     def _run_search(self, evaluate_candidates):
#    1190         """Search all candidates in param_grid"""
# -> 1191         evaluate_candidates(ParameterGrid(self.param_grid))
#    1192
#    1193
#
# H:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     709                                for parameters, (train, test)
#     710                                in product(candidate_params,
# --> 711                                           cv.split(X, y, groups)))
#     712
#     713                 all_candidate_params.extend(candidate_params)
#
# H:\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self, iterable)
#     984                 self._iterating = self._original_iterator is not None
#     985
# --> 986             while self.dispatch_one_batch(iterator):
#     987                 pass
#     988
#
# H:\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     823                 return False
#     824             else:
# --> 825                 self._dispatch(tasks)
#     826                 return True
#     827
#
# H:\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in _dispatch(self, batch)
#     780         with self._lock:
#     781             job_idx = len(self._jobs)
# --> 782             job = self._backend.apply_async(batch, callback=cb)
#     783             # A job can complete so quickly than its callback is
#     784             # called before we get here, causing self._jobs to
#
# H:\Anaconda3\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# H:\Anaconda3\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in __init__(self, batch)
#     543         # Don't delay the application, to avoid keeping the input
#     544         # arguments in memory
# --> 545         self.results = batch()
#     546
#     547     def get(self):
#
# H:\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# H:\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in <listcomp>(.0)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# H:\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     526             estimator.fit(X_train, **fit_params)
#     527         else:
# --> 528             estimator.fit(X_train, y_train, **fit_params)
#     529
#     530     except Exception as e:
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py in fit(self, x, y, **kwargs)
#     222       raise ValueError('Invalid shape for y: ' + str(y.shape))
#     223     self.n_classes_ = len(self.classes_)
# --> 224     return super(KerasClassifier, self).fit(x, y, **kwargs)
#     225
#     226   def predict(self, x, **kwargs):
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py in fit(self, x, y, **kwargs)
#     165     fit_args.update(kwargs)
#     166
# --> 167     history = self.model.fit(x, y, **fit_args)
#     168
#     169     return history
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1534         steps_name='steps_per_epoch',
#    1535         steps=steps_per_epoch,
# -> 1536         validation_split=validation_split)
#    1537
#    1538     # Prepare validation data.
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split)
#     990         x, y, sample_weight = next_element
#     991     x, y, sample_weights = self._standardize_weights(x, y, sample_weight,
# --> 992                                                      class_weight, batch_size)
#     993     return x, y, sample_weights
#     994
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _standardize_weights(self, x, y, sample_weight, class_weight, batch_size)
#    1078                      metrics=self.metrics,
#    1079                      loss_weights=self.loss_weights,
# -> 1080                      target_tensors=target_tensors)
#    1081
#    1082     # In graph mode, if we had just set inputs and targets as symbolic tensors
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\training\checkpointable\base.py in _method_wrapper(self, *args, **kwargs)
#     472     self._setattr_tracking = False  # pylint: disable=protected-access
#     473     try:
# --> 474       method(self, *args, **kwargs)
#     475     finally:
#     476       self._setattr_tracking = previous_value  # pylint: disable=protected-access
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in compile(self, optimizer, loss, metrics, loss_weights, sample_weight_mode, weighted_metrics, target_tensors, distribute, **kwargs)
#     615         loss_weight = loss_weights_list[i]
#     616         with K.name_scope(self.output_names[i] + '_loss'):
# --> 617           output_loss = weighted_loss(y_true, y_pred, sample_weight, mask)
#     618         if len(self.outputs) > 1:
#     619           self.metrics_tensors.append(output_loss)
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_utils.py in weighted(y_true, y_pred, weights, mask)
#     625       try:
#     626         # Broadcast weights if possible.
# --> 627         weights = weights_broadcast_ops.broadcast_weights(weights, score_array)
#     628       except ValueError:
#     629         # Reduce values to same ndim as weight array.
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\ops\weights_broadcast_ops.py in broadcast_weights(weights, values)
#     165       return weights
#     166
# --> 167     with ops.control_dependencies((assert_broadcastable(weights, values),)):
#     168       return math_ops.multiply(
#     169           weights, array_ops.ones_like(values), name=scope)
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\ops\weights_broadcast_ops.py in assert_broadcastable(weights, values)
#     131             weights_rank, weights_shape, values_rank, values_shape),
#     132         name="is_valid_shape")
# --> 133     return control_flow_ops.Assert(is_valid_shape, data, name=scope)
#     134
#     135
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\util\tf_should_use.py in wrapped(*args, **kwargs)
#     187   """
#     188   def wrapped(*args, **kwargs):
# --> 189     return _add_should_use_warning(fn(*args, **kwargs))
#     190   return tf_decorator.make_decorator(
#     191       fn, wrapped, 'should_use_result',
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in Assert(condition, data, summarize, name)
#     152
#     153   with ops.name_scope(name, "Assert", [condition, data]) as name:
# --> 154     xs = ops.convert_n_to_tensor(data)
#     155     if all([x.dtype in {dtypes.string, dtypes.int32} for x in xs]):
#     156       # As a simple heuristic, we assume that string and int32 are
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in convert_n_to_tensor(values, dtype, name, preferred_dtype)
#    1242       name=name,
#    1243       preferred_dtype=preferred_dtype,
# -> 1244       as_ref=False)
#    1245
#    1246
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in internal_convert_n_to_tensor(values, dtype, name, as_ref, preferred_dtype, ctx)
#    1209             as_ref=as_ref,
#    1210             preferred_dtype=preferred_dtype,
# -> 1211             ctx=ctx))
#    1212   return ret
#    1213
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, ctx)
#    1144
#    1145     if ret is None:
# -> 1146       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1147
#    1148     if ret is NotImplemented:
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     227                                          as_ref=False):
#     228   _ = as_ref
# --> 229   return constant(v, dtype=dtype, name=name)
#     230
#     231
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py in constant(value, dtype, shape, name, verify_shape)
#     212       attrs={"value": tensor_value,
#     213              "dtype": dtype_value},
# --> 214       name=name).outputs[0]
#     215   return const_tensor
#     216
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     486                 'in a future version' if date is None else ('after %s' % date),
#     487                 instructions)
# --> 488       return func(*args, **kwargs)
#     489     return tf_decorator.make_decorator(func, new_func, 'deprecated',
#     490                                        _add_deprecated_arg_notice_to_docstring(
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in create_op(***failed resolving arguments***)
#    3272           input_types=input_types,
#    3273           original_op=self._default_original_op,
# -> 3274           op_def=op_def)
#    3275       self._create_op_helper(ret, compute_device=compute_device)
#    3276     return ret
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1790           op_def, inputs, node_def.attr)
#    1791       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
# -> 1792                                 control_input_ops)
#    1793
#    1794     # Initialize self._outputs.
#
# H:\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1605   op_desc = c_api.TF_NewOperation(graph._c_graph,
#    1606                                   compat.as_str(node_def.op),
# -> 1607                                   compat.as_str(node_def.name))
#    1608   # Add inputs
#    1609   for op_input in inputs:
#
# KeyboardInterrupt:

# %%
print(grid_result.best_params_)
print(grid_result.best_score_)
# Out:
# {'dropout_rate': 0.2, 'epochs': 20, 'units1': 1024, 'units2': 512, 'units3': 256, 'units4': 128}
# 0.7005431487644798

# %%
print(grid_result.best_estimator_.model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                multiple                  78848
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# dense_1 (Dense)              multiple                  524800
# _________________________________________________________________
# dropout_1 (Dropout)          multiple                  0
# _________________________________________________________________
# dense_2 (Dense)              multiple                  131328
# _________________________________________________________________
# dropout_2 (Dropout)          multiple                  0
# _________________________________________________________________
# dense_3 (Dense)              multiple                  32896
# _________________________________________________________________
# dropout_3 (Dropout)          multiple                  0
# _________________________________________________________________
# dense_4 (Dense)              multiple                  129
# =================================================================
# Total params: 768,001
# Trainable params: 768,001
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
grid_result.best_estimator_.model.history.history.keys()
# Out:
# dict_keys(['loss', 'balanced_accuracy'])

# %%
pd.DataFrame(grid_result.best_estimator_.model.history.history)[['loss']].plot(figsize=(10,8))
pd.DataFrame(grid_result.best_estimator_.model.history.history)[['balanced_accuracy']].plot(figsize=(10,8))

# %%
pd.DataFrame(grid.cv_results_)[pd.DataFrame(grid.cv_results_)['rank_test_score']==1]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1       8.397348      0.155083         0.139568        0.007091
#
#   param_dropout_rate param_epochs param_units1 param_units2 param_units3  \
# 1                0.2           20         1024          512          256
#
#   param_units4                                             params  \
# 1          128  {'dropout_rate': 0.2, 'epochs': 20, 'units1': ...
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 1           0.707765           0.701719           0.714711           0.706704
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score  \
# 1           0.671741         0.700543        0.014968                1
#
#    split0_train_score  split1_train_score  split2_train_score  \
# 1            0.982307            0.984065            0.983711
#
#    split3_train_score  split4_train_score  mean_train_score  std_train_score
# 1            0.989339            0.985523          0.984989         0.002404

# %%
a = pd.DataFrame(grid_result.best_estimator_.predict(X_test_std), columns=['prediction'])
a['original'] = list(Y_test)

# %%
from sklearn import metrics
print(metrics.confusion_matrix(a['original'],a['prediction']))
print(metrics.balanced_accuracy_score(a['original'],a['prediction']))
# Out:
# [[415  35]
#  [ 21   7]]
# 0.5861111111111111

# %%
a = pd.DataFrame(grid_result.best_estimator_.predict_proba(X_test_std), columns=['prob_0','prediction_prob'])
a['prediction_prob'] = np.round(a['prediction_prob'],3)
a['prediction'] = np.where(a['prediction_prob']>=0.50, 1,0)
a['original'] = list(Y_test)

# %%
from sklearn import metrics
print(metrics.confusion_matrix(a['original'],a['prediction']))
print(metrics.balanced_accuracy_score(a['original'],a['prediction']))
# Out:
# [[415  35]
#  [ 21   7]]
# 0.5861111111111111

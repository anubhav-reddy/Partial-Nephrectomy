# %%
# Import Packages
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)  
#pd.set_option('display.expand_frame_repr', False)
#pd.set_option('max_colwidth', -1)

# %%
output_path = 'output/models/'

import os
if not os.path.exists(output_path):
    os.makedirs(output_path)

# %%
# Import prospective dataset
df = pd.read_excel('H:/RediMinds/DRMahen/Preethi PN_Data validation_2014-2018.xlsx', sheet_name='PN_Data validation_2014-2018')

# %%
# Exploring outcome of intrest
print("Unique values for tumour type {}".format(df['SURGICALMARGIN'].unique()))
print("Number of patients with SURGICALMARGIN missing {}".format(sum(df['SURGICALMARGIN'].isnull())))
print("Distribution of tumor type \n{}".format(df['SURGICALMARGIN'].value_counts()))
# Out:
# Unique values for tumour type ['Negative' nan 'Positive']
# Number of patients with SURGICALMARGIN missing 252
# Distribution of tumor type
# Negative    3042
# Positive     101
# Name: SURGICALMARGIN, dtype: int64

# %%
# drop records with no target variable
df = df[df['SURGICALMARGIN'].notnull()].copy()

# %%
# Encode the target variable
df['SURGICALMARGIN'] = df['SURGICALMARGIN'].map({'Positive':1,'Negative':0}).copy()

# %%
df_ori = df.copy()

# %%
#check number of patients and columns in Retrospective dataset
print('Number of patients in Combined dataset {}'. format(df.shape[0]))
print('Number of variables in Combined dataset {}'. format(df.shape[1]))
# Out:
# Number of patients in Combined dataset 3143
# Number of variables in Combined dataset 161

# %%
# reset index for combined dataset
df.reset_index(inplace=True, drop=True)

# %%
df.head(5)
# Out:
#   PATIENTNUMBER             PROCNAME CENTERCODE SURGEONCODE  \
# 0   10PAT000065  Partial Nephrectomy   U5WT3NOY    QIG8PUOL
# 1   13PAT000522  Partial Nephrectomy   08ZMCILJ    G4X4XVDW
# 2   11PAT000166  Partial Nephrectomy   0VZRZWAI    WLU4FAKU
# 3   13PAT000509  Partial Nephrectomy   08ZMCILJ    G4X4XVDW
# 4   15PAT000088  Partial Nephrectomy   VNO3BPES    D0PCULV2
#
#            RECPROGRESS            CREATEDDATE  GENDER  DATEOFBIRTH  \
# 0  Pathology completed  2018-11-18 13:00:00.0    Male       1964.0
# 1  Pathology completed  2018-04-22 18:30:00.0    Male       1957.0
# 2           Follow-up1  2018-08-15 18:30:00.0    Male       1962.0
# 3  Pathology completed  2018-04-12 18:30:00.0  Female       1948.0
# 4    Post-Op Completed  2018-07-17 22:00:00.0  Female       1974.0
#
#    AGEATSURGERY MARITALSTATUS             RACE     EDUCATION  WEIGHT  HEIGHT  \
# 0          54.0       Married  White/Caucasian  Not Provided     NaN     NaN
# 1          61.0       Married  Mongoloid/Asian      Graduate    70.0   167.0
# 2          56.0       Married  Mongoloid/Asian  Not Provided    74.0   178.0
# 3          70.0       Married  Mongoloid/Asian      Graduate    85.0   160.0
# 4          44.0        Single  White/Caucasian  Not Provided    75.0   160.0
#
#      BMI  CLINICALSIZEmm                                               ECOG  \
# 0    NaN             NaN  Fully active, able to carry on all pre-disease...
# 1  25.10            33.0  Fully active, able to carry on all pre-disease...
# 2  23.36             NaN  Fully active, able to carry on all pre-disease...
# 3  33.20             2.1  Ambulatory and capable of all selfcare but una...
# 4  29.30            57.0  Fully active, able to carry on all pre-disease...
#
#    CHARLSONSCORE  CHARLSONAGEADJUSTSCORE        SYMPTOMS SOLITARYKIDNEY  \
# 0            0.0                     2.0          Absent             No
# 1            0.0                     3.0          Absent            Yes
# 2            0.0                     2.0          Absent             No
# 3            5.0                     9.0          Absent             No
# 4            0.0                     1.0  Local Symptoms             No
#
#   TYPEOFSOLITARYKIDNEY BILATERALITYOFTUMOR SIDEOFTUMOR SIDEOFSURGERY  \
# 0                  NaN                  No        Left          Left
# 1                 Left                  No        Left          Left
# 2                  NaN                  No        Left          Left
# 3                  NaN                  No        Left          Left
# 4                  NaN                  No        Left          Left
#
#   PREOPMULTIFOCALITY       FACE TUMORlOCATION  PREOPHB  PREOPHT  PREOPWBC  \
# 0                 No        NaN     Lower Pol     15.4     48.0    6300.0
# 1                 No   Anterior     Lower Pol     12.3     39.4    5400.0
# 2                 No   Anterior     Lower Pol     10.2     36.4    5200.0
# 3                 No   Anterior     Upper Pol      9.4     28.4    6020.0
# 4                 No  Posterior      Mid Pole     13.5     41.3    6300.0
#
#    PREOPCREAT PREOPGFR  PREOPEGFR PREOPERPF  PADUASCORE  \
# 0        8.10      NaN       0.49       NaN         NaN
# 1        1.25      NaN      58.72       NaN         9.0
# 2        0.70      NaN     116.66       NaN         6.0
# 3        1.70       52      29.71       NaN         6.0
# 4        0.83      999      74.68       999        10.0
#
#                PADUARISK                                      POLARLOCATION  \
# 0                    NaN                                                NaN
# 1  2(Intermidiate  Risk)  Tumours entirely located above the upper or be...
# 2           1(Low  Risk)  Tumours entirely located above the upper or be...
# 3           1(Low  Risk)  Tumours entirely located above the upper or be...
# 4          3(High  Risk)  Tumours crossing the sinus line >50% or fallin...
#
#                                 RIMLOCATION  \
# 0                                       NaN
# 1              At the medial rim (2 points)
# 2  Tumours located at the lateral (1 point)
# 3  Tumours located at the lateral (1 point)
# 4  Tumours located at the lateral (1 point)
#
#                                           RENALSINUS  \
# 0                                                NaN
# 1  Tumours without renal sinus involvement (1 point)
# 2  Tumours without renal sinus involvement (1 point)
# 3  Tumours without renal sinus involvement (1 point)
# 4            With renal sinus involvement (2 points)
#
#                                          UCSINVASION  \
# 0                                                NaN
# 1  With involving, dislocation or infiltration of...
# 2             Absent relationship with UCS (1 point)
# 3             Absent relationship with UCS (1 point)
# 4  With involving, dislocation or infiltration of...
#
#                EXOPHYTICRATE CLINICALSIZEGROUP   CT   CN   CM  \
# 0                        NaN               NaN  NaN  NaN  NaN
# 1  < 50%exophytic (2 points)             =<4cm  T1a   N0   M0
# 2  = 50% exophytic (1 point)             =<4cm  T1a   N0   M0
# 3  = 50% exophytic (1 point)             =<4cm  T1a   N0   M0
# 4  = 50% exophytic (1 point)         4.1cm-7cm  T1b   N0   M0
#
#   R.E.N.A.L.NEPHROSCORE R.E.N.A.L.NEPHRORISKSTRATIFICATION  \
# 0                   NaN                                NaN
# 1                    8x               2(Intermidiate Risk)
# 2                    4a                        1(Low Risk)
# 3                    5a                        1(Low Risk)
# 4                    8p               2(Intermidiate Risk)
#
#   RADIUSmaximaldiameterincm EXOPHYTICENDOPHYTICPROPERTIES NEARNESSOFTUMOUR  \
# 0                       NaN                           NaN              NaN
# 1                       =<4                          <50%              =<4
# 2                       =<4                           50%              =>7
# 3                       =<4                           50%        >4 but <7
# 4                  4 but <7                           50%              =<4
#
#   ANTERIORORPOSTERIOR  LOCATIONTOPOLARLINE TumorConsistencyonImaging  \
# 0                 NaN                  NaN                       NaN
# 1          Neither(x)                  2.0    Some cystic components
# 2        Anterior (a)                  1.0            Entirely solid
# 3        Anterior (a)                  1.0            Entirely solid
# 4       Posterior (p)                  2.0            Entirely solid
#
#   BosniakClassification          DATEOFSURGERY    ASASCORE  \
# 0                   NaN  2018-11-21 00:00:00.0  Category 2
# 1  Bosniak Grade 4 cyst  2018-04-23 00:00:00.0  Category 3
# 2  Entirely solid tumor  2018-08-16 00:00:00.0  Category 1
# 3  Entirely solid tumor  2018-04-13 00:00:00.0  Category 2
# 4  Entirely solid tumor  2018-07-18 00:00:00.0  Category 2
#
#   PARTIALNEPHROINDICATION MULTIFOCALITY  NOOFLESIONS  \
# 0                Relative            No          1.0
# 1                Elective            No          1.0
# 2                Elective            No          1.0
# 3                Elective            No          1.0
# 4                Elective            No          1.0
#
#   ImagingFeaturesofotherexcisedtumor Consistencyoftheotherexcisedtumors  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN               Entirely solid tumor
# 3                                NaN               Entirely solid tumor
# 4                                NaN               Entirely solid tumor
#
#             ACCESS DAVINCIMODEL ROBOTICSARMS ASSISTENTTROCARS DUALCONSOLE  \
# 0  Transperitoneal           Xi       4-arms       Only 12 mm          No
# 1  Transperitoneal           Xi       4-arms       Only 12 mm          No
# 2  Transperitoneal           Xi       4-arms       Only 12 mm          No
# 3  Transperitoneal           Xi       4-arms       Only 12 mm          No
# 4  Transperitoneal           Si       3-arms     5 mm + 12 mm          No
#
#   PRIMARYSURGEON OPERATIVETIMEmin       ISCHEMIA CLAMPARTERY  \
# 0          Staff            02:30           Warm     Bulldog
# 1          Staff            03:00           Warm     Bulldog
# 2          Staff            02:40           Warm     Bulldog
# 3          Staff            01:42  Not Performed          No
# 4          Staff            01:48           Warm     Bulldog
#
#   SELECTIVEARTERIALCLAMPING CLAMPVEIN EARLYUNCLAMPING FLUORESCENCE  \
# 0                        No        No              No         Used
# 1                       Yes        No              No         Used
# 2                        No        No              No     Not Used
# 3                       Yes        No              No         Used
# 4                        No        No              No     Not Used
#
#   INNERRENORRHAPHY OUTERRENORRHAPHY  ISCHEMIATIMEmin      UCSREPAIR  \
# 0              Yes              Yes             31.0      Performed
# 1              Yes              Yes             25.0      Performed
# 2               No               No             20.0  Not Performed
# 3              Yes              Yes              0.0      Performed
# 4              Yes              Yes             23.0  Not Performed
#
#   HAEMOSTATICAGENTS HAEMOSTATICDetails LYMPHNODEDISSECTIONLND  BLOODLOSSml  \
# 0               Yes           Surgiflo          Not Performed         50.0
# 1               Yes           surgicel              Performed        100.0
# 2                No                NaN          Not Performed         75.0
# 3               Yes           surgicel          Not Performed         40.0
# 4                No                NaN          Not Performed        999.0
#
#   INTRAOPTRANSUFUSION                    SURGICALCONSIDERATIONS  \
# 0                  No                                       NaN
# 1                  No  single kidney - tertiary artery clamping
# 2                  No                                       NaN
# 3                  No                           supra selective
# 4                  No                                       NaN
#
#   INTRAOPCOMPLICATION INTRAOPCOMPLICATIONS NeedtoConverttoRadicalNephrectomy  \
# 0                  No                  NaN                                No
# 1                  No                  NaN                                No
# 2                  No                  NaN                                No
# 3                  No                  NaN                                No
# 4                  No                  NaN                                No
#
#   TREATMENTOFCOMPLICATION POSTOPCOMPLICATION SURGICALCOMPLICATIONS  \
# 0                     NaN      Complications                   NaN
# 1                     NaN   No Complications                   320
# 2                     NaN      Complications                   314
# 3                     NaN   No Complications                   314
# 4                     NaN      Complications                   NaN
#
#   NONSURGICALCOMPLICATIONS                     POSTOPTREATMENTOFCOMPLICATION  \
# 0                  321,323  IV antibiotics, discharged with oral antibiotics
# 1                      321                                               NaN
# 2                      321                                               NaN
# 3                      321                                               NaN
# 4                      321                                ANTIBIOTIC THERAPY
#
#                                         CLAVIENGRADE       POSTOPHB_Day1  \
# 0  Grade 2: Complications needing only use of int...  13.699999999999999
# 1  Grade 1: Any deviation from the normal postope...                  12
# 2  Grade 1: Any deviation from the normal postope...                10.9
# 3               Grade 0: Absence of any complication                  12
# 4  Grade 1: Any deviation from the normal postope...                12.5
#
#   POSTOPHT_Day1 POSTOPCreat_Day1 POSTOPEGFR_Day1 POSTOPWBC_Day1 POSTOPHB_Day2  \
# 0            45             1.14              63          12900           999
# 1            32              1.3              49           8000          12.2
# 2          39.9              0.9             110           9800          14.1
# 3            35              1.3              37           7200           999
# 4          38.2             0.71           119.7          12200          10.6
#
#   POSTOPHT_Day2 POSTOPCreat_Day2 POSTOPEGFR_Day2 POSTOPWBC_Day2 POSTOPHB_Day3  \
# 0           999              999             999            NaN            13
# 1          39.7              1.2              78           9050           999
# 2          42.3             1.13              75          14560           999
# 3           999              999             999            NaN           999
# 4          33.0             0.74             999           8700           999
#
#   POSTOPHT_Day3 POSTOPCreat_Day3 POSTOPEGFR_Day3 POSTOPWBC_Day3  \
# 0            35              0,9              61           4300
# 1           999              999             999            999
# 2          37.1             1.04            55.1           5470
# 3           999              999             999            999
# 4           999              999             999            999
#
#    LENGTHOFSTAYdays  PATHOLOGICALTUMORSIZE  MINTHICKNESSMARGIN  \
# 0               5.0                    8.0                 NaN
# 1               2.0                    3.5                 1.0
# 2               5.0                    3.0               999.0
# 3               4.0                   25.0                 5.0
# 4               3.0                   42.0                 2.0
#
#    MAXTHICKNESSMARGIN MULITIFOCALITY PATHOLOGY HYSTOTYPEMALIGNANAT  \
# 0                 NaN         Absent    Benign                  No
# 1                 3.0         Absent    Malign                 Yes
# 2               999.0         Absent    Malign                 Yes
# 3                 NaN         Absent    Malign                 Yes
# 4                 6.0         Absent    Malign                 Yes
#
#             HYSTOTYPEMALIGNANATYES HYSTOTYPEBENIGN HYSTOTYPEBENIGNYES  \
# 0                              NaN             Yes     Angiomyolipoma
# 1  Clear cell renal cell carcinoma              No                NaN
# 2  Clear cell renal cell carcinoma              No                NaN
# 3  Clear cell renal cell carcinoma             NaN                NaN
# 4  Clear cell renal cell carcinoma              No                NaN
#
#    FUHRMANGRADING SARCOMATOIDDIFF  SARCOMATOIDDIFF_A NECROSIS  \
# 0             NaN          Absent                NaN   Absent
# 1             1.0          Absent                0.0   Absent
# 2             3.0          Absent                NaN   Absent
# 3             2.0          Absent                NaN   Absent
# 4             1.0          Absent                NaN   Absent
#
#   MICROVENOUSINVASION UCSINVASION_A PERIRENALFATINVASION HilarFatInvasion  \
# 0              Absent        Absent               Absent           Absent
# 1              Absent        Absent               Absent           Absent
# 2              Absent        Absent               Absent           Absent
# 3              Absent        Absent               Absent           Absent
# 4              Absent        Absent               Absent           Absent
#
#   SINUSFATINVASION  MICSCORE ADRENALINVASION GEROTAINVASION RenalVeinInvasion  \
# 0           Absent       0.0          Absent         Absent            Absent
# 1           Absent       0.0          Absent         Absent            Absent
# 2           Absent       0.0          Absent         Absent            Absent
# 3           Absent       0.0          Absent         Absent            Absent
# 4           Absent       0.0          Absent         Absent            Absent
#
#   VENOUSTHROMBUS  SURGICALMARGIN UNIFOCALMULTIFOCAL  NO_OF_NODE_TAKEN  \
# 0         Absent               0                NaN               NaN
# 1         Absent               0                NaN               0.0
# 2         Absent               0                NaN               0.0
# 3         Absent               0                NaN               NaN
# 4         Absent               0                NaN               0.0
#
#   NO_OF_NODE_POSITIVE SITEOFPOSITIVENODE    TREATMENTPSM      PT   PN  \
# 0                 NaN                NaN  Wait and Watch  Benign  NaN
# 1                   0     Not Applicable             NaN     T1a   Nx
# 2                 NaN                NaN  Wait and Watch     T1a   Nx
# 3                 NaN                NaN             NaN     T1a   Nx
# 4                   0     Not Applicable             NaN     T1b   Nx
#
#   OTHERTUMORS DATEOFRECURRENCE  LASTFOLLOWUPDURATION TIMETORECURRENCE  \
# 0         NaN              NaN                   NaN              NaN
# 1         NaN              NaN                   NaN              NaN
# 2         NaN              NaN                   NaN              NaN
# 3         NaN              NaN                   NaN              NaN
# 4         NaN              NaN                   NaN              NaN
#
#   LASTFOLLOWUPSTATUS LASTFOLLOWUPRECURRENCE LASTTREATMENTOFRECURRENCE  \
# 0                NaN                    NaN                       NaN
# 1                NaN                    NaN                       NaN
# 2                NaN                    NaN                       NaN
# 3                NaN                    NaN                       NaN
# 4                NaN                    NaN                       NaN
#
#   TYPEOFCOMPLICATIONSs SELECTEDSURGICALCOMPLICATIONSs  \
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2                  NaN                            NaN
# 3                  NaN                            NaN
# 4                  NaN                            NaN
#
#   SELECTEDNONSURGICALCOMPLICATIONSs TREATMENTOFCOMPLICATIONSs RECURRENCEs  \
# 0                               NaN                       NaN         NaN
# 1                               NaN                       NaN         NaN
# 2                               NaN                       NaN         NaN
# 3                               NaN                       NaN         NaN
# 4                               NaN                       NaN         NaN
#
#   FOLLOWUPDATEs STATUSs TREATMENTs CREATININEs EGFRs SRFs ERPFs    Year
# 0           NaN     NaN        NaN         NaN   NaN  NaN   NaN  2018.0
# 1           NaN     NaN        NaN         NaN   NaN  NaN   NaN  2018.0
# 2           NaN     NaN        NaN         NaN   NaN  NaN   NaN  2018.0
# 3           NaN     NaN        NaN         NaN   NaN  NaN   NaN  2018.0
# 4           NaN     NaN        NaN         NaN   NaN  NaN   NaN  2018.0

# %%
df.info(verbose = True, null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3143 entries, 0 to 3142
# Data columns (total 161 columns):
# PATIENTNUMBER                         3143 non-null object
# PROCNAME                              3143 non-null object
# CENTERCODE                            3143 non-null object
# SURGEONCODE                           886 non-null object
# RECPROGRESS                           3143 non-null object
# CREATEDDATE                           3143 non-null object
# GENDER                                3132 non-null object
# DATEOFBIRTH                           1914 non-null float64
# AGEATSURGERY                          3129 non-null float64
# MARITALSTATUS                         2075 non-null object
# RACE                                  1932 non-null object
# EDUCATION                             1850 non-null object
# WEIGHT                                2162 non-null float64
# HEIGHT                                2160 non-null float64
# BMI                                   2800 non-null float64
# CLINICALSIZEmm                        3072 non-null float64
# ECOG                                  1741 non-null object
# CHARLSONSCORE                         2642 non-null float64
# CHARLSONAGEADJUSTSCORE                2655 non-null float64
# SYMPTOMS                              2447 non-null object
# SOLITARYKIDNEY                        2743 non-null object
# TYPEOFSOLITARYKIDNEY                  114 non-null object
# BILATERALITYOFTUMOR                   1991 non-null object
# SIDEOFTUMOR                           2120 non-null object
# SIDEOFSURGERY                         3133 non-null object
# PREOPMULTIFOCALITY                    916 non-null object
# FACE                                  2424 non-null object
# TUMORlOCATION                         2784 non-null object
# PREOPHB                               2317 non-null float64
# PREOPHT                               2222 non-null float64
# PREOPWBC                              1925 non-null float64
# PREOPCREAT                            3085 non-null float64
# PREOPGFR                              149 non-null object
# PREOPEGFR                             2457 non-null float64
# PREOPERPF                             158 non-null object
# PADUASCORE                            2053 non-null float64
# PADUARISK                             1996 non-null object
# POLARLOCATION                         2524 non-null object
# RIMLOCATION                           1919 non-null object
# RENALSINUS                            2016 non-null object
# UCSINVASION                           2021 non-null object
# EXOPHYTICRATE                         2356 non-null object
# CLINICALSIZEGROUP                     2669 non-null object
# CT                                    2769 non-null object
# CN                                    2490 non-null object
# CM                                    1950 non-null object
# R.E.N.A.L.NEPHROSCORE                 2637 non-null object
# R.E.N.A.L.NEPHRORISKSTRATIFICATION    2493 non-null object
# RADIUSmaximaldiameterincm             2777 non-null object
# EXOPHYTICENDOPHYTICPROPERTIES         2208 non-null object
# NEARNESSOFTUMOUR                      2122 non-null object
# ANTERIORORPOSTERIOR                   2465 non-null object
# LOCATIONTOPOLARLINE                   1834 non-null float64
# TumorConsistencyonImaging             543 non-null object
# BosniakClassification                 541 non-null object
# DATEOFSURGERY                         3142 non-null object
# ASASCORE                              2854 non-null object
# PARTIALNEPHROINDICATION               2265 non-null object
# MULTIFOCALITY                         1997 non-null object
# NOOFLESIONS                           2576 non-null float64
# ImagingFeaturesofotherexcisedtumor    74 non-null object
# Consistencyoftheotherexcisedtumors    357 non-null object
# ACCESS                                2297 non-null object
# DAVINCIMODEL                          2110 non-null object
# ROBOTICSARMS                          2738 non-null object
# ASSISTENTTROCARS                      2513 non-null object
# DUALCONSOLE                           2256 non-null object
# PRIMARYSURGEON                        1988 non-null object
# OPERATIVETIMEmin                      2974 non-null object
# ISCHEMIA                              2604 non-null object
# CLAMPARTERY                           2598 non-null object
# SELECTIVEARTERIALCLAMPING             1995 non-null object
# CLAMPVEIN                             2489 non-null object
# EARLYUNCLAMPING                       2473 non-null object
# FLUORESCENCE                          2371 non-null object
# INNERRENORRHAPHY                      1997 non-null object
# OUTERRENORRHAPHY                      1996 non-null object
# ISCHEMIATIMEmin                       2929 non-null float64
# UCSREPAIR                             2336 non-null object
# HAEMOSTATICAGENTS                     2360 non-null object
# HAEMOSTATICDetails                    1660 non-null object
# LYMPHNODEDISSECTIONLND                2370 non-null object
# BLOODLOSSml                           3052 non-null float64
# INTRAOPTRANSUFUSION                   2609 non-null object
# SURGICALCONSIDERATIONS                200 non-null object
# INTRAOPCOMPLICATION                   2821 non-null object
# INTRAOPCOMPLICATIONS                  165 non-null object
# NeedtoConverttoRadicalNephrectomy     882 non-null object
# TREATMENTOFCOMPLICATION               572 non-null object
# POSTOPCOMPLICATION                    2758 non-null object
# SURGICALCOMPLICATIONS                 109 non-null object
# NONSURGICALCOMPLICATIONS              66 non-null object
# POSTOPTREATMENTOFCOMPLICATION         525 non-null object
# CLAVIENGRADE                          2339 non-null object
# POSTOPHB_Day1                         1214 non-null object
# POSTOPHT_Day1                         1332 non-null object
# POSTOPCreat_Day1                      2204 non-null object
# POSTOPEGFR_Day1                       1986 non-null object
# POSTOPWBC_Day1                        940 non-null object
# POSTOPHB_Day2                         830 non-null object
# POSTOPHT_Day2                         896 non-null object
# POSTOPCreat_Day2                      1049 non-null object
# POSTOPEGFR_Day2                       905 non-null object
# POSTOPWBC_Day2                        768 non-null object
# POSTOPHB_Day3                         762 non-null object
# POSTOPHT_Day3                         807 non-null object
# POSTOPCreat_Day3                      977 non-null object
# POSTOPEGFR_Day3                       776 non-null object
# POSTOPWBC_Day3                        755 non-null object
# LENGTHOFSTAYdays                      3027 non-null float64
# PATHOLOGICALTUMORSIZE                 2910 non-null float64
# MINTHICKNESSMARGIN                    1524 non-null float64
# MAXTHICKNESSMARGIN                    647 non-null float64
# MULITIFOCALITY                        2441 non-null object
# PATHOLOGY                             3117 non-null object
# HYSTOTYPEMALIGNANAT                   3142 non-null object
# HYSTOTYPEMALIGNANATYES                2523 non-null object
# HYSTOTYPEBENIGN                       3113 non-null object
# HYSTOTYPEBENIGNYES                    604 non-null object
# FUHRMANGRADING                        2638 non-null float64
# SARCOMATOIDDIFF                       2195 non-null object
# SARCOMATOIDDIFF_A                     1403 non-null float64
# NECROSIS                              2336 non-null object
# MICROVENOUSINVASION                   2399 non-null object
# UCSINVASION_A                         2295 non-null object
# PERIRENALFATINVASION                  2698 non-null object
# HilarFatInvasion                      1058 non-null object
# SINUSFATINVASION                      2293 non-null object
# MICSCORE                              2430 non-null float64
# ADRENALINVASION                       2239 non-null object
# GEROTAINVASION                        2302 non-null object
# RenalVeinInvasion                     925 non-null object
# VENOUSTHROMBUS                        2353 non-null object
# SURGICALMARGIN                        3143 non-null int64
# UNIFOCALMULTIFOCAL                    78 non-null object
# NO_OF_NODE_TAKEN                      2016 non-null float64
# NO_OF_NODE_POSITIVE                   1204 non-null object
# SITEOFPOSITIVENODE                    816 non-null object
# TREATMENTPSM                          308 non-null object
# PT                                    2898 non-null object
# PN                                    2423 non-null object
# OTHERTUMORS                           15 non-null object
# DATEOFRECURRENCE                      24 non-null object
# LASTFOLLOWUPDURATION                  1893 non-null float64
# TIMETORECURRENCE                      199 non-null object
# LASTFOLLOWUPSTATUS                    1518 non-null object
# LASTFOLLOWUPRECURRENCE                1445 non-null object
# LASTTREATMENTOFRECURRENCE             469 non-null object
# TYPEOFCOMPLICATIONSs                  2625 non-null object
# SELECTEDSURGICALCOMPLICATIONSs        2625 non-null object
# SELECTEDNONSURGICALCOMPLICATIONSs     2625 non-null object
# TREATMENTOFCOMPLICATIONSs             2625 non-null object
# RECURRENCEs                           2625 non-null object
# FOLLOWUPDATEs                         2625 non-null object
# STATUSs                               2625 non-null object
# TREATMENTs                            2625 non-null object
# CREATININEs                           2625 non-null object
# EGFRs                                 2625 non-null object
# SRFs                                  2625 non-null object
# ERPFs                                 2625 non-null object
# Year                                  3140 non-null float64
# dtypes: float64(28), int64(1), object(132)
# memory usage: 3.9+ MB

# %% [markdown]
# ### Define numeric columns and replace encoded missing values with NaN

# %%
# List of columns tobre converted to numeric
numeric_col_list = ['AGEATSURGERY',
'WEIGHT',
'HEIGHT',
'BMI',
'CLINICALSIZEmm',
'PREOPHB',
'PREOPHT',
'PREOPWBC',
'PREOPCREAT',
'PREOPGFR',
'PREOPEGFR',
'PREOPERPF',
'NOOFLESIONS',
'BLOODLOSSml',
'POSTOPHB_Day1',
'POSTOPHT_Day1',
'POSTOPCreat_Day1',
'POSTOPEGFR_Day1',
'POSTOPWBC_Day1',
'POSTOPHB_Day2',
'POSTOPHT_Day2',
'POSTOPCreat_Day2',
'POSTOPEGFR_Day2',
'POSTOPWBC_Day2',
'POSTOPHB_Day3',
'POSTOPHT_Day3',
'POSTOPCreat_Day3',
'POSTOPEGFR_Day3',
'POSTOPWBC_Day3',
'LENGTHOFSTAYdays',
'PATHOLOGICALTUMORSIZE',
'MINTHICKNESSMARGIN',
'MAXTHICKNESSMARGIN',
'SARCOMATOIDDIFF_A',
'NO_OF_NODE_TAKEN',
'LASTFOLLOWUPDURATION',
'CHARLSONSCORE',
'CHARLSONAGEADJUSTSCORE',
'PADUASCORE',
]

# %%
# Convert columns in numeric_col_list to numeric and invalid values are set NaN 
for col in numeric_col_list:
    df[col]= pd.to_numeric(df[col], errors='coerce')

# %%
# Summary of numeric columns
df.describe(include = [np.number]).round(2)
# Out:
#        DATEOFBIRTH  AGEATSURGERY   WEIGHT   HEIGHT      BMI  CLINICALSIZEmm  \
# count      1914.00       3129.00  2162.00  2160.00  2800.00         3072.00
# mean       1956.10         57.75    89.97   163.65    28.70           34.22
# std          13.27         12.71    51.03    41.36     5.95           34.33
# min        1921.00         16.00     7.71     1.70    15.10            0.00
# 25%        1947.00         49.00    69.00   160.00    24.60           22.00
# 50%        1955.00         59.00    80.00   169.00    27.56           30.00
# 75%        1965.00         67.00    93.70   176.00    31.78           42.00
# max        1998.00         89.00   999.00   999.00    55.60          999.00
#
#        CHARLSONSCORE  CHARLSONAGEADJUSTSCORE  PREOPHB  PREOPHT  PREOPWBC  \
# count        2642.00                 2655.00  2317.00  2222.00   1925.00
# mean            1.59                    3.56    19.80    45.69   6933.17
# std             2.02                    2.29    76.38    98.63   3103.50
# min             0.00                    0.00     3.80     0.25      0.00
# 25%             0.00                    2.00    12.90    36.00   5600.00
# 50%             1.00                    3.00    13.90    41.00   6800.00
# 75%             2.00                    5.00    15.00    44.00   8300.00
# max            19.00                   18.00   999.00   999.00  56000.00
#
#        PREOPCREAT  PREOPGFR  PREOPEGFR  PREOPERPF  PADUASCORE  \
# count     3085.00    122.00    2457.00     151.00     2053.00
# mean         4.03    599.99      80.29     694.94        8.42
# std         53.93    465.09      30.74     410.26        1.75
# min          0.00     18.00       0.02      43.50        2.00
# 25%          0.78     72.80      65.00     157.50        7.00
# 50%          0.91    999.00      79.09     999.00        8.00
# 75%          1.10    999.00      94.00     999.00       10.00
# max        999.00    999.00     999.00     999.00       14.00
#
#        LOCATIONTOPOLARLINE  NOOFLESIONS  ISCHEMIATIMEmin  BLOODLOSSml  \
# count              1834.00      2576.00          2929.00      3052.00
# mean                  1.90         1.06            19.87       188.41
# std                   0.82         0.30            37.79       228.33
# min                   1.00         0.00             0.00         0.00
# 25%                   1.00         1.00            14.00        50.00
# 50%                   2.00         1.00            18.00       100.00
# 75%                   3.00         1.00            23.00       200.00
# max                   3.00         6.00           999.00      3500.00
#
#        POSTOPHB_Day1  POSTOPHT_Day1  POSTOPCreat_Day1  POSTOPEGFR_Day1  \
# count        1118.00        1296.00           2164.00          1750.00
# mean           52.34          59.57             19.27            95.84
# std           183.86         168.31            132.81           165.66
# min             1.00           0.27              0.00             4.00
# 25%            11.00          30.10              0.98            52.00
# 50%            12.20          35.00              1.00            64.82
# 75%            13.60          38.40              1.30            80.45
# max           999.00         999.00            999.00           999.00
#
#        POSTOPWBC_Day1  POSTOPHB_Day2  POSTOPHT_Day2  POSTOPCreat_Day2  \
# count          800.00         550.00         591.00            773.00
# mean          2155.65         161.40         157.95            104.70
# std           4396.07         346.81         333.38            304.11
# min              4.80           0.00           0.00              0.00
# 25%              9.40          10.90          27.00              0.91
# 50%             11.90          12.20          34.00              1.17
# 75%            999.00          14.40          40.35              1.57
# max          19610.00         999.00         999.00            999.00
#
#        POSTOPEGFR_Day2  POSTOPWBC_Day2  POSTOPHB_Day3  POSTOPHT_Day3  \
# count           560.00          477.00         417.00         427.00
# mean            210.29         2713.99         220.52         255.17
# std             341.62         4960.93         403.22         412.30
# min               0.00            2.10           0.00           0.00
# 25%              49.30            9.40          10.70          28.45
# 50%              67.10           12.00          12.10          34.90
# 75%              93.25         4100.00          14.00          44.05
# max             999.00        27780.00         999.00         999.00
#
#        POSTOPCreat_Day3  POSTOPEGFR_Day3  POSTOPWBC_Day3  LENGTHOFSTAYdays  \
# count            632.00           389.00          407.00           3027.00
# mean             135.36           279.42         2737.62              3.88
# std              340.72           393.79         4146.54             25.71
# min                0.00             0.00            2.60              0.00
# 25%                0.90            55.00            9.10              2.00
# 50%                1.12            73.00          999.00              3.00
# 75%                1.52           110.00         4300.00              4.00
# max              999.00           999.00        16060.00            999.00
#
#        PATHOLOGICALTUMORSIZE  MINTHICKNESSMARGIN  MAXTHICKNESSMARGIN  \
# count                2910.00             1524.00              647.00
# mean                   10.88               73.42              194.65
# std                    23.72              253.37              386.45
# min                     0.00                0.00                0.00
# 25%                     2.40                1.00                2.00
# 50%                     3.60                2.00                5.00
# 75%                     8.28                5.00               25.50
# max                   999.00              999.00              999.00
#
#        FUHRMANGRADING  SARCOMATOIDDIFF_A  MICSCORE  SURGICALMARGIN  \
# count         2638.00            1403.00   2430.00         3143.00
# mean           121.18              15.05      0.28            0.03
# std            323.31             142.96      0.45            0.18
# min              1.00            -999.00      0.00            0.00
# 25%              2.00               0.00      0.00            0.00
# 50%              2.00               0.00      0.00            0.00
# 75%              3.00               0.00      1.00            0.00
# max            999.00             999.00      1.00            1.00
#
#        NO_OF_NODE_TAKEN  LASTFOLLOWUPDURATION     Year
# count           2016.00               1893.00  3140.00
# mean               0.61                 16.85  2013.21
# std               22.26                 19.58     3.00
# min                0.00                  0.00  2006.00
# 25%                0.00                  3.00  2011.00
# 50%                0.00                 10.00  2013.00
# 75%                0.00                 24.00  2016.00
# max              999.00                101.00  2018.00

# %%
#replace missing values such as 999 in the dataframe with NaN
df = df.replace([99,999,9999,99999,999999,-99,-999,-9999,-99999,-999999],np.nan)

# %%
# replacing negative numbers in the dataframe with nan as given variables cannot contain negative numbers
for col in list(df.select_dtypes('float64')):
    df[col] = df[col].apply(lambda x: np.nan if x<0 else x)

# %%
# Summary of numeric columns - to check missing values such as 99, 999, 999 have been replaced
df.describe(include = [np.number]).round(2)
# Out:
#        DATEOFBIRTH  AGEATSURGERY   WEIGHT   HEIGHT      BMI  CLINICALSIZEmm  \
# count      1914.00       3129.00  2154.00  2157.00  2800.00         3069.00
# mean       1956.10         57.75    88.68   162.48    28.70           33.28
# std          13.27         12.71    38.22    27.21     5.95           16.39
# min        1921.00         16.00     7.71     1.70    15.10            0.00
# 25%        1947.00         49.00    69.00   160.00    24.60           22.00
# 50%        1955.00         59.00    80.00   169.00    27.56           30.00
# 75%        1965.00         67.00    93.30   176.00    31.78           42.00
# max        1998.00         89.00   377.00   208.30    55.60          135.00
#
#        CHARLSONSCORE  CHARLSONAGEADJUSTSCORE  PREOPHB  PREOPHT  PREOPWBC  \
# count        2642.00                 2655.00  2303.00  2199.00   1905.00
# mean            1.59                    3.56    13.85    35.72   6995.48
# std             2.02                    2.29     1.75    14.82   3059.27
# min             0.00                    0.00     3.80     0.25      0.00
# 25%             0.00                    2.00    12.90    36.00   5600.00
# 50%             1.00                    3.00    13.90    40.90   6850.00
# 75%             2.00                    5.00    15.00    44.00   8300.00
# max            19.00                   18.00    39.60    88.00  56000.00
#
#        PREOPCREAT  PREOPGFR  PREOPEGFR  PREOPERPF  PADUASCORE  \
# count     3076.00     52.00    2442.00      54.00     2053.00
# mean         1.12     62.86      79.81     148.75        8.42
# std          3.39     22.42      24.56      56.66        1.75
# min          0.00     18.00       0.02      43.50        2.00
# 25%          0.78     43.18      65.00     110.00        7.00
# 50%          0.91     58.50      79.00     132.00        8.00
# 75%          1.10     82.50      93.59     177.75       10.00
# max         96.00    116.80     210.87     340.00       14.00
#
#        LOCATIONTOPOLARLINE  NOOFLESIONS  ISCHEMIATIMEmin  BLOODLOSSml  \
# count              1834.00      2576.00          2925.00      3049.00
# mean                  1.90         1.06            18.54       187.61
# std                   0.82         0.30            10.82       227.02
# min                   1.00         0.00             0.00         0.00
# 25%                   1.00         1.00            14.00        50.00
# 50%                   2.00         1.00            18.00       100.00
# 75%                   3.00         1.00            23.00       200.00
# max                   3.00         6.00           320.00      3500.00
#
#        POSTOPHB_Day1  POSTOPHT_Day1  POSTOPCreat_Day1  POSTOPEGFR_Day1  \
# count        1078.00        1256.00           2125.00          1690.00
# mean           17.21          29.65              1.29            65.90
# std            23.24          14.39              3.78            21.79
# min             1.00           0.27              0.00             4.00
# 25%            11.00          30.00              0.98            51.26
# 50%            12.10          35.00              1.00            64.00
# 75%            13.30          38.00              1.30            78.10
# max           162.00          96.80            143.00           198.30
#
#        POSTOPWBC_Day1  POSTOPHB_Day2  POSTOPHT_Day2  POSTOPCreat_Day2  \
# count          758.00         470.00         511.00            693.00
# mean          2219.74          18.82          26.28              1.46
# std           4507.70          27.47          15.72              6.59
# min              4.80           0.00           0.00              0.00
# 25%              9.30          10.70           0.96              0.90
# 50%             11.70          11.90          32.60              1.10
# 75%             17.65          13.20          36.90              1.40
# max          19610.00         152.00          51.00            174.00
#
#        POSTOPEGFR_Day2  POSTOPWBC_Day2  POSTOPHB_Day3  POSTOPHT_Day3  \
# count           468.00          451.00         329.00         327.00
# mean             62.94         2812.86          12.30          27.69
# std              24.78         5084.59          11.09          22.65
# min               0.00            2.10           0.00           0.00
# 25%              46.49            9.20          10.40          24.95
# 50%              62.00           11.60          11.60          32.70
# 75%              78.98         5270.00          12.70          36.75
# max             157.70        27780.00         131.00         332.00
#
#        POSTOPCreat_Day3  POSTOPEGFR_Day3  POSTOPWBC_Day3  LENGTHOFSTAYdays  \
# count            547.00           297.00          320.00           3025.00
# mean               1.16            65.61         3210.30              3.22
# std                0.57            37.09         4564.48              2.49
# min                0.00             0.00            2.60              0.00
# 25%                0.86            49.00            8.50              2.00
# 50%                1.07            65.00           11.60              3.00
# 75%                1.27            79.00         6622.50              4.00
# max                5.80           543.00        16060.00             51.00
#
#        PATHOLOGICALTUMORSIZE  MINTHICKNESSMARGIN  MAXTHICKNESSMARGIN  \
# count                2909.00             1416.00              525.00
# mean                   10.54                4.10               11.17
# std                    15.07               10.43               46.75
# min                     0.00                0.00                0.00
# 25%                     2.40                1.00                1.80
# 50%                     3.60                2.00                3.00
# 75%                     8.20                4.00                8.00
# max                   115.00              240.00              979.00
#
#        FUHRMANGRADING  SARCOMATOIDDIFF_A  MICSCORE  SURGICALMARGIN  \
# count         2323.00            1371.00   2430.00         3143.00
# mean             2.15               0.12      0.28            0.03
# std              0.67               2.28      0.45            0.18
# min              1.00               0.00      0.00            0.00
# 25%              2.00               0.00      0.00            0.00
# 50%              2.00               0.00      0.00            0.00
# 75%              3.00               0.00      1.00            0.00
# max              4.00              70.00      1.00            1.00
#
#        NO_OF_NODE_TAKEN  LASTFOLLOWUPDURATION     Year
# count           2015.00               1893.00  3140.00
# mean               0.11                 16.85  2013.21
# std                0.64                 19.58     3.00
# min                0.00                  0.00  2006.00
# 25%                0.00                  3.00  2011.00
# 50%                0.00                 10.00  2013.00
# 75%                0.00                 24.00  2016.00
# max               12.00                101.00  2018.00

# %%
# Correcting the units for erroroneously entered data
def clean_WBC(x):
    if len(str(x))<6:
        x = x*1000
    return x
        

# if the value of PRE-OP WBC value contains is less the 4 digits then multiply it by 1000
df['PREOPWBC'] = df['PREOPWBC'].apply(lambda x: clean_WBC(x))

# if the value of POST-OP WBC_Day 1 value contains is less the 4 digits then multiply it by 1000
df['POSTOPWBC_Day1'] = df['POSTOPWBC_Day1'].apply(lambda x: clean_WBC(x))

# if the value of POST-OP WBC_Day 2 value contains is less the 4 digits then multiply it by 1000
df['POSTOPWBC_Day2'] = df['POSTOPWBC_Day2'].apply(lambda x: clean_WBC(x))

# if the value of POST-OP WBC_Day 2 value contains is less the 4 digits then multiply it by 1000
df['POSTOPWBC_Day3'] = df['POSTOPWBC_Day3'].apply(lambda x: clean_WBC(x))

# %%
# Correcting the units for erroroneously entered data for PREOPHB
df['PREOPHB'] = df['PREOPHB'].apply(lambda x: x*100 if x<10 else x)

# Correcting the units for erroroneously entered data for PREOPHB
df['PREOPHT'] = df['PREOPHT'].apply(lambda x: x*100 if x<10 else x)

# %% [markdown]
# ### Define Categorical columns

# %%
cat_col = ['PROCNAME',
'CENTERCODE',
'SURGEONCODE',
'RECPROGRESS',
'GENDER',
'MARITALSTATUS',
'RACE',
'EDUCATION',
'ECOG',
'SYMPTOMS',
'SOLITARYKIDNEY',
'TYPEOFSOLITARYKIDNEY',
'BILATERALITYOFTUMOR',
'SIDEOFTUMOR',
'SIDEOFSURGERY',
'PREOPMULTIFOCALITY',
'FACE',
'TUMORlOCATION',
'PADUARISK',
'POLARLOCATION',
'RIMLOCATION',
'RENALSINUS',
'UCSINVASION',
'EXOPHYTICRATE',
'CLINICALSIZEGROUP',
'CT',
'CN',
'CM',
'R.E.N.A.L.NEPHROSCORE',
'R.E.N.A.L.NEPHRORISKSTRATIFICATION',
'RADIUSmaximaldiameterincm',
'EXOPHYTICENDOPHYTICPROPERTIES',
'NEARNESSOFTUMOUR',
'ANTERIORORPOSTERIOR',
'LOCATIONTOPOLARLINE',
'TumorConsistencyonImaging',
'BosniakClassification',
'ASASCORE',
'PARTIALNEPHROINDICATION',
'MULTIFOCALITY',
'ImagingFeaturesofotherexcisedtumor',
'Consistencyoftheotherexcisedtumors',
'ACCESS',
'DAVINCIMODEL',
'ROBOTICSARMS',
'ASSISTENTTROCARS',
'DUALCONSOLE',
'PRIMARYSURGEON',
'ISCHEMIA',
'CLAMPARTERY',
'SELECTIVEARTERIALCLAMPING',
'CLAMPVEIN',
'EARLYUNCLAMPING',
'FLUORESCENCE',
'INNERRENORRHAPHY',
'OUTERRENORRHAPHY',
'UCSREPAIR',
'HAEMOSTATICAGENTS',
'HAEMOSTATICDetails',
'LYMPHNODEDISSECTIONLND',
'INTRAOPTRANSUFUSION',
'SURGICALCONSIDERATIONS',
'INTRAOPCOMPLICATION',
'INTRAOPCOMPLICATIONS',
'NeedtoConverttoRadicalNephrectomy',
'TREATMENTOFCOMPLICATION',
'POSTOPCOMPLICATION',
'SURGICALCOMPLICATIONS',
'NONSURGICALCOMPLICATIONS',
'POSTOPTREATMENTOFCOMPLICATION',
'CLAVIENGRADE',
'MULITIFOCALITY',
'PATHOLOGY',
'HYSTOTYPEMALIGNANAT',
'HYSTOTYPEMALIGNANATYES',
'HYSTOTYPEBENIGN',
'HYSTOTYPEBENIGNYES',
'FUHRMANGRADING',
'SARCOMATOIDDIFF',
'NECROSIS',
'MICROVENOUSINVASION',
'UCSINVASION_A',
'PERIRENALFATINVASION',
'HilarFatInvasion',
'SINUSFATINVASION',
'MICSCORE',
'ADRENALINVASION',
'GEROTAINVASION',
'RenalVeinInvasion',
'VENOUSTHROMBUS',
#'SURGICALMARGIN',
'UNIFOCALMULTIFOCAL',
'NO_OF_NODE_POSITIVE',
'SITEOFPOSITIVENODE',
'TREATMENTPSM',
'PT',
'PN',
'OTHERTUMORS',
'LASTFOLLOWUPSTATUS',
'LASTFOLLOWUPRECURRENCE',
'LASTTREATMENTOFRECURRENCE'
]

# %% [markdown]
# ### Select Variables for analysis

# %%
# list of variables included for Intra-Op complications 
intra_op_col = [
'PATIENTNUMBER',
#'PROCNAME',
'CENTERCODE',
#'SURGEONCODE',
#'RECPROGRESS',
#'CREATEDDATE',
'GENDER',
#'DATEOFBIRTH',
'AGEATSURGERY',
'MARITALSTATUS',
'RACE',
'EDUCATION',
#'WEIGHT',
#'HEIGHT',
'BMI',
'CLINICALSIZEmm',
'ECOG',
'CHARLSONSCORE',
#'CHARLSONAGEADJUSTSCORE',
'SYMPTOMS',
'SOLITARYKIDNEY',
'TYPEOFSOLITARYKIDNEY',
'BILATERALITYOFTUMOR',
'SIDEOFTUMOR',
'SIDEOFSURGERY',
'PREOPMULTIFOCALITY',
'FACE',
'TUMORlOCATION',
'PREOPHB',
'PREOPHT',
'PREOPWBC',
'PREOPCREAT',
'PREOPGFR',
'PREOPEGFR',
'PREOPERPF',
#'PADUASCORE',
'PADUARISK',
'POLARLOCATION',
'RIMLOCATION',
'RENALSINUS',
#'UCSINVASION',
'EXOPHYTICRATE',
'CLINICALSIZEGROUP',
'CT',
'CN',
'CM',
#'R.E.N.A.L.NEPHROSCORE',
'R.E.N.A.L.NEPHRORISKSTRATIFICATION',
'RADIUSmaximaldiameterincm',
'EXOPHYTICENDOPHYTICPROPERTIES',
'NEARNESSOFTUMOUR',
'ANTERIORORPOSTERIOR',
'LOCATIONTOPOLARLINE',
'TumorConsistencyonImaging',
'BosniakClassification',
#'DATEOFSURGERY',
'ASASCORE',
'PARTIALNEPHROINDICATION',
'MULTIFOCALITY',
'NOOFLESIONS',
#'ImagingFeaturesofotherexcisedtumor', #too many categories
#'Consistencyoftheotherexcisedtumors',
#'ACCESS',
#'DAVINCIMODEL',
#'ROBOTICSARMS',
#'ASSISTENTTROCARS',
#'DUALCONSOLE',
#'PRIMARYSURGEON',
#'OPERATIVETIMEmin',
#'ISCHEMIA',
#'CLAMPARTERY',
#'SELECTIVEARTERIALCLAMPING',
#'CLAMPVEIN',
#'EARLYUNCLAMPING',
#'FLUORESCENCE',
#'INNERRENORRHAPHY',
#'OUTERRENORRHAPHY',
#'ISCHEMIATIMEmin',
#'UCSREPAIR',
#'HAEMOSTATICAGENTS',
#'HAEMOSTATICDetails',
#'LYMPHNODEDISSECTIONLND',
#'BLOODLOSSml',
#'INTRAOPTRANSUFUSION',
#'SURGICALCONSIDERATIONS',
#'INTRAOPCOMPLICATION',
#'INTRAOPCOMPLICATIONS',
'SURGICALMARGIN'    
]

# %%
len(intra_op_col)
# Out:
# 49

# %% [markdown]
# ### Data Cleaning

# %%
# Selecting dataframe relevant columsn for analysis
df = df[intra_op_col].copy()

# %%
#Keep columns having less than 50% missing data
print("Total number of columns before removing columns with more than 50% missing data: {}".format(len(list(df))))

df = df[df.columns[df.isnull().mean() <= 0.50]].copy()

print("Total number of columns left after removing columns with more than 50% missing data: {}".format(len(list(df))))
# Out:
# Total number of columns before removing columns with more than 50% missing data: 49
# Total number of columns left after removing columns with more than 50% missing data: 43

# %%
target = 'SURGICALMARGIN'

# %%
df.describe()
# Out:
#        AGEATSURGERY          BMI  CLINICALSIZEmm  CHARLSONSCORE      PREOPHB  \
# count   3129.000000  2800.000000     3069.000000    2642.000000  2303.000000
# mean      57.752637    28.703648       33.276409       1.589705    29.021042
# std       12.709555     5.949738       16.387838       2.024952   114.739041
# min       16.000000    15.100000        0.000000       0.000000    10.000000
# 25%       49.000000    24.600000       22.000000       0.000000    12.900000
# 50%       59.000000    27.555000       30.000000       1.000000    14.000000
# 75%       67.000000    31.780000       42.000000       2.000000    15.100000
# max       89.000000    55.600000      135.000000      19.000000   990.000000
#
#            PREOPHT       PREOPWBC   PREOPCREAT    PREOPEGFR  \
# count  2199.000000    1905.000000  3076.000000  2442.000000
# mean     41.490587    7320.294457     1.120425    79.805066
# std       6.179841    4970.382189     3.387927    24.555382
# min      10.400000       0.000000     0.000000     0.020000
# 25%      38.600000    5700.000000     0.780000    65.000000
# 50%      41.800000    7000.000000     0.910000    79.000000
# 75%      44.700000    8360.000000     1.100000    93.590000
# max     180.000000  186000.000000    96.000000   210.865863
#
#        LOCATIONTOPOLARLINE  NOOFLESIONS  SURGICALMARGIN
# count          1834.000000  2576.000000     3143.000000
# mean              1.901309     1.059783        0.032135
# std               0.823528     0.300675        0.176386
# min               1.000000     0.000000        0.000000
# 25%               1.000000     1.000000        0.000000
# 50%               2.000000     1.000000        0.000000
# 75%               3.000000     1.000000        0.000000
# max               3.000000     6.000000        1.000000

# %%
numeric_stats = df.describe()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)
f, axes = plt.subplots(2, 4, figsize=(20, 8))
sns.despine(left=True)
sns.boxplot(data = df, y = 'AGEATSURGERY', x = target,ax=axes[0, 0])
sns.boxplot(data = df, y = 'BMI', x = target, ax=axes[0, 1])
sns.boxplot(data = df, y = 'CLINICALSIZEmm', x = target, ax=axes[0, 2])
sns.boxplot(data = df, y = 'PREOPHB', x = target, ax=axes[0, 3])
sns.boxplot(data = df, y = 'PREOPHT', x = target, ax=axes[1, 0])
sns.boxplot(data = df, y = 'PREOPWBC', x = target, ax=axes[1, 1])
sns.boxplot(data = df, y = 'PREOPCREAT', x = target, ax=axes[1, 2])
sns.boxplot(data = df, y = 'PREOPEGFR', x = target, ax=axes[1, 3])

# %%
# Check the number of outliers
outlier_dict = {}
clean_cols = ['BMI','CLINICALSIZEmm','PREOPHB','PREOPHT','PREOPWBC','PREOPCREAT','PREOPEGFR']
for i in clean_cols:
    q1 = numeric_stats.loc['25%'][i]
    q3 = numeric_stats.loc['75%'][i]
    IQR = q3-q1
    LL = q1-(1.5*IQR)
    UL = q3+(1.5*IQR)
    outlier_dict.update({i:{'LL':LL,'UL':UL}})
    print('{:<14s} {:>4d} {:>4d}'.format(i,len(df.loc[(df[i]>=UL)]),len(df.loc[(df[i]<=LL)])), 'UL-LL {:>4.2f}-{:>4.2f}'.format(UL,LL))
print(outlier_dict)
# Out:
# BMI              90    0 UL-LL 42.55-13.83
# CLINICALSIZEmm   74    0 UL-LL 72.00--8.00
# PREOPHB          47    0 UL-LL 18.40-9.60
# PREOPHT           8   33 UL-LL 53.85-29.45
# PREOPWBC         52   39 UL-LL 12350.00-1710.00
# PREOPCREAT      152    1 UL-LL 1.58-0.30
# PREOPEGFR        47   25 UL-LL 136.48-22.11
# {'BMI': {'LL': 13.830000000000002, 'UL': 42.55}, 'CLINICALSIZEmm': {'LL': -8.0, 'UL': 72.0}, 'PREOPHB': {'LL': 9.600000000000001, 'UL': 18.4}, 'PREOPHT': {'LL': 29.45, 'UL': 53.85000000000001}, 'PREOPWBC': {'LL': 1710.0, 'UL': 12350.0}, 'PREOPCREAT': {'LL': 0.29999999999999993, 'UL': 1.58}, 'PREOPEGFR': {'LL': 22.114999999999995, 'UL': 136.47500000000002}}

# %%
#Export the outlier dict
import json
with open(output_path + "outlier_dict.json", "w") as write_file:
    json.dump(outlier_dict, write_file)

# %%
#replacing inaccurate readings with missing values
clean_cols = ['BMI','CLINICALSIZEmm','PREOPHB','PREOPHT','PREOPWBC','PREOPCREAT','PREOPEGFR']
for i in clean_cols:
    q1 = numeric_stats.loc['25%'][i]
    q3 = numeric_stats.loc['75%'][i]
    IQR = q3-q1
    LL = q1-(1.5*IQR)
    UL = q3+(1.5*IQR)
    df.drop(df.loc[(df[i]<=LL)|(df[i]>=UL),[i]].index, inplace=True)

# %%
df.describe()
# Out:
#        AGEATSURGERY          BMI  CLINICALSIZEmm  CHARLSONSCORE      PREOPHB  \
# count   2651.000000  2368.000000     2603.000000    2241.000000  1972.000000
# mean      57.575255    28.131902       31.765501       1.521642    13.960020
# std       12.582674     5.067985       13.895704       1.985123     1.427056
# min       16.000000    15.100000        0.000000       0.000000    10.000000
# 25%       49.000000    24.490000       22.000000       0.000000    13.000000
# 50%       58.000000    27.300000       30.000000       1.000000    14.000000
# 75%       67.000000    31.250000       40.000000       2.000000    15.000000
# max       89.000000    42.500000       71.000000      19.000000    18.200000
#
#            PREOPHT      PREOPWBC   PREOPCREAT    PREOPEGFR  \
# count  1873.000000   1579.000000  2619.000000  2023.000000
# mean     41.727549   7070.771336     0.928429    80.980746
# std       4.196274   1811.789659     0.209634    18.857776
# min      29.800000   1840.000000     0.360000    34.000000
# 25%      39.000000   5600.000000     0.780000    67.386654
# 50%      42.000000   6900.000000     0.900000    80.000000
# 75%      44.800000   8280.000000     1.060000    93.125000
# max      53.700000  12300.000000     1.570000   136.080000
#
#        LOCATIONTOPOLARLINE  NOOFLESIONS  SURGICALMARGIN
# count          1527.000000  2179.000000     2665.000000
# mean              1.897184     1.049105        0.033771
# std               0.823499     0.251484        0.180673
# min               1.000000     0.000000        0.000000
# 25%               1.000000     1.000000        0.000000
# 50%               2.000000     1.000000        0.000000
# 75%               3.000000     1.000000        0.000000
# max               3.000000     4.000000        1.000000

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)
f, axes = plt.subplots(2, 4, figsize=(20, 8))
sns.despine(left=True)
sns.boxplot(data = df, y = 'AGEATSURGERY', x = target,ax=axes[0, 0])
sns.boxplot(data = df, y = 'BMI', x = target, ax=axes[0, 1])
sns.boxplot(data = df, y = 'CLINICALSIZEmm', x = target, ax=axes[0, 2])
sns.boxplot(data = df, y = 'PREOPHB', x = target, ax=axes[0, 3])
sns.boxplot(data = df, y = 'PREOPHT', x = target, ax=axes[1, 0])
sns.boxplot(data = df, y = 'PREOPWBC', x = target, ax=axes[1, 1])
sns.boxplot(data = df, y = 'PREOPCREAT', x = target, ax=axes[1, 2])
sns.boxplot(data = df, y = 'PREOPEGFR', x = target, ax=axes[1, 3])

# %%
# The percentage of missing data
df.isnull().mean()
# Out:
# PATIENTNUMBER                         0.000000
# CENTERCODE                            0.000000
# GENDER                                0.004128
# AGEATSURGERY                          0.005253
# MARITALSTATUS                         0.351595
# RACE                                  0.398874
# EDUCATION                             0.428518
# BMI                                   0.111445
# CLINICALSIZEmm                        0.023265
# ECOG                                  0.453659
# CHARLSONSCORE                         0.159099
# SYMPTOMS                              0.221388
# SOLITARYKIDNEY                        0.125328
# BILATERALITYOFTUMOR                   0.378236
# SIDEOFTUMOR                           0.338086
# SIDEOFSURGERY                         0.003377
# FACE                                  0.229644
# TUMORlOCATION                         0.112570
# PREOPHB                               0.260038
# PREOPHT                               0.297186
# PREOPWBC                              0.407505
# PREOPCREAT                            0.017261
# PREOPEGFR                             0.240901
# PADUARISK                             0.365103
# POLARLOCATION                         0.193996
# RIMLOCATION                           0.398124
# RENALSINUS                            0.359850
# EXOPHYTICRATE                         0.255535
# CLINICALSIZEGROUP                     0.146341
# CT                                    0.118199
# CN                                    0.203002
# CM                                    0.392495
# R.E.N.A.L.NEPHRORISKSTRATIFICATION    0.213508
# RADIUSmaximaldiameterincm             0.120450
# EXOPHYTICENDOPHYTICPROPERTIES         0.303940
# NEARNESSOFTUMOUR                      0.341088
# ANTERIORORPOSTERIOR                   0.225891
# LOCATIONTOPOLARLINE                   0.427017
# ASASCORE                              0.101313
# PARTIALNEPHROINDICATION               0.284428
# MULTIFOCALITY                         0.375985
# NOOFLESIONS                           0.182364
# SURGICALMARGIN                        0.000000
# dtype: float64

# %%
# Calculate number missing values per row
df.reset_index(inplace=True, drop=True)
missing = {}

for i in range(len(df)):
    miss_cnt = 0
    for col in df.columns:
        if pd.isna(df[col][i]) == True:
            miss_cnt = miss_cnt+1
    df.loc[i,'Missing'] = miss_cnt

# %%
# calculate number of records with over 25% missing data
print("Total Records {}".format(len(df)))
print("Records with >=25% missing data {}".format(sum(df['Missing']<= round((len(df.columns)-2)*.30))))
print("Records to be dropped {}".format(len(df) - sum(df['Missing']<= round((len(df.columns)-2)*.30))))
# Out:
# Total Records 2665
# Records with >=25% missing data 1627
# Records to be dropped 1038

# %%
# Check thenumber of missing values for eahc variables if records with a certain missing threshold were removed
df[df['Missing']<= round((len(df.columns)-2)*.30) ].isnull().mean()
# Out:
# PATIENTNUMBER                         0.000000
# CENTERCODE                            0.000000
# GENDER                                0.000000
# AGEATSURGERY                          0.001229
# MARITALSTATUS                         0.087892
# RACE                                  0.101414
# EDUCATION                             0.124155
# BMI                                   0.068838
# CLINICALSIZEmm                        0.027658
# ECOG                                  0.305470
# CHARLSONSCORE                         0.049170
# SYMPTOMS                              0.019668
# SOLITARYKIDNEY                        0.001229
# BILATERALITYOFTUMOR                   0.086663
# SIDEOFTUMOR                           0.083589
# SIDEOFSURGERY                         0.000000
# FACE                                  0.103258
# TUMORlOCATION                         0.013522
# PREOPHB                               0.022127
# PREOPHT                               0.022741
# PREOPWBC                              0.110633
# PREOPCREAT                            0.008605
# PREOPEGFR                             0.192993
# PADUARISK                             0.135833
# POLARLOCATION                         0.067609
# RIMLOCATION                           0.122926
# RENALSINUS                            0.121082
# EXOPHYTICRATE                         0.099570
# CLINICALSIZEGROUP                     0.041180
# CT                                    0.060848
# CN                                    0.062077
# CM                                    0.245237
# R.E.N.A.L.NEPHRORISKSTRATIFICATION    0.116779
# RADIUSmaximaldiameterincm             0.004302
# EXOPHYTICENDOPHYTICPROPERTIES         0.237861
# NEARNESSOFTUMOUR                      0.119852
# ANTERIORORPOSTERIOR                   0.098341
# LOCATIONTOPOLARLINE                   0.100184
# ASASCORE                              0.047326
# PARTIALNEPHROINDICATION               0.001844
# MULTIFOCALITY                         0.082360
# NOOFLESIONS                           0.012293
# SURGICALMARGIN                        0.000000
# Missing                               0.000000
# dtype: float64

# %%
#removing patients with more than 75% missing data
df = df[df['Missing']<= round((len(df.columns)-2)*.30) ].copy()

# %%
#Keep columns having less than 10% missing data
df = df[df.columns[df.isnull().mean() <= 0.15]].copy()

print("Total number of columns left after removing columns with missing data: {}".format(len(list(df))))
# Out:
# Total number of columns left after removing columns with missing data: 40

# %%
# Print the list of patients with clean data
patient_list = df['PATIENTNUMBER'].tolist()
with open(output_path + 'patient_list.txt', 'w') as f:
    for item in patient_list:
        f.write("%s\n" % item)

# %%
# The percentage of missing data
df.isnull().mean()
# Out:
# PATIENTNUMBER                         0.000000
# CENTERCODE                            0.000000
# GENDER                                0.000000
# AGEATSURGERY                          0.001229
# MARITALSTATUS                         0.087892
# RACE                                  0.101414
# EDUCATION                             0.124155
# BMI                                   0.068838
# CLINICALSIZEmm                        0.027658
# CHARLSONSCORE                         0.049170
# SYMPTOMS                              0.019668
# SOLITARYKIDNEY                        0.001229
# BILATERALITYOFTUMOR                   0.086663
# SIDEOFTUMOR                           0.083589
# SIDEOFSURGERY                         0.000000
# FACE                                  0.103258
# TUMORlOCATION                         0.013522
# PREOPHB                               0.022127
# PREOPHT                               0.022741
# PREOPWBC                              0.110633
# PREOPCREAT                            0.008605
# PADUARISK                             0.135833
# POLARLOCATION                         0.067609
# RIMLOCATION                           0.122926
# RENALSINUS                            0.121082
# EXOPHYTICRATE                         0.099570
# CLINICALSIZEGROUP                     0.041180
# CT                                    0.060848
# CN                                    0.062077
# R.E.N.A.L.NEPHRORISKSTRATIFICATION    0.116779
# RADIUSmaximaldiameterincm             0.004302
# NEARNESSOFTUMOUR                      0.119852
# ANTERIORORPOSTERIOR                   0.098341
# LOCATIONTOPOLARLINE                   0.100184
# ASASCORE                              0.047326
# PARTIALNEPHROINDICATION               0.001844
# MULTIFOCALITY                         0.082360
# NOOFLESIONS                           0.012293
# SURGICALMARGIN                        0.000000
# Missing                               0.000000
# dtype: float64

# %%
# Replcaing missing values in categorical column with NA
for k in cat_col:
    if k in df.columns:
        df[k].fillna('NA',inplace = True)

# %%
# Create dictionary mean value for numeric columns
numeric_col_mean_dict = {}
for k in numeric_col_list:
    if k in df.columns:
        numeric_col_mean_dict.update({k:round(df[k].mean())})
print(numeric_col_mean_dict)
# Out:
# {'AGEATSURGERY': 57.0, 'BMI': 28.0, 'CLINICALSIZEmm': 32.0, 'PREOPHB': 14.0, 'PREOPHT': 42.0, 'PREOPWBC': 7085.0, 'PREOPCREAT': 1.0, 'NOOFLESIONS': 1.0, 'CHARLSONSCORE': 1.0}

# %%
# export the numeric_col_mean_dict
import json
with open(output_path+ "numeric_col_mean_dict.json", "w") as write_file:
    json.dump(numeric_col_mean_dict, write_file)

# %%
# Replacing missing values in numerical columns with their respective mean 
for k in numeric_col_list:
    if k in df.columns:
        df[k].fillna(round(df[k].mean()), inplace = True)

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1627 entries, 0 to 2664
# Data columns (total 40 columns):
# PATIENTNUMBER                         1627 non-null object
# CENTERCODE                            1627 non-null object
# GENDER                                1627 non-null object
# AGEATSURGERY                          1627 non-null float64
# MARITALSTATUS                         1627 non-null object
# RACE                                  1627 non-null object
# EDUCATION                             1627 non-null object
# BMI                                   1627 non-null float64
# CLINICALSIZEmm                        1627 non-null float64
# CHARLSONSCORE                         1627 non-null float64
# SYMPTOMS                              1627 non-null object
# SOLITARYKIDNEY                        1627 non-null object
# BILATERALITYOFTUMOR                   1627 non-null object
# SIDEOFTUMOR                           1627 non-null object
# SIDEOFSURGERY                         1627 non-null object
# FACE                                  1627 non-null object
# TUMORlOCATION                         1627 non-null object
# PREOPHB                               1627 non-null float64
# PREOPHT                               1627 non-null float64
# PREOPWBC                              1627 non-null float64
# PREOPCREAT                            1627 non-null float64
# PADUARISK                             1627 non-null object
# POLARLOCATION                         1627 non-null object
# RIMLOCATION                           1627 non-null object
# RENALSINUS                            1627 non-null object
# EXOPHYTICRATE                         1627 non-null object
# CLINICALSIZEGROUP                     1627 non-null object
# CT                                    1627 non-null object
# CN                                    1627 non-null object
# R.E.N.A.L.NEPHRORISKSTRATIFICATION    1627 non-null object
# RADIUSmaximaldiameterincm             1627 non-null object
# NEARNESSOFTUMOUR                      1627 non-null object
# ANTERIORORPOSTERIOR                   1627 non-null object
# LOCATIONTOPOLARLINE                   1627 non-null object
# ASASCORE                              1627 non-null object
# PARTIALNEPHROINDICATION               1627 non-null object
# MULTIFOCALITY                         1627 non-null object
# NOOFLESIONS                           1627 non-null float64
# SURGICALMARGIN                        1627 non-null int64
# Missing                               1627 non-null float64
# dtypes: float64(10), int64(1), object(29)
# memory usage: 521.1+ KB

# %%
# check unique value in each column of type object
unique_count_list = {}

for k in cat_col:
    if k in df.columns:
        unique_count_list.update({k:len(df[k].unique())})

unique_count_list
# Out:
# {'CENTERCODE': 18,
#  'GENDER': 2,
#  'MARITALSTATUS': 5,
#  'RACE': 5,
#  'EDUCATION': 5,
#  'SYMPTOMS': 4,
#  'SOLITARYKIDNEY': 4,
#  'BILATERALITYOFTUMOR': 3,
#  'SIDEOFTUMOR': 4,
#  'SIDEOFSURGERY': 3,
#  'FACE': 3,
#  'TUMORlOCATION': 6,
#  'PADUARISK': 5,
#  'POLARLOCATION': 3,
#  'RIMLOCATION': 3,
#  'RENALSINUS': 3,
#  'EXOPHYTICRATE': 4,
#  'CLINICALSIZEGROUP': 4,
#  'CT': 6,
#  'CN': 4,
#  'R.E.N.A.L.NEPHRORISKSTRATIFICATION': 5,
#  'RADIUSmaximaldiameterincm': 4,
#  'NEARNESSOFTUMOUR': 4,
#  'ANTERIORORPOSTERIOR': 4,
#  'LOCATIONTOPOLARLINE': 4,
#  'ASASCORE': 5,
#  'PARTIALNEPHROINDICATION': 4,
#  'MULTIFOCALITY': 3}

# %%
# convert object columns with less than 10 unique values into type category
for col in unique_count_list:
        df[col] = df[col].astype('category').copy()

# %%
# list of features with high number of categories
for col in unique_count_list:
    if unique_count_list[col]>10:
        print(col,unique_count_list[col])
# Out:
# CENTERCODE 18

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df.reset_index(drop=True, inplace=True)
print("Number records for predicting intra-op complications: {}".format(len(df)))
# Out:
# Number records for predicting intra-op complications: 1627

# %%
for i in df.select_dtypes('category').columns:
    df[i] = df[i].apply(str)

# %%
# fit label encoder to each column of type category
cat_col =df.select_dtypes('category')
df_codes = df.copy()
from sklearn.preprocessing import LabelEncoder
le_dict = {col: LabelEncoder() for col in cat_col }
for col in cat_col:
    le_dict[col].fit_transform(df_codes[col])

# %%
# create a dictionary cantaining mapping of categorical values to numerical values
label_mapping = dict()
label_mapping = {col: dict(zip(le_dict[col].classes_,le_dict[col].transform(le_dict[col].classes_))) for col in cat_col}
label_mapping
# Out:
# {'CENTERCODE': {'08ZMCILJ': 0,
#   '0VZRZWAI': 1,
#   '39HIP3LQ': 2,
#   '3QWOG020': 3,
#   '4M49I4D5': 4,
#   '4UPDM0XB': 5,
#   '57T3OUKU': 6,
#   '63DCGHNW': 7,
#   '94ISQMHX': 8,
#   'FWL0MH42': 9,
#   'GCIEYK6L': 10,
#   'GQHLD5Q4': 11,
#   'QRJWT5QR': 12,
#   'RETM03Y8': 13,
#   'U5WT3NOY': 14,
#   'VNO3BPES': 15,
#   'VRVRQ639': 16,
#   'WGC7XYXZ': 17},
#  'GENDER': {'Female': 0, 'Male': 1},
#  'MARITALSTATUS': {'Divorced': 0,
#   'Married': 1,
#   'NA': 2,
#   'Single': 3,
#   'Widowed': 4},
#  'RACE': {'Black': 0,
#   'Mongoloid/Asian': 1,
#   'NA': 2,
#   'Others': 3,
#   'White/Caucasian': 4},
#  'EDUCATION': {'Graduate': 0,
#   'NA': 1,
#   'Not Provided': 2,
#   'Post Graduate': 3,
#   'Upto High School': 4},
#  'SYMPTOMS': {'Absent': 0,
#   'Local Symptoms': 1,
#   'NA': 2,
#   'Systemic Symptoms': 3},
#  'SOLITARYKIDNEY': {'NA': 0, 'No': 1, 'Yes': 2, 'no': 3},
#  'BILATERALITYOFTUMOR': {'NA': 0, 'No': 1, 'Yes': 2},
#  'SIDEOFTUMOR': {'Bilateral': 0, 'Left': 1, 'NA': 2, 'Right': 3},
#  'SIDEOFSURGERY': {'Bilateral': 0, 'Left': 1, 'Right': 2},
#  'FACE': {'Anterior': 0, 'NA': 1, 'Posterior': 2},
#  'TUMORlOCATION': {'Lower Pol': 0,
#   'Lower Pole': 1,
#   'Mid Pole': 2,
#   'NA': 3,
#   'Upper Pol': 4,
#   'Upper Pole': 5},
#  'PADUARISK': {'0': 0,
#   '1(Low  Risk)': 1,
#   '2(Intermidiate  Risk)': 2,
#   '3(High  Risk)': 3,
#   'NA': 4},
#  'POLARLOCATION': {'NA': 0,
#   'Tumours crossing the sinus line >50% or falling entirely between the sinus lines (2 points)': 1,
#   'Tumours entirely located above the upper or below the lower sinus line, or crossing the sinus line < 50% (1 point)': 2},
#  'RIMLOCATION': {'At the medial rim (2 points)': 0,
#   'NA': 1,
#   'Tumours located at the lateral (1 point)': 2},
#  'RENALSINUS': {'NA': 0,
#   'Tumours without renal sinus involvement (1 point)': 1,
#   'With renal sinus involvement (2 points)': 2},
#  'EXOPHYTICRATE': {'< 50%exophytic (2 points)': 0,
#   '= 50% exophytic (1 point)': 1,
#   'Endophytic (3 points)': 2,
#   'NA': 3},
#  'CLINICALSIZEGROUP': {'4.1cm-7cm': 0, '=<4cm': 1, '=>7cm': 2, 'NA': 3},
#  'CT': {'NA': 0, 'T1a': 1, 'T1b': 2, 'T2a': 3, 'T2b': 4, 'T3a': 5},
#  'CN': {'N+': 0, 'N0': 1, 'NA': 2, 'Nx': 3},
#  'R.E.N.A.L.NEPHRORISKSTRATIFICATION': {'0': 0,
#   '1(Low Risk)': 1,
#   '2(Intermidiate Risk)': 2,
#   '3(High Risk)': 3,
#   'NA': 4},
#  'RADIUSmaximaldiameterincm': {'4 but <7': 0, '=<4': 1, '=>7': 2, 'NA': 3},
#  'NEARNESSOFTUMOUR': {'=<4': 0, '=>7': 1, '>4 but <7': 2, 'NA': 3},
#  'ANTERIORORPOSTERIOR': {'Anterior (a)': 0,
#   'NA': 1,
#   'Neither(x)': 2,
#   'Posterior (p)': 3},
#  'LOCATIONTOPOLARLINE': {'1.0': 0, '2.0': 1, '3.0': 2, 'NA': 3},
#  'ASASCORE': {'Category 1': 0,
#   'Category 2': 1,
#   'Category 3': 2,
#   'Category 4': 3,
#   'NA': 4},
#  'PARTIALNEPHROINDICATION': {'Absolute': 0,
#   'Elective': 1,
#   'NA': 2,
#   'Relative': 3},
#  'MULTIFOCALITY': {'NA': 0, 'No': 1, 'Yes': 2}}

# %%
# export the numeric_col_mean_dict
from joblib import dump
dump(le_dict, output_path + 'Label_enc_dict.joblib')
# Out:
# ['output/models/Label_enc_dict.joblib']

# %%
# mapping categorical column values to integer labels
for col in cat_col:
    df_codes[col] = le_dict[col].transform(df_codes[col]).copy()

# %%
df_codes.head()
# Out:
#   PATIENTNUMBER  CENTERCODE  GENDER  AGEATSURGERY  MARITALSTATUS  RACE  \
# 0   13PAT000522           0       1          61.0              1     1
# 1   11PAT000166           1       1          56.0              1     1
# 2   15PAT000088          15       0          44.0              3     4
# 3   11PAT000124           1       0          63.0              1     1
# 4   15PAT000080          15       1          63.0              3     4
#
#    EDUCATION    BMI  CLINICALSIZEmm  CHARLSONSCORE  SYMPTOMS  SOLITARYKIDNEY  \
# 0          0  25.10            33.0            0.0         0               2
# 1          2  23.36            32.0            0.0         0               1
# 2          2  29.30            57.0            0.0         1               1
# 3          2  32.02            32.0            1.0         0               1
# 4          2  25.08            37.0            2.0         0               1
#
#    BILATERALITYOFTUMOR  SIDEOFTUMOR  SIDEOFSURGERY  FACE  TUMORlOCATION  \
# 0                    1            1              1     0              0
# 1                    1            1              1     0              0
# 2                    1            1              1     2              2
# 3                    1            3              2     2              0
# 4                    1            3              2     2              4
#
#    PREOPHB  PREOPHT  PREOPWBC  PREOPCREAT  PADUARISK  POLARLOCATION  \
# 0     12.3     39.4    5400.0        1.25          2              2
# 1     10.2     36.4    5200.0        0.70          1              2
# 2     13.5     41.3    6300.0        0.83          3              1
# 3     12.4     36.5    9500.0        1.10          1              2
# 4     14.4     42.7    5500.0        1.01          3              1
#
#    RIMLOCATION  RENALSINUS  EXOPHYTICRATE  CLINICALSIZEGROUP  CT  CN  \
# 0            0           1              0                  1   1   1
# 1            2           1              1                  1   1   1
# 2            2           2              1                  0   2   1
# 3            2           1              1                  0   2   1
# 4            0           2              1                  1   1   1
#
#    R.E.N.A.L.NEPHRORISKSTRATIFICATION  RADIUSmaximaldiameterincm  \
# 0                                   2                          1
# 1                                   1                          1
# 2                                   2                          0
# 3                                   2                          0
# 4                                   2                          1
#
#    NEARNESSOFTUMOUR  ANTERIORORPOSTERIOR  LOCATIONTOPOLARLINE  ASASCORE  \
# 0                 0                    2                    1         2
# 1                 1                    0                    0         0
# 2                 0                    3                    1         1
# 3                 2                    3                    1         1
# 4                 0                    3                    1         1
#
#    PARTIALNEPHROINDICATION  MULTIFOCALITY  NOOFLESIONS  SURGICALMARGIN  \
# 0                        1              1          1.0               0
# 1                        1              1          1.0               0
# 2                        1              1          1.0               0
# 3                        1              1          1.0               0
# 4                        1              1          1.0               0
#
#    Missing
# 0      0.0
# 1      2.0
# 2      1.0
# 3      2.0
# 4      1.0

# %% [markdown]
# ### Create Stats fot dataset

# %%
# print median , IQR for numeric columns 
for i in df.columns:#['AGEATSURGERY','BMI','CLINICALSIZEmm','PREOPHB','PREOPHT','PREOPWBC','PREOPCREAT','PREOPEGFR','NOOFLESIONS']:
    if i in numeric_col_list:
        print(i, "{0:.1f} [{1:.1f}-{2:.1f}]".format(np.median(df[i]),np.percentile(df[i],25),np.percentile(df[i],75)))
# Out:
# AGEATSURGERY 58.0 [48.0-66.0]
# BMI 27.3 [24.4-30.1]
# CLINICALSIZEmm 30.0 [22.0-41.0]
# CHARLSONSCORE 1.0 [0.0-2.0]
# PREOPHB 14.0 [13.1-15.0]
# PREOPHT 42.0 [39.2-44.9]
# PREOPWBC 7085.0 [5800.0-8100.0]
# PREOPCREAT 0.9 [0.8-1.1]
# NOOFLESIONS 1.0 [1.0-1.0]

# %%
#Print number of records for each category in categorical columns
for i in df_codes.columns:
    if i in cat_col:
        print(pd.DataFrame(df_codes[i].apply(lambda x: le_dict[i].inverse_transform([x])[0]).value_counts()))
# Out:
#           CENTERCODE
# GCIEYK6L         443
# 63DCGHNW         211
# 4UPDM0XB         170
# 4M49I4D5         170
# VNO3BPES         104
# 08ZMCILJ          93
# FWL0MH42          70
# 0VZRZWAI          70
# QRJWT5QR          55
# U5WT3NOY          54
# WGC7XYXZ          40
# GQHLD5Q4          30
# RETM03Y8          30
# 57T3OUKU          28
# 3QWOG020          25
# VRVRQ639          15
# 39HIP3LQ          13
# 94ISQMHX           6
#         GENDER
# Male      1060
# Female     567
#           MARITALSTATUS
# Married            1234
# Single              151
# NA                  143
# Divorced             50
# Widowed              49
#                  RACE
# White/Caucasian   844
# Others            340
# Mongoloid/Asian   233
# NA                165
# Black              45
#                   EDUCATION
# Not Provided            691
# Graduate                365
# Upto High School        213
# NA                      202
# Post Graduate           156
#                    SYMPTOMS
# Absent                 1278
# Local Symptoms          287
# NA                       32
# Systemic Symptoms        30
#      SOLITARYKIDNEY
# No             1093
# no              489
# Yes              43
# NA                2
#      BILATERALITYOFTUMOR
# No                  1413
# NA                   141
# Yes                   73
#            SIDEOFTUMOR
# Right              738
# Left               696
# NA                 136
# Bilateral           57
#            SIDEOFSURGERY
# Right                842
# Left                 784
# Bilateral              1
#            FACE
# Anterior    771
# Posterior   688
# NA          168
#             TUMORlOCATION
# Mid Pole              619
# Upper Pole            451
# Lower Pole            431
# Upper Pol              55
# Lower Pol              49
# NA                     22
#                        PADUARISK
# 1(Low  Risk)                 508
# 2(Intermidiate  Risk)        488
# 3(High  Risk)                409
# NA                           221
# 0                              1
#                                                     POLARLOCATION
# Tumours entirely located above the upper or bel...            871
# Tumours crossing the sinus line >50% or falling...            646
# NA                                                            110
#                                           RIMLOCATION
# Tumours located at the lateral (1 point)          926
# At the medial rim (2 points)                      501
# NA                                                200
#                                                    RENALSINUS
# Tumours without renal sinus involvement (1 point)         940
# With renal sinus involvement (2 points)                   490
# NA                                                        197
#                            EXOPHYTICRATE
# = 50% exophytic (1 point)            657
# < 50%exophytic (2 points)            594
# Endophytic (3 points)                214
# NA                                   162
#            CLINICALSIZEGROUP
# =<4cm                   1089
# 4.1cm-7cm                459
# NA                        67
# =>7cm                     12
#        CT
# T1a  1091
# T1b   406
# NA     99
# T2a    24
# T3a     5
# T2b     2
#      CN
# N0  921
# Nx  600
# NA  101
# N+    5
#                       R.E.N.A.L.NEPHRORISKSTRATIFICATION
# 2(Intermidiate Risk)                                 753
# 1(Low Risk)                                          534
# NA                                                   190
# 3(High Risk)                                         148
# 0                                                      2
#           RADIUSmaximaldiameterincm
# =<4                            1137
# 4 but <7                        469
# =>7                              14
# NA                                7
#            NEARNESSOFTUMOUR
# =<4                     646
# =>7                     434
# >4 but <7               352
# NA                      195
#                ANTERIORORPOSTERIOR
# Anterior (a)                   648
# Posterior (p)                  620
# Neither(x)                     199
# NA                             160
#      LOCATIONTOPOLARLINE
# 1.0                  571
# 2.0                  455
# 3.0                  438
# NA                   163
#             ASASCORE
# Category 2       774
# Category 1       482
# Category 3       289
# NA                77
# Category 4         5
#           PARTIALNEPHROINDICATION
# Elective                     1301
# Relative                      261
# Absolute                       62
# NA                              3
#      MULTIFOCALITY
# No            1413
# NA             134
# Yes             80

# %%
#traget_stats = pd.merge(df_codes[['PATIENTNUMBER','PATHOLOGY']],
                        #df_ori[['PATIENTNUMBER','PATHOLOGY']], 
                        #left_on='PATIENTNUMBER', 
                        #right_on='PATIENTNUMBER').copy()

# %%
#traget_stats

# %%
#traget_stats.loc[traget_stats['INTRA_OP_COMPLICATIONS']==1]['INTRAOPTRANSUFUSION'].value_counts()

# %% [markdown]
# ### Create Train and Test dataset

# %%
df_codes.corr()['SURGICALMARGIN']
# Out:
# CENTERCODE                            0.033872
# GENDER                                0.001753
# AGEATSURGERY                         -0.012468
# MARITALSTATUS                         0.006739
# RACE                                  0.013687
# EDUCATION                            -0.035555
# BMI                                  -0.064305
# CLINICALSIZEmm                        0.043139
# CHARLSONSCORE                         0.032195
# SYMPTOMS                             -0.013908
# SOLITARYKIDNEY                       -0.050217
# BILATERALITYOFTUMOR                  -0.039971
# SIDEOFTUMOR                          -0.023393
# SIDEOFSURGERY                        -0.035724
# FACE                                  0.014069
# TUMORlOCATION                        -0.023390
# PREOPHB                               0.033077
# PREOPHT                               0.035756
# PREOPWBC                             -0.037974
# PREOPCREAT                           -0.040233
# PADUARISK                            -0.018133
# POLARLOCATION                        -0.007995
# RIMLOCATION                          -0.003361
# RENALSINUS                            0.000076
# EXOPHYTICRATE                         0.017453
# CLINICALSIZEGROUP                     0.008691
# CT                                    0.009066
# CN                                   -0.073399
# R.E.N.A.L.NEPHRORISKSTRATIFICATION   -0.005570
# RADIUSmaximaldiameterincm             0.023311
# NEARNESSOFTUMOUR                     -0.008058
# ANTERIORORPOSTERIOR                   0.010450
# LOCATIONTOPOLARLINE                   0.012137
# ASASCORE                             -0.039994
# PARTIALNEPHROINDICATION              -0.009848
# MULTIFOCALITY                        -0.035615
# NOOFLESIONS                           0.003831
# SURGICALMARGIN                        1.000000
# Missing                              -0.002264
# Name: SURGICALMARGIN, dtype: float64

# %%
print('Number of patients {}'.format(len(df_codes)))
print('% of patients with complications {:.2f}%'.format(sum(df_codes['SURGICALMARGIN'])/len(df_codes)*100))
# Out:
# Number of patients 1627
# % of patients with complications 3.75%

# %%
# Split data in test and train
from sklearn.model_selection import train_test_split
train, test = train_test_split(df_codes, test_size=0.30, random_state=42, stratify = df_codes['SURGICALMARGIN'])

# %%
# Percentage of complications in trainset
train['SURGICALMARGIN'].sum()/len(train)
# Out:
# 0.037785588752196834

# %%
# Percentage of complications in testset
test['SURGICALMARGIN'].sum()/len(test)
# Out:
# 0.03680981595092025

# %%
# define data output path
data_path = 'H:/RediMinds/VCQI/SURGICALMARGIN/'
import os
if not os.path.exists(data_path):
    os.makedirs(data_path)

# %%
df_codes.drop(labels=['Missing','PATIENTNUMBER'], axis='columns', inplace=True)
df_codes.to_csv(data_path+"\VCQI_clean_SURGICALMARGIN.csv",index=False)

# %%
patient_list_train = train['PATIENTNUMBER'].tolist()
patient_list_test = test['PATIENTNUMBER'].tolist()
from joblib import dump
dump(patient_list_train, output_path + 'patient_list_train.joblib')
dump(patient_list_test, output_path + 'patient_list_test.joblib')
# Out:
# ['output/models/patient_list_test.joblib']

# %%
# Save train and test dataset

train.drop(labels=['Missing','PATIENTNUMBER'], axis='columns', inplace=True)
test.drop(labels=['Missing','PATIENTNUMBER'], axis='columns', inplace=True)
train.to_csv(data_path+"VCQI_clean_train_SURGICALMARGIN.csv",index=False)
test.to_csv(data_path+"VCQI_clean_test_SURGICALMARGIN.csv",index=False)
# Out:
# C:\Users\anubhav\Anaconda3\envs\Tensorflow\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
import pickle

cat_col = df.select_dtypes('category')

with open(output_path+'\cat_col_SURGICALMARGIN', 'wb') as fp:
    pickle.dump(cat_col.columns.to_list(), fp)

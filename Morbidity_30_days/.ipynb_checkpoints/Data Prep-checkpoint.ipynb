# %%
# Import Packages
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)  
#pd.set_option('display.expand_frame_repr', False)
#pd.set_option('max_colwidth', -1)

# %%
# Import prospective dataset
df= pd.read_excel('H:/RediMinds/DRMahen/Preethi PN_Data validation_2014-2018.xlsx', sheet_name='PN_Data validation_2014-2018')

# %%
# import patient list
f = open("../Intra-op Complications/output/models/patient_list.txt", "r")

# %%
# create aptient list
patient_list = f.read().splitlines()
f.close()

# %%
df = df[df['PATIENTNUMBER'].isin(patient_list)].copy()

# %%
df_ori = df.copy()

# %%
#check number of patients and columns in Retrospective dataset
print('Number of patients in Combined dataset {}'. format(df.shape[0]))
print('Number of variables in Combined dataset {}'. format(df.shape[1]))
# Out:
# Number of patients in Combined dataset 1690
# Number of variables in Combined dataset 161

# %%
# reset index for combined dataset
df.reset_index(inplace=True, drop=True)

# %%
df.info(verbose = True, null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1690 entries, 0 to 1689
# Data columns (total 161 columns):
# PATIENTNUMBER                         1690 non-null object
# PROCNAME                              1690 non-null object
# CENTERCODE                            1690 non-null object
# SURGEONCODE                           722 non-null object
# RECPROGRESS                           1690 non-null object
# CREATEDDATE                           1690 non-null object
# GENDER                                1690 non-null object
# DATEOFBIRTH                           1274 non-null float64
# AGEATSURGERY                          1688 non-null float64
# MARITALSTATUS                         1543 non-null object
# RACE                                  1524 non-null object
# EDUCATION                             1481 non-null object
# WEIGHT                                1554 non-null float64
# HEIGHT                                1552 non-null float64
# BMI                                   1574 non-null float64
# CLINICALSIZEmm                        1643 non-null float64
# ECOG                                  1188 non-null object
# CHARLSONSCORE                         1608 non-null float64
# CHARLSONAGEADJUSTSCORE                1479 non-null float64
# SYMPTOMS                              1657 non-null object
# SOLITARYKIDNEY                        1688 non-null object
# TYPEOFSOLITARYKIDNEY                  46 non-null object
# BILATERALITYOFTUMOR                   1548 non-null object
# SIDEOFTUMOR                           1553 non-null object
# SIDEOFSURGERY                         1689 non-null object
# PREOPMULTIFOCALITY                    746 non-null object
# FACE                                  1506 non-null object
# TUMORlOCATION                         1664 non-null object
# PREOPHB                               1662 non-null float64
# PREOPHT                               1666 non-null float64
# PREOPWBC                              1521 non-null float64
# PREOPCREAT                            1678 non-null float64
# PREOPGFR                              136 non-null object
# PREOPEGFR                             1380 non-null float64
# PREOPERPF                             114 non-null object
# PADUASCORE                            1488 non-null float64
# PADUARISK                             1455 non-null object
# POLARLOCATION                         1576 non-null object
# RIMLOCATION                           1480 non-null object
# RENALSINUS                            1480 non-null object
# UCSINVASION                           1494 non-null object
# EXOPHYTICRATE                         1518 non-null object
# CLINICALSIZEGROUP                     1617 non-null object
# CT                                    1587 non-null object
# CN                                    1586 non-null object
# CM                                    1286 non-null object
# R.E.N.A.L.NEPHROSCORE                 1497 non-null object
# R.E.N.A.L.NEPHRORISKSTRATIFICATION    1489 non-null object
# RADIUSmaximaldiameterincm             1683 non-null object
# EXOPHYTICENDOPHYTICPROPERTIES         1297 non-null object
# NEARNESSOFTUMOUR                      1485 non-null object
# ANTERIORORPOSTERIOR                   1521 non-null object
# LOCATIONTOPOLARLINE                   1516 non-null float64
# TumorConsistencyonImaging             489 non-null object
# BosniakClassification                 487 non-null object
# DATEOFSURGERY                         1689 non-null object
# ASASCORE                              1597 non-null object
# PARTIALNEPHROINDICATION               1671 non-null object
# MULTIFOCALITY                         1539 non-null object
# NOOFLESIONS                           1654 non-null float64
# ImagingFeaturesofotherexcisedtumor    64 non-null object
# Consistencyoftheotherexcisedtumors    311 non-null object
# ACCESS                                1647 non-null object
# DAVINCIMODEL                          1531 non-null object
# ROBOTICSARMS                          1626 non-null object
# ASSISTENTTROCARS                      1624 non-null object
# DUALCONSOLE                           1612 non-null object
# PRIMARYSURGEON                        1529 non-null object
# OPERATIVETIMEmin                      1599 non-null object
# ISCHEMIA                              1644 non-null object
# CLAMPARTERY                           1648 non-null object
# SELECTIVEARTERIALCLAMPING             1536 non-null object
# CLAMPVEIN                             1647 non-null object
# EARLYUNCLAMPING                       1617 non-null object
# FLUORESCENCE                          1644 non-null object
# INNERRENORRHAPHY                      1539 non-null object
# OUTERRENORRHAPHY                      1538 non-null object
# ISCHEMIATIMEmin                       1584 non-null float64
# UCSREPAIR                             1631 non-null object
# HAEMOSTATICAGENTS                     1640 non-null object
# HAEMOSTATICDetails                    1099 non-null object
# LYMPHNODEDISSECTIONLND                1645 non-null object
# BLOODLOSSml                           1641 non-null float64
# INTRAOPTRANSUFUSION                   1582 non-null object
# SURGICALCONSIDERATIONS                124 non-null object
# INTRAOPCOMPLICATION                   1465 non-null object
# INTRAOPCOMPLICATIONS                  104 non-null object
# NeedtoConverttoRadicalNephrectomy     705 non-null object
# TREATMENTOFCOMPLICATION               276 non-null object
# POSTOPCOMPLICATION                    1417 non-null object
# SURGICALCOMPLICATIONS                 74 non-null object
# NONSURGICALCOMPLICATIONS              51 non-null object
# POSTOPTREATMENTOFCOMPLICATION         297 non-null object
# CLAVIENGRADE                          1344 non-null object
# POSTOPHB_Day1                         789 non-null object
# POSTOPHT_Day1                         913 non-null object
# POSTOPCreat_Day1                      1123 non-null object
# POSTOPEGFR_Day1                       958 non-null object
# POSTOPWBC_Day1                        686 non-null object
# POSTOPHB_Day2                         613 non-null object
# POSTOPHT_Day2                         662 non-null object
# POSTOPCreat_Day2                      793 non-null object
# POSTOPEGFR_Day2                       665 non-null object
# POSTOPWBC_Day2                        561 non-null object
# POSTOPHB_Day3                         565 non-null object
# POSTOPHT_Day3                         593 non-null object
# POSTOPCreat_Day3                      746 non-null object
# POSTOPEGFR_Day3                       567 non-null object
# POSTOPWBC_Day3                        558 non-null object
# LENGTHOFSTAYdays                      1653 non-null float64
# PATHOLOGICALTUMORSIZE                 1625 non-null float64
# MINTHICKNESSMARGIN                    1090 non-null float64
# MAXTHICKNESSMARGIN                    478 non-null float64
# MULITIFOCALITY                        1610 non-null object
# PATHOLOGY                             1641 non-null object
# HYSTOTYPEMALIGNANAT                   1642 non-null object
# HYSTOTYPEMALIGNANATYES                1352 non-null object
# HYSTOTYPEBENIGN                       1619 non-null object
# HYSTOTYPEBENIGNYES                    298 non-null object
# FUHRMANGRADING                        1436 non-null float64
# SARCOMATOIDDIFF                       1521 non-null object
# SARCOMATOIDDIFF_A                     999 non-null float64
# NECROSIS                              1603 non-null object
# MICROVENOUSINVASION                   1603 non-null object
# UCSINVASION_A                         1604 non-null object
# PERIRENALFATINVASION                  1623 non-null object
# HilarFatInvasion                      711 non-null object
# SINUSFATINVASION                      1604 non-null object
# MICSCORE                              1260 non-null float64
# ADRENALINVASION                       1563 non-null object
# GEROTAINVASION                        1566 non-null object
# RenalVeinInvasion                     705 non-null object
# VENOUSTHROMBUS                        1602 non-null object
# SURGICALMARGIN                        1626 non-null object
# UNIFOCALMULTIFOCAL                    62 non-null object
# NO_OF_NODE_TAKEN                      1439 non-null float64
# NO_OF_NODE_POSITIVE                   914 non-null object
# SITEOFPOSITIVENODE                    612 non-null object
# TREATMENTPSM                          175 non-null object
# PT                                    1604 non-null object
# PN                                    1515 non-null object
# OTHERTUMORS                           13 non-null object
# DATEOFRECURRENCE                      16 non-null object
# LASTFOLLOWUPDURATION                  1106 non-null float64
# TIMETORECURRENCE                      83 non-null object
# LASTFOLLOWUPSTATUS                    789 non-null object
# LASTFOLLOWUPRECURRENCE                758 non-null object
# LASTTREATMENTOFRECURRENCE             346 non-null object
# TYPEOFCOMPLICATIONSs                  1233 non-null object
# SELECTEDSURGICALCOMPLICATIONSs        1233 non-null object
# SELECTEDNONSURGICALCOMPLICATIONSs     1233 non-null object
# TREATMENTOFCOMPLICATIONSs             1233 non-null object
# RECURRENCEs                           1233 non-null object
# FOLLOWUPDATEs                         1233 non-null object
# STATUSs                               1233 non-null object
# TREATMENTs                            1233 non-null object
# CREATININEs                           1233 non-null object
# EGFRs                                 1233 non-null object
# SRFs                                  1233 non-null object
# ERPFs                                 1233 non-null object
# Year                                  1689 non-null float64
# dtypes: float64(28), object(133)
# memory usage: 2.1+ MB

# %%
#clean Clavien grade
df['CLAVIENGRADE'] = df['CLAVIENGRADE'].map(lambda x: str(x).split(':')[0])

# %%
df['CLAVIENGRADE'].value_counts()
# Out:
# Grade 0    1200
# nan         346
# Grade 1      84
# Grade 2      32
# Grade 3      26
# Grade 4       2
# Name: CLAVIENGRADE, dtype: int64

# %%
# Clean Surgical and Non- Surgical Complications
df['SURGICALCOMPLICATIONS'] = df['SURGICALCOMPLICATIONS'].map(lambda x: str(x).split(',')[0])
df['NONSURGICALCOMPLICATIONS'] = df['NONSURGICALCOMPLICATIONS'].map(lambda x: str(x).split(',')[0])
print(df['SURGICALCOMPLICATIONS'].unique())
print(df['NONSURGICALCOMPLICATIONS'].unique())
# Out:
# ['320' '319' '314' 'nan' '318' '316' '314315320' '317']
# ['321' 'nan' '324326' '323']

# %%
# Dropping Surgical Complciations coded as "Others"
df = df[df['SURGICALCOMPLICATIONS']!='320'].copy()

# %%
# Prepare target variable for morbidity
df['POSTOP_COMPLICATIONS'] = 0
df.loc[#((df['POSTOPCOMPLICATION']== 'Complications') & ((df['SURGICALCOMPLICATIONS'].notnull()) | (df['NONSURGICALCOMPLICATIONS'].notnull()))) |
           (df['LENGTHOFSTAYdays']>4)|
           ((df['CLAVIENGRADE']== 'Grade 3') | 
            (df['CLAVIENGRADE']=='Grade 4')),['POSTOP_COMPLICATIONS']] = 1

# %%
df = df[df['LENGTHOFSTAYdays']<=14].copy()

# %%
# Total Number patients with complications
print('Total number of patients {}'.format(len(df)))
print('Total number of patients with complications {}'.format(df['POSTOP_COMPLICATIONS'].sum()))
print('Total % of patients with complications {:.3f}'.format(df['POSTOP_COMPLICATIONS'].sum()/len(df)))
# Out:
# Total number of patients 1602
# Total number of patients with complications 346
# Total % of patients with complications 0.216

# %% [markdown]
# ### Define numeric columns and identify missing values

# %%
# List of columns tobre converted to numeric
numeric_col_list = ['AGEATSURGERY',
'WEIGHT',
'HEIGHT',
'BMI',
'CLINICALSIZEmm',
'PREOPHB',
'PREOPHT',
'PREOPWBC',
'PREOPCREAT',
'PREOPGFR',
'PREOPEGFR',
'PREOPERPF',
'NOOFLESIONS',
'BLOODLOSSml',
'POSTOPHB_Day1',
'POSTOPHT_Day1',
'POSTOPCreat_Day1',
'POSTOPEGFR_Day1',
'POSTOPWBC_Day1',
'POSTOPHB_Day2',
'POSTOPHT_Day2',
'POSTOPCreat_Day2',
'POSTOPEGFR_Day2',
'POSTOPWBC_Day2',
'POSTOPHB_Day3',
'POSTOPHT_Day3',
'POSTOPCreat_Day3',
'POSTOPEGFR_Day3',
'POSTOPWBC_Day3',
'LENGTHOFSTAYdays',
'PATHOLOGICALTUMORSIZE',
'MINTHICKNESSMARGIN',
'MAXTHICKNESSMARGIN',
'SARCOMATOIDDIFF_A',
'NO_OF_NODE_TAKEN',
'LASTFOLLOWUPDURATION',
'CHARLSONSCORE',
'CHARLSONAGEADJUSTSCORE',
'PADUASCORE',
'ISCHEMIATIMEmin',
'OPERATIVETIMEmin'
]

# %% [markdown]
# ### Define Categorical columns

# %%
cat_col = ['PROCNAME',
'CENTERCODE',
'SURGEONCODE',
'RECPROGRESS',
'GENDER',
'MARITALSTATUS',
'RACE',
'EDUCATION',
'ECOG',
'SYMPTOMS',
'SOLITARYKIDNEY',
'TYPEOFSOLITARYKIDNEY',
'BILATERALITYOFTUMOR',
'SIDEOFTUMOR',
'SIDEOFSURGERY',
'PREOPMULTIFOCALITY',
'FACE',
'TUMORlOCATION',

'PADUARISK',
'POLARLOCATION',
'RIMLOCATION',
'RENALSINUS',
'UCSINVASION',
'EXOPHYTICRATE',
'CLINICALSIZEGROUP',
'CT',
'CN',
'CM',
'R.E.N.A.L.NEPHROSCORE',
'R.E.N.A.L.NEPHRORISKSTRATIFICATION',
'RADIUSmaximaldiameterincm',
'EXOPHYTICENDOPHYTICPROPERTIES',
'NEARNESSOFTUMOUR',
'ANTERIORORPOSTERIOR',
'LOCATIONTOPOLARLINE',
'TumorConsistencyonImaging',
'BosniakClassification',
'ASASCORE',
'PARTIALNEPHROINDICATION',
'MULTIFOCALITY',
'ImagingFeaturesofotherexcisedtumor',
'Consistencyoftheotherexcisedtumors',
'ACCESS',
'DAVINCIMODEL',
'ROBOTICSARMS',
'ASSISTENTTROCARS',
'DUALCONSOLE',
'PRIMARYSURGEON',
'ISCHEMIA',
'CLAMPARTERY',
'SELECTIVEARTERIALCLAMPING',
'CLAMPVEIN',
'EARLYUNCLAMPING',
'FLUORESCENCE',
'INNERRENORRHAPHY',
'OUTERRENORRHAPHY',
'UCSREPAIR',
'HAEMOSTATICAGENTS',
'HAEMOSTATICDetails',
'LYMPHNODEDISSECTIONLND',
'INTRAOPTRANSUFUSION',
'SURGICALCONSIDERATIONS',
'INTRAOPCOMPLICATION',
'INTRAOPCOMPLICATIONS',
'NeedtoConverttoRadicalNephrectomy',
'TREATMENTOFCOMPLICATION',
'POSTOPCOMPLICATION',
'SURGICALCOMPLICATIONS',
'NONSURGICALCOMPLICATIONS',
'POSTOPTREATMENTOFCOMPLICATION',
'CLAVIENGRADE',
'MULITIFOCALITY',
'PATHOLOGY',
'HYSTOTYPEMALIGNANAT',
'HYSTOTYPEMALIGNANATYES',
'HYSTOTYPEBENIGN',
'HYSTOTYPEBENIGNYES',
'FUHRMANGRADING',
'SARCOMATOIDDIFF',
'NECROSIS',
'MICROVENOUSINVASION',
'UCSINVASION_A',
'PERIRENALFATINVASION',
'HilarFatInvasion',
'SINUSFATINVASION',
'MICSCORE',
'ADRENALINVASION',
'GEROTAINVASION',
'RenalVeinInvasion',
'VENOUSTHROMBUS',
'SURGICALMARGIN',
'UNIFOCALMULTIFOCAL',
'NO_OF_NODE_POSITIVE',
'SITEOFPOSITIVENODE',
'TREATMENTPSM',
'PT',
'PN',
'OTHERTUMORS',
'LASTFOLLOWUPSTATUS',
'LASTFOLLOWUPRECURRENCE',
'LASTTREATMENTOFRECURRENCE'
]

# %% [markdown]
# ### Select Variables for analysis

# %%
post_op_col = [
'PATIENTNUMBER',
#'PROCNAME',
'CENTERCODE',
#'SURGEONCODE',
#'RECPROGRESS',
#'CREATEDDATE',
'GENDER',
#'DATEOFBIRTH',
'AGEATSURGERY',
'MARITALSTATUS',
'RACE',
'EDUCATION',
#'WEIGHT',
#'HEIGHT',
'BMI',
'CLINICALSIZEmm',
'ECOG',
'CHARLSONSCORE',
#'CHARLSONAGEADJUSTSCORE',
'SYMPTOMS',
'SOLITARYKIDNEY',
'TYPEOFSOLITARYKIDNEY',
'BILATERALITYOFTUMOR',
'SIDEOFTUMOR',
'SIDEOFSURGERY',
'PREOPMULTIFOCALITY',
'FACE',
'TUMORlOCATION',
'PREOPHB',
'PREOPHT',
'PREOPWBC',
'PREOPCREAT',
'PREOPGFR',
'PREOPEGFR',
'PREOPERPF',
#'PADUASCORE',
'PADUARISK',
'POLARLOCATION',
'RIMLOCATION',
'RENALSINUS',
#'UCSINVASION',
'EXOPHYTICRATE',
'CLINICALSIZEGROUP',
'CT',
'CN',
'CM',
#'R.E.N.A.L.NEPHROSCORE',
'R.E.N.A.L.NEPHRORISKSTRATIFICATION',
'RADIUSmaximaldiameterincm',
'EXOPHYTICENDOPHYTICPROPERTIES',
'NEARNESSOFTUMOUR',
'ANTERIORORPOSTERIOR',
'LOCATIONTOPOLARLINE',
'TumorConsistencyonImaging',
'BosniakClassification',
#'DATEOFSURGERY',
'ASASCORE',
'PARTIALNEPHROINDICATION',
'MULTIFOCALITY',
'NOOFLESIONS',
#'ImagingFeaturesofotherexcisedtumor', #too many categories
'Consistencyoftheotherexcisedtumors',
'ACCESS',
'DAVINCIMODEL',
'ROBOTICSARMS',
'ASSISTENTTROCARS',
'DUALCONSOLE',
#'PRIMARYSURGEON',
'OPERATIVETIMEmin',
'ISCHEMIA',
'CLAMPARTERY',
'SELECTIVEARTERIALCLAMPING',
'CLAMPVEIN',
'EARLYUNCLAMPING',
'FLUORESCENCE',
'INNERRENORRHAPHY',
'OUTERRENORRHAPHY',
'ISCHEMIATIMEmin',
'UCSREPAIR',
'HAEMOSTATICAGENTS',
#'HAEMOSTATICDetails', # too many values
'LYMPHNODEDISSECTIONLND',
'BLOODLOSSml',
'INTRAOPTRANSUFUSION',
#'SURGICALCONSIDERATIONS', too many values
'INTRAOPCOMPLICATION',
'INTRAOPCOMPLICATIONS',
'NeedtoConverttoRadicalNephrectomy',
'POSTOP_COMPLICATIONS'    
]

# %% [markdown]
# ### Data Cleaning

# %%
# function to clean operative time which contains a mix of time and numeric data i.e. '2:30' & '120.6'
def clean_oprerative_time(t):
    if ':' in t:
        x = float(t.split(':')[0])*60 + float(t.split(':')[1])
    else:
        x = float(t)
    return x

# clean operative time 
df['OPERATIVETIMEmin'] = df['OPERATIVETIMEmin'].map(lambda x: clean_oprerative_time(str(x)))

# %%
# Clean INTRAOPCOMPLICATIONS consider first code as primary complication
df['INTRAOPCOMPLICATIONS'] = df['INTRAOPCOMPLICATIONS'].map(lambda x: str(x).split(',')[0])

# %%
# Define Intra-op Complications
df['INTRA_OP_COMPLICATIONS'] = 0

# selecting indicator == 'Yes' and code vailability or Intra-op Bloos transfusion>1 unit as Intra-op complication
df.loc[((df['INTRAOPCOMPLICATIONS'].notnull()) & (df['INTRAOPCOMPLICATION'] == 'Yes'))|(df['INTRAOPTRANSUFUSION']=='>1 Unit') ,['INTRA_OP_COMPLICATIONS']] = 1

# %%
#Drop INTRAOPCOMPLICATION as it has been replaced by INTRA_OP_COMPLICATIONS
df.drop(labels=['INTRAOPCOMPLICATION'],axis = 'columns' ,inplace=True)
post_op_col.remove('INTRAOPCOMPLICATION') # remove the varibale from list of predictors for post-op complications

# %%
# Convert columns in numeric_col_list to numeric and invalid values are set NaN 
for col in numeric_col_list:
    df[col]= pd.to_numeric(df[col], errors='coerce')

# %%
# Summary of numeric columns
df.describe(include = [np.number]).round(2)
# Out:
#        DATEOFBIRTH  AGEATSURGERY   WEIGHT   HEIGHT      BMI  CLINICALSIZEmm  \
# count      1190.00       1600.00  1472.00  1470.00  1489.00         1558.00
# mean       1957.11         56.77    89.05   163.46    27.61           33.73
# std          13.18         12.79    54.73    41.15     4.88           44.81
# min        1925.00         16.00     7.71     1.70    15.10            0.00
# 25%        1948.00         48.00    68.47   160.00    24.16           21.25
# 50%        1956.00         58.00    79.00   169.00    26.87           30.00
# 75%        1966.00         66.00    92.00   176.00    30.55           41.00
# max        1998.00         87.00   999.00   999.00    42.30          999.00
#
#        CHARLSONSCORE  CHARLSONAGEADJUSTSCORE  PREOPHB  PREOPHT  PREOPWBC  \
# count        1523.00                 1395.00  1574.00  1578.00   1436.00
# mean            1.26                    3.29    19.01    45.57   6857.22
# std             1.80                    2.14    70.08    87.89   2245.20
# min             0.00                    0.00    10.00     0.34      4.00
# 25%             0.00                    2.00    13.10    37.70   5600.00
# 50%             1.00                    3.00    14.00    41.60   6800.00
# 75%             2.00                    4.00    15.10    44.68   8200.00
# max            19.00                   18.00   999.00   999.00  12840.00
#
#        PREOPCREAT  PREOPGFR  PREOPEGFR  PREOPERPF  PADUASCORE  \
# count     1591.00     99.00    1297.00      94.00     1410.00
# mean         2.18    659.92      81.10     878.44        8.45
# std         35.38    451.03      18.61     290.96        1.73
# min          0.40     35.00      34.00      43.50        2.00
# 25%          0.78     83.00      67.15     999.00        7.00
# 50%          0.90    999.00      80.44     999.00        8.00
# 75%          1.05    999.00      94.00     999.00       10.00
# max        999.00    999.00     136.49     999.00       13.00
#
#        LOCATIONTOPOLARLINE  NOOFLESIONS  OPERATIVETIMEmin  ISCHEMIATIMEmin  \
# count              1438.00      1582.00           1529.00          1515.00
# mean                  1.92         1.04            174.30            20.42
# std                   0.83         0.26             74.43            37.98
# min                   1.00         0.00             24.00             0.00
# 25%                   1.00         1.00            132.00            14.00
# 50%                   2.00         1.00            163.00            18.00
# 75%                   3.00         1.00            198.00            23.00
# max                   3.00         4.00            999.00           999.00
#
#        BLOODLOSSml  POSTOPHB_Day1  POSTOPHT_Day1  POSTOPCreat_Day1  \
# count      1572.00         684.00         844.00           1049.00
# mean        189.58          64.80          73.29             35.36
# std         217.22         220.49         195.88            181.75
# min           0.00           7.40           0.28              0.46
# 25%          50.00          11.20          32.08              1.00
# 50%         100.00          12.50          36.00              1.00
# 75%         200.00          13.42          39.02              1.20
# max        2000.00         999.00         999.00            999.00
#
#        POSTOPEGFR_Day1  POSTOPWBC_Day1  POSTOPHB_Day2  POSTOPHT_Day2  \
# count           794.00          551.00         370.00         405.00
# mean            128.88         2536.25         168.45         170.79
# std             231.35         4643.70         358.90         342.67
# min              16.84            5.20           0.00           0.00
# 25%              54.14            9.75          10.82          30.30
# 50%              68.00           12.60          12.20          35.70
# 75%              83.74          999.00          14.10          41.00
# max             999.00        19610.00         999.00         999.00
#
#        POSTOPCreat_Day2  POSTOPEGFR_Day2  POSTOPWBC_Day2  POSTOPHB_Day3  \
# count            552.00           384.00          315.00         285.00
# mean             105.99           226.23         3438.25         250.52
# std              306.27           353.19         5394.42         423.79
# min                0.00             0.00            2.10           0.00
# 25%                0.90            52.96            9.80          11.00
# 50%                1.12            70.00           12.50          12.20
# 75%                1.47            98.96         6960.00          14.80
# max              999.00           999.00        27780.00         999.00
#
#        POSTOPHT_Day3  POSTOPCreat_Day3  POSTOPEGFR_Day3  POSTOPWBC_Day3  \
# count         291.00            466.00           262.00          276.00
# mean          294.14            142.42           315.34         3385.41
# std           431.52            348.32           414.04         4446.61
# min             0.00              0.00             0.00            4.70
# 25%            31.70              0.89            60.23            9.70
# 50%            37.00              1.10            74.71          999.00
# 75%           999.00              1.42           999.00         6010.00
# max           999.00            999.00           999.00        16060.00
#
#        LENGTHOFSTAYdays  PATHOLOGICALTUMORSIZE  MINTHICKNESSMARGIN  \
# count           1602.00                1571.00             1053.00
# mean               3.27                  12.91               79.70
# std                1.84                  29.39              263.95
# min                0.00                   0.00                0.00
# 25%                2.00                   2.50                1.00
# 50%                3.00                   4.00                2.00
# 75%                4.00                  20.00                5.00
# max               13.00                 999.00              999.00
#
#        MAXTHICKNESSMARGIN  FUHRMANGRADING  SARCOMATOIDDIFF_A  MICSCORE  \
# count              468.00         1391.00             963.00   1213.00
# mean               204.13          160.53              20.66      0.19
# std                393.98          364.54             162.97      0.39
# min                  0.00            1.00            -999.00      0.00
# 25%                  2.00            2.00               0.00      0.00
# 50%                  5.00            2.00               0.00      0.00
# 75%                 30.00            3.00               0.00      0.00
# max                999.00          999.00             999.00      1.00
#
#        NO_OF_NODE_TAKEN  LASTFOLLOWUPDURATION     Year  POSTOP_COMPLICATIONS  \
# count           1388.00               1076.00  1601.00               1602.00
# mean               1.52                 17.32  2014.05                  0.22
# std               37.91                 20.90     3.00                  0.41
# min                0.00                  0.00  2006.00                  0.00
# 25%                0.00                  3.00  2012.00                  0.00
# 50%                0.00                  9.05  2015.00                  0.00
# 75%                0.00                 23.00  2017.00                  0.00
# max              999.00                101.00  2018.00                  1.00
#
#        INTRA_OP_COMPLICATIONS
# count                 1602.00
# mean                     0.06
# std                      0.23
# min                      0.00
# 25%                      0.00
# 50%                      0.00
# 75%                      0.00
# max                      1.00

# %%
#replace missing values such as 999 in the dataframe with NaN
df = df.replace([99,999,9999,99999,999999,-99,-999,-9999,-99999,-999999],np.nan)

# %%
# replacing negative numbers in the dataframe with nan as given variables cannot contain negative numbers
for col in list(df.select_dtypes('float64')):
    df[col] = df[col].apply(lambda x: np.nan if x<0 else x)

# %%
# Summary of numeric columns - to check missing values such as 99, 999, 999 have been replaced
df.describe(include = [np.number]).round(2)
# Out:
#        DATEOFBIRTH  AGEATSURGERY   WEIGHT   HEIGHT      BMI  CLINICALSIZEmm  \
# count      1190.00       1600.00  1467.00  1468.00  1489.00         1555.00
# mean       1957.11         56.77    87.17   162.33    27.61           31.87
# std          13.18         12.79    36.16    27.25     4.88           14.49
# min        1925.00         16.00     7.71     1.70    15.10            0.00
# 25%        1948.00         48.00    68.30   160.00    24.16           21.00
# 50%        1956.00         58.00    79.00   169.00    26.87           30.00
# 75%        1966.00         66.00    92.00   176.00    30.55           41.00
# max        1998.00         87.00   298.00   198.12    42.30           71.00
#
#        CHARLSONSCORE  CHARLSONAGEADJUSTSCORE  PREOPHB  PREOPHT  PREOPWBC  \
# count        1523.00                 1395.00  1566.00  1565.00   1425.00
# mean            1.26                    3.29    14.00    37.65   6902.44
# std             1.80                    2.14     1.42    13.07   2193.79
# min             0.00                    0.00    10.00     0.34      4.00
# 25%             0.00                    2.00    13.10    37.60   5600.00
# 50%             1.00                    3.00    14.00    41.60   6800.00
# 75%             2.00                    4.00    15.08    44.50   8210.00
# max            19.00                   18.00    17.80    53.70  12840.00
#
#        PREOPCREAT  PREOPGFR  PREOPEGFR  PREOPERPF  PADUASCORE  \
# count     1589.00     36.00    1291.00      14.00     1410.00
# mean         0.93     66.53      81.02     189.54        8.45
# std          0.20     21.78      18.61      71.30        1.73
# min          0.40     35.00      34.00      43.50        2.00
# 25%          0.78     46.75      67.00     145.00        7.00
# 50%          0.90     70.20      80.26     203.00        8.00
# 75%          1.05     86.50      93.97     230.50       10.00
# max          1.57    116.80     136.49     340.00       13.00
#
#        LOCATIONTOPOLARLINE  NOOFLESIONS  OPERATIVETIMEmin  ISCHEMIATIMEmin  \
# count              1438.00      1582.00           1521.00          1513.00
# mean                  1.92         1.04            171.74            19.13
# std                   0.83         0.26             57.57            13.28
# min                   1.00         0.00             24.00             0.00
# 25%                   1.00         1.00            132.00            14.00
# 50%                   2.00         1.00            163.00            18.00
# 75%                   3.00         1.00            197.00            23.00
# max                   3.00         4.00            546.00           320.00
#
#        BLOODLOSSml  POSTOPHB_Day1  POSTOPHT_Day1  POSTOPCreat_Day1  \
# count      1569.00         648.00         808.00           1013.00
# mean        188.04          12.90          32.04              1.11
# std         214.52           7.91          12.26              0.36
# min           0.00           7.40           0.28              0.46
# 25%          50.00          11.00          31.90              0.99
# 50%         100.00          12.30          35.80              1.00
# 75%         200.00          13.10          38.60              1.18
# max        2000.00         129.00          49.30              3.90
#
#        POSTOPEGFR_Day1  POSTOPWBC_Day1  POSTOPHB_Day2  POSTOPHT_Day2  \
# count           741.00          514.00         312.00         346.00
# mean             67.86         2646.91          14.05          29.56
# std              20.64         4789.21          16.41          14.03
# min              16.84            5.20           0.00           0.00
# 25%              53.23            9.50          10.70          28.85
# 50%              65.00           12.00          11.80          33.95
# 75%              80.08         3400.00          13.00          38.00
# max             155.50        19610.00         136.00          51.00
#
#        POSTOPCreat_Day2  POSTOPEGFR_Day2  POSTOPWBC_Day2  POSTOPHB_Day3  \
# count            494.00           315.00          299.00         216.00
# mean               1.14            65.53         3568.77          11.42
# std                0.45            24.02         5506.87           2.29
# min                0.00             0.00            2.10           0.00
# 25%                0.89            49.86            9.40          10.50
# 50%                1.08            64.00           12.10          11.90
# 75%                1.31            81.00         7410.00          12.82
# max                5.29           157.70        27780.00          15.20
#
#        POSTOPHT_Day3  POSTOPCreat_Day3  POSTOPEGFR_Day3  POSTOPWBC_Day3  \
# count         212.00            400.00           190.00          209.00
# mean           31.47              1.08            65.74         4150.44
# std            24.39              0.43            22.37         4870.19
# min             0.00              0.00             0.00            4.70
# 25%            29.37              0.84            54.25            8.80
# 50%            34.00              1.04            66.00           15.90
# 75%            37.38              1.21            78.00         8700.00
# max           332.00              4.64           150.00        16060.00
#
#        LENGTHOFSTAYdays  PATHOLOGICALTUMORSIZE  MINTHICKNESSMARGIN  \
# count           1602.00                1570.00              971.00
# mean               3.27                  12.29                3.92
# std                1.84                  15.63               10.36
# min                0.00                   0.00                0.00
# 25%                2.00                   2.50                1.00
# 50%                3.00                   4.00                2.00
# 75%                4.00                  20.00                4.00
# max               13.00                 110.00              240.00
#
#        MAXTHICKNESSMARGIN  FUHRMANGRADING  SARCOMATOIDDIFF_A  MICSCORE  \
# count              375.00         1170.00             936.00   1213.00
# mean                11.80            2.16               0.03      0.19
# std                 54.17            0.67               0.52      0.39
# min                  0.00            1.00               0.00      0.00
# 25%                  1.55            2.00               0.00      0.00
# 50%                  3.00            2.00               0.00      0.00
# 75%                  8.00            3.00               0.00      0.00
# max                979.00            4.00              15.00      1.00
#
#        NO_OF_NODE_TAKEN  LASTFOLLOWUPDURATION     Year  POSTOP_COMPLICATIONS  \
# count           1386.00               1076.00  1601.00               1602.00
# mean               0.09                 17.32  2014.05                  0.22
# std                0.57                 20.90     3.00                  0.41
# min                0.00                  0.00  2006.00                  0.00
# 25%                0.00                  3.00  2012.00                  0.00
# 50%                0.00                  9.05  2015.00                  0.00
# 75%                0.00                 23.00  2017.00                  0.00
# max               11.00                101.00  2018.00                  1.00
#
#        INTRA_OP_COMPLICATIONS
# count                 1602.00
# mean                     0.06
# std                      0.23
# min                      0.00
# 25%                      0.00
# 50%                      0.00
# 75%                      0.00
# max                      1.00

# %%
# Correcting the units for erroroneously entered data
def clean_WBC(x):
    if len(str(x))<6:
        x = x*1000
    return x
        

# if the value of PRE-OP WBC value contains is less the 4 digits then multiply it by 1000
df['PREOPWBC'] = df['PREOPWBC'].apply(lambda x: clean_WBC(x))

# if the value of POST-OP WBC_Day 1 value contains is less the 4 digits then multiply it by 1000
df['POSTOPWBC_Day1'] = df['POSTOPWBC_Day1'].apply(lambda x: clean_WBC(x))

# if the value of POST-OP WBC_Day 2 value contains is less the 4 digits then multiply it by 1000
df['POSTOPWBC_Day2'] = df['POSTOPWBC_Day2'].apply(lambda x: clean_WBC(x))

# if the value of POST-OP WBC_Day 2 value contains is less the 4 digits then multiply it by 1000
df['POSTOPWBC_Day3'] = df['POSTOPWBC_Day3'].apply(lambda x: clean_WBC(x))

# %%
# Correcting the units for erroroneously entered data for PREOPHB
df['PREOPHB'] = df['PREOPHB'].apply(lambda x: x*100 if x<10 else x)

# Correcting the units for erroroneously entered data for PREOPHB
df['PREOPHT'] = df['PREOPHT'].apply(lambda x: x*100 if x<10 else x)

# %%
# Selecting dataframe relevant columsn for analysis
df = df[post_op_col].copy()

# %%
#Keep columns having less than 50% missing data
print("Total number of columns before removing columns with more than 50% missing data: {}".format(len(list(df))))

df = df[df.columns[df.isnull().mean() <= 0.50]].copy()

print("Total number of columns left after removing columns with more than 50% missing data: {}".format(len(list(df))))
# Out:
# Total number of columns before removing columns with more than 50% missing data: 72
# Total number of columns left after removing columns with more than 50% missing data: 64

# %%
# select target variable
target = 'POSTOP_COMPLICATIONS'

# %%
df.describe()
# Out:
#        AGEATSURGERY          BMI  CLINICALSIZEmm  CHARLSONSCORE      PREOPHB  \
# count   1600.000000  1489.000000     1555.000000    1523.000000  1566.000000
# mean      56.767500    27.611387       31.869582       1.262640    14.000868
# std       12.785905     4.875161       14.488933       1.801763     1.418317
# min       16.000000    15.100000        0.000000       0.000000    10.000000
# 25%       48.000000    24.160000       21.000000       0.000000    13.100000
# 50%       58.000000    26.870000       30.000000       1.000000    14.000000
# 75%       66.000000    30.550000       41.000000       2.000000    15.075000
# max       87.000000    42.300000       71.000000      19.000000    17.800000
#
#            PREOPHT      PREOPWBC   PREOPCREAT    PREOPEGFR  \
# count  1565.000000   1425.000000  1589.000000  1291.000000
# mean     41.826709   7114.863818     0.927844    81.015102
# std       4.197366   1865.068912     0.203869    18.611653
# min      29.000000   1840.000000     0.400000    34.000000
# 25%      39.100000   5700.000000     0.780000    67.000000
# 50%      42.100000   6920.000000     0.900000    80.260000
# 75%      45.000000   8300.000000     1.050000    93.970000
# max      53.700000  12840.000000     1.570000   136.493592
#
#        LOCATIONTOPOLARLINE  NOOFLESIONS  OPERATIVETIMEmin  ISCHEMIATIMEmin  \
# count          1438.000000  1582.000000       1521.000000      1513.000000
# mean              1.916551     1.044880        171.737673        19.127369
# std               0.828337     0.258705         57.573273        13.281617
# min               1.000000     0.000000         24.000000         0.000000
# 25%               1.000000     1.000000        132.000000        14.000000
# 50%               2.000000     1.000000        163.000000        18.000000
# 75%               3.000000     1.000000        197.000000        23.000000
# max               3.000000     4.000000        546.000000       320.000000
#
#        BLOODLOSSml  POSTOP_COMPLICATIONS
# count  1569.000000           1602.000000
# mean    188.035054              0.215980
# std     214.520557              0.411629
# min       0.000000              0.000000
# 25%      50.000000              0.000000
# 50%     100.000000              0.000000
# 75%     200.000000              0.000000
# max    2000.000000              1.000000

# %%
numeric_stats = df.describe()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)
f, axes = plt.subplots(2, 5, figsize=(20, 8))
sns.despine(left=True)
sns.boxplot(data = df, y = 'AGEATSURGERY', x = target,ax=axes[0, 0])
sns.boxplot(data = df, y = 'BMI', x = target, ax=axes[0, 1])
sns.boxplot(data = df, y = 'CLINICALSIZEmm', x = target, ax=axes[0, 2])
sns.boxplot(data = df, y = 'PREOPHB', x = target, ax=axes[0, 3])
sns.boxplot(data = df, y = 'PREOPHT', x = target, ax=axes[0, 4])
sns.boxplot(data = df, y = 'PREOPWBC', x = target, ax=axes[1, 0])
sns.boxplot(data = df, y = 'PREOPCREAT', x = target, ax=axes[1, 1])
sns.boxplot(data = df, y = 'PREOPEGFR', x = target, ax=axes[1, 2])
sns.boxplot(data = df, y = 'OPERATIVETIMEmin', x = target, ax=axes[1, 3])
sns.boxplot(data = df, y = 'ISCHEMIATIMEmin', x = target, ax=axes[1, 4])

# %%
# Check the number of outliers
clean_cols = ['BMI','CLINICALSIZEmm','PREOPHB','PREOPHT','PREOPWBC','PREOPCREAT','PREOPEGFR','OPERATIVETIMEmin','ISCHEMIATIMEmin']
for i in clean_cols:
    q1 = numeric_stats.loc['25%'][i]
    q3 = numeric_stats.loc['75%'][i]
    IQR = q3-q1
    LL = q1-(1.5*IQR)
    UL = q3+(1.5*IQR)
    print('{:<20s} {:>4d} {:>4d}'.format(i,len(df.loc[(df[i]>=UL)]),len(df.loc[(df[i]<=LL)])), 'UL-LL {:>4.2f}-{:>4.2f}'.format(UL,LL))
# Out:
# BMI                    24    0 UL-LL 40.14-14.57
# CLINICALSIZEmm          3    0 UL-LL 71.00--9.00
# PREOPHB                 0    7 UL-LL 18.04-10.14
# PREOPHT                 0    5 UL-LL 53.85-30.25
# PREOPWBC                9    0 UL-LL 12200.00-1800.00
# PREOPCREAT             22    0 UL-LL 1.46-0.38
# PREOPEGFR               4    0 UL-LL 134.43-26.55
# OPERATIVETIMEmin       53    1 UL-LL 294.50-34.50
# ISCHEMIATIMEmin        53   78 UL-LL 36.50-0.50

# %%
#replacing inaccurate readings with missing values
clean_cols = ['OPERATIVETIMEmin','ISCHEMIATIMEmin']
for i in clean_cols:
    q1 = numeric_stats.loc['25%'][i]
    q3 = numeric_stats.loc['75%'][i]
    IQR = q3-q1
    LL = q1-(1.5*IQR)
    UL = q3+(1.5*IQR)
    df.drop(df.loc[(df[i]<=LL)|(df[i]>=UL),[i]].index, inplace=True)

# %%
df.describe()
# Out:
#        AGEATSURGERY          BMI  CLINICALSIZEmm  CHARLSONSCORE      PREOPHB  \
# count   1429.000000  1324.000000     1388.000000    1356.000000  1398.000000
# mean      56.761372    27.506187       31.519236       1.171829    13.994392
# std       12.765599     4.785238       14.271235       1.782027     1.418450
# min       17.000000    15.100000        0.000000       0.000000    10.000000
# 25%       48.000000    24.195000       21.000000       0.000000    13.000000
# 50%       57.000000    26.810000       30.000000       1.000000    14.000000
# 75%       66.000000    30.360000       41.000000       2.000000    15.000000
# max       87.000000    42.300000       71.000000      19.000000    17.800000
#
#            PREOPHT      PREOPWBC   PREOPCREAT    PREOPEGFR  \
# count  1397.000000   1260.000000  1420.000000  1163.000000
# mean     41.788690   7110.437254     0.927743    81.023047
# std       4.206514   1875.362715     0.203122    18.608312
# min      29.000000   1840.000000     0.460000    34.000000
# 25%      39.000000   5700.000000     0.780000    67.000000
# 50%      42.000000   6925.000000     0.900000    80.170407
# 75%      45.000000   8300.000000     1.050000    93.845000
# max      53.700000  12840.000000     1.570000   136.493592
#
#        LOCATIONTOPOLARLINE  NOOFLESIONS  OPERATIVETIMEmin  ISCHEMIATIMEmin  \
# count          1276.000000  1411.000000       1357.000000      1343.000000
# mean              1.904389     1.043232        163.389831        18.696307
# std               0.829994     0.250337         45.491423         6.186458
# min               1.000000     0.000000         35.000000         1.000000
# 25%               1.000000     1.000000        130.000000        14.000000
# 50%               2.000000     1.000000        160.000000        18.000000
# 75%               3.000000     1.000000        189.000000        23.000000
# max               3.000000     3.000000        293.000000        36.000000
#
#        BLOODLOSSml  POSTOP_COMPLICATIONS
# count  1400.000000           1431.000000
# mean    180.374286              0.218728
# std     208.253560              0.413528
# min       0.000000              0.000000
# 25%      50.000000              0.000000
# 50%     100.000000              0.000000
# 75%     200.000000              0.000000
# max    2000.000000              1.000000

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)
f, axes = plt.subplots(2, 5, figsize=(20, 8))
sns.despine(left=True)
sns.boxplot(data = df, y = 'AGEATSURGERY', x = target,ax=axes[0, 0])
sns.boxplot(data = df, y = 'BMI', x = target, ax=axes[0, 1])
sns.boxplot(data = df, y = 'CLINICALSIZEmm', x = target, ax=axes[0, 2])
sns.boxplot(data = df, y = 'PREOPHB', x = target, ax=axes[0, 3])
sns.boxplot(data = df, y = 'PREOPHT', x = target, ax=axes[0, 4])
sns.boxplot(data = df, y = 'PREOPWBC', x = target, ax=axes[1, 0])
sns.boxplot(data = df, y = 'PREOPCREAT', x = target, ax=axes[1, 1])
sns.boxplot(data = df, y = 'PREOPEGFR', x = target, ax=axes[1, 2])
sns.boxplot(data = df, y = 'OPERATIVETIMEmin', x = target, ax=axes[1, 3])
sns.boxplot(data = df, y = 'ISCHEMIATIMEmin', x = target, ax=axes[1, 4])

# %%
# The percentage of missing data
df.isnull().mean()
# Out:
# PATIENTNUMBER             0.000000
# CENTERCODE                0.000000
# GENDER                    0.000000
# AGEATSURGERY              0.001398
# MARITALSTATUS             0.099930
#                             ...
# LYMPHNODEDISSECTIONLND    0.018169
# BLOODLOSSml               0.021663
# INTRAOPTRANSUFUSION       0.058001
# INTRAOPCOMPLICATIONS      0.000000
# POSTOP_COMPLICATIONS      0.000000
# Length: 64, dtype: float64

# %%
# Calculate number missing values per row
df.reset_index(inplace=True, drop=True)
missing = {}

for i in range(len(df)):
    miss_cnt = 0
    for col in df.columns:
        if pd.isna(df[col][i]) == True:
            miss_cnt = miss_cnt+1
    df.loc[i,'Missing'] = miss_cnt

# %%
# calculate number of records with over 25% missing data
print("Total Records {}".format(len(df)))
print("Records with >=25% missing data {}".format(sum(df['Missing']<= round((len(df.columns)-2)*.30))))
print("Records to be dropped {}".format(len(df) - sum(df['Missing']<= round((len(df.columns)-2)*.30))))
# Out:
# Total Records 1431
# Records with >=25% missing data 1406
# Records to be dropped 25

# %%
# Chekc the number of missing values for each variables if records with a certain missing threshold were removed
df[df['Missing']<= round((len(df.columns)-2)*.30) ].isnull().mean()
# Out:
# PATIENTNUMBER           0.000000
# CENTERCODE              0.000000
# GENDER                  0.000000
# AGEATSURGERY            0.001422
# MARITALSTATUS           0.086060
#                           ...
# BLOODLOSSml             0.006401
# INTRAOPTRANSUFUSION     0.041963
# INTRAOPCOMPLICATIONS    0.000000
# POSTOP_COMPLICATIONS    0.000000
# Missing                 0.000000
# Length: 65, dtype: float64

# %%
#removing patients with more than 70% missing data
df = df[df['Missing']<= round((len(df.columns)-2)*.30) ].copy()

# %%
df[df.columns[df.isnull().mean() <= 0.15]].isnull().mean()
# Out:
# PATIENTNUMBER           0.000000
# CENTERCODE              0.000000
# GENDER                  0.000000
# AGEATSURGERY            0.001422
# MARITALSTATUS           0.086060
#                           ...
# BLOODLOSSml             0.006401
# INTRAOPTRANSUFUSION     0.041963
# INTRAOPCOMPLICATIONS    0.000000
# POSTOP_COMPLICATIONS    0.000000
# Missing                 0.000000
# Length: 61, dtype: float64

# %%
df = df[df.columns[df.isnull().mean() <= 0.15]]

# %%
# Replcaing missing values in categorical column with NA
for k in cat_col:
    if k in df.columns:
        df[k].fillna('NA',inplace = True)

# %%
# Replacing missing values in numerical columns with their respective mean 
for k in numeric_col_list:
    if k in df.columns:
        df[k].fillna(round(df[k].mean()), inplace = True)

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1406 entries, 0 to 1430
# Data columns (total 61 columns):
# PATIENTNUMBER                         1406 non-null object
# CENTERCODE                            1406 non-null object
# GENDER                                1406 non-null object
# AGEATSURGERY                          1406 non-null float64
# MARITALSTATUS                         1406 non-null object
# RACE                                  1406 non-null object
# EDUCATION                             1406 non-null object
# BMI                                   1406 non-null float64
# CLINICALSIZEmm                        1406 non-null float64
# CHARLSONSCORE                         1406 non-null float64
# SYMPTOMS                              1406 non-null object
# SOLITARYKIDNEY                        1406 non-null object
# BILATERALITYOFTUMOR                   1406 non-null object
# SIDEOFTUMOR                           1406 non-null object
# SIDEOFSURGERY                         1406 non-null object
# FACE                                  1406 non-null object
# TUMORlOCATION                         1406 non-null object
# PREOPHB                               1406 non-null float64
# PREOPHT                               1406 non-null float64
# PREOPWBC                              1406 non-null float64
# PREOPCREAT                            1406 non-null float64
# PADUARISK                             1406 non-null object
# POLARLOCATION                         1406 non-null object
# RIMLOCATION                           1406 non-null object
# RENALSINUS                            1406 non-null object
# EXOPHYTICRATE                         1406 non-null object
# CLINICALSIZEGROUP                     1406 non-null object
# CT                                    1406 non-null object
# CN                                    1406 non-null object
# R.E.N.A.L.NEPHRORISKSTRATIFICATION    1406 non-null object
# RADIUSmaximaldiameterincm             1406 non-null object
# NEARNESSOFTUMOUR                      1406 non-null object
# ANTERIORORPOSTERIOR                   1406 non-null object
# LOCATIONTOPOLARLINE                   1406 non-null object
# ASASCORE                              1406 non-null object
# PARTIALNEPHROINDICATION               1406 non-null object
# MULTIFOCALITY                         1406 non-null object
# NOOFLESIONS                           1406 non-null float64
# ACCESS                                1406 non-null object
# DAVINCIMODEL                          1406 non-null object
# ROBOTICSARMS                          1406 non-null object
# ASSISTENTTROCARS                      1406 non-null object
# DUALCONSOLE                           1406 non-null object
# OPERATIVETIMEmin                      1406 non-null float64
# ISCHEMIA                              1406 non-null object
# CLAMPARTERY                           1406 non-null object
# SELECTIVEARTERIALCLAMPING             1406 non-null object
# CLAMPVEIN                             1406 non-null object
# EARLYUNCLAMPING                       1406 non-null object
# FLUORESCENCE                          1406 non-null object
# INNERRENORRHAPHY                      1406 non-null object
# OUTERRENORRHAPHY                      1406 non-null object
# ISCHEMIATIMEmin                       1406 non-null float64
# UCSREPAIR                             1406 non-null object
# HAEMOSTATICAGENTS                     1406 non-null object
# LYMPHNODEDISSECTIONLND                1406 non-null object
# BLOODLOSSml                           1406 non-null float64
# INTRAOPTRANSUFUSION                   1406 non-null object
# INTRAOPCOMPLICATIONS                  1406 non-null object
# POSTOP_COMPLICATIONS                  1406 non-null int64
# Missing                               1406 non-null float64
# dtypes: float64(13), int64(1), object(47)
# memory usage: 681.0+ KB

# %%
# check unique value in each column of type object
unique_count_list = {}

for k in cat_col:
    if k in df.columns:
        unique_count_list.update({k:len(df[k].unique())})

unique_count_list
# Out:
# {'CENTERCODE': 18,
#  'GENDER': 2,
#  'MARITALSTATUS': 5,
#  'RACE': 5,
#  'EDUCATION': 5,
#  'SYMPTOMS': 4,
#  'SOLITARYKIDNEY': 4,
#  'BILATERALITYOFTUMOR': 3,
#  'SIDEOFTUMOR': 4,
#  'SIDEOFSURGERY': 3,
#  'FACE': 3,
#  'TUMORlOCATION': 6,
#  'PADUARISK': 5,
#  'POLARLOCATION': 3,
#  'RIMLOCATION': 3,
#  'RENALSINUS': 3,
#  'EXOPHYTICRATE': 4,
#  'CLINICALSIZEGROUP': 4,
#  'CT': 6,
#  'CN': 4,
#  'R.E.N.A.L.NEPHRORISKSTRATIFICATION': 5,
#  'RADIUSmaximaldiameterincm': 4,
#  'NEARNESSOFTUMOUR': 4,
#  'ANTERIORORPOSTERIOR': 4,
#  'LOCATIONTOPOLARLINE': 4,
#  'ASASCORE': 5,
#  'PARTIALNEPHROINDICATION': 4,
#  'MULTIFOCALITY': 3,
#  'ACCESS': 3,
#  'DAVINCIMODEL': 4,
#  'ROBOTICSARMS': 3,
#  'ASSISTENTTROCARS': 3,
#  'DUALCONSOLE': 3,
#  'ISCHEMIA': 4,
#  'CLAMPARTERY': 4,
#  'SELECTIVEARTERIALCLAMPING': 3,
#  'CLAMPVEIN': 4,
#  'EARLYUNCLAMPING': 3,
#  'FLUORESCENCE': 3,
#  'INNERRENORRHAPHY': 3,
#  'OUTERRENORRHAPHY': 3,
#  'UCSREPAIR': 3,
#  'HAEMOSTATICAGENTS': 3,
#  'LYMPHNODEDISSECTIONLND': 3,
#  'INTRAOPTRANSUFUSION': 4,
#  'INTRAOPCOMPLICATIONS': 6}

# %%
# convert object columns with less than 10 unique values into type category
for col in unique_count_list:
        df[col] = df[col].astype('category').copy()

# %%
# list of features with object type
for col in unique_count_list:
    if unique_count_list[col]>10:
        print(col,unique_count_list[col])
# Out:
# CENTERCODE 18

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1406 entries, 0 to 1430
# Data columns (total 61 columns):
# PATIENTNUMBER                         1406 non-null object
# CENTERCODE                            1406 non-null category
# GENDER                                1406 non-null category
# AGEATSURGERY                          1406 non-null float64
# MARITALSTATUS                         1406 non-null category
# RACE                                  1406 non-null category
# EDUCATION                             1406 non-null category
# BMI                                   1406 non-null float64
# CLINICALSIZEmm                        1406 non-null float64
# CHARLSONSCORE                         1406 non-null float64
# SYMPTOMS                              1406 non-null category
# SOLITARYKIDNEY                        1406 non-null category
# BILATERALITYOFTUMOR                   1406 non-null category
# SIDEOFTUMOR                           1406 non-null category
# SIDEOFSURGERY                         1406 non-null category
# FACE                                  1406 non-null category
# TUMORlOCATION                         1406 non-null category
# PREOPHB                               1406 non-null float64
# PREOPHT                               1406 non-null float64
# PREOPWBC                              1406 non-null float64
# PREOPCREAT                            1406 non-null float64
# PADUARISK                             1406 non-null category
# POLARLOCATION                         1406 non-null category
# RIMLOCATION                           1406 non-null category
# RENALSINUS                            1406 non-null category
# EXOPHYTICRATE                         1406 non-null category
# CLINICALSIZEGROUP                     1406 non-null category
# CT                                    1406 non-null category
# CN                                    1406 non-null category
# R.E.N.A.L.NEPHRORISKSTRATIFICATION    1406 non-null category
# RADIUSmaximaldiameterincm             1406 non-null category
# NEARNESSOFTUMOUR                      1406 non-null category
# ANTERIORORPOSTERIOR                   1406 non-null category
# LOCATIONTOPOLARLINE                   1406 non-null category
# ASASCORE                              1406 non-null category
# PARTIALNEPHROINDICATION               1406 non-null category
# MULTIFOCALITY                         1406 non-null category
# NOOFLESIONS                           1406 non-null float64
# ACCESS                                1406 non-null category
# DAVINCIMODEL                          1406 non-null category
# ROBOTICSARMS                          1406 non-null category
# ASSISTENTTROCARS                      1406 non-null category
# DUALCONSOLE                           1406 non-null category
# OPERATIVETIMEmin                      1406 non-null float64
# ISCHEMIA                              1406 non-null category
# CLAMPARTERY                           1406 non-null category
# SELECTIVEARTERIALCLAMPING             1406 non-null category
# CLAMPVEIN                             1406 non-null category
# EARLYUNCLAMPING                       1406 non-null category
# FLUORESCENCE                          1406 non-null category
# INNERRENORRHAPHY                      1406 non-null category
# OUTERRENORRHAPHY                      1406 non-null category
# ISCHEMIATIMEmin                       1406 non-null float64
# UCSREPAIR                             1406 non-null category
# HAEMOSTATICAGENTS                     1406 non-null category
# LYMPHNODEDISSECTIONLND                1406 non-null category
# BLOODLOSSml                           1406 non-null float64
# INTRAOPTRANSUFUSION                   1406 non-null category
# INTRAOPCOMPLICATIONS                  1406 non-null category
# POSTOP_COMPLICATIONS                  1406 non-null int64
# Missing                               1406 non-null float64
# dtypes: category(46), float64(13), int64(1), object(1)
# memory usage: 246.5+ KB

# %%
df.reset_index(drop=True, inplace=True)
print("Number records for predicting 30 day complications: {}".format(len(df)))
# Out:
# Number records for predicting 30 day complications: 1406

# %%
for i in df.select_dtypes('category').columns:
    df[i] = df[i].apply(str)

# %%
# fit label encoder to each column of type category
cat_col =df.select_dtypes('category')
df_codes = df.copy()
from sklearn.preprocessing import LabelEncoder
le_dict = {col: LabelEncoder() for col in cat_col }
for col in cat_col:
    le_dict[col].fit_transform(df_codes[col])

# %%
# create a dictionary cantaining mapping of categorical values to numerical values
label_mapping = dict()
label_mapping = {col: dict(zip(le_dict[col].classes_,le_dict[col].transform(le_dict[col].classes_))) for col in cat_col}
label_mapping
# Out:
# {'CENTERCODE': {'08ZMCILJ': 0,
#   '0VZRZWAI': 1,
#   '39HIP3LQ': 2,
#   '3QWOG020': 3,
#   '4M49I4D5': 4,
#   '4UPDM0XB': 5,
#   '57T3OUKU': 6,
#   '63DCGHNW': 7,
#   '94ISQMHX': 8,
#   'FWL0MH42': 9,
#   'GCIEYK6L': 10,
#   'GQHLD5Q4': 11,
#   'QRJWT5QR': 12,
#   'RETM03Y8': 13,
#   'U5WT3NOY': 14,
#   'VNO3BPES': 15,
#   'VRVRQ639': 16,
#   'WGC7XYXZ': 17},
#  'GENDER': {'Female': 0, 'Male': 1},
#  'MARITALSTATUS': {'Divorced': 0,
#   'Married': 1,
#   'NA': 2,
#   'Single': 3,
#   'Widowed': 4},
#  'RACE': {'Black': 0,
#   'Mongoloid/Asian': 1,
#   'NA': 2,
#   'Others': 3,
#   'White/Caucasian': 4},
#  'EDUCATION': {'Graduate': 0,
#   'NA': 1,
#   'Not Provided': 2,
#   'Post Graduate': 3,
#   'Upto High School': 4},
#  'SYMPTOMS': {'Absent': 0,
#   'Local Symptoms': 1,
#   'NA': 2,
#   'Systemic Symptoms': 3},
#  'SOLITARYKIDNEY': {'NA': 0, 'No': 1, 'Yes': 2, 'no': 3},
#  'BILATERALITYOFTUMOR': {'NA': 0, 'No': 1, 'Yes': 2},
#  'SIDEOFTUMOR': {'Bilateral': 0, 'Left': 1, 'NA': 2, 'Right': 3},
#  'SIDEOFSURGERY': {'Bilateral': 0, 'Left': 1, 'Right': 2},
#  'FACE': {'Anterior': 0, 'NA': 1, 'Posterior': 2},
#  'TUMORlOCATION': {'Lower Pol': 0,
#   'Lower Pole': 1,
#   'Mid Pole': 2,
#   'NA': 3,
#   'Upper Pol': 4,
#   'Upper Pole': 5},
#  'PADUARISK': {'0': 0,
#   '1(Low  Risk)': 1,
#   '2(Intermidiate  Risk)': 2,
#   '3(High  Risk)': 3,
#   'NA': 4},
#  'POLARLOCATION': {'NA': 0,
#   'Tumours crossing the sinus line >50% or falling entirely between the sinus lines (2 points)': 1,
#   'Tumours entirely located above the upper or below the lower sinus line, or crossing the sinus line < 50% (1 point)': 2},
#  'RIMLOCATION': {'At the medial rim (2 points)': 0,
#   'NA': 1,
#   'Tumours located at the lateral (1 point)': 2},
#  'RENALSINUS': {'NA': 0,
#   'Tumours without renal sinus involvement (1 point)': 1,
#   'With renal sinus involvement (2 points)': 2},
#  'EXOPHYTICRATE': {'< 50%exophytic (2 points)': 0,
#   '= 50% exophytic (1 point)': 1,
#   'Endophytic (3 points)': 2,
#   'NA': 3},
#  'CLINICALSIZEGROUP': {'4.1cm-7cm': 0, '=<4cm': 1, '=>7cm': 2, 'NA': 3},
#  'CT': {'NA': 0, 'T1a': 1, 'T1b': 2, 'T2a': 3, 'T2b': 4, 'T3a': 5},
#  'CN': {'N+': 0, 'N0': 1, 'NA': 2, 'Nx': 3},
#  'R.E.N.A.L.NEPHRORISKSTRATIFICATION': {'0': 0,
#   '1(Low Risk)': 1,
#   '2(Intermidiate Risk)': 2,
#   '3(High Risk)': 3,
#   'NA': 4},
#  'RADIUSmaximaldiameterincm': {'4 but <7': 0, '=<4': 1, '=>7': 2, 'NA': 3},
#  'NEARNESSOFTUMOUR': {'=<4': 0, '=>7': 1, '>4 but <7': 2, 'NA': 3},
#  'ANTERIORORPOSTERIOR': {'Anterior (a)': 0,
#   'NA': 1,
#   'Neither(x)': 2,
#   'Posterior (p)': 3},
#  'LOCATIONTOPOLARLINE': {'1.0': 0, '2.0': 1, '3.0': 2, 'NA': 3},
#  'ASASCORE': {'Category 1': 0,
#   'Category 2': 1,
#   'Category 3': 2,
#   'Category 4': 3,
#   'NA': 4},
#  'PARTIALNEPHROINDICATION': {'Absolute': 0,
#   'Elective': 1,
#   'NA': 2,
#   'Relative': 3},
#  'MULTIFOCALITY': {'NA': 0, 'No': 1, 'Yes': 2},
#  'ACCESS': {'NA': 0, 'Retroperitoneal': 1, 'Transperitoneal': 2},
#  'DAVINCIMODEL': {'NA': 0, 'S': 1, 'Si': 2, 'Xi': 3},
#  'ROBOTICSARMS': {'3-arms': 0, '4-arms': 1, 'NA': 2},
#  'ASSISTENTTROCARS': {'5 mm + 12 mm': 0, 'NA': 1, 'Only 12 mm': 2},
#  'DUALCONSOLE': {'NA': 0, 'No': 1, 'Yes': 2},
#  'ISCHEMIA': {'Cold': 0, 'NA': 1, 'Not Performed': 2, 'Warm': 3},
#  'CLAMPARTERY': {'Bulldog': 0, 'NA': 1, 'No': 2, 'Satinsky Clamp': 3},
#  'SELECTIVEARTERIALCLAMPING': {'NA': 0, 'No': 1, 'Yes': 2},
#  'CLAMPVEIN': {'Bulldog': 0, 'NA': 1, 'No': 2, 'Satinsky Clamp': 3},
#  'EARLYUNCLAMPING': {'NA': 0, 'No': 1, 'Yes': 2},
#  'FLUORESCENCE': {'NA': 0, 'Not Used': 1, 'Used': 2},
#  'INNERRENORRHAPHY': {'NA': 0, 'No': 1, 'Yes': 2},
#  'OUTERRENORRHAPHY': {'NA': 0, 'No': 1, 'Yes': 2},
#  'UCSREPAIR': {'NA': 0, 'Not Performed': 1, 'Performed': 2},
#  'HAEMOSTATICAGENTS': {'NA': 0, 'No': 1, 'Yes': 2},
#  'LYMPHNODEDISSECTIONLND': {'NA': 0, 'Not Performed': 1, 'Performed': 2},
#  'INTRAOPTRANSUFUSION': {'1 Unit': 0, '>1 Unit': 1, 'NA': 2, 'No': 3},
#  'INTRAOPCOMPLICATIONS': {'179': 0,
#   '180': 1,
#   '181': 2,
#   '182': 3,
#   '310': 4,
#   'nan': 5}}

# %%
# mapping categorical column values to integer labels
for col in cat_col:
    df_codes[col] = le_dict[col].transform(df_codes[col]).copy()

# %%
df_codes.head()
# Out:
#   PATIENTNUMBER  CENTERCODE  GENDER  AGEATSURGERY  MARITALSTATUS  RACE  \
# 0   22PAT000131          17       1          58.0              1     1
# 1   11PAT000166           1       1          56.0              1     1
# 2   15PAT000097          15       0          65.0              1     4
# 3   15PAT000095          15       0          23.0              3     4
# 4   15PAT000088          15       0          44.0              3     4
#
#    EDUCATION    BMI  CLINICALSIZEmm  CHARLSONSCORE  SYMPTOMS  SOLITARYKIDNEY  \
# 0          2  23.18            44.0            0.0         0               1
# 1          2  23.36            31.0            0.0         0               1
# 2          2  26.67            31.0            0.0         0               1
# 3          2  19.65            23.0            0.0         0               1
# 4          2  29.30            57.0            0.0         1               1
#
#    BILATERALITYOFTUMOR  SIDEOFTUMOR  SIDEOFSURGERY  FACE  TUMORlOCATION  \
# 0                    1            1              1     0              2
# 1                    1            1              1     0              0
# 2                    1            1              1     1              4
# 3                    1            3              2     2              3
# 4                    1            1              1     2              2
#
#    PREOPHB  PREOPHT  PREOPWBC  PREOPCREAT  PADUARISK  POLARLOCATION  \
# 0     14.0     41.0    5100.0        0.90          3              1
# 1     10.2     36.4    5200.0        0.70          1              2
# 2     11.8     36.0    5300.0        1.12          1              2
# 3     13.3     39.2   12100.0        0.70          3              1
# 4     13.5     41.3    6300.0        0.83          3              1
#
#    RIMLOCATION  RENALSINUS  EXOPHYTICRATE  CLINICALSIZEGROUP  CT  CN  \
# 0            0           2              1                  0   2   1
# 1            2           1              1                  1   1   1
# 2            2           1              0                  1   1   1
# 3            0           2              2                  1   1   1
# 4            2           2              1                  0   2   1
#
#    R.E.N.A.L.NEPHRORISKSTRATIFICATION  RADIUSmaximaldiameterincm  \
# 0                                   3                          0
# 1                                   1                          1
# 2                                   1                          1
# 3                                   3                          1
# 4                                   2                          0
#
#    NEARNESSOFTUMOUR  ANTERIORORPOSTERIOR  LOCATIONTOPOLARLINE  ASASCORE  \
# 0                 0                    0                    2         0
# 1                 1                    0                    0         0
# 2                 2                    2                    0         1
# 3                 0                    3                    2         0
# 4                 0                    3                    1         1
#
#    PARTIALNEPHROINDICATION  MULTIFOCALITY  NOOFLESIONS  ACCESS  DAVINCIMODEL  \
# 0                        1              1          1.0       2             3
# 1                        1              1          1.0       2             3
# 2                        1              1          1.0       2             2
# 3                        1              1          1.0       2             3
# 4                        1              1          1.0       2             2
#
#    ROBOTICSARMS  ASSISTENTTROCARS  DUALCONSOLE  OPERATIVETIMEmin  ISCHEMIA  \
# 0             0                 0            1             170.0         3
# 1             1                 2            1             160.0         3
# 2             0                 0            1             212.0         3
# 3             0                 0            1             174.0         3
# 4             0                 0            1             108.0         3
#
#    CLAMPARTERY  SELECTIVEARTERIALCLAMPING  CLAMPVEIN  EARLYUNCLAMPING  \
# 0            0                          1          2                1
# 1            0                          1          2                1
# 2            0                          1          2                1
# 3            0                          1          2                1
# 4            0                          1          2                1
#
#    FLUORESCENCE  INNERRENORRHAPHY  OUTERRENORRHAPHY  ISCHEMIATIMEmin  \
# 0             1                 2                 2             21.0
# 1             1                 1                 1             20.0
# 2             1                 2                 2             13.0
# 3             1                 2                 2             11.0
# 4             1                 2                 2             23.0
#
#    UCSREPAIR  HAEMOSTATICAGENTS  LYMPHNODEDISSECTIONLND  BLOODLOSSml  \
# 0          1                  1                       1        300.0
# 1          1                  1                       1         75.0
# 2          1                  1                       1         50.0
# 3          1                  1                       1         20.0
# 4          1                  1                       1        179.0
#
#    INTRAOPTRANSUFUSION  INTRAOPCOMPLICATIONS  POSTOP_COMPLICATIONS  Missing
# 0                    3                     5                     1      0.0
# 1                    3                     5                     1      2.0
# 2                    3                     5                     1      3.0
# 3                    3                     5                     0      2.0
# 4                    3                     5                     0      2.0

# %% [markdown]
# ### Create Stats for dataset

# %%
# print median , IQR for numeric columns 
for i in df.columns:#['AGEATSURGERY','BMI','CLINICALSIZEmm','PREOPHB','PREOPHT','PREOPWBC','PREOPCREAT','PREOPEGFR','NOOFLESIONS']:
    if i in numeric_col_list:
        print(i, "{0:.1f} [{1:.1f}-{2:.1f}]".format(np.median(df[i]),np.percentile(df[i],25),np.percentile(df[i],75)))
# Out:
# AGEATSURGERY 57.0 [48.0-66.0]
# BMI 27.2 [24.3-30.0]
# CLINICALSIZEmm 30.0 [21.2-40.0]
# CHARLSONSCORE 1.0 [0.0-2.0]
# PREOPHB 14.0 [13.1-15.0]
# PREOPHT 42.0 [39.2-44.9]
# PREOPWBC 7110.0 [5800.0-8100.0]
# PREOPCREAT 0.9 [0.8-1.1]
# NOOFLESIONS 1.0 [1.0-1.0]
# OPERATIVETIMEmin 160.0 [130.0-186.0]
# ISCHEMIATIMEmin 18.0 [15.0-22.0]
# BLOODLOSSml 100.0 [50.0-200.0]

# %%
for i in df_codes.columns:
    if i in cat_col:
        print(pd.DataFrame(df_codes[i].apply(lambda x: le_dict[i].inverse_transform([x])[0]).value_counts()))
# Out:
#           CENTERCODE
# GCIEYK6L         397
# 63DCGHNW         172
# 4UPDM0XB         168
# 4M49I4D5         125
# VNO3BPES          92
# 08ZMCILJ          89
# 0VZRZWAI          72
# U5WT3NOY          54
# QRJWT5QR          50
# WGC7XYXZ          37
# RETM03Y8          29
# GQHLD5Q4          28
# 57T3OUKU          25
# 3QWOG020          24
# FWL0MH42          16
# VRVRQ639          15
# 39HIP3LQ           7
# 94ISQMHX           6
#         GENDER
# Male       923
# Female     483
#           MARITALSTATUS
# Married            1071
# Single              132
# NA                  121
# Widowed              42
# Divorced             40
#                  RACE
# White/Caucasian   734
# Others            280
# Mongoloid/Asian   226
# NA                134
# Black              32
#                   EDUCATION
# Not Provided            576
# Graduate                317
# Upto High School        200
# NA                      172
# Post Graduate           141
#                    SYMPTOMS
# Absent                 1097
# Local Symptoms          255
# NA                       29
# Systemic Symptoms        25
#      SOLITARYKIDNEY
# No              971
# no              400
# Yes              33
# NA                2
#      BILATERALITYOFTUMOR
# No                  1238
# NA                   112
# Yes                   56
#            SIDEOFTUMOR
# Right              643
# Left               612
# NA                 107
# Bilateral           44
#            SIDEOFSURGERY
# Right                723
# Left                 682
# Bilateral              1
#            FACE
# Anterior    642
# Posterior   600
# NA          164
#             TUMORlOCATION
# Mid Pole              529
# Upper Pole            382
# Lower Pole            379
# Upper Pol              48
# Lower Pol              47
# NA                     21
#                        PADUARISK
# 1(Low  Risk)                 456
# 2(Intermidiate  Risk)        422
# 3(High  Risk)                352
# NA                           175
# 0                              1
#                                                     POLARLOCATION
# Tumours entirely located above the upper or bel...            769
# Tumours crossing the sinus line >50% or falling...            577
# NA                                                             60
#                                           RIMLOCATION
# Tumours located at the lateral (1 point)          818
# At the medial rim (2 points)                      439
# NA                                                149
#                                                    RENALSINUS
# Tumours without renal sinus involvement (1 point)         841
# With renal sinus involvement (2 points)                   414
# NA                                                        151
#                            EXOPHYTICRATE
# = 50% exophytic (1 point)            584
# < 50%exophytic (2 points)            514
# Endophytic (3 points)                192
# NA                                   116
#            CLINICALSIZEGROUP
# =<4cm                    979
# 4.1cm-7cm                392
# NA                        24
# =>7cm                     11
#       CT
# T1a  943
# T1b  338
# NA   100
# T2a   19
# T3a    4
# T2b    2
#      CN
# N0  798
# Nx  505
# NA   98
# N+    5
#                       R.E.N.A.L.NEPHRORISKSTRATIFICATION
# 2(Intermidiate Risk)                                 644
# 1(Low Risk)                                          456
# NA                                                   183
# 3(High Risk)                                         122
# 0                                                      1
#           RADIUSmaximaldiameterincm
# =<4                             994
# 4 but <7                        396
# =>7                              11
# NA                                5
#            NEARNESSOFTUMOUR
# =<4                     551
# =>7                     372
# >4 but <7               296
# NA                      187
#                ANTERIORORPOSTERIOR
# Posterior (p)                  538
# Anterior (a)                   537
# Neither(x)                     175
# NA                             156
#      LOCATIONTOPOLARLINE
# 1.0                  498
# 3.0                  379
# 2.0                  374
# NA                   155
#             ASASCORE
# Category 2       687
# Category 1       437
# Category 3       222
# NA                56
# Category 4         4
#           PARTIALNEPHROINDICATION
# Elective                     1128
# Relative                      226
# Absolute                       51
# NA                              1
#      MULTIFOCALITY
# No            1232
# NA             105
# Yes             69
#                  ACCESS
# Transperitoneal    1156
# Retroperitoneal     246
# NA                    4
#     DAVINCIMODEL
# Si           964
# Xi           274
# NA           109
# S             59
#         ROBOTICSARMS
# 3-arms           697
# 4-arms           686
# NA                23
#               ASSISTENTTROCARS
# 5 mm + 12 mm               758
# Only 12 mm                 626
# NA                          22
#      DUALCONSOLE
# Yes          772
# No           600
# NA            34
#                ISCHEMIA
# Warm               1343
# Not Performed        55
# NA                    5
# Cold                  3
#                 CLAMPARTERY
# Bulldog                1348
# No                       53
# Satinsky Clamp            4
# NA                        1
#      SELECTIVEARTERIALCLAMPING
# No                        1048
# Yes                        252
# NA                         106
#                 CLAMPVEIN
# No                    965
# Bulldog               435
# Satinsky Clamp          4
# NA                      2
#      EARLYUNCLAMPING
# No              1192
# Yes              185
# NA                29
#           FLUORESCENCE
# Not Used          1015
# Used               388
# NA                   3
#      INNERRENORRHAPHY
# Yes              1172
# No                129
# NA                105
#      OUTERRENORRHAPHY
# Yes              1211
# NA                106
# No                 89
#                UCSREPAIR
# Not Performed        916
# Performed            472
# NA                    18
#      HAEMOSTATICAGENTS
# Yes                934
# No                 464
# NA                   8
#                LYMPHNODEDISSECTIONLND
# Not Performed                    1358
# Performed                          45
# NA                                  3
#          INTRAOPTRANSUFUSION
# No                      1336
# NA                        59
# 1 Unit                     9
# >1 Unit                    2
#      INTRAOPCOMPLICATIONS
# nan                  1325
# 179                    56
# 180                    17
# 181                     4
# 182                     3
# 310                     1

# %%
traget_stats = pd.merge(df_codes[['PATIENTNUMBER','POSTOP_COMPLICATIONS','INTRAOPCOMPLICATIONS']],
                        df_ori[['PATIENTNUMBER','SURGICALCOMPLICATIONS','NONSURGICALCOMPLICATIONS','CLAVIENGRADE','LENGTHOFSTAYdays']], 
                        left_on='PATIENTNUMBER', 
                        right_on='PATIENTNUMBER').copy()

# %%
traget_stats['CLAVIENGRADE'].value_counts()
# Out:
# Grade 0: Absence of any complication                                                                                                                                                                       1058
# Grade 1: Any deviation from the normal postoperative course, including the need for pharmacologic treatment other than antiemetics, antipyretics, analgesics, diuretics, electrolytes, or physiotherapy      57
# Grade 3: Complications needing surgical, endoscopic, or radiologic intervention                                                                                                                              12
# Grade 2: Complications needing only use of intravenous medications, total parenteral nutrition, enteral nutrition, or blood transfusion                                                                      11
# Grade 4: Life-threatening complication requiring intensive care/intensive care unit (ICU) management                                                                                                          2
# Grade 1: Absence of any complication                                                                                                                                                                          1
# Name: CLAVIENGRADE, dtype: int64

# %%
traget_stats[traget_stats['POSTOP_COMPLICATIONS']==1]['CLAVIENGRADE'].value_counts()
# Out:
# Grade 0: Absence of any complication                                                                                                                                                                       181
# Grade 1: Any deviation from the normal postoperative course, including the need for pharmacologic treatment other than antiemetics, antipyretics, analgesics, diuretics, electrolytes, or physiotherapy     35
# Grade 3: Complications needing surgical, endoscopic, or radiologic intervention                                                                                                                             12
# Grade 2: Complications needing only use of intravenous medications, total parenteral nutrition, enteral nutrition, or blood transfusion                                                                      6
# Grade 4: Life-threatening complication requiring intensive care/intensive care unit (ICU) management                                                                                                         2
# Name: CLAVIENGRADE, dtype: int64

# %%
sum(traget_stats['LENGTHOFSTAYdays']>4)
# Out:
# 290

# %% [markdown]
# ### Create Train and Test dataset

# %%
df_codes.drop(labels=['Missing'], axis='columns', inplace=True)

# %%
df_codes.corr()[target]
# Out:
# CENTERCODE                           -0.144072
# GENDER                               -0.035530
# AGEATSURGERY                         -0.012279
# MARITALSTATUS                        -0.001787
# RACE                                 -0.248197
# EDUCATION                            -0.140270
# BMI                                  -0.066350
# CLINICALSIZEmm                        0.122509
# CHARLSONSCORE                        -0.020578
# SYMPTOMS                             -0.078224
# SOLITARYKIDNEY                       -0.049105
# BILATERALITYOFTUMOR                  -0.194584
# SIDEOFTUMOR                           0.022457
# SIDEOFSURGERY                        -0.012150
# FACE                                 -0.009646
# TUMORlOCATION                        -0.042384
# PREOPHB                              -0.074785
# PREOPHT                              -0.018808
# PREOPWBC                              0.030670
# PREOPCREAT                           -0.035961
# PADUARISK                             0.018461
# POLARLOCATION                         0.079155
# RIMLOCATION                           0.039473
# RENALSINUS                            0.060039
# EXOPHYTICRATE                        -0.011741
# CLINICALSIZEGROUP                    -0.029179
# CT                                    0.100658
# CN                                   -0.340610
# R.E.N.A.L.NEPHRORISKSTRATIFICATION   -0.029449
# RADIUSmaximaldiameterincm            -0.055488
# NEARNESSOFTUMOUR                     -0.004883
# ANTERIORORPOSTERIOR                  -0.014154
# LOCATIONTOPOLARLINE                  -0.012081
# ASASCORE                             -0.081712
# PARTIALNEPHROINDICATION              -0.115962
# MULTIFOCALITY                        -0.186430
# NOOFLESIONS                           0.013114
# ACCESS                                0.215163
# DAVINCIMODEL                         -0.161485
# ROBOTICSARMS                          0.040817
# ASSISTENTTROCARS                     -0.150862
# DUALCONSOLE                          -0.332422
# OPERATIVETIMEmin                     -0.014648
# ISCHEMIA                              0.010093
# CLAMPARTERY                           0.038271
# SELECTIVEARTERIALCLAMPING            -0.115435
# CLAMPVEIN                             0.077420
# EARLYUNCLAMPING                      -0.045446
# FLUORESCENCE                         -0.150300
# INNERRENORRHAPHY                     -0.260195
# OUTERRENORRHAPHY                     -0.253110
# ISCHEMIATIMEmin                       0.097335
# UCSREPAIR                            -0.099870
# HAEMOSTATICAGENTS                    -0.019007
# LYMPHNODEDISSECTIONLND                0.020958
# BLOODLOSSml                           0.111857
# INTRAOPTRANSUFUSION                  -0.099493
# INTRAOPCOMPLICATIONS                  0.063366
# POSTOP_COMPLICATIONS                  1.000000
# Name: POSTOP_COMPLICATIONS, dtype: float64

# %%
print('Number of patients {}'.format(len(df_codes)))
print('% of patients with complications {:.2f}%'.format(sum(df_codes[target])/len(df_codes)*100))
# Out:
# Number of patients 1406
# % of patients with complications 20.98%

# %%
output_path = 'H:\RediMinds\VCQI'
df_codes.to_csv(output_path+"\VCQI_clean_30_day_complications.csv",index=False)

# %%
# Split data in test and train
from sklearn.model_selection import train_test_split
train, test = train_test_split(df_codes, test_size=0.30, random_state=42, stratify = df_codes[target])

# %%
# Percentage of complications in trainset
train[target].sum()/len(train)
# Out:
# 0.20934959349593496

# %%
# Percentage of complications in testset
test[target].sum()/len(test)
# Out:
# 0.2109004739336493

# %%
# Save train and test dataset
train.to_csv(output_path+"\VCQI_clean_train_30_day_complications.csv",index=False)
test.to_csv(output_path+"\VCQI_clean_test_30_day_complications.csv",index=False)

# %%
import pickle

cat_col = df.select_dtypes('category')

with open(output_path+'\cat_col_30_day_complications', 'wb') as fp:
    pickle.dump(cat_col.columns.to_list(), fp)

# %% [markdown]
# ### Generate Evaluvation Metrics for PADUA Score and RENAL Score

# %%
x = test.loc[test['PADUARISK']!=4][['PADUARISK',target]].copy()
x['Pred'] = x['PADUARISK'].apply(lambda y: 1 if y==3 else 0)
from sklearn import metrics
print(metrics.classification_report(x[target], x['Pred']))
print(metrics.confusion_matrix(x[target], x['Pred']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74       292
#            1       0.26      0.40      0.32        82
#
#     accuracy                           0.62       374
#    macro avg       0.53      0.54      0.53       374
# weighted avg       0.68      0.62      0.65       374
#
# [[199  93]
#  [ 49  33]]

# %%
x = test.loc[test['R.E.N.A.L.NEPHRORISKSTRATIFICATION']!=4][['R.E.N.A.L.NEPHRORISKSTRATIFICATION',target]].copy()
x['Pred'] = x['R.E.N.A.L.NEPHRORISKSTRATIFICATION'].apply(lambda y: 1 if y==3 else 0)
from sklearn import metrics
print(metrics.classification_report(x[target], x['Pred']))
print(metrics.confusion_matrix(x[target], x['Pred']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.82       287
#            1       0.19      0.11      0.14        81
#
#     accuracy                           0.70       368
#    macro avg       0.48      0.49      0.48       368
# weighted avg       0.65      0.70      0.67       368
#
# [[249  38]
#  [ 72   9]]
